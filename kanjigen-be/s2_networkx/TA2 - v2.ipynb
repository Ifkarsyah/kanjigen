# %%
from pprint import pprint as pp
from typing import Dict, List, Tuple

import random
import csv

# %% [markdown]
# # Building Knowledge Graph

# %% [markdown]
# ## Extract Data from CSV

# %% [markdown]
# ### Extract s7_nodes_kanji_meaning.csv

# %%
def get_data_kanji_from_csv(filepath: str):
    data = dict()
    with open(filepath) as file:
        next(file)
        rows = csv.reader(file, delimiter=",")
        for row in rows:
            num,kanji,meaning = row
            data[kanji] = meaning
    return data

# %%
data_kanji = get_data_kanji_from_csv(filepath="dataset/s7_nodes_kanji_meaning.csv")
print("len(data_kanji) = ", len(data_kanji))
pp(data_kanji)
# Out:
# len(data_kanji) =  2136
# {'一': 'one',
#  '丁': 'ward',
#  '七': 'seven',
#  '万': 'ten thousand',
#  '丈': 'length',
#  '三': 'three',
#  '上': 'up',
#  '下': 'below',
#  '不': 'non-',
#  '与': 'give',
#  '且': 'moreover',
#  '世': 'world',
#  '丘': 'hill',
#  '丙': 'third class',
#  '両': 'both',
#  '並': 'line-up',
#  '中': 'middle',
#  '串': 'skewer',
#  '丸': 'circle',
#  '丹': 'cinnabar',
#  '主': 'master',
#  '丼': 'bowl of food',
#  '久': 'long time',
#  '乏': 'scarce',
#  '乗': 'ride',
#  '乙': 'the latter',
#  '九': 'nine',
#  '乞': 'beg',
#  '乱': 'riot',
#  '乳': 'milk',
#  '乾': 'dry',
#  '亀': 'turtle',
#  '了': 'finish',
#  '予': 'in advance',
#  '争': 'conflict',
#  '事': 'abstract thing',
#  '二': 'two',
#  '互': 'mutually',
#  '五': 'five',
#  '井': 'well',
#  '亜': 'sub-',
#  '亡': 'deceased',
#  '交': 'mix',
#  '享': 'receive',
#  '京': 'capital',
#  '亭': 'pavilion',
#  '人': 'person',
#  '仁': 'humanity',
#  '今': 'now',
#  '介': 'jammed in',
#  '仏': 'Buddha',
#  '仕': 'do',
#  '他': 'other',
#  '付': 'attach',
#  '仙': 'hermit',
#  '代': 'substitute',
#  '令': 'orders',
#  '以': 'by means of',
#  '仮': 'temporary',
#  '仰': 'face-up',
#  '仲': 'relationship',
#  '件': 'affair',
#  '任': 'responsibility',
#  '企': 'plan',
#  '伎': 'deed',
#  '伏': 'prostrated',
#  '伐': 'fell',
#  '休': 'rest',
#  '会': 'association',
#  '伝': 'transmit',
#  '伯': 'chief',
#  '伴': 'consort',
#  '伸': 'lengthen',
#  '伺': 'pay respects',
#  '似': 'becoming',
#  '但': 'however',
#  '位': 'rank',
#  '低': 'low',
#  '住': 'dwelling',
#  '佐': 'help',
#  '体': 'body',
#  '何': 'what',
#  '余': 'leave over',
#  '作': 'make',
#  '佳': 'excellent',
#  '併': 'join',
#  '使': 'use',
#  '例': 'example',
#  '侍': 'waiter',
#  '供': 'offer',
#  '依': 'reliant',
#  '価': 'value',
#  '侮': 'scorn',
#  '侯': 'marquis',
#  '侵': 'encroach',
#  '侶': 'companion',
#  '便': 'convenience',
#  '係': 'person in charge',
#  '促': 'stimulate',
#  '俊': 'genius',
#  '俗': 'vulgar',
#  '保': 'preserve',
#  '信': 'trust',
#  '修': 'discipline',
#  '俳': 'haiku',
#  '俵': 'bag',
#  '俸': 'salary',
#  '俺': 'I, we',
#  '倉': 'warehouse',
#  '個': 'individual',
#  '倍': 'double',
#  '倒': 'overthrow',
#  '候': 'climate',
#  '借': 'borrow',
#  '倣': 'emulate',
#  '値': 'value',
#  '倫': 'ethics',
#  '倹': 'frugal',
#  '偉': 'admirable',
#  '偏': 'partial',
#  '停': 'halt',
#  '健': 'healthy',
#  '側': 'side',
#  '偵': 'spy',
#  '偶': 'accidentally',
#  '偽': 'falsehood',
#  '傍': 'bystander',
#  '傑': 'greatness',
#  '傘': 'umbrella',
#  '備': 'provide',
#  '催': 'sponsor',
#  '傲': 'be proud',
#  '債': 'bond',
#  '傷': 'wound',
#  '傾': 'lean',
#  '僅': 'a wee bit',
#  '働': 'work',
#  '像': 'statue',
#  '僕': 'me',
#  '僚': 'colleague',
#  '僧': 'Buddhist priest',
#  '儀': 'ceremony',
#  '億': 'hundred million',
#  '儒': 'Confucian',
#  '償': 'reparation',
#  '優': 'superior',
#  '元': 'origin',
#  '兄': 'older brother',
#  '充': 'allot',
#  '兆': 'portent, trillion',
#  '先': 'previous',
#  '光': 'ray',
#  '克': 'overcome',
#  '免': 'excuse',
#  '児': 'child',
#  '党': 'group',
#  '入': 'enter',
#  '全': 'whole',
#  '八': 'eight',
#  '公': 'public',
#  '六': 'six',
#  '共': 'together',
#  '兵': 'soldier',
#  '具': 'tool',
#  '典': 'code',
#  '兼': 'concurrently',
#  '内': 'inside',
#  '円': 'round, yen',
#  '冊': 'counter for books',
#  '再': 'again',
#  '冒': 'risk',
#  '冗': 'superfluous',
#  '写': 'copy',
#  '冠': 'crown',
#  '冥': 'dark',
#  '冬': 'winter',
#  '冶': 'melting',
#  '冷': 'cool',
#  '凄': 'uncanny',
#  '准': 'quasi-',
#  '凍': 'frozen',
#  '凝': 'congeal',
#  '凡': 'mediocre',
#  '処': 'dispose',
#  '凶': 'villain',
#  '凸': 'convex',
#  '凹': 'concave',
#  '出': 'exit',
#  '刀': 'sword',
#  '刃': 'blade',
#  '分': 'part, minute of time',
#  '切': 'cut',
#  '刈': 'reap',
#  '刊': 'publish',
#  '刑': 'punish',
#  '列': 'row',
#  '初': 'first',
#  '判': 'judge',
#  '別': 'separate',
#  '利': 'profit',
#  '到': 'arrival',
#  '制': 'control',
#  '刷': 'printing',
#  '券': 'ticket',
#  '刹': 'temple',
#  '刺': 'thorn',
#  '刻': 'engrave',
#  '則': 'rule',
#  '削': 'plane',
#  '前': 'in front',
#  '剖': 'divide',
#  '剛': 'sturdy',
#  '剝': 'peel',
#  '剣': 'sabre',
#  '剤': 'dose',
#  '副': 'vice',
#  '剰': 'surplus',
#  '割': 'divide',
#  '創': 'create',
#  '劇': 'drama',
#  '力': 'power',
#  '功': 'achievement',
#  '加': 'add',
#  '劣': 'inferiority',
#  '助': 'help',
#  '努': 'toil',
#  '励': 'encourage',
#  '労': 'labour',
#  '効': 'effect',
#  '劾': 'censure',
#  '勃': 'rise',
#  '勅': 'imperial order',
#  '勇': 'courage',
#  '勉': 'exertion',
#  '動': 'move',
#  '勘': 'intuition',
#  '務': 'duty',
#  '勝': 'win',
#  '募': 'recruit',
#  '勢': 'power',
#  '勤': 'diligence',
#  '勧': 'persuade',
#  '勲': 'meritorious deed',
#  '勾': 'capture',
#  '匂': 'scent',
#  '包': 'wrap',
#  '化': 'change',
#  '北': 'north',
#  '匠': 'artisan',
#  '匹': 'equal',
#  '区': 'ward',
#  '医': 'medicine',
#  '匿': 'hide',
#  '十': 'ten',
#  '千': 'thousand',
#  '升': 'measuring box',
#  '午': 'noon',
#  '半': 'half',
#  '卑': 'lowly',
#  '卒': 'graduate',
#  '卓': 'eminent',
#  '協': 'cooperation',
#  '南': 'south',
#  '単': 'simple',
#  '博': 'Dr.',
#  '占': 'fortune telling',
#  '印': 'mark',
#  '危': 'dangerous',
#  '即': 'instant',
#  '却': 'instead',
#  '卵': 'egg',
#  '卸': 'wholesale',
#  '厄': 'unlucky',
#  '厘': 'thousandth',
#  '厚': 'thick',
#  '原': 'field',
#  '厳': 'strict',
#  '去': 'leave',
#  '参': 'participate',
#  '又': 'or again',
#  '及': 'reach out',
#  '友': 'friend',
#  '双': 'pair',
#  '反': 'anti-',
#  '収': 'take in',
#  '叔': 'uncle',
#  '取': 'take',
#  '受': 'accept',
#  '叙': 'confer',
#  '口': 'mouth',
#  '古': 'old',
#  '句': 'phrase',
#  '叫': 'shout',
#  '召': 'summon',
#  '可': 'possible',
#  '台': 'pedestal',
#  '史': 'history',
#  '右': 'right (direction)',
#  '号': 'number',
#  '司': 'director',
#  '各': 'each',
#  '合': 'fit',
#  '吉': 'good luck',
#  '同': 'same',
#  '名': 'name',
#  '后': 'empress',
#  '吏': 'officer',
#  '吐': 'spit',
#  '向': 'over there',
#  '君': 'you',
#  '吟': 'versify',
#  '否': 'negate',
#  '含': 'include',
#  '吸': 'suck',
#  '吹': 'blow',
#  '呂': 'spine',
#  '呈': 'display',
#  '呉': 'give',
#  '告': 'tell',
#  '周': 'circumference',
#  '呪': 'curse',
#  '味': 'flavor',
#  '呼': 'call',
#  '命': 'fate',
#  '和': 'peace',
#  '咲': 'blossom',
#  '咽': 'throat',
#  '哀': 'pathetic',
#  '品': 'article',
#  '員': 'member',
#  '哲': 'philosophy',
#  '哺': 'suckle',
#  '唄': 'song',
#  '唆': 'tempt',
#  '唇': 'lips',
#  '唐': "T'ang",
#  '唯': 'solely',
#  '唱': 'chant',
#  '唾': 'saliva',
#  '商': 'sell',
#  '問': 'question',
#  '啓': 'disclose',
#  '善': 'good',
#  '喉': 'throat',
#  '喚': 'yell',
#  '喜': 'rejoice',
#  '喝': 'hoarse',
#  '喩': 'metaphor',
#  '喪': 'miss',
#  '喫': 'consume',
#  '営': 'manage',
#  '嗅': 'smell',
#  '嗣': 'heir',
#  '嘆': 'sigh',
#  '嘱': 'entrust',
#  '嘲': 'ridicule',
#  '器': 'container',
#  '噴': 'erupt',
#  '嚇': 'menacing',
#  '囚': 'captured',
#  '四': 'four',
#  '回': 'times',
#  '因': 'cause',
#  '団': 'group',
#  '困': 'become distressed',
#  '囲': 'surround',
#  '図': 'diagram',
#  '固': 'hard',
#  '国': 'country',
#  '圏': 'sphere',
#  '園': 'garden',
#  '土': 'soil',
#  '圧': 'pressure',
#  '在': 'exist',
#  '地': 'ground',
#  '坂': 'slope',
#  '均': 'level',
#  '坊': 'boy',
#  '坑': 'pit',
#  '坪': 'two-mat area',
#  '垂': 'droop',
#  '型': 'model',
#  '垣': 'hedge',
#  '埋': 'bury',
#  '城': 'castle',
#  '域': 'range',
#  '執': 'tenacious',
#  '培': 'cultivate',
#  '基': 'foundation',
#  '埼': 'cape (geography)',
#  '堀': 'ditch',
#  '堂': 'public chamber',
#  '堅': 'strict',
#  '堆': 'piled high',
#  '堕': 'degenerate',
#  '堤': 'dike',
#  '堪': 'withstand',
#  '報': 'report',
#  '場': 'place',
#  '塀': 'fence',
#  '塁': 'bases',
#  '塊': 'clod',
#  '塑': 'model',
#  '塔': 'pagoda',
#  '塗': 'paint',
#  '塚': 'hillock',
#  '塞': 'obstruct',
#  '塡': 'fill in',
#  '塩': 'salt',
#  '塾': 'cram school',
#  '境': 'boundary',
#  '墓': 'grave',
#  '増': 'increase',
#  '墜': 'crash',
#  '墨': 'black ink',
#  '墳': 'tomb',
#  '墾': 'ground-breaking',
#  '壁': 'wall',
#  '壇': 'podium',
#  '壊': 'demolition',
#  '壌': 'lot',
#  '士': 'gentleman',
#  '壮': 'robust',
#  '声': 'voice',
#  '壱': 'one (falsification prevention)',
#  '売': 'sell',
#  '変': 'change',
#  '夏': 'summer',
#  '夕': 'evening',
#  '外': 'outside',
#  '多': 'many',
#  '夜': 'night',
#  '夢': 'dream',
#  '大': 'large',
#  '天': 'heaven',
#  '太': 'thick',
#  '夫': 'husband',
#  '央': 'center',
#  '失': 'lose',
#  '奇': 'strange',
#  '奈': 'what',
#  '奉': 'observance',
#  '奏': 'play music',
#  '契': 'pledge',
#  '奔': 'bustle',
#  '奥': 'heart',
#  '奨': 'exhort',
#  '奪': 'rob',
#  '奮': 'stirred up',
#  '女': 'woman',
#  '奴': 'guy',
#  '好': 'like',
#  '如': 'likeness',
#  '妃': 'queen',
#  '妄': 'delusion',
#  '妊': 'pregnancy',
#  '妖': 'bewitching',
#  '妙': 'exquisite',
#  '妥': 'gentle',
#  '妨': 'disturb',
#  '妬': 'jealousy',
#  '妹': 'younger sister',
#  '妻': 'wife',
#  '姉': 'older sister',
#  '始': 'begin',
#  '姓': 'surname',
#  '委': 'committee',
#  '姫': 'princess',
#  '姻': 'matrimony',
#  '姿': 'figure',
#  '威': 'intimidate',
#  '娘': 'daughter',
#  '娠': 'with child',
#  '娯': 'recreation',
#  '婆': 'old woman',
#  '婚': 'marriage',
#  '婦': 'lady',
#  '婿': 'bridegroom',
#  '媒': 'mediator',
#  '媛': 'princess',
#  '嫁': 'marry into',
#  '嫉': 'envy',
#  '嫌': 'dislike',
#  '嫡': 'legitimate wife',
#  '嬢': 'lass',
#  '子': 'child',
#  '孔': 'cavity',
#  '字': 'letter',
#  '存': 'suppose',
#  '孝': 'filial piety',
#  '季': 'seasons',
#  '孤': 'orphan',
#  '学': 'study',
#  '孫': 'grandchild',
#  '宅': 'home',
#  '宇': 'eaves',
#  '守': 'protect',
#  '安': 'cheap',
#  '完': 'perfect',
#  '宗': 'religion',
#  '官': 'government official',
#  '宙': 'mid-air',
#  '定': 'decide',
#  '宛': 'allocate',
#  '宜': 'best regards',
#  '宝': 'treasure',
#  '実': 'truth',
#  '客': 'guest',
#  '宣': 'proclaim',
#  '室': 'room',
#  '宮': 'Shinto shrine',
#  '宰': 'superintend',
#  '害': 'harm',
#  '宴': 'banquet',
#  '宵': 'wee hours',
#  '家': 'house',
#  '容': 'contain',
#  '宿': 'inn',
#  '寂': 'loneliness',
#  '寄': 'approach',
#  '密': 'secrecy',
#  '富': 'rich',
#  '寒': 'cold',
#  '寛': 'tolerant',
#  '寝': 'lie down',
#  '察': 'guess',
#  '寡': 'widow',
#  '寧': 'rather',
#  '審': 'examine',
#  '寮': 'dormitory',
#  '寸': 'measurement',
#  '寺': 'Buddhist temple',
#  '対': 'opposite',
#  '寿': 'longevity',
#  '封': 'seal',
#  '専': 'specialty',
#  '射': 'shoot',
#  '将': 'leader',
#  '尉': 'military officer',
#  '尊': 'revered',
#  '尋': 'inquire',
#  '導': 'guide',
#  '小': 'small',
#  '少': 'few',
#  '尚': 'esteem',
#  '就': 'concerning',
#  '尺': 'shaku',
#  '尻': 'buttocks',
#  '尼': 'nun',
#  '尽': 'exhaust',
#  '尾': 'tail',
#  '尿': 'urine',
#  '局': 'office',
#  '居': 'reside',
#  '屈': 'yield',
#  '届': 'deliver',
#  '屋': 'roof',
#  '展': 'expand',
#  '属': 'belong',
#  '層': 'stratum',
#  '履': 'footgear',
#  '屯': 'barracks',
#  '山': 'mountain',
#  '岐': 'branch off',
#  '岡': 'hill',
#  '岩': 'boulder',
#  '岬': 'headland',
#  '岳': 'point',
#  '岸': 'beach',
#  '峠': 'mountain peak',
#  '峡': 'gorge',
#  '峰': 'summit',
#  '島': 'island',
#  '崇': 'adore',
#  '崎': 'promontory',
#  '崖': 'cliff',
#  '崩': 'crumble',
#  '嵐': 'storm',
#  '川': 'river',
#  '州': 'state',
#  '巡': 'patrol',
#  '巣': 'nest',
#  '工': 'craft',
#  '左': 'left (direction)',
#  '巧': 'adroit',
#  '巨': 'gigantic',
#  '差': 'distinction',
#  '己': 'self',
#  '巻': 'scroll',
#  '巾': 'towel',
#  '市': 'market',
#  '布': 'linen',
#  '帆': 'sail',
#  '希': 'hope',
#  '帝': 'sovereign',
#  '帥': 'commander',
#  '師': 'expert',
#  '席': 'seat',
#  '帯': 'sash',
#  '帰': 'return',
#  '帳': 'account book',
#  '常': 'normal',
#  '帽': 'cap',
#  '幅': 'breadth',
#  '幕': 'curtain',
#  '幣': 'cash',
#  '干': 'dry',
#  '平': 'flat',
#  '年': 'year',
#  '幸': 'happiness',
#  '幹': 'tree-trunk',
#  '幻': 'phantasm',
#  '幼': 'infancy',
#  '幽': 'seclude',
#  '幾': 'how many',
#  '庁': 'government office',
#  '広': 'wide',
#  '床': 'bed',
#  '序': 'preface',
#  '底': 'bottom',
#  '店': 'shop',
#  '府': 'urban prefecture',
#  '度': 'degrees',
#  '座': 'sit',
#  '庫': 'warehouse',
#  '庭': 'garden',
#  '庶': 'commoner',
#  '康': 'health',
#  '庸': 'commonplace',
#  '廃': 'abolish',
#  '廉': 'bargain',
#  '廊': 'corridor',
#  '延': 'prolong',
#  '廷': 'courts',
#  '建': 'build',
#  '弁': 'valve',
#  '弄': 'tamper with',
#  '弊': 'abuse',
#  '式': 'style',
#  '弐': 'two (falsification prevention)',
#  '弓': 'bow (archery, violin)',
#  '弔': 'condolences',
#  '引': 'pull',
#  '弟': 'younger brother',
#  '弥': 'all the more',
#  '弦': 'bowstring',
#  '弧': 'arc',
#  '弱': 'weak',
#  '張': 'stretch',
#  '強': 'strong',
#  '弾': 'bullet',
#  '当': 'hit',
#  '彙': 'same kind',
#  '形': 'shape',
#  '彩': 'coloring',
#  '彫': 'carve',
#  '彰': 'patent',
#  '影': 'shadow',
#  '役': 'service',
#  '彼': 'he',
#  '往': 'outward journey',
#  '征': 'subjugate',
#  '径': 'diameter',
#  '待': 'wait',
#  '律': 'law',
#  '後': 'behind',
#  '徐': 'gradually',
#  '徒': 'junior',
#  '従': 'obey',
#  '得': 'acquire',
#  '御': 'honorable',
#  '復': 'again',
#  '循': 'sequential',
#  '微': 'delicate',
#  '徳': 'benevolence',
#  '徴': 'indications',
#  '徹': 'penetrate',
#  '心': 'heart',
#  '必': 'without fail',
#  '忌': 'mourning',
#  '忍': 'endure',
#  '志': 'intention',
#  '忘': 'forget',
#  '忙': 'busy',
#  '応': 'respond',
#  '忠': 'loyalty',
#  '快': 'cheerful',
#  '念': 'thought',
#  '怒': 'angry',
#  '怖': 'dreadful',
#  '思': 'think',
#  '怠': 'neglect',
#  '急': 'hurry',
#  '性': 'gender',
#  '怨': 'grudge',
#  '怪': 'suspicious',
#  '恋': 'romance',
#  '恐': 'fear',
#  '恒': 'constancy',
#  '恣': 'selfish',
#  '恥': 'shame',
#  '恨': 'rancor',
#  '恩': 'grace',
#  '恭': 'respect',
#  '息': 'breath',
#  '恵': 'favor',
#  '悔': 'repent',
#  '悟': 'enlightenment',
#  '悠': 'permanence',
#  '患': 'afflicted',
#  '悦': 'ecstasy',
#  '悩': 'trouble',
#  '悪': 'bad',
#  '悲': 'sad',
#  '悼': 'lament',
#  '情': 'feelings',
#  '惑': 'beguile',
#  '惜': 'pity',
#  '惧': 'dread',
#  '惨': 'wretched',
#  '惰': 'lazy',
#  '想': 'concept',
#  '愁': 'distress',
#  '愉': 'pleasure',
#  '意': 'idea',
#  '愚': 'foolish',
#  '愛': 'love',
#  '感': 'feeling',
#  '慄': 'fear',
#  '慈': 'mercy',
#  '態': 'condition',
#  '慌': 'disconcerted',
#  '慎': 'humility',
#  '慕': 'pining',
#  '慢': 'ridicule',
#  '慣': 'accustomed',
#  '慨': 'rue',
#  '慮': 'prudence',
#  '慰': 'consolation',
#  '慶': 'jubilation',
#  '憂': 'melancholy',
#  '憎': 'hate',
#  '憤': 'aroused',
#  '憧': 'desire',
#  '憩': 'recess',
#  '憬': 'long for',
#  '憲': 'constitution',
#  '憶': 'recollection',
#  '憾': 'remorse',
#  '懇': 'sociable',
#  '懐': 'pocket',
#  '懲': 'penal',
#  '懸': 'suspend',
#  '成': 'become',
#  '我': 'ego',
#  '戒': 'commandment',
#  '戚': 'grieve',
#  '戦': 'war',
#  '戯': 'frolic',
#  '戴': 'be crowned with',
#  '戸': 'door',
#  '戻': 're-',
#  '房': 'tassel',
#  '所': 'place',
#  '扇': 'fan',
#  '扉': 'front door',
#  '手': 'hand',
#  '才': 'genius',
#  '打': 'hit',
#  '払': 'pay',
#  '扱': 'handle',
#  '扶': 'aid',
#  '批': 'criticism',
#  '承': 'acquiesce',
#  '技': 'skill',
#  '抄': 'extract',
#  '把': 'grasp',
#  '抑': 'repress',
#  '投': 'throw',
#  '抗': 'confront',
#  '折': 'fold',
#  '抜': 'slip out',
#  '択': 'choose',
#  '披': 'expose',
#  '抱': 'embrace',
#  '抵': 'resist',
#  '抹': 'rub',
#  '押': 'push',
#  '抽': 'pluck',
#  '担': 'shouldering',
#  '拉': 'crush',
#  '拍': 'clap',
#  '拐': 'kidnap',
#  '拒': 'repel',
#  '拓': 'clear (the land)',
#  '拘': 'arrest',
#  '拙': 'bungling',
#  '招': 'beckon',
#  '拝': 'worship',
#  '拠': 'foothold',
#  '拡': 'broaden',
#  '括': 'fasten',
#  '拭': 'wipe',
#  '拳': 'fist',
#  '拶': 'be imminent',
#  '拷': 'torture',
#  '拾': 'pick up',
#  '持': 'hold',
#  '指': 'finger',
#  '挑': 'challenge',
#  '挙': 'raise',
#  '挟': 'pinch',
#  '挨': 'push open',
#  '挫': 'sprain',
#  '振': 'shake',
#  '挿': 'insert',
#  '捉': 'capture',
#  '捕': 'catch',
#  '捗': 'make progress',
#  '捜': 'search',
#  '捨': 'throw away',
#  '据': 'set',
#  '捻': 'twist',
#  '掃': 'sweep',
#  '授': 'instruct',
#  '掌': 'manipulate',
#  '排': 'repudiate',
#  '掘': 'dig',
#  '掛': 'hang',
#  '採': 'pick',
#  '探': 'grope',
#  '接': 'contact',
#  '控': 'withdraw',
#  '推': 'infer',
#  '措': 'set aside',
#  '掲': 'put up (a notice)',
#  '描': 'sketch',
#  '提': 'present',
#  '揚': 'hoist',
#  '換': 'interchange',
#  '握': 'grip',
#  '揮': 'brandish',
#  '援': 'aid',
#  '揺': 'swing',
#  '損': 'loss',
#  '搬': 'conveyor',
#  '搭': 'board',
#  '携': 'portable',
#  '搾': 'squeeze',
#  '摂': 'vicarious',
#  '摘': 'pinch',
#  '摩': 'chafe',
#  '摯': 'seriousness',
#  '撃': 'beat',
#  '撤': 'remove',
#  '撮': 'snapshot',
#  '撲': 'slap',
#  '擁': 'embrace',
#  '操': 'maneuver',
#  '擦': 'grate',
#  '擬': 'mimic',
#  '支': 'branch',
#  '改': 'reformation',
#  '攻': 'aggression',
#  '放': 'release',
#  '政': 'politics',
#  '故': 'circumstances',
#  '敏': 'cleverness',
#  '救': 'salvation',
#  '敗': 'failure',
#  '教': 'teach',
#  '敢': 'daring',
#  '散': 'scatter',
#  '敬': 'respect',
#  '数': 'number',
#  '整': 'put in order',
#  '敵': 'enemy',
#  '敷': 'spread',
#  '文': 'writing',
#  '斉': 'adjusted',
#  '斎': 'purification',
#  '斑': 'blemish',
#  '斗': 'Big Dipper',
#  '料': 'fee',
#  '斜': 'diagonal',
#  '斤': 'axe',
#  '斥': 'reject',
#  '斬': 'kill by slicing',
#  '断': 'cut off',
#  '新': 'new',
#  '方': 'direction',
#  '施': 'carry out',
#  '旅': 'trip',
#  '旋': 'rotation',
#  '族': 'tribe',
#  '旗': 'national flag',
#  '既': 'previously',
#  '日': 'day',
#  '旦': 'daybreak',
#  '旧': 'old times',
#  '旨': 'delicious',
#  '早': 'early',
#  '旬': '10-day period (of the month)',
#  '旺': 'flourishing',
#  '昆': 'descendants',
#  '昇': 'rise up',
#  '明': 'bright',
#  '易': 'easy',
#  '昔': 'long ago',
#  '星': 'star',
#  '映': 'reflect',
#  '春': 'springtime',
#  '昧': 'foolish',
#  '昨': 'previous',
#  '昭': 'shining',
#  '是': 'just so',
#  '昼': 'daytime',
#  '時': 'time',
#  '晩': 'nightfall',
#  '普': 'universal',
#  '景': 'scenery',
#  '晴': 'clear up',
#  '晶': 'sparkle',
#  '暁': 'daybreak',
#  '暇': 'spare time',
#  '暑': 'hot',
#  '暖': 'warmth',
#  '暗': 'dark',
#  '暦': 'calendar',
#  '暫': 'temporarily',
#  '暮': 'livelihood',
#  '暴': 'outburst',
#  '曇': 'cloudy weather',
#  '曖': 'not clear',
#  '曜': 'day of the week',
#  '曲': 'musical composition',
#  '更': 'grow late',
#  '書': 'write',
#  '曹': 'cadet',
#  '曽': 'formerly',
#  '替': 'exchange',
#  '最': 'most',
#  '月': 'month, moon',
#  '有': 'have',
#  '服': 'clothes',
#  '朕': 'majestic plural',
#  '朗': 'melodious',
#  '望': 'hope',
#  '朝': 'morning',
#  '期': 'period of time',
#  '木': 'tree',
#  '未': 'not yet',
#  '末': 'end',
#  '本': 'book',
#  '札': 'tag',
#  '朱': 'vermilion',
#  '朴': 'crude',
#  '机': 'desk',
#  '朽': 'decay',
#  '杉': 'cedar',
#  '材': 'lumber',
#  '村': 'village',
#  '束': 'bundle',
#  '条': 'clause',
#  '来': 'come',
#  '杯': 'counter for cupfuls',
#  '東': 'east',
#  '松': 'pine',
#  '板': 'board',
#  '析': 'chop',
#  '枕': 'pillow',
#  '林': 'woods',
#  '枚': 'sheet of...',
#  '果': 'fruit',
#  '枝': 'branch',
#  '枠': 'frame',
#  '枢': 'hinge',
#  '枯': 'wither',
#  '架': 'rack',
#  '柄': 'design',
#  '某': 'so-and-so',
#  '染': 'dye',
#  '柔': 'tender',
#  '柱': 'pillar',
#  '柳': 'willow',
#  '柵': 'fence',
#  '査': 'investigate',
#  '柿': 'persimmon',
#  '栃': 'horse chestnut',
#  '栄': 'prosperity',
#  '栓': 'plug',
#  '校': 'school',
#  '株': 'stocks',
#  '核': 'nucleus',
#  '根': 'root',
#  '格': 'status',
#  '栽': 'plantation',
#  '桁': 'beam',
#  '桃': 'peach tree',
#  '案': 'plan',
#  '桑': 'mulberry',
#  '桜': 'cherry tree',
#  '桟': 'scaffold',
#  '梅': 'ume (Japanese apricot)',
#  '梗': 'close up',
#  '梨': 'pear tree',
#  '械': 'contraption',
#  '棄': 'abandon',
#  '棋': 'chess piece',
#  '棒': 'rod',
#  '棚': 'shelf',
#  '棟': 'ridgepole',
#  '森': 'forest',
#  '棺': 'coffin',
#  '椅': 'chair',
#  '植': 'plant',
#  '椎': 'oak',
#  '検': 'examine',
#  '業': 'business',
#  '極': 'poles',
#  '楷': 'square character style',
#  '楼': 'watchtower',
#  '楽': 'pleasure',
#  '概': 'outline',
#  '構': 'construct',
#  '様': 'formal title',
#  '槽': 'vat',
#  '標': 'signpost',
#  '模': 'imitation',
#  '権': 'rights',
#  '横': 'side',
#  '樹': 'trees',
#  '橋': 'bridge',
#  '機': 'machine',
#  '欄': 'column',
#  '欠': 'lack',
#  '次': 'next',
#  '欧': 'Europe',
#  '欲': 'longing',
#  '欺': 'deceit',
#  '款': 'goodwill',
#  '歌': 'song',
#  '歓': 'delight',
#  '止': 'stop',
#  '正': 'correct',
#  '武': 'military',
#  '歩': 'walk',
#  '歯': 'tooth',
#  '歳': 'year-end',
#  '歴': 'curriculum',
#  '死': 'death',
#  '殉': 'martyrdom',
#  '殊': 'particularly',
#  '残': 'remainder',
#  '殖': 'augment',
#  '殴': 'assault',
#  '段': 'steps',
#  '殺': 'kill',
#  '殻': 'husk',
#  '殿': 'Mr.',
#  '毀': 'destroy',
#  '母': 'mother',
#  '毎': 'every',
#  '毒': 'poison',
#  '比': 'compare',
#  '毛': 'hair',
#  '氏': 'family name',
#  '民': 'people',
#  '気': 'feeling',
#  '水': 'water',
#  '氷': 'ice',
#  '永': 'eternity',
#  '氾': 'spread out',
#  '汁': 'soup',
#  '求': 'request',
#  '汎': 'pan-',
#  '汗': 'sweat',
#  '汚': 'dirty',
#  '江': 'inlet',
#  '池': 'pond',
#  '汰': 'luxury',
#  '決': 'decide',
#  '汽': 'steam',
#  '沃': 'fertility',
#  '沈': 'sink',
#  '沖': 'open sea',
#  '沙': 'sand',
#  '没': 'drown',
#  '沢': 'swamp',
#  '河': 'river',
#  '沸': 'seethe',
#  '油': 'oil',
#  '治': 'govern',
#  '沼': 'marsh',
#  '沿': 'run alongside',
#  '況': 'condition',
#  '泉': 'spring',
#  '泊': 'overnight',
#  '泌': 'ooze',
#  '法': 'method',
#  '泡': 'bubbles',
#  '波': 'wave',
#  '泣': 'cry',
#  '泥': 'mud',
#  '注': 'pour',
#  '泰': 'peaceful',
#  '泳': 'swim',
#  '洋': 'ocean',
#  '洗': 'wash',
#  '洞': 'den',
#  '津': 'haven',
#  '洪': 'deluge',
#  '活': 'active',
#  '派': 'sect',
#  '流': 'stream',
#  '浄': 'clean',
#  '浅': 'shallow',
#  '浜': 'seacoast',
#  '浦': 'bay',
#  '浪': 'wandering',
#  '浮': 'floating',
#  '浴': 'bathe',
#  '海': 'sea',
#  '浸': 'immersed',
#  '消': 'extinguish',
#  '涙': 'tears',
#  '涯': 'horizon',
#  '液': 'fluid',
#  '涼': 'refreshing',
#  '淑': 'graceful',
#  '淡': 'thin',
#  '淫': 'lewdness',
#  '深': 'deep',
#  '混': 'mix',
#  '添': 'annexed',
#  '清': 'pure',
#  '渇': 'thirst',
#  '済': 'settle',
#  '渉': 'ford',
#  '渋': 'astringent',
#  '渓': 'mountain stream',
#  '減': 'decrease',
#  '渡': 'transit',
#  '渦': 'whirlpool',
#  '温': 'warm',
#  '測': 'fathom',
#  '港': 'harbor',
#  '湖': 'lake',
#  '湧': 'boil',
#  '湯': 'hot water',
#  '湾': 'gulf',
#  '湿': 'damp',
#  '満': 'full',
#  '源': 'origin',
#  '準': 'standard',
#  '溝': 'gutter',
#  '溶': 'melt',
#  '溺': 'drown',
#  '滅': 'destroy',
#  '滋': 'nourishing',
#  '滑': 'slippery',
#  '滝': 'waterfall',
#  '滞': 'stagnate',
#  '滴': 'drip',
#  '漁': 'fishing',
#  '漂': 'drift',
#  '漆': 'lacquer',
#  '漏': 'leak',
#  '演': 'perform',
#  '漠': 'vague',
#  '漢': 'China',
#  '漫': 'cartoon',
#  '漬': 'pickling',
#  '漸': 'steadily',
#  '潔': 'undefiled',
#  '潜': 'submerge',
#  '潟': 'lagoon',
#  '潤': 'wet',
#  '潮': 'tide',
#  '潰': 'crush',
#  '澄': 'lucidity',
#  '激': 'violent',
#  '濁': 'voiced',
#  '濃': 'concentrated',
#  '濫': 'excessive',
#  '濯': 'laundry',
#  '瀬': 'rapids',
#  '火': 'fire',
#  '灯': 'lamp',
#  '灰': 'ashes',
#  '災': 'disaster',
#  '炉': 'hearth',
#  '炊': 'cook',
#  '炎': 'inflammation',
#  '炭': 'charcoal',
#  '点': 'point',
#  '為': 'do',
#  '烈': 'ardent',
#  '無': 'nothing',
#  '焦': 'char',
#  '然': 'so',
#  '焼': 'bake',
#  '煎': 'broil',
#  '煙': 'smoke',
#  '照': 'illuminate',
#  '煩': 'anxiety',
#  '煮': 'boil',
#  '熊': 'bear',
#  '熟': 'ripen',
#  '熱': 'heat',
#  '燃': 'burn',
#  '燥': 'parch',
#  '爆': 'explode',
#  '爪': 'claw',
#  '爵': 'baron',
#  '父': 'father',
#  '爽': 'refreshing',
#  '片': 'one-sided',
#  '版': 'printing block',
#  '牙': 'tusk',
#  '牛': 'cow',
#  '牧': 'breed',
#  '物': 'thing',
#  '牲': 'animal sacrifice',
#  '特': 'special',
#  '犠': 'sacrifice',
#  '犬': 'dog',
#  '犯': 'crime',
#  '状': 'form',
#  '狂': 'lunatic',
#  '狙': 'aim at',
#  '狩': 'hunt',
#  '独': 'alone',
#  '狭': 'cramped',
#  '猛': 'fierce',
#  '猟': 'game-hunting',
#  '猫': 'cat',
#  '献': 'offering',
#  '猶': 'furthermore',
#  '猿': 'monkey',
#  '獄': 'prison',
#  '獣': 'animal',
#  '獲': 'seize',
#  '玄': 'mysterious',
#  '率': 'rate',
#  '玉': 'ball',
#  '王': 'king',
#  '玩': 'trifle with',
#  '珍': 'rare',
#  '珠': 'pearl',
#  '班': 'squad',
#  '現': 'appear',
#  '球': 'sphere',
#  '理': 'reason',
#  '琴': 'harp',
#  '瑠': 'lapis lazuli',
#  '璃': 'glassy',
#  '璧': 'sphere',
#  '環': 'ring',
#  '璽': "emperor's seal",
#  '瓦': 'tile',
#  '瓶': 'flower pot',
#  '甘': 'sweet',
#  '甚': 'tremendously',
#  '生': 'life',
#  '産': 'give birth',
#  '用': 'use',
#  '田': 'rice paddy',
#  '由': 'reason',
#  '甲': 'armor',
#  '申': 'say',
#  '男': 'male',
#  '町': 'town',
#  '画': 'tableau',
#  '界': 'world',
#  '畏': 'fear',
#  '畑': 'farm',
#  '畔': 'paddy-ridge',
#  '留': 'detain',
#  '畜': 'livestock',
#  '畝': 'furrow',
#  '略': 'abbreviation',
#  '番': "one's turn",
#  '異': 'uncommon',
#  '畳': 'tatami mat',
#  '畿': 'capital',
#  '疎': 'alienate',
#  '疑': 'doubt',
#  '疫': 'epidemic',
#  '疲': 'exhausted',
#  '疾': 'rapidly',
#  '病': 'sick',
#  '症': 'symptoms',
#  '痕': 'mark',
#  '痘': 'pox',
#  '痛': 'pain',
#  '痢': 'diarrhea',
#  '痩': 'get thin',
#  '痴': 'stupid',
#  '瘍': 'boil (medical)',
#  '療': 'heal',
#  '癒': 'healing',
#  '癖': 'mannerism',
#  '発': 'departure',
#  '登': 'climb',
#  '白': 'white',
#  '百': 'hundred',
#  '的': 'target',
#  '皆': 'all',
#  '皇': 'emperor',
#  '皮': 'skin',
#  '皿': 'dish',
#  '盆': 'basin',
#  '益': 'benefit',
#  '盗': 'steal',
#  '盛': 'prosper',
#  '盟': 'alliance',
#  '監': 'oversee',
#  '盤': 'tray',
#  '目': 'eye',
#  '盲': 'blind',
#  '直': 'straight',
#  '相': 'mutual',
#  '盾': 'shield',
#  '省': 'government ministry',
#  '眉': 'eyebrow',
#  '看': 'watch over',
#  '県': 'prefecture',
#  '真': 'true',
#  '眠': 'sleep',
#  '眺': 'stare',
#  '眼': 'eyeball',
#  '着': 'wear',
#  '睡': 'drowsy',
#  '督': 'coach',
#  '睦': 'harmonious',
#  '瞬': 'wink',
#  '瞭': 'clear',
#  '瞳': 'pupil',
#  '矛': 'halberd',
#  '矢': 'arrow',
#  '知': 'know',
#  '短': 'short',
#  '矯': 'rectify',
#  '石': 'stone',
#  '砂': 'sand',
#  '研': 'sharpen',
#  '砕': 'smash',
#  '砲': 'cannon',
#  '破': 'rend',
#  '硝': 'nitrate',
#  '硫': 'sulphur',
#  '硬': 'stiff',
#  '碁': 'Go',
#  '碑': 'tombstone',
#  '確': 'certain',
#  '磁': 'magnet',
#  '磨': 'grind',
#  '礁': 'reef',
#  '礎': 'cornerstone',
#  '示': 'indicate',
#  '礼': 'thanks',
#  '社': 'company',
#  '祈': 'pray',
#  '祉': 'welfare',
#  '祖': 'ancestor',
#  '祝': 'celebrate',
#  '神': 'god',
#  '祥': 'auspicious',
#  '票': 'ballot',
#  '祭': 'festival',
#  '禁': 'prohibition',
#  '禅': 'Zen',
#  '禍': 'calamity',
#  '福': 'luck',
#  '秀': 'excel',
#  '私': 'me',
#  '秋': 'autumn',
#  '科': 'section',
#  '秒': 'second (part of time)',
#  '秘': 'secret',
#  '租': 'tariff',
#  '秩': 'regularity',
#  '称': 'appellation',
#  '移': 'shift',
#  '程': 'extent',
#  '税': 'tax',
#  '稚': 'immature',
#  '種': 'kind',
#  '稲': 'rice plant',
#  '稼': 'earnings',
#  '稽': 'consider',
#  '稿': 'draft',
#  '穀': 'cereals',
#  '穂': 'ear',
#  '積': 'accumulate',
#  '穏': 'calm',
#  '穫': 'harvest',
#  '穴': 'hole',
#  '究': 'research',
#  '空': 'sky',
#  '突': 'stab',
#  '窃': 'stealth',
#  '窒': 'plug up',
#  '窓': 'window',
#  '窟': 'cavern',
#  '窮': 'hard up',
#  '窯': 'kiln',
#  '立': 'stand up',
#  '竜': 'dragon',
#  '章': 'chapter',
#  '童': 'juvenile',
#  '端': 'edge',
#  '競': 'compete',
#  '竹': 'bamboo',
#  '笑': 'laugh',
#  '笛': 'flute',
#  '符': 'token',
#  '第': 'ordinal number prefix',
#  '筆': 'writing brush',
#  '等': 'class',
#  '筋': 'muscle',
#  '筒': 'cylinder',
#  '答': 'answer',
#  '策': 'scheme',
#  '箇': 'counters for things',
#  '箋': 'paper',
#  '算': 'calculate',
#  '管': 'pipe',
#  '箱': 'box',
#  '箸': 'chopsticks',
#  '節': 'node',
#  '範': 'pattern',
#  '築': 'fabricate',
#  '篤': 'fervent',
#  '簡': 'simplicity',
#  '簿': 'register',
#  '籍': 'enroll',
#  '籠': 'basket',
#  '米': 'rice',
#  '粉': 'flour',
#  '粋': 'chic',
#  '粒': 'grains',
#  '粗': 'coarse',
#  '粘': 'sticky',
#  '粛': 'solemn',
#  '粧': 'cosmetics',
#  '精': 'refined',
#  '糖': 'sugar',
#  '糧': 'provisions',
#  '糸': 'thread',
#  '系': 'lineage',
#  '糾': 'twist',
#  '紀': 'chronicle',
#  '約': 'promise',
#  '紅': 'deep red',
#  '紋': 'family crest',
#  '納': 'settlement',
#  '純': 'genuine',
#  '紙': 'paper',
#  '級': 'rank',
#  '紛': 'distract',
#  '素': 'elementary',
#  '紡': 'spinning',
#  '索': 'cord',
#  '紫': 'purple',
#  '累': 'accumulate',
#  '細': 'thin',
#  '紳': 'sire',
#  '紹': 'introduce',
#  '紺': 'dark blue',
#  '終': 'end',
#  '組': 'association',
#  '経': 'manage',
#  '結': 'tie',
#  '絞': 'strangle',
#  '絡': 'entwine',
#  '給': 'salary',
#  '統': 'unite',
#  '絵': 'picture',
#  '絶': 'discontinue',
#  '絹': 'silk',
#  '継': 'inherit',
#  '続': 'continue',
#  '維': 'fiber',
#  '綱': 'hawser',
#  '網': 'netting',
#  '綻': 'rip',
#  '綿': 'cotton',
#  '緊': 'tense',
#  '総': 'whole',
#  '緑': 'green',
#  '緒': 'thong',
#  '線': 'line',
#  '締': 'tighten',
#  '編': 'compile',
#  '緩': 'slacken',
#  '緯': 'horizontal',
#  '練': 'practice',
#  '緻': 'fine (not coarse)',
#  '縁': 'affinity',
#  '縄': 'straw rope',
#  '縛': 'truss',
#  '縦': 'vertical',
#  '縫': 'sew',
#  '縮': 'shrink',
#  '績': 'exploits',
#  '繁': 'luxuriant',
#  '繊': 'slender',
#  '織': 'weave',
#  '繕': 'darning',
#  '繭': 'cocoon',
#  '繰': 'winding',
#  '缶': 'tin can',
#  '罪': 'guilt',
#  '置': 'put',
#  '罰': 'penalty',
#  '署': 'government office',
#  '罵': 'insult',
#  '罷': 'quit',
#  '羅': 'gauze',
#  '羊': 'sheep',
#  '美': 'beauty',
#  '羞': 'feel ashamed',
#  '群': 'flock',
#  '羨': 'envy',
#  '義': 'righteousness',
#  '羽': 'feather',
#  '翁': 'venerable old man',
#  '翌': 'the following',
#  '習': 'learn',
#  '翻': 'flip',
#  '翼': 'wing',
#  '老': 'old man',
#  '考': 'think',
#  '者': 'someone',
#  '耐': 'resistant',
#  '耕': 'till',
#  '耗': 'decrease',
#  '耳': 'ear',
#  '聖': 'holy',
#  '聞': 'hear',
#  '聴': 'listen',
#  '職': 'employment',
#  '肉': 'meat',
#  '肌': 'texture',
#  '肖': 'resemblance',
#  '肘': 'elbow',
#  '肝': 'liver',
#  '股': 'crotch',
#  '肢': 'limb',
#  '肥': 'fertilizer',
#  '肩': 'shoulder',
#  '肪': 'obese',
#  '肯': 'agreement',
#  '育': 'nurture',
#  '肺': 'lungs',
#  '胃': 'stomach',
#  '胆': 'gall bladder',
#  '背': 'back',
#  '胎': 'womb',
#  '胞': 'placenta',
#  '胴': 'trunk',
#  '胸': 'bosom',
#  '能': 'ability',
#  '脂': 'fat',
#  '脅': 'threaten',
#  '脇': 'aside',
#  '脈': 'vein',
#  '脊': 'stature',
#  '脚': 'leg',
#  '脱': 'undress',
#  '脳': 'brain',
#  '腎': 'kidney',
#  '腐': 'rot',
#  '腕': 'arm',
#  '腫': 'tumor',
#  '腰': 'loins',
#  '腸': 'intestines',
#  '腹': 'abdomen',
#  '腺': 'gland',
#  '膚': 'skin',
#  '膜': 'membrane',
#  '膝': 'knee',
#  '膨': 'swell',
#  '膳': 'tray',
#  '臆': 'timidity',
#  '臓': 'entrails',
#  '臣': 'retainer',
#  '臨': 'look to',
#  '自': 'oneself',
#  '臭': 'stinking',
#  '至': 'climax',
#  '致': '(to) do',
#  '臼': 'mortar',
#  '興': 'entertain',
#  '舌': 'tongue',
#  '舎': 'cottage',
#  '舗': 'pavement',
#  '舞': 'dance',
#  '舟': 'boat',
#  '航': 'cruise',
#  '般': 'generally',
#  '舶': 'liner',
#  '舷': 'gunwale',
#  '船': 'boat',
#  '艇': 'rowboat',
#  '艦': 'warship',
#  '良': 'good',
#  '色': 'color',
#  '艶': 'glossy',
#  '芋': 'potato',
#  '芝': 'turf',
#  '芯': 'core',
#  '花': 'flower',
#  '芳': 'perfume',
#  '芸': 'art',
#  '芽': 'bud',
#  '苗': 'seedling',
#  '苛': 'torment',
#  '若': 'young',
#  '苦': 'suffer',
#  '英': 'England',
#  '茂': 'overgrown',
#  '茎': 'stalk',
#  '茨': 'thorn',
#  '茶': 'tea',
#  '草': 'grass',
#  '荒': 'laid waste',
#  '荘': 'villa',
#  '荷': 'luggage',
#  '菊': 'chrysanthemum',
#  '菌': 'germ',
#  '菓': 'confectionery',
#  '菜': 'vegetable',
#  '華': 'splendor',
#  '萎': 'wither',
#  '落': 'fall',
#  '葉': 'leaf',
#  '著': 'renowned',
#  '葛': 'arrowroot',
#  '葬': 'interment',
#  '蒸': 'steam',
#  '蓄': 'amass',
#  '蓋': 'cover',
#  '蔑': 'ignore',
#  '蔵': 'warehouse',
#  '蔽': 'cover',
#  '薄': 'dilute',
#  '薦': 'recommend',
#  '薪': 'fuel',
#  '薫': 'fragrant',
#  '薬': 'medicine',
#  '藍': 'indigo',
#  '藤': 'wisteria',
#  '藩': 'clan',
#  '藻': 'seaweed',
#  '虎': 'tiger',
#  '虐': 'tyrannize',
#  '虚': 'void',
#  '虜': 'captive',
#  '虞': 'uneasiness',
#  '虫': 'insect',
#  '虹': 'rainbow',
#  '蚊': 'mosquito',
#  '蚕': 'silkworm',
#  '蛇': 'snake',
#  '蛍': 'lightning-bug',
#  '蛮': 'barbarian',
#  '蜂': 'bee',
#  '蜜': 'honey',
#  '融': 'dissolve',
#  '血': 'blood',
#  '衆': 'masses',
#  '行': 'go',
#  '術': 'art',
#  '街': 'street',
#  '衛': 'defense',
#  '衝': 'collide',
#  '衡': 'equilibrium',
#  '衣': 'clothes',
#  '表': 'express',
#  '衰': 'decline',
#  '衷': 'inmost',
#  '袋': 'sack',
#  '袖': 'sleeve',
#  '被': 'incur',
#  '裁': 'judge',
#  '裂': 'split',
#  '装': 'attire',
#  '裏': 'back',
#  '裕': 'abundant',
#  '補': 'supplement',
#  '裸': 'naked',
#  '製': 'manufacture',
#  '裾': 'cuff',
#  '複': 'duplicate',
#  '褐': 'brown',
#  '褒': 'praise',
#  '襟': 'collar',
#  '襲': 'attack',
#  '西': 'west',
#  '要': 'need',
#  '覆': 'capsize',
#  '覇': 'hegemony',
#  '見': 'see',
#  '規': 'rule',
#  '視': 'look at',
#  '覚': 'memorize',
#  '覧': 'perusal',
#  '親': 'parent',
#  '観': 'observe',
#  '角': 'angle',
#  '解': 'untie',
#  '触': 'contact',
#  '言': 'say',
#  '訂': 'revise',
#  '訃': 'obituary',
#  '計': 'measure',
#  '討': 'chastise',
#  '訓': 'instruction',
#  '託': 'consign',
#  '記': 'write down',
#  '訟': 'sue',
#  '訪': 'visit',
#  '設': 'establish',
#  '許': 'permit',
#  '訳': 'translate',
#  '訴': 'sue',
#  '診': 'checkup',
#  '証': 'evidence',
#  '詐': 'lie',
#  '詔': 'imperial edict',
#  '評': 'evaluate',
#  '詞': 'poetry',
#  '詠': 'recitation',
#  '詣': 'visit a temple',
#  '試': 'test',
#  '詩': 'poem',
#  '詮': 'discussion',
#  '詰': 'packed',
#  '話': 'talk',
#  '該': 'above-stated',
#  '詳': 'detailed',
#  '誇': 'boast',
#  '誉': 'reputation',
#  '誌': 'document',
#  '認': 'recognize',
#  '誓': 'vow',
#  '誕': 'nativity',
#  '誘': 'entice',
#  '語': 'language',
#  '誠': 'sincerity',
#  '誤': 'mistake',
#  '説': 'theory',
#  '読': 'read',
#  '誰': 'who (question word)',
#  '課': 'section',
#  '調': 'investigate',
#  '談': 'discuss',
#  '請': 'solicit',
#  '論': 'theory',
#  '諦': 'abandon',
#  '諧': 'harmony',
#  '諭': 'rebuke',
#  '諮': 'consult with',
#  '諸': 'various',
#  '諾': 'consent',
#  '謀': 'conspire',
#  '謁': 'audience',
#  '謄': 'mimeograph',
#  '謎': 'riddle',
#  '謙': 'self-effacing',
#  '講': 'lecture',
#  '謝': 'apologize',
#  '謡': 'noh chanting',
#  '謹': 'discreet',
#  '識': 'discriminating',
#  '譜': 'musical score',
#  '警': 'guard against',
#  '議': 'deliberation',
#  '譲': 'defer',
#  '護': 'safeguard',
#  '谷': 'valley',
#  '豆': 'beans',
#  '豊': 'bountiful',
#  '豚': 'pork',
#  '象': 'elephant',
#  '豪': 'overpowering',
#  '貌': 'appearance',
#  '貝': 'shellfish',
#  '貞': 'upright',
#  '負': 'lose',
#  '財': 'wealth',
#  '貢': 'tribute',
#  '貧': 'poor',
#  '貨': 'freight',
#  '販': 'marketing',
#  '貪': 'covet',
#  '貫': 'pierce',
#  '責': 'blame',
#  '貯': 'savings',
#  '貴': 'precious',
#  '買': 'buy',
#  '貸': 'lend',
#  '費': 'expense',
#  '貼': 'paste',
#  '貿': 'trade',
#  '賀': 'congratulations',
#  '賂': 'bribe',
#  '賃': 'fare',
#  '賄': 'bribe',
#  '資': 'resources',
#  '賊': 'burglar',
#  '賓': 'V.I.P.',
#  '賛': 'approve',
#  '賜': 'grant',
#  '賞': 'prize',
#  '賠': 'compensation',
#  '賢': 'intelligent',
#  '賦': 'levy',
#  '質': 'quality',
#  '賭': 'gamble',
#  '購': 'subscription',
#  '贈': 'presents',
#  '赤': 'red',
#  '赦': 'pardon',
#  '走': 'run',
#  '赴': 'proceed',
#  '起': 'wake up',
#  '超': 'transcend',
#  '越': 'cross over',
#  '趣': 'gist',
#  '足': 'foot',
#  '距': 'long-distance',
#  '跡': 'tracks',
#  '路': 'road',
#  '跳': 'hop',
#  '践': 'tread',
#  '踊': 'jump',
#  '踏': 'step',
#  '踪': 'remains',
#  '蹴': 'kick',
#  '躍': 'leap',
#  '身': 'body',
#  '車': 'car',
#  '軌': 'rut',
#  '軍': 'army',
#  '軒': 'flats',
#  '軟': 'soft',
#  '転': 'revolve',
#  '軸': 'axis',
#  '軽': 'light',
#  '較': 'contrast',
#  '載': 'ride',
#  '輝': 'radiance',
#  '輩': 'comrade',
#  '輪': 'wheel',
#  '輸': 'transport',
#  '轄': 'control',
#  '辛': 'spicy',
#  '辞': 'resign',
#  '辣': 'bitter',
#  '辱': 'embarrass',
#  '農': 'farming',
#  '辺': 'environs',
#  '込': 'crowded',
#  '迅': 'swift',
#  '迎': 'welcome',
#  '近': 'near',
#  '返': 'return',
#  '迫': 'urge',
#  '迭': 'transfer',
#  '述': 'mention',
#  '迷': 'astray',
#  '追': 'follow',
#  '退': 'retreat',
#  '送': 'send',
#  '逃': 'escape',
#  '逆': 'inverted',
#  '透': 'transparent',
#  '逐': 'pursue',
#  '逓': 'relay',
#  '途': 'route',
#  '通': 'pass through',
#  '逝': 'departed',
#  '速': 'fast',
#  '造': 'create',
#  '連': 'take along',
#  '逮': 'apprehend',
#  '週': 'week',
#  '進': 'advance',
#  '逸': 'deviate',
#  '遂': 'consummate',
#  '遅': 'slow',
#  '遇': 'interview',
#  '遊': 'play',
#  '運': 'carry',
#  '遍': 'everywhere',
#  '過': 'go beyond',
#  '道': 'road',
#  '達': 'attain',
#  '違': 'differ',
#  '遜': 'humble',
#  '遠': 'far',
#  '遡': 'go upstream',
#  '遣': 'dispatch',
#  '適': 'suitable',
#  '遭': 'encounter',
#  '遮': 'intercept',
#  '遵': 'abide by',
#  '遷': 'transition',
#  '選': 'choose',
#  '遺': 'bequeath',
#  '避': 'evade',
#  '還': 'send back',
#  '那': 'what',
#  '邦': 'home country',
#  '邪': 'wicked',
#  '邸': 'residence',
#  '郊': 'outskirts',
#  '郎': 'son',
#  '郡': 'county',
#  '部': 'part',
#  '郭': 'enclosure',
#  '郵': 'mail',
#  '郷': 'home town',
#  '都': 'metropolis',
#  '酌': 'bartending',
#  '配': 'distribute',
#  '酎': 'sake',
#  '酒': 'alcoholic drink',
#  '酔': 'drunk',
#  '酢': 'vinegar',
#  '酪': 'dairy products',
#  '酬': 'repay',
#  '酵': 'fermentation',
#  '酷': 'cruel',
#  '酸': 'acid',
#  '醒': 'be disillusioned',
#  '醜': 'ugly',
#  '醸': 'brew',
#  '采': 'form',
#  '釈': 'explanation',
#  '里': 'village',
#  '重': 'heavy',
#  '野': 'field',
#  '量': 'quantity',
#  '金': 'gold',
#  '釜': 'kettle',
#  '針': 'needle',
#  '釣': 'angling',
#  '鈍': 'dull',
#  '鈴': 'small bell',
#  '鉄': 'iron',
#  '鉛': 'lead',
#  '鉢': 'bowl',
#  '鉱': 'mineral',
#  '銀': 'silver',
#  '銃': 'gun',
#  '銅': 'copper',
#  '銘': 'inscription',
#  '銭': 'coin',
#  '鋭': 'pointed',
#  '鋳': 'casting',
#  '鋼': 'steel',
#  '錠': 'lock',
#  '錦': 'brocade',
#  '錬': 'tempering',
#  '錮': 'tie up',
#  '錯': 'confused',
#  '録': 'record',
#  '鍋': 'pot',
#  '鍛': 'forge',
#  '鍵': 'key',
#  '鎌': 'sickle',
#  '鎖': 'chain',
#  '鎮': 'tranquilize',
#  '鏡': 'mirror',
#  '鐘': 'bell',
#  '鑑': 'specimen',
#  '長': 'long',
#  '門': 'gates',
#  '閉': 'closed',
#  '開': 'open',
#  '閑': 'leisure',
#  '間': 'interval',
#  '関': 'related',
#  '閣': 'tall',
#  '閥': 'clique',
#  '閲': 'review',
#  '闇': 'darkness',
#  '闘': 'fight',
#  '阜': 'mound',
#  '阪': 'heights',
#  '防': 'prevent',
#  '阻': 'thwart',
#  '附': 'affixed',
#  '降': 'descend',
#  '限': 'limit',
#  '陛': 'highness',
#  '院': 'institution',
#  '陣': 'camp',
#  '除': 'exclude',
#  '陥': 'collapse',
#  '陪': 'obeisance',
#  '陰': 'shade',
#  '陳': 'exhibit',
#  '陵': 'mausoleum',
#  '陶': 'pottery',
#  '陸': 'land',
#  '険': 'precipitous',
#  '陽': 'sunshine',
#  '隅': 'corner',
#  '隆': 'hump',
#  '隊': 'group',
#  '階': 'floor of a building',
#  '随': 'follow',
#  '隔': 'isolate',
#  '隙': 'fissure',
#  '際': 'occasion',
#  '障': 'hurt',
#  '隠': 'conceal',
#  '隣': 'neighboring',
#  '隷': 'slave',
#  '隻': 'vessels',
#  '雄': 'male',
#  '雅': 'gracious',
#  '集': 'collect',
#  '雇': 'employ',
#  '雌': 'feminine',
#  '雑': 'miscellaneous',
#  '離': 'detach',
#  '難': 'difficult',
#  '雨': 'rain',
#  '雪': 'snow',
#  '雰': 'atmosphere',
#  '雲': 'cloud',
#  '零': 'zero',
#  '雷': 'thunder',
#  '電': 'electricity',
#  '需': 'demand',
#  '震': 'quake',
#  '霊': 'spirits',
#  '霜': 'frost',
#  '霧': 'fog',
#  '露': 'dew',
#  '青': 'blue',
#  '静': 'quiet',
#  '非': 'negative',
#  '面': 'face',
#  '革': 'leather',
#  '靴': 'shoes',
#  '韓': 'Korea',
#  '音': 'sound',
#  '韻': 'rhyme',
#  '響': 'echo',
#  '頂': 'place on the head',
#  '頃': 'times',
#  '項': 'paragraph',
#  '順': 'obey',
#  '須': 'by all means',
#  '預': 'deposit',
#  '頑': 'stubborn',
#  '頒': 'partition',
#  '頓': 'suddenly',
#  '領': 'territory',
#  '頭': 'head',
#  '頰': 'cheek',
#  '頻': 'repeatedly',
#  '頼': 'trust',
#  '題': 'topic',
#  '額': 'amount',
#  '顎': 'jaw',
#  '顔': 'face',
#  '顕': 'appear',
#  '願': 'request',
#  '類': 'sort',
#  '顧': 'look back',
#  '風': 'wind',
#  '飛': 'fly',
#  '食': 'eat, meal',
#  '飢': 'hungry',
#  '飯': 'meal',
#  '飲': 'drink',
#  '飼': 'domesticate',
#  '飽': 'sated',
#  '飾': 'decorate',
#  '餅': 'mochi rice cake',
#  '養': 'foster',
#  '餌': 'bait',
#  '餓': 'starve',
#  '館': 'public building',
#  '首': 'neck',
#  '香': 'incense',
#  '馬': 'horse',
#  '駄': 'burdensome',
#  '駅': 'station',
#  '駆': 'drive',
#  '駐': 'stop-over',
#  '駒': 'horse',
#  '騎': 'equestrian',
#  '騒': 'boisterous',
#  '験': 'test',
#  '騰': 'inflation',
#  '驚': 'wonder',
#  '骨': 'bone',
#  '骸': 'dead remains',
#  '髄': 'marrow',
#  '高': 'tall, expensive',
#  '髪': 'hair of the head',
#  '鬱': 'gloom',
#  '鬼': 'ghost',
#  '魂': 'soul',
#  '魅': 'fascination',
#  '魔': 'witch',
#  '魚': 'fish',
#  '鮮': 'fresh',
#  '鯨': 'whale',
#  '鳥': 'bird',
#  '鳴': 'chirp',
#  '鶏': 'chicken',
#  '鶴': 'crane',
#  '鹿': 'deer',
#  '麓': 'foot of a mountain',
#  '麗': 'lovely',
#  '麦': 'wheat',
#  '麺': 'noodles',
#  '麻': 'hemp',
#  '黄': 'yellow',
#  '黒': 'black',
#  '黙': 'silence',
#  '鼓': 'drum',
#  '鼻': 'nose',
#  '齢': 'age',
#  '𠮟': 'scold'}

# %% [markdown]
# ### Extract s7_nodes_radical_meaning.csv

# %%
def get_data_radical_from_csv(filepath: str):
    data = dict()
    with open(filepath) as file:
        next(file)
        rows = csv.reader(file, delimiter=",")
        for row in rows:
            radical,meaning,_ = row
            data[radical] = meaning
    return data

# %%
data_radical = get_data_radical_from_csv(filepath="dataset/s7_nodes_radical_meaning.csv")
print("len(data_radical) = ", len(data_radical))
pp(data_radical)
# Out:
# len(data_radical) =  255
# {'.阝': 'right village',
#  'マ': 'kana ma',
#  'ユ': 'kana yu',
#  '世': 'generation',
#  '个': 'human roof (top)',
#  '丶': 'dot',
#  '丷': 'eight-head',
#  '丿': 'kana no',
#  '乃': 'from',
#  '久': 'long time',
#  '乙': 'fish hook',
#  '九': 'nine',
#  '也': 'to be',
#  '亅': 'feathered stick',
#  '二': 'two',
#  '五': 'five',
#  '井': 'well',
#  '亠': 'lid',
#  '亡': 'deceased',
#  '人': 'person',
#  '亻': 'person',
#  '儿': 'human legs',
#  '元': 'beginning',
#  '免': 'excuse',
#  '入': 'enter',
#  '八': 'eight',
#  '冂': 'upside down box',
#  '冊': 'tome',
#  '冖': 'crown shaped wa',
#  '冫': 'ice',
#  '几': 'table',
#  '凵': 'open box',
#  '刀': 'sword',
#  '刂': 'sword',
#  '力': 'strong',
#  '勹': 'wrapping',
#  '勿': 'not',
#  '匕': 'spoon',
#  '匚': 'sideways box',
#  '匸': 'hiding',
#  '十': 'cross',
#  '卜': 'divining rod',
#  '卩': 'seal',
#  '厂': 'cliff',
#  '厶': 'myself',
#  '又': 'again',
#  '及': 'reach out',
#  '口': 'mouth',
#  '品': 'goods',
#  '啇': 'antique',
#  '囗': 'box',
#  '土': 'earth',
#  '士': 'samurai',
#  '夂': 'winter',
#  '夊': 'go slowly',
#  '夕': 'evening',
#  '大': 'big',
#  '奄': 'cover',
#  '女': 'woman',
#  '子': 'child',
#  '宀': 'crown',
#  '寸': 'inch',
#  '小': 'little',
#  '尚': 'small (top)',
#  '尢': 'crooked leg',
#  '尤': 'reasonable',
#  '尸': 'flag',
#  '屮': 'old grass',
#  '屯': 'barracks',
#  '山': 'mountain',
#  '岡': 'mount',
#  '巛': 'crooked river',
#  '工': 'craft',
#  '巨': 'gigantic',
#  '己': 'snake',
#  '巴': 'comma-design',
#  '巾': 'cloth',
#  '干': 'dry',
#  '幺': 'short thread',
#  '广': 'dotted cliff',
#  '廴': 'long stride',
#  '廾': 'twenty legs',
#  '弋': 'ceremony',
#  '弓': 'bow',
#  '彐': 'pig head',
#  '彑': 'pig head',
#  '彡': 'short hair',
#  '彳': 'going man',
#  '心': 'heart',
#  '忄': 'heart',
#  '戈': 'tasseled spear',
#  '戸': 'door',
#  '手': 'hand',
#  '扌': 'hand',
#  '支': 'branch',
#  '攴': 'folding chair',
#  '文': 'sentence',
#  '斗': 'dipper',
#  '斤': 'axe',
#  '方': 'direction',
#  '无': 'crooked heaven',
#  '日': 'sun',
#  '曰': 'flat sun',
#  '月': 'moon',
#  '木': 'tree',
#  '欠': 'yawn',
#  '止': 'stop',
#  '歹': 'death',
#  '殳': 'windy again',
#  '毋': 'mother',
#  '比': 'race',
#  '毛': 'wool',
#  '氏': 'clan',
#  '气': 'spirit',
#  '水': 'water',
#  '氵': 'water',
#  '火': 'fire',
#  '灬': 'fire',
#  '無': 'nothingness',
#  '爪': 'claw',
#  '父': 'father',
#  '爻': 'double x',
#  '爿': 'left-side kata',
#  '片': 'one-sided leaf sheet',
#  '牙': 'fang',
#  '牛': 'cow',
#  '犬': 'dog',
#  '犭': 'dog',
#  '玄': 'mysterious',
#  '玉': 'jewel',
#  '瓜': 'melon',
#  '瓦': 'tile',
#  '甘': 'sweet',
#  '生': 'life',
#  '用': 'use',
#  '田': 'rice field',
#  '疋': 'head count',
#  '疒': 'sick',
#  '癶': 'dotted tent',
#  '白': 'white',
#  '皮': 'skin',
#  '皿': 'dish',
#  '目': 'eye',
#  '矛': 'halberd',
#  '矢': 'arrow',
#  '石': 'stone',
#  '示': 'show',
#  '礻': 'show',
#  '禸': 'mu in box',
#  '禾': 'two branch tree',
#  '穴': 'hole',
#  '立': 'stand',
#  '竜': 'dragon',
#  '竹': 'bamboo',
#  '米': 'rice',
#  '糸': 'thread',
#  '缶': 'can',
#  '网': 'net crown',
#  '羊': 'sheep',
#  '羽': 'feathers',
#  '老': 'old man',
#  '而': 'rake',
#  '耒': 'three branch tree',
#  '耳': 'ear',
#  '聿': 'writing brush',
#  '肉': 'meat',
#  '臣': 'retainer',
#  '自': 'oneself',
#  '至': 'climax',
#  '臼': 'mortar',
#  '舌': 'tongue',
#  '舛': 'dancing',
#  '舟': 'ship',
#  '艮': 'good',
#  '色': 'color',
#  '艸': 'grass',
#  '艹': 'grass',
#  '虍': 'tiger crown',
#  '虫': 'bug',
#  '血': 'blood',
#  '行': 'journey',
#  '衣': 'clothing',
#  '衤': 'clothing',
#  '襾': 'west',
#  '見': 'see',
#  '角': 'corner',
#  '言': 'say',
#  '谷': 'valley',
#  '豆': 'bean',
#  '豕': 'pig',
#  '豸': 'badger',
#  '貝': 'shellfish',
#  '赤': 'red',
#  '走': 'run',
#  '足': 'foot',
#  '身': 'body',
#  '車': 'car',
#  '辛': 'spicy hot',
#  '辰': 'sign of the dragon',
#  '辵': 'road',
#  '辶': 'road',
#  '邑': 'right village',
#  '酉': 'sake',
#  '釆': 'topped rice',
#  '里': 'village',
#  '金': 'metal',
#  '長': 'long',
#  '門': 'gate',
#  '阜': 'left village',
#  '阝.': 'left village',
#  '隶': 'slave',
#  '隹': 'old bird',
#  '雨': 'rain',
#  '青': 'blue',
#  '非': 'injustice',
#  '面': 'face',
#  '革': 'leather pelt',
#  '韋': 'tanned leather',
#  '韭': 'leek',
#  '音': 'sound',
#  '頁': 'page',
#  '風': 'wind',
#  '飛': 'flying',
#  '食': 'food',
#  '首': 'neck',
#  '香': 'smell',
#  '馬': 'horse',
#  '骨': 'bone',
#  '高': 'high',
#  '髟': 'long hair',
#  '鬥': 'broken gate',
#  '鬯': 'fragrant herbs',
#  '鬲': 'tripod',
#  '鬼': 'devil',
#  '魚': 'fish',
#  '鳥': 'bird',
#  '鹵': 'salt',
#  '鹿': 'deer',
#  '麥': 'wheat',
#  '麻': 'hemp',
#  '黄': 'yellow',
#  '黍': 'millet',
#  '黒': 'black',
#  '黹': 'sewing',
#  '黽': 'green frog',
#  '鼎': 'three legged kettle',
#  '鼓': 'drum beat',
#  '鼠': 'mouse',
#  '鼻': 'nose',
#  '齊': 'equal',
#  '齒': 'tooth',
#  '龍': 'dragon',
#  '龜': 'turtle',
#  '龠': 'flute',
#  '｜': 'stick'}

# %% [markdown]
# ### Extract s7_edges_kanji_radical.csv

# %%
def get_kanji_radical_edge(filepath: str):
    data = dict()
    with open(filepath) as file:
        next(file)
        rows = csv.reader(file, delimiter=",")
        for row in rows:
            kanji,radical_list = row
            data[kanji] = radical_list.split(':')
    return data

# %%
data_edges = get_kanji_radical_edge(filepath="dataset/s7_edges_kanji_radical.csv")
print("len(data_edges) = ", len(data_edges))
pp(data_edges)
# Out:
# len(data_edges) =  6215
# {'丁': ['亅'],
#  '七': ['丿', '乙', '匕'],
#  '万': ['｜', '丿'],
#  '丈': ['丶', '丿'],
#  '三': ['二'],
#  '上': ['卜'],
#  '下': ['｜', '卜'],
#  '不': ['｜', '丶', '丿'],
#  '与': ['勹', '卜'],
#  '丐': ['弓', '止', '疋'],
#  '丑': ['｜', '丿'],
#  '且': ['目'],
#  '丕': ['｜', '丶', '丿'],
#  '世': ['｜'],
#  '丗': ['｜', '十', '山'],
#  '丘': ['斤'],
#  '丙': ['人', '冂'],
#  '丞': ['丿', '亅', 'マ'],
#  '両': ['｜', '冂', '山'],
#  '並': ['｜', '二', '丷'],
#  '个': ['｜'],
#  '中': ['｜', '口'],
#  '丱': ['｜', '丿'],
#  '串': ['｜', '口'],
#  '丸': ['丶', '九'],
#  '丹': ['丶', '丿', '亅'],
#  '主': ['丶', '玉'],
#  '丼': ['｜', '丶', '丿', '二', '廾', '井'],
#  '乂': ['丿'],
#  '乃': ['｜', '丿'],
#  '久': ['丿', '入'],
#  '之': ['丶', '乙', '亠', '廴'],
#  '乍': ['｜', '丿'],
#  '乎': ['丿', '亅', '丷'],
#  '乏': ['丶', '丿', '乙', '亠'],
#  '乕': ['｜', '丿', '厂', '巾'],
#  '乖': ['丿', '匕', '十', '爿'],
#  '乗': ['｜', '丿', '八', '禾'],
#  '乘': ['丿', '八', '匕', '十', '爿'],
#  '乞': ['丿', '乙'],
#  '也': ['｜', '乙', '匕'],
#  '乢': ['乙', '山'],
#  '乱': ['乙', '口', '舌'],
#  '乳': ['乙', '子', '爪'],
#  '乾': ['乙', '十', '日'],
#  '亀': ['乙', '勹', '田', '龜'],
#  '亂': ['乙', '冂', '厶', '爪'],
#  '了': ['亅'],
#  '予': ['亅', 'マ'],
#  '争': ['亅', '勹', '彐'],
#  '亊': ['亅', '彐', '丷'],
#  '事': ['亅', '口', '彐'],
#  '于': ['亅', '二'],
#  '云': ['二', '厶'],
#  '互': ['彐', '彑'],
#  '五': ['二'],
#  '井': ['｜', '丿', '二'],
#  '亘': ['二', '日'],
#  '亙': ['丶', '丿', '二'],
#  '些': ['二', '匕', '止'],
#  '亜': ['｜', '口'],
#  '亞': ['二'],
#  '亟': ['二', '又', '口'],
#  '亡': ['亠'],
#  '亢': ['亠', '几'],
#  '交': ['亠', '父'],
#  '亥': ['亠', '人'],
#  '亦': ['丿', '亅', '亠', '八'],
#  '亨': ['亠', '口'],
#  '享': ['亠', '口', '子'],
#  '京': ['亠', '口', '小'],
#  '亭': ['亅', '亠', '冖', '口'],
#  '亮': ['亠', '儿', '冖', '口'],
#  '亰': ['亠', '小', '日'],
#  '亳': ['丿', '乙', '亠', '冖', '口'],
#  '亶': ['亠', '口', '囗', '日'],
#  '什': ['十', '亻'],
#  '仁': ['二', '亻'],
#  '仂': ['力', '亻'],
#  '仄': ['人', '厂'],
#  '仆': ['卜', '亻'],
#  '仇': ['亻', '九'],
#  '今': ['个'],
#  '介': ['八', '个'],
#  '仍': ['丿', '亻', '乃'],
#  '从': ['人'],
#  '仏': ['厶', '亻'],
#  '仔': ['子', '亻'],
#  '仕': ['士', '亻'],
#  '他': ['亻', '也'],
#  '仗': ['丿', '亻'],
#  '付': ['寸', '亻'],
#  '仙': ['山', '亻'],
#  '仞': ['丶', '刀', '亻'],
#  '仟': ['丿', '十', '亻'],
#  '代': ['弋', '亻'],
#  '令': ['卩', '个'],
#  '以': ['｜', '丶', '人'],
#  '仭': ['丶', '刀', '亻'],
#  '仮': ['厂', '又', '亻'],
#  '仰': ['卩', '亻'],
#  '仲': ['｜', '口', '亻'],
#  '件': ['牛', '亻'],
#  '价': ['儿', '个', '亻'],
#  '任': ['丿', '士', '玉', '亻'],
#  '企': ['止', '个'],
#  '伉': ['亠', '几', '亻'],
#  '伊': ['｜', '彐', '亻'],
#  '伍': ['亻'],
#  '伎': ['十', '又', '支', '亻'],
#  '伏': ['犬', '亻'],
#  '伐': ['戈', '亻'],
#  '休': ['木', '亻'],
#  '会': ['二', '厶', '个'],
#  '伜': ['十', '亻', '九'],
#  '伝': ['二', '厶', '亻'],
#  '伯': ['白', '亻'],
#  '估': ['十', '口', '亻'],
#  '伴': ['｜', '二', '十', '亻', '丷'],
#  '伶': ['二', '士', '小', '彐', '水'],
#  '伸': ['｜', '日', '田', '亻'],
#  '伺': ['亅', '口', '亻'],
#  '似': ['丶', '人', '亻'],
#  '伽': ['力', '口', '亻'],
#  '佃': ['田', '亻'],
#  '但': ['日', '亻'],
#  '佇': ['亅', '宀', '亻'],
#  '位': ['立', '亻'],
#  '低': ['氏', '亻'],
#  '住': ['丶', '玉', '亻'],
#  '佐': ['丿', '工', '亻'],
#  '佑': ['丿', '口', '亻'],
#  '体': ['木', '亻'],
#  '何': ['亅', '口', '亻'],
#  '佗': ['匕', '宀', '亻'],
#  '余': ['亅', '二', '八', '示', '个'],
#  '佚': ['丿', '二', '人', '大', '亻'],
#  '佛': ['｜', '丿', '弓', '亻'],
#  '作': ['｜', '丿', '亻'],
#  '佝': ['勹', '口', '亻'],
#  '佞': ['二', '女', '亻'],
#  '佩': ['几', '巾', '亻'],
#  '佯': ['玉', '羊', '亻', '丷'],
#  '佰': ['白', '亻'],
#  '佳': ['土', '亻'],
#  '併': ['｜', '丿', '二', '廾', '亻', '丷'],
#  '佶': ['口', '士', '亻'],
#  '佻': ['儿', '冫', '亻'],
#  '佼': ['亠', '父', '亻'],
#  '使': ['丿', '口', '亻'],
#  '侃': ['口', '巛', '亻'],
#  '來': ['｜', '人', '八', '十', '木'],
#  '侈': ['夕', '亻'],
#  '例': ['歹', '亻', '刂'],
#  '侍': ['土', '寸', '亻'],
#  '侏': ['丿', '八', '木', '牛', '亻'],
#  '侑': ['丿', '月', '亻'],
#  '侖': ['冂', '廾', '个', '冊'],
#  '侘': ['丿', '乙', '宀', '亻'],
#  '供': ['｜', '二', '八', '亻'],
#  '依': ['亠', '衣', '亻'],
#  '侠': ['二', '亠', '人', '大', '亻', '丷'],
#  '価': ['襾', '亻'],
#  '侫': ['女', '亻', '亡'],
#  '侭': ['尸', '亻'],
#  '侮': ['毋', '亻'],
#  '侯': ['矢', '亻'],
#  '侵': ['冖', '又', '彐', '亻'],
#  '侶': ['｜', '口', '亻'],
#  '便': ['｜', '丿', '日', '田', '亻'],
#  '係': ['丿', '糸', '亻'],
#  '促': ['口', '足', '亻'],
#  '俄': ['亅', '戈', '手', '亻'],
#  '俊': ['儿', '厶', '夂', '亻'],
#  '俎': ['人', '目'],
#  '俐': ['禾', '亻', '刂'],
#  '俑': ['用', '亻', 'マ'],
#  '俔': ['見', '亻'],
#  '俗': ['八', '口', '谷', '个', '亻'],
#  '俘': ['子', '爪', '亻'],
#  '俚': ['里', '亻'],
#  '俛': ['儿', '亻', '免'],
#  '保': ['口', '木', '亻'],
#  '俟': ['厶', '矢', '亻'],
#  '信': ['言', '亻'],
#  '俣': ['二', '口', '大', '亻'],
#  '俤': ['｜', '丿', '弓', '亻', '丷'],
#  '俥': ['車', '亻'],
#  '修': ['｜', '彡', '攴', '亻'],
#  '俯': ['寸', '广', '亻'],
#  '俳': ['非', '亻'],
#  '俵': ['士', '衣', '亻'],
#  '俶': ['卜', '又', '小', '亻'],
#  '俸': ['｜', '丿', '二', '人', '大', '亻'],
#  '俺': ['乙', '大', '亻', '奄'],
#  '俾': ['十', '田', '亻'],
#  '倅': ['亠', '人', '十', '亻'],
#  '倆': ['｜', '人', '冂', '亻'],
#  '倉': ['丿', '口', '个'],
#  '個': ['十', '口', '囗', '亻'],
#  '倍': ['口', '立', '亻'],
#  '倏': ['夂', '攴', '犬', '亻'],
#  '們': ['門', '亻'],
#  '倒': ['厶', '土', '至', '亻', '刂'],
#  '倔': ['｜', '尸', '山', '亻'],
#  '倖': ['亠', '十', '立', '辛', '亻'],
#  '候': ['｜', '矢', '亻'],
#  '倚': ['亅', '口', '大', '亻'],
#  '借': ['日', '亻'],
#  '倡': ['日', '亻'],
#  '倣': ['攴', '方', '亻'],
#  '値': ['｜', '十', '目', '亻'],
#  '倥': ['儿', '宀', '工', '穴', '亻'],
#  '倦': ['大', '己', '亻'],
#  '倨': ['十', '口', '尸', '亻'],
#  '倩': ['二', '亠', '土', '月', '青', '亻'],
#  '倪': ['儿', '臼', '亻'],
#  '倫': ['｜', '亅', '个', '亻', '冊'],
#  '倬': ['十', '卜', '日', '曰', '亻'],
#  '倭': ['女', '禾', '亻'],
#  '倶': ['八', '目', '亻'],
#  '倹': ['人', '口', '个', '亻'],
#  '偃': ['匚', '女', '日', '亻'],
#  '假': ['｜', '又', '亻'],
#  '偈': ['勹', '匕', '日', '亻'],
#  '偉': ['口', '韋', '亻'],
#  '偏': ['｜', '冂', '戸', '亻', '冊'],
#  '偐': ['亠', '厂', '彡', '立', '亻', '丷'],
#  '偕': ['比', '白', '亻'],
#  '偖': ['日', '老', '亻'],
#  '做': ['十', '口', '攴', '亻'],
#  '停': ['亅', '亠', '冖', '口', '亻'],
#  '健': ['廴', '聿', '亻'],
#  '偬': ['丶', '心', '亻', '勿'],
#  '偲': ['心', '田', '亻'],
#  '側': ['貝', '亻', '刂'],
#  '偵': ['卜', '貝', '亻'],
#  '偶': ['冂', '厶', '田', '禸', '亻'],
#  '偸': ['月', '个', '亻', '刂'],
#  '偽': ['丶', '亻', '灬'],
#  '傀': ['儿', '匕', '厶', '田', '鬼', '亻'],
#  '傅': ['丶', '寸', '田', '亻'],
#  '傍': ['亠', '冖', '方', '立', '亻', '丷'],
#  '傑': ['夕', '木', '舛', '亻'],
#  '傘': ['人', '十', '个'],
#  '備': ['厂', '用', '亻', '艹'],
#  '傚': ['亠', '攴', '父', '亻'],
#  '催': ['山', '隹', '亻'],
#  '傭': ['广', '彐', '用', '亻'],
#  '傲': ['土', '攴', '方', '亻'],
#  '傳': ['厶', '寸', '田', '亻'],
#  '傴': ['匚', '口', '亻', '品'],
#  '債': ['亠', '土', '貝', '亻'],
#  '傷': ['丿', '日', '亻', '勿'],
#  '傾': ['匕', '貝', '頁', '亻'],
#  '僂': ['十', '女', '亻'],
#  '僅': ['口', '土', '亻', '艹'],
#  '僉': ['人', '口', '个'],
#  '僊': ['大', '己', '襾', '亻'],
#  '働': ['｜', '力', '日', '亻'],
#  '像': ['勹', '口', '豕', '亻'],
#  '僑': ['丿', '冂', '口', '大', '亻'],
#  '僕': ['玉', '羊', '亻', '丷'],
#  '僖': ['十', '口', '士', '豆', '亻', '丷'],
#  '僚': ['小', '日', '亻'],
#  '僞': ['爪', '亻', '灬'],
#  '僣': ['人', '土', '日', '亻'],
#  '僥': ['儿', '土', '亻'],
#  '僧': ['日', '田', '亻', '丷'],
#  '僭': ['亠', '无', '日', '亻'],
#  '僮': ['立', '里', '亻'],
#  '僵': ['二', '田', '亻'],
#  '價': ['襾', '貝', '亻'],
#  '僻': ['十', '口', '尸', '立', '辛', '亻'],
#  '儀': ['亅', '戈', '手', '玉', '羊', '亻', '丷'],
#  '儁': ['隹', '亻'],
#  '儂': ['｜', '辰', '亻'],
#  '億': ['心', '日', '立', '音', '亻'],
#  '儉': ['人', '口', '个', '亻'],
#  '儒': ['而', '雨', '亻'],
#  '儔': ['口', '士', '寸', '工', '亻'],
#  '儕': ['亠', '刀', '齊', '亻'],
#  '儖': ['二', '皿', '臣', '亻'],
#  '儘': ['彐', '皿', '亻', '灬'],
#  '儚': ['冖', '夕', '网', '亻', '艹'],
#  '償': ['冖', '口', '貝', '亻', '尚'],
#  '儡': ['田', '亻'],
#  '優': ['冖', '夂', '心', '白', '亻'],
#  '儲': ['日', '老', '言', '亻'],
#  '儷': ['冂', '广', '比', '鹿', '亻'],
#  '儺': ['隹', '亻', '艹'],
#  '儻': ['冖', '口', '里', '黒', '亻', '尚', '灬'],
#  '儼': ['厂', '口', '攴', '耳', '亻'],
#  '兀': ['儿'],
#  '允': ['儿', '厶'],
#  '元': ['二', '儿'],
#  '兄': ['儿', '口'],
#  '充': ['亠', '儿', '厶'],
#  '兆': ['儿', '冫'],
#  '兇': ['丶', '丿', '儿', '凵'],
#  '先': ['丿', '儿', '土'],
#  '光': ['儿', '尚'],
#  '克': ['儿', '十', '口'],
#  '兌': ['儿', '口', '丷'],
#  '免': ['｜', '儿', '勹', '口'],
#  '兎': ['｜', '丶', '丿', '儿', '口'],
#  '児': ['｜', '儿', '日'],
#  '兒': ['儿', '臼'],
#  '兔': ['丶', '儿', '免'],
#  '党': ['儿', '冖', '口', '尚'],
#  '兜': ['儿', '白'],
#  '兢': ['儿', '十', '口'],
#  '全': ['八', '玉'],
#  '兩': ['｜', '入', '冂'],
#  '兪': ['入', '月', '个'],
#  '公': ['八', '厶'],
#  '六': ['亠', '八'],
#  '兮': ['八', '弓'],
#  '共': ['八'],
#  '兵': ['八', '斤'],
#  '其': ['八', '甘'],
#  '具': ['八', '目'],
#  '典': ['｜', '八', '日'],
#  '兼': ['｜', '八', '彐', '丷'],
#  '冀': ['二', '八', '匕', '爿', '田'],
#  '内': ['人', '冂'],
#  '円': ['亠', '冂'],
#  '冉': ['｜', '冂'],
#  '冊': ['｜', '亅', '冂', '廾'],
#  '册': ['冂'],
#  '再': ['｜', '冂', '玉'],
#  '冏': ['儿', '冂', '口'],
#  '冐': ['二', '冂', '月'],
#  '冑': ['二', '冂', '月', '田'],
#  '冒': ['日', '目'],
#  '冓': ['｜', '冂'],
#  '冕': ['二', '儿', '冂', '月', '免'],
#  '冗': ['冖', '几'],
#  '写': ['冖', '勹'],
#  '冠': ['儿', '冖', '寸'],
#  '冢': ['冖', '豕'],
#  '冤': ['丶', '儿', '冖', '免'],
#  '冥': ['亠', '八', '冖', '日'],
#  '冦': ['二', '儿', '冖', '卜', '又'],
#  '冨': ['冖', '口', '田'],
#  '冩': ['冖', '勹', '臼', '灬'],
#  '冪': ['冖', '大', '巾', '日', '艹'],
#  '冬': ['丶', '夂', '攴'],
#  '冰': ['冫', '水'],
#  '冱': ['二', '冫'],
#  '冲': ['｜', '冫', '口'],
#  '决': ['丿', '人', '冫', '大', 'ユ'],
#  '冴': ['冫', '牙'],
#  '况': ['儿', '冫', '口'],
#  '冶': ['冫', '厶', '口'],
#  '冷': ['冫', '卩', '个'],
#  '冽': ['冫', '歹', '刂'],
#  '凄': ['冫', '十', '女', '彐'],
#  '凅': ['冫', '十', '口', '囗'],
#  '准': ['冫', '隹'],
#  '凉': ['亠', '冫', '口', '小'],
#  '凋': ['冂', '冫', '口', '土'],
#  '凌': ['儿', '冫', '土', '夂'],
#  '凍': ['｜', '冫', '日', '木', '田'],
#  '凖': ['冫', '十', '隹'],
#  '凛': ['亠', '冫', '口', '囗', '示'],
#  '凜': ['亠', '冫', '口', '禾'],
#  '凝': ['冫', '匕', '疋', '矢', 'マ'],
#  '凡': ['丶', '几'],
#  '処': ['几', '夂', '攴'],
#  '凧': ['｜', '冂', '几', '巾'],
#  '凩': ['几', '木'],
#  '凪': ['几', '止'],
#  '凭': ['丿', '几', '士', '亻'],
#  '凰': ['几', '玉', '白'],
#  '凱': ['几', '口', '山', '豆', '丷'],
#  '凶': ['丶', '丿', '凵'],
#  '凸': ['｜', '冂', '凵'],
#  '凹': ['凵'],
#  '出': ['｜', '山'],
#  '函': ['凵', '水'],
#  '凾': ['凵', '又', '口'],
#  '刃': ['丶', '刀'],
#  '刄': ['刀'],
#  '分': ['八', '刀'],
#  '切': ['刀', '匕'],
#  '刈': ['刂'],
#  '刊': ['干', '刂'],
#  '刋': ['丿', '十', '刂'],
#  '刎': ['勹', '刂', '勿'],
#  '刑': ['丿', '廾', '刂'],
#  '刔': ['人', '大', '刂', 'ユ'],
#  '列': ['歹', '刂'],
#  '初': ['刀', '衤'],
#  '判': ['｜', '二', '十', '丷', '刂'],
#  '別': ['力', '口', '刂'],
#  '刧': ['刀', '厶', '土'],
#  '利': ['禾', '刂'],
#  '刪': ['冂', '刂', '冊'],
#  '刮': ['口', '舌', '刂'],
#  '到': ['厶', '土', '至', '刂'],
#  '刳': ['二', '勹', '大', '刂'],
#  '制': ['丿', '二', '巾', '牛', '刂'],
#  '刷': ['尸', '巾', '刂'],
#  '券': ['二', '人', '刀', '大', '大', '丷'],
#  '刹': ['木', '刂'],
#  '刺': ['｜', '亅', '八', '冂', '巾', '木', '刂'],
#  '刻': ['亠', '刂'],
#  '剃': ['｜', '丿', '弓', '丷', '刂'],
#  '剄': ['巛', '工', '刂'],
#  '則': ['貝', '刂'],
#  '削': ['月', '刂', '尚'],
#  '剋': ['儿', '十', '口', '刂'],
#  '剌': ['｜', '八', '口', '木', '刂'],
#  '前': ['月', '丷', '刂'],
#  '剏': ['｜', '丿', '二', '刀', '廾', '丷'],
#  '剔': ['日', '刂', '勿'],
#  '剖': ['口', '立', '刂'],
#  '剛': ['冂', '山', '丷', '刂', '岡'],
#  '剞': ['亅', '口', '大', '刂'],
#  '剣': ['人', '口', '个', '刂'],
#  '剤': ['｜', '丿', '廾', '文', '齊', '刂'],
#  '剥': ['彐', '水', '刂'],
#  '剩': ['｜', '匕', '爿', '刂'],
#  '剪': ['刀', '月', '丷', '刂'],
#  '副': ['口', '田', '刂'],
#  '剰': ['｜', '丿', '刂'],
#  '剱': ['丶', '人', '刀', '口', '个'],
#  '割': ['亠', '口', '土', '宀', '刂'],
#  '剳': ['口', '个', '刂', '艹'],
#  '剴': ['口', '山', '豆', '丷', '刂'],
#  '創': ['口', '个', '刂'],
#  '剽': ['示', '襾', '刂'],
#  '剿': ['木', '田', '刂', '尚'],
#  '劃': ['田', '聿', '刂'],
#  '劇': ['匕', '卜', '厂', '虍', '豕', '刂'],
#  '劈': ['刀', '十', '口', '尸', '立', '辛'],
#  '劉': ['厶', '金', '刂'],
#  '劍': ['人', '口', '个', '刂'],
#  '劑': ['亠', '齊', '刂'],
#  '劒': ['丶', '人', '刀', '口', '个'],
#  '劔': ['丶', '人', '刀', '口', '个'],
#  '功': ['力', '工'],
#  '加': ['力', '口'],
#  '劣': ['丿', '力', '小'],
#  '助': ['力', '目'],
#  '努': ['力', '又', '女'],
#  '劫': ['力', '厶', '土'],
#  '劬': ['力', '勹', '口'],
#  '劭': ['刀', '力', '口'],
#  '励': ['力', '厂', '斤'],
#  '労': ['冖', '力', '尚'],
#  '劵': ['二', '人', '八', '力', '大'],
#  '効': ['亠', '力', '父'],
#  '劼': ['力', '口', '士'],
#  '劾': ['亠', '人', '力'],
#  '勁': ['力', '巛', '工'],
#  '勃': ['冖', '力', '十', '子'],
#  '勅': ['｜', '力', '口', '木'],
#  '勇': ['力', '田', 'マ'],
#  '勉': ['儿', '力', '免'],
#  '勍': ['亠', '力', '口', '小'],
#  '勒': ['力', '革'],
#  '動': ['｜', '力', '日', '里'],
#  '勗': ['力', '日', '目'],
#  '勘': ['儿', '力', '匚', '甘'],
#  '務': ['力', '夂', '矛'],
#  '勝': ['二', '人', '力', '大', '月', '丷'],
#  '勞': ['冖', '力', '火'],
#  '募': ['力', '大', '日', '艹'],
#  '勠': ['冫', '力', '彡', '羽', '个'],
#  '勢': ['丶', '儿', '力', '土', '九'],
#  '勣': ['亠', '力', '土', '貝'],
#  '勤': ['力', '口', '土', '艹'],
#  '勦': ['力', '木', '田', '尚'],
#  '勧': ['丿', '力', '矢', '隹'],
#  '勲': ['｜', '丿', '力', '日', '田', '灬'],
#  '勳': ['｜', '力', '灬'],
#  '勵': ['力', '厂', '田', '禸'],
#  '勸': ['力', '十', '口', '隹', '艹'],
#  '勺': ['丶', '勹'],
#  '勾': ['勹', '厶'],
#  '勿': ['丿', '勹'],
#  '匁': ['丶', '丿', '勹'],
#  '匂': ['勹', '匕'],
#  '包': ['勹', '己'],
#  '匆': ['丶', '勹', '勿'],
#  '匈': ['凵', '勹'],
#  '匍': ['丶', '勹', '十', '用'],
#  '匏': ['二', '勹', '大', '己'],
#  '匐': ['勹', '口', '田'],
#  '化': ['匕', '亻'],
#  '北': ['匕', '爿'],
#  '匙': ['匕', '日'],
#  '匝': ['匚', '巾'],
#  '匠': ['匚', '斤'],
#  '匡': ['匚', '玉'],
#  '匣': ['｜', '匚', '田'],
#  '匪': ['匚', '非'],
#  '匯': ['匚', '隹', '氵'],
#  '匱': ['匚', '貝'],
#  '匳': ['人', '匚', '口', '个'],
#  '匹': ['儿', '匚'],
#  '区': ['丶', '丿', '匚'],
#  '医': ['匚', '矢'],
#  '匿': ['丿', '匚', '口', '艹'],
#  '區': ['匚', '口', '品'],
#  '千': ['丿', '十'],
#  '卅': ['｜', '丿', '十', '巛'],
#  '卆': ['十', '九'],
#  '升': ['丿', '十', '廾'],
#  '午': ['丿', '十', '干'],
#  '卉': ['十', '廾'],
#  '半': ['｜', '二', '十', '丷'],
#  '卍': ['｜', '十'],
#  '卑': ['十', '田'],
#  '卒': ['亠', '人', '十'],
#  '卓': ['十', '卜', '日'],
#  '協': ['力', '十'],
#  '南': ['冂', '十', '干', '丷'],
#  '単': ['十', '田', '尚'],
#  '博': ['丶', '十', '寸', '田'],
#  '卞': ['亠', '卜'],
#  '占': ['卜', '口'],
#  '卦': ['卜', '土'],
#  '卮': ['卩', '厂'],
#  '卯': ['卩'],
#  '印': ['｜', '卩'],
#  '危': ['勹', '厂'],
#  '即': ['卩', '艮'],
#  '却': ['卩', '厶', '土'],
#  '卵': ['丶', '丿', '卜'],
#  '卷': ['二', '人', '八', '卩', '大'],
#  '卸': ['丿', '卩', '止'],
#  '卻': ['八', '卩', '口', '谷'],
#  '卿': ['卩', '艮'],
#  '厄': ['卩', '厂'],
#  '厖': ['丶', '厂', '尢', '彡', '尤'],
#  '厘': ['厂', '里'],
#  '厚': ['厂', '子', '日'],
#  '原': ['厂', '小', '白'],
#  '厠': ['厂', '貝', '刂'],
#  '厥': ['厂', '屮', '欠', '丷'],
#  '厦': ['厂', '夂', '自'],
#  '厨': ['厂', '口', '寸', '豆', '丷'],
#  '厩': ['儿', '厂', '牙', '艮'],
#  '厭': ['厂', '日', '月', '犬'],
#  '厮': ['八', '厂', '斤', '甘'],
#  '厰': ['冂', '厂', '口', '攴', '尚'],
#  '厳': ['厂', '攴', '耳', '尚'],
#  '去': ['厶', '土'],
#  '参': ['厶', '彡'],
#  '參': ['厶', '彡', '个'],
#  '叉': ['丶', '又'],
#  '及': ['丶', '乃'],
#  '友': ['丿', '又'],
#  '双': ['丶', '又'],
#  '反': ['厂', '又'],
#  '収': ['｜', '又'],
#  '叔': ['卜', '又', '小'],
#  '取': ['又', '耳'],
#  '受': ['冖', '又', '爪'],
#  '叙': ['又', '禾', '个'],
#  '叛': ['厂', '又', '丷'],
#  '叟': ['十', '又', '支', '臼'],
#  '叡': ['八', '冖', '卜', '又', '目'],
#  '叢': ['又', '玉', '羊', '耳', '丷'],
#  '口': ['囗'],
#  '古': ['十', '口'],
#  '句': ['勹', '口'],
#  '叨': ['刀', '口'],
#  '叩': ['卩', '口'],
#  '只': ['八', '口'],
#  '叫': ['｜', '十', '口'],
#  '召': ['刀', '口'],
#  '叭': ['八', '口'],
#  '叮': ['亅', '口'],
#  '可': ['亅', '口'],
#  '台': ['厶', '口'],
#  '叱': ['匕', '口'],
#  '史': ['丿', '口'],
#  '右': ['丿', '口'],
#  '叶': ['十', '口'],
#  '号': ['勹', '口'],
#  '司': ['亅', '口'],
#  '叺': ['入', '口'],
#  '吁': ['亅', '二', '口'],
#  '吃': ['乙', '口'],
#  '各': ['口', '夂', '攴'],
#  '合': ['口', '个'],
#  '吉': ['口', '士'],
#  '吊': ['口', '巾'],
#  '吋': ['口', '寸'],
#  '同': ['冂', '口'],
#  '名': ['口', '夕'],
#  '后': ['丿', '亅', '厂', '口', '斤'],
#  '吏': ['丶', '丿', '口'],
#  '吐': ['口', '土'],
#  '向': ['冂', '口'],
#  '君': ['丿', '口', '日'],
#  '吝': ['口', '文'],
#  '吟': ['口', '个'],
#  '吠': ['口', '犬'],
#  '否': ['丿', '口'],
#  '吩': ['八', '刀', '口'],
#  '含': ['口', '个'],
#  '听': ['口', '斤'],
#  '吭': ['亠', '几', '口'],
#  '吮': ['儿', '厶', '口'],
#  '吶': ['人', '冂', '口'],
#  '吸': ['丿', '口', '及'],
#  '吹': ['口', '欠'],
#  '吻': ['勹', '口', '勿'],
#  '吼': ['乙', '口', '子'],
#  '吽': ['｜', '二', '口', '牛'],
#  '吾': ['口', '五'],
#  '呀': ['口', '牙'],
#  '呂': ['口'],
#  '呆': ['口', '木'],
#  '呈': ['口', '玉'],
#  '呉': ['八', '口'],
#  '告': ['丿', '口', '土'],
#  '呎': ['口', '尸'],
#  '呑': ['丿', '口', '大'],
#  '呟': ['亠', '口', '幺', '玄'],
#  '周': ['冂', '口', '土'],
#  '呪': ['儿', '口'],
#  '呰': ['匕', '口', '止'],
#  '呱': ['口', '瓜'],
#  '味': ['｜', '二', '亠', '八', '口', '木'],
#  '呵': ['亅', '口'],
#  '呶': ['又', '口', '女'],
#  '呷': ['｜', '口', '田'],
#  '呻': ['｜', '口', '田'],
#  '呼': ['丿', '亅', '口', '丷'],
#  '命': ['卩', '口', '个'],
#  '咀': ['口', '目'],
#  '咄': ['｜', '口', '山'],
#  '咆': ['勹', '口', '己'],
#  '咋': ['｜', '丿', '口'],
#  '和': ['口', '禾'],
#  '咎': ['人', '口', '夂'],
#  '咏': ['丶', '丿', '口', '水'],
#  '咐': ['口', '寸', '亻'],
#  '咒': ['几', '口'],
#  '咢': ['二', '勹', '口'],
#  '咤': ['丿', '乙', '口', '宀'],
#  '咥': ['厶', '口', '土', '至'],
#  '咨': ['冫', '口', '欠'],
#  '咫': ['八', '口', '尸'],
#  '咬': ['亠', '口', '父'],
#  '咯': ['口', '夂'],
#  '咲': ['二', '人', '口', '大', '丷'],
#  '咳': ['亠', '人', '口'],
#  '咸': ['丿', '口', '戈'],
#  '咼': ['冂', '口'],
#  '咽': ['口', '囗', '大'],
#  '咾': ['口', '老'],
#  '哀': ['亠', '口', '衣'],
#  '品': ['口'],
#  '哂': ['口', '襾'],
#  '哄': ['｜', '二', '八', '口'],
#  '哇': ['口', '土'],
#  '哈': ['口', '个'],
#  '哉': ['口', '土', '戈'],
#  '哘': ['口', '彳', '行'],
#  '員': ['口', '貝'],
#  '哢': ['口', '廾', '玉'],
#  '哥': ['亅', '口'],
#  '哦': ['亅', '口', '戈'],
#  '哨': ['口', '月', '尚'],
#  '哩': ['口', '里'],
#  '哭': ['口', '犬'],
#  '哮': ['口', '子', '老'],
#  '哲': ['口', '斤', '扌'],
#  '哺': ['丶', '十', '口', '用'],
#  '哽': ['丿', '口', '田'],
#  '唄': ['口', '貝'],
#  '唆': ['儿', '厶', '口', '夂'],
#  '唇': ['厂', '口', '衣', '辰'],
#  '唏': ['丿', '口', '巾'],
#  '唐': ['｜', '口', '广', '彐'],
#  '唔': ['口', '五'],
#  '唖': ['｜', '口', '刂'],
#  '售': ['口', '隹'],
#  '唯': ['口', '隹'],
#  '唱': ['口', '日'],
#  '唳': ['口', '大', '戸'],
#  '唸': ['口', '心', '个'],
#  '唹': ['冫', '口', '方', '个'],
#  '唾': ['｜', '丿', '口'],
#  '啀': ['厂', '口', '土'],
#  '啄': ['口', '豕'],
#  '啅': ['十', '卜', '口', '日'],
#  '商': ['亠', '儿', '冂', '口', '立', '丷'],
#  '啌': ['儿', '口', '宀', '工', '穴'],
#  '問': ['口', '門'],
#  '啓': ['口', '戸', '攴'],
#  '啖': ['口', '火'],
#  '啗': ['勹', '口', '臼'],
#  '啜': ['又', '口'],
#  '啝': ['口', '禾'],
#  '啣': ['凵', '卩', '口', '止', '缶'],
#  '啻': ['亠', '冖', '口', '巾', '立', '丷'],
#  '啼': ['亠', '冖', '口', '巾', '立', '丷'],
#  '啾': ['口', '火', '禾'],
#  '喀': ['口', '夂', '宀'],
#  '喃': ['冂', '十', '口', '干', '丷'],
#  '善': ['口', '玉', '羊', '丷'],
#  '喇': ['｜', '亠', '八', '口', '木', '刂'],
#  '喉': ['口', '矢', '亻'],
#  '喊': ['丿', '口', '戈'],
#  '喋': ['口', '木', '世'],
#  '喘': ['｜', '冂', '口', '山', '而'],
#  '喙': ['口', '彐', '豕'],
#  '喚': ['儿', '冂', '勹', '口', '大'],
#  '喜': ['口', '士', '豆', '丷'],
#  '喝': ['勹', '匕', '口', '日'],
#  '喞': ['卩', '口', '艮'],
#  '喟': ['口', '月', '田'],
#  '喧': ['口', '宀', '日'],
#  '喨': ['亠', '儿', '冖', '口'],
#  '喩': ['口', '月', '个', '刂'],
#  '喪': ['｜', '口', '衣'],
#  '喫': ['亠', '刀', '口', '土', '大'],
#  '喬': ['丿', '冂', '口', '大'],
#  '單': ['十', '口', '田'],
#  '喰': ['口', '食'],
#  '営': ['冖', '口', '尚'],
#  '嗄': ['口', '夂', '自'],
#  '嗅': ['口', '大', '自'],
#  '嗇': ['人', '口', '囗', '土'],
#  '嗔': ['八', '十', '口', '目'],
#  '嗚': ['口', '鳥', '灬'],
#  '嗜': ['口', '日', '老'],
#  '嗟': ['丿', '口', '工', '玉', '羊', '丷'],
#  '嗣': ['｜', '亅', '冂', '口'],
#  '嗤': ['口', '山', '虫'],
#  '嗷': ['口', '土', '攴', '方'],
#  '嗹': ['口', '車', '辶'],
#  '嗽': ['｜', '八', '口', '木', '欠'],
#  '嗾': ['口', '方', '矢'],
#  '嘆': ['丿', '口', '艹'],
#  '嘉': ['力', '口', '士'],
#  '嘔': ['匚', '口', '品'],
#  '嘖': ['亠', '口', '土', '貝'],
#  '嘗': ['冖', '匕', '口', '日', '尚'],
#  '嘘': ['匕', '卜', '厂', '口', '虍'],
#  '嘛': ['口', '广', '木', '麻'],
#  '嘩': ['｜', '口', '艹'],
#  '嘯': ['｜', '丿', '口', '彐', '水', '米', '聿', '隶'],
#  '嘱': ['口', '尸', '禸'],
#  '嘲': ['十', '口', '日', '月'],
#  '嘴': ['匕', '口', '止', '角'],
#  '嘶': ['八', '口', '斤', '甘'],
#  '嘸': ['｜', '丿', '口', '灬', '無'],
#  '噂': ['口', '寸', '襾', '丷'],
#  '噌': ['口', '日', '田', '丷'],
#  '噎': ['冖', '口', '士', '豆', '丷'],
#  '噐': ['口', '工'],
#  '噛': ['口', '止', '米', '齒'],
#  '噤': ['口', '木', '示'],
#  '器': ['口', '大'],
#  '噪': ['口', '木', '品'],
#  '噫': ['口', '心', '日', '立', '音'],
#  '噬': ['人', '口', '工', '竹'],
#  '噴': ['十', '口', '貝', '艹'],
#  '噸': ['口', '貝', '頁', '屯'],
#  '噺': ['亠', '十', '口', '斤', '木', '立', '辛', '丷'],
#  '嚀': ['口', '宀', '心', '网'],
#  '嚆': ['亠', '冂', '口', '高', '艹'],
#  '嚇': ['口', '土', '赤'],
#  '嚊': ['口', '廾', '田', '自', '鼻'],
#  '嚏': ['冖', '十', '口', '田', '疋'],
#  '嚔': ['冖', '十', '口', '田', '疋'],
#  '嚠': ['厶', '口', '金', '刂'],
#  '嚢': ['｜', '亠', '八', '冖', '口', '衣'],
#  '嚥': ['凵', '匕', '口', '爿', '灬'],
#  '嚮': ['冂', '口', '艮', '.阝'],
#  '嚴': ['厂', '口', '攴', '耳'],
#  '嚶': ['口', '女', '貝'],
#  '嚼': ['口', '寸', '爪', '网', '艮'],
#  '囀': ['十', '厶', '口', '寸', '田', '車'],
#  '囁': ['口', '耳'],
#  '囂': ['八', '口', '自'],
#  '囃': ['亠', '人', '口', '木', '隹'],
#  '囈': ['丶', '二', '儿', '厶', '口', '土', '九', '艹'],
#  '囎': ['八', '口', '日', '田', '貝', '丷'],
#  '囑': ['勹', '口', '尸', '网', '虫'],
#  '囓': ['亠', '凵', '刀', '口', '土', '止', '米', '齒'],
#  '囘': ['冂', '己'],
#  '囚': ['人', '囗'],
#  '四': ['儿', '囗'],
#  '回': ['口', '囗'],
#  '因': ['囗', '大'],
#  '団': ['囗', '寸'],
#  '囮': ['匕', '囗', '亻'],
#  '困': ['囗', '木'],
#  '囲': ['囗', '井'],
#  '図': ['囗', '斗'],
#  '囹': ['刀', '囗', '个'],
#  '固': ['十', '口', '囗'],
#  '国': ['丶', '囗', '玉'],
#  '囿': ['丿', '囗', '月'],
#  '圀': ['儿', '囗', '方'],
#  '圃': ['丶', '十', '囗', '用'],
#  '圄': ['口', '囗', '五'],
#  '圈': ['二', '人', '卩', '囗', '大', '丷'],
#  '圉': ['亠', '十', '囗', '土', '干', '立', '辛'],
#  '國': ['口', '囗', '戈'],
#  '圍': ['口', '囗', '韋'],
#  '圏': ['二', '人', '囗', '大', '大', '己', '丷'],
#  '園': ['口', '囗', '土', '衣'],
#  '圓': ['口', '囗', '貝'],
#  '圖': ['口', '囗'],
#  '團': ['十', '厶', '囗', '寸'],
#  '圜': ['口', '囗', '网', '衣'],
#  '圦': ['入', '土'],
#  '圧': ['厂', '土'],
#  '在': ['｜', '丿', '土'],
#  '圭': ['土'],
#  '地': ['土', '也'],
#  '圷': ['卜', '土'],
#  '圸': ['土', '山'],
#  '圻': ['土', '斤'],
#  '址': ['土', '止'],
#  '坂': ['厂', '又', '土'],
#  '均': ['二', '冫', '勹', '土'],
#  '坊': ['土', '方'],
#  '坎': ['土', '欠'],
#  '坏': ['｜', '丶', '丿', '土'],
#  '坐': ['｜', '人', '入', '土'],
#  '坑': ['亠', '几', '土'],
#  '坡': ['又', '土', '皮'],
#  '坤': ['｜', '土', '日', '田'],
#  '坦': ['土', '日'],
#  '坩': ['土', '甘'],
#  '坪': ['土', '干', '丷'],
#  '坿': ['土', '寸', '亻'],
#  '垂': ['｜', '丿'],
#  '垈': ['土', '弋', '亻'],
#  '垉': ['勹', '土', '己'],
#  '型': ['丿', '土', '廾', '刂'],
#  '垓': ['亠', '人', '土'],
#  '垠': ['土', '艮'],
#  '垢': ['丿', '亅', '厂', '口', '土', '斤'],
#  '垣': ['土', '日'],
#  '垤': ['厶', '土', '至'],
#  '垪': ['｜', '丿', '二', '土', '廾', '丷'],
#  '垰': ['卜', '土'],
#  '垳': ['土', '彳', '行'],
#  '埀': ['丿', '匕', '土', '爿'],
#  '埃': ['厶', '土', '矢'],
#  '埆': ['土', '角'],
#  '埋': ['土', '里'],
#  '城': ['丿', '土', '戈'],
#  '埒': ['土', '寸', '爪'],
#  '埓': ['丿', '土', '寸'],
#  '埔': ['丶', '十', '土', '用'],
#  '埖': ['匕', '土', '亻', '艹'],
#  '埜': ['土', '木'],
#  '域': ['口', '土', '戈'],
#  '埠': ['｜', '十', '口', '土', '阝.'],
#  '埣': ['亠', '人', '十', '土'],
#  '埴': ['十', '土', '目'],
#  '執': ['丶', '丿', '亠', '十', '土', '立', '辛', '九'],
#  '培': ['口', '土', '立'],
#  '基': ['八', '土', '甘'],
#  '埼': ['｜', '口', '土', '大'],
#  '堀': ['｜', '土', '尸', '山'],
#  '堂': ['冖', '口', '土', '尚'],
#  '堅': ['又', '土', '臣'],
#  '堆': ['土', '隹'],
#  '堊': ['二', '土'],
#  '堋': ['土', '月'],
#  '堕': ['丿', '土', '月', '阝.'],
#  '堙': ['｜', '土', '襾'],
#  '堝': ['冂', '口', '土'],
#  '堡': ['口', '土', '木', '亻'],
#  '堤': ['土', '日', '疋'],
#  '堪': ['儿', '匚', '土', '甘'],
#  '堯': ['儿', '土'],
#  '堰': ['匚', '土', '女', '日'],
#  '報': ['亠', '十', '卩', '又', '土', '立', '辛'],
#  '場': ['土', '日', '勿'],
#  '堵': ['土', '日', '老'],
#  '堺': ['儿', '八', '土', '田'],
#  '堽': ['土', '止', '网'],
#  '塀': ['｜', '丿', '二', '八', '土', '尸', '廾'],
#  '塁': ['冫', '土', '田'],
#  '塊': ['儿', '匕', '厶', '土', '田', '鬼'],
#  '塋': ['冖', '土', '火'],
#  '塑': ['土', '屮', '月', '丷'],
#  '塒': ['土', '寸', '日'],
#  '塔': ['口', '土', '个', '艹'],
#  '塗': ['亅', '八', '土', '木', '个', '氵'],
#  '塘': ['｜', '口', '土', '广', '彐'],
#  '塙': ['亠', '冂', '口', '土', '高'],
#  '塚': ['冖', '土', '豕'],
#  '塞': ['八', '土', '宀'],
#  '塢': ['土', '鳥', '灬'],
#  '塩': ['口', '土', '皿'],
#  '填': ['八', '十', '土', '目'],
#  '塰': ['土', '毋', '氵'],
#  '塲': ['土', '日', '勿'],
#  '塵': ['土', '广', '比', '鹿'],
#  '塹': ['土', '斤', '車'],
#  '塾': ['丶', '亠', '口', '土', '子', '九'],
#  '境': ['儿', '土', '日', '立', '音'],
#  '墅': ['土', '里', 'マ'],
#  '墓': ['土', '大', '日', '艹'],
#  '増': ['土', '日', '田', '丷'],
#  '墜': ['土', '豕', '丷', '阝.'],
#  '墟': ['｜', '匕', '卜', '厂', '土', '虍', '丷'],
#  '墨': ['土', '里', '黒', '灬'],
#  '墫': ['土', '寸', '酉', '丷'],
#  '墮': ['土', '工', '月', '阝.'],
#  '墳': ['十', '土', '貝', '艹'],
#  '墸': ['土', '日', '老', '艹'],
#  '墹': ['土', '日', '門'],
#  '墺': ['冂', '土', '大', '米'],
#  '墻': ['人', '口', '囗', '土'],
#  '墾': ['土', '爪', '艮', '豸', '犭'],
#  '壁': ['十', '口', '土', '尸', '立', '辛'],
#  '壅': ['亠', '土', '隹'],
#  '壇': ['亠', '口', '囗', '土', '日'],
#  '壊': ['十', '土', '网', '衣'],
#  '壌': ['亠', '八', '土', '衣'],
#  '壑': ['八', '冖', '卜', '又', '口', '土', '个'],
#  '壓': ['厂', '土', '日', '月', '犬'],
#  '壕': ['亠', '冖', '口', '土', '豕'],
#  '壗': ['土', '彐', '皿', '聿', '灬'],
#  '壘': ['土', '田'],
#  '壙': ['｜', '二', '八', '土', '广', '田', '黄'],
#  '壜': ['二', '厶', '土', '日', '雨'],
#  '壞': ['亠', '土', '网', '衣'],
#  '壟': ['土', '月', '立'],
#  '壤': ['｜', '亠', '口', '土', '衣'],
#  '壥': ['厂', '土', '里', '黒', '灬'],
#  '壬': ['丿', '士'],
#  '壮': ['士', '爿'],
#  '壯': ['士', '爿'],
#  '声': ['士', '尸'],
#  '壱': ['冖', '匕', '士'],
#  '売': ['儿', '冖', '士'],
#  '壷': ['｜', '冖', '口', '士'],
#  '壹': ['冖', '口', '士', '豆', '丷'],
#  '壺': ['冖', '士'],
#  '壻': ['土', '月', '疋'],
#  '壼': ['二', '冖', '士'],
#  '壽': ['口', '士', '寸', '工'],
#  '夂': ['攴'],
#  '変': ['亠', '夂'],
#  '夊': ['夂'],
#  '夏': ['夂', '自'],
#  '夐': ['人', '冂', '勹', '夂', '目'],
#  '外': ['卜', '夕'],
#  '夘': ['卩', '夕'],
#  '夙': ['几', '歹'],
#  '多': ['夕'],
#  '夛': ['夕', '彐'],
#  '夜': ['亠', '夕', '亻'],
#  '夢': ['冖', '夕', '网', '艹'],
#  '夥': ['夕', '木', '田'],
#  '天': ['大'],
#  '太': ['丶', '大'],
#  '夫': ['二', '人', '大'],
#  '夬': ['二', '人', '大', 'ユ'],
#  '夭': ['丿', '大'],
#  '央': ['丿', '冖', '大'],
#  '失': ['丿', '二', '人', '大'],
#  '夲': ['十', '大'],
#  '夷': ['丿', '大', '弓'],
#  '夸': ['二', '勹', '大'],
#  '夾': ['人', '大'],
#  '奄': ['乙', '大', '日'],
#  '奇': ['亅', '口', '大'],
#  '奈': ['大', '示'],
#  '奉': ['｜', '丿', '二', '人', '大'],
#  '奎': ['土', '大'],
#  '奏': ['｜', '丿', '二', '大', '禾'],
#  '奐': ['儿', '冂', '勹', '大'],
#  '契': ['亠', '刀', '土', '大'],
#  '奔': ['丿', '十', '大', '廾'],
#  '奕': ['亠', '八', '大', '赤'],
#  '套': ['厶', '大', '長'],
#  '奘': ['士', '大', '爿'],
#  '奚': ['大', '幺', '爪'],
#  '奠': ['大', '酉', '丷'],
#  '奢': ['大', '日', '老'],
#  '奥': ['冂', '大', '米'],
#  '奧': ['丿', '冂', '大', '米'],
#  '奨': ['大', '寸', '爪', '爿'],
#  '奩': ['匚', '口', '大', '品'],
#  '奪': ['大', '寸', '隹'],
#  '奬': ['夕', '大', '寸', '爿'],
#  '奮': ['大', '田', '隹'],
#  '奴': ['又', '女'],
#  '奸': ['女', '干'],
#  '好': ['女', '子'],
#  '妁': ['丶', '勹', '女'],
#  '如': ['口', '女'],
#  '妃': ['女', '己'],
#  '妄': ['亠', '女', '亡'],
#  '妊': ['丿', '士', '女', '玉'],
#  '妍': ['｜', '丿', '二', '女', '廾'],
#  '妓': ['十', '又', '女', '支'],
#  '妖': ['丿', '大', '女'],
#  '妙': ['丿', '女', '小'],
#  '妛': ['女', '山'],
#  '妝': ['女', '爿'],
#  '妣': ['女', '比'],
#  '妥': ['女', '爪'],
#  '妨': ['女', '方'],
#  '妬': ['口', '女', '石'],
#  '妲': ['女', '日'],
#  '妹': ['｜', '二', '亠', '八', '女', '木'],
#  '妻': ['｜', '女', '彐'],
#  '妾': ['女', '立'],
#  '姆': ['女', '毋'],
#  '姉': ['亠', '女', '巾'],
#  '始': ['厶', '口', '女'],
#  '姐': ['女', '目'],
#  '姑': ['十', '口', '女'],
#  '姓': ['女', '生'],
#  '委': ['女', '禾'],
#  '姙': ['丿', '士', '女', '亻'],
#  '姚': ['儿', '冫', '女'],
#  '姜': ['女', '玉', '羊', '丷'],
#  '姥': ['匕', '女', '老'],
#  '姦': ['女'],
#  '姨': ['人', '大', '女', '弓'],
#  '姪': ['厶', '土', '女', '至'],
#  '姫': ['女', '臣'],
#  '姶': ['口', '女', '个'],
#  '姻': ['囗', '大', '女'],
#  '姿': ['冫', '女', '欠'],
#  '威': ['丿', '厂', '女', '戈'],
#  '娃': ['土', '女'],
#  '娉': ['｜', '勹', '女', '田'],
#  '娑': ['丿', '女', '小', '氵'],
#  '娘': ['女', '艮'],
#  '娚': ['力', '女', '田'],
#  '娜': ['二', '刀', '女', '.阝'],
#  '娟': ['口', '女', '月'],
#  '娠': ['厂', '女', '衣', '辰'],
#  '娥': ['亅', '女', '戈'],
#  '娩': ['儿', '女', '免'],
#  '娯': ['八', '口', '女'],
#  '娵': ['又', '女', '耳'],
#  '娶': ['又', '女', '耳'],
#  '娼': ['女', '日'],
#  '婀': ['亅', '口', '女', '阝.'],
#  '婁': ['｜', '口', '女'],
#  '婆': ['又', '女', '皮', '氵'],
#  '婉': ['卩', '夕', '女', '宀'],
#  '婚': ['女', '日', '氏'],
#  '婢': ['十', '女', '田'],
#  '婦': ['冖', '女', '巾', '彐'],
#  '婪': ['女', '木'],
#  '婬': ['丿', '士', '女', '爪'],
#  '婿': ['女', '月', '疋'],
#  '媒': ['女', '木', '甘'],
#  '媚': ['｜', '女', '尸', '目'],
#  '媛': ['丿', '又', '女', '爪'],
#  '媼': ['女', '日', '皿'],
#  '媽': ['女', '馬'],
#  '媾': ['｜', '二', '冂', '女'],
#  '嫁': ['女', '宀', '豕'],
#  '嫂': ['｜', '又', '女', '田'],
#  '嫉': ['女', '疒', '矢'],
#  '嫋': ['冫', '女', '弓'],
#  '嫌': ['｜', '八', '女', '彐', '丷'],
#  '嫐': ['力', '女', '田'],
#  '嫖': ['女', '示', '襾'],
#  '嫗': ['匚', '口', '女', '品'],
#  '嫡': ['亠', '冂', '十', '口', '女', '立', '丷', '啇'],
#  '嫣': ['女', '止', '鳥', '灬'],
#  '嫦': ['口', '女', '巾', '尚'],
#  '嫩': ['｜', '八', '口', '女', '攴', '木'],
#  '嫺': ['女', '日', '門'],
#  '嫻': ['女', '木', '門'],
#  '嬉': ['口', '士', '女', '豆', '丷'],
#  '嬋': ['｜', '十', '口', '女', '田'],
#  '嬌': ['丿', '冂', '口', '大', '女'],
#  '嬖': ['十', '口', '女', '尸', '立', '辛'],
#  '嬢': ['亠', '八', '女', '衣'],
#  '嬪': ['丿', '女', '宀', '小', '貝'],
#  '嬬': ['女', '而', '雨'],
#  '嬰': ['女', '貝'],
#  '嬲': ['力', '女', '田'],
#  '嬶': ['女', '廾', '田', '目', '自', '鼻'],
#  '嬾': ['｜', '八', '口', '女', '木', '貝', '頁'],
#  '孀': ['女', '木', '目', '雨'],
#  '孃': ['｜', '亠', '口', '女', '衣'],
#  '孅': ['人', '女', '戈', '韭'],
#  '孔': ['乙', '子'],
#  '孕': ['子', '乃'],
#  '字': ['子', '宀'],
#  '存': ['｜', '丿', '子'],
#  '孚': ['子', '爪'],
#  '孛': ['冖', '十', '士', '子'],
#  '孜': ['子', '攴'],
#  '孝': ['子', '老'],
#  '孟': ['子', '皿'],
#  '季': ['子', '禾'],
#  '孤': ['子', '瓜'],
#  '孥': ['又', '女', '子'],
#  '学': ['冖', '子', '尚'],
#  '孩': ['亠', '子'],
#  '孫': ['丿', '子', '糸'],
#  '孰': ['丶', '亠', '口', '子', '九'],
#  '孱': ['子', '尸'],
#  '孳': ['子', '幺', '丷'],
#  '孵': ['丶', '卩', '子', '爪'],
#  '學': ['冖', '子', '臼'],
#  '孺': ['｜', '冂', '子', '而', '雨'],
#  '它': ['匕', '宀'],
#  '宅': ['丿', '乙', '宀'],
#  '宇': ['亅', '宀', '干'],
#  '守': ['宀', '寸'],
#  '安': ['女', '宀'],
#  '宋': ['宀', '木'],
#  '完': ['二', '儿', '宀', '元'],
#  '宍': ['亠', '八', '宀'],
#  '宏': ['丿', '厶', '宀'],
#  '宕': ['口', '宀', '石'],
#  '宗': ['宀', '示'],
#  '官': ['口', '宀'],
#  '宙': ['｜', '宀', '日', '田'],
#  '定': ['宀', '疋'],
#  '宛': ['卩', '夕', '宀'],
#  '宜': ['宀', '目'],
#  '宝': ['丶', '宀', '玉'],
#  '実': ['士', '大', '宀'],
#  '客': ['口', '夂', '宀'],
#  '宣': ['宀', '日'],
#  '室': ['厶', '土', '宀', '至'],
#  '宥': ['丿', '宀', '月'],
#  '宦': ['宀', '臣'],
#  '宮': ['口', '宀'],
#  '宰': ['十', '宀', '立', '辛'],
#  '害': ['亠', '口', '土', '宀'],
#  '宴': ['女', '宀', '日'],
#  '宵': ['宀', '月', '尚'],
#  '家': ['宀', '豕'],
#  '宸': ['厂', '宀', '衣', '辰'],
#  '容': ['八', '口', '宀', '穴', '谷', '个'],
#  '宿': ['宀', '白', '亻'],
#  '寂': ['卜', '又', '宀', '小'],
#  '寃': ['丶', '儿', '宀', '免'],
#  '寄': ['亅', '口', '大', '宀'],
#  '寅': ['八', '宀', '田'],
#  '密': ['丶', '丿', '宀', '山', '心'],
#  '寇': ['二', '儿', '卜', '又', '宀', '元'],
#  '寉': ['宀', '隹'],
#  '富': ['口', '宀', '田'],
#  '寐': ['亅', '二', '八', '宀', '爿'],
#  '寒': ['丶', '八', '宀', '井'],
#  '寓': ['冂', '厶', '宀', '田', '禸'],
#  '寔': ['宀', '日', '疋'],
#  '寛': ['宀', '見', '艹'],
#  '寝': ['冖', '又', '宀', '彐', '爿'],
#  '寞': ['大', '宀', '日', '艹'],
#  '察': ['丿', '宀', '癶', '示'],
#  '寡': ['八', '刀', '宀', '自'],
#  '寢': ['冖', '又', '宀', '彐', '爿'],
#  '寤': ['口', '宀', '爿', '五'],
#  '寥': ['冫', '宀', '彡', '羽', '个'],
#  '實': ['宀', '田', '貝'],
#  '寧': ['亅', '宀', '心', '网'],
#  '寨': ['｜', '八', '宀', '木'],
#  '審': ['宀', '田', '米', '釆'],
#  '寫': ['勹', '宀', '臼', '灬'],
#  '寮': ['宀', '小', '日', '个', '丷'],
#  '寰': ['口', '宀', '网', '衣'],
#  '寳': ['宀', '小', '玉', '貝'],
#  '寵': ['宀', '月', '立'],
#  '寶': ['凵', '宀', '玉', '缶', '貝'],
#  '寺': ['土', '寸'],
#  '対': ['寸', '文'],
#  '寿': ['丿', '二', '寸'],
#  '封': ['土', '寸'],
#  '専': ['十', '寸', '田'],
#  '射': ['寸', '身'],
#  '尅': ['儿', '十', '口', '寸'],
#  '将': ['寸', '爪', '爿'],
#  '將': ['夕', '寸', '爿'],
#  '專': ['十', '厶', '寸', '田', '虫'],
#  '尉': ['寸', '尸', '示'],
#  '尊': ['寸', '酉', '丷'],
#  '尋': ['口', '寸', '工', '彐'],
#  '對': ['寸', '玉', '羊', '丷'],
#  '導': ['寸', '自', '丷', '辶'],
#  '少': ['丿', '小'],
#  '尓': ['丿', '小'],
#  '尖': ['大', '小'],
#  '尚': ['冂', '口'],
#  '尠': ['丿', '儿', '匚', '小', '甘'],
#  '尤': ['丶', '尢'],
#  '尨': ['丶', '尢', '彡', '尤'],
#  '尭': ['儿', '十', '廾'],
#  '就': ['丶', '亠', '口', '小', '尢', '尤'],
#  '尹': ['丿', '彐'],
#  '尺': ['丶', '尸'],
#  '尻': ['尸', '九'],
#  '尼': ['匕', '尸'],
#  '尽': ['丶', '尸'],
#  '尾': ['尸', '毛'],
#  '尿': ['尸', '水'],
#  '局': ['口', '尸'],
#  '屁': ['尸', '比'],
#  '居': ['十', '口', '尸'],
#  '屆': ['凵', '土', '士', '尸'],
#  '屈': ['｜', '尸', '山'],
#  '届': ['｜', '尸', '日', '田'],
#  '屋': ['厶', '土', '尸', '至'],
#  '屍': ['匕', '夕', '尸', '歹'],
#  '屎': ['尸', '米'],
#  '屏': ['｜', '丿', '二', '尸', '廾', '丷'],
#  '屐': ['十', '又', '尸', '彳', '支'],
#  '屑': ['尸', '月', '尚'],
#  '屓': ['尸', '貝'],
#  '展': ['｜', '二', '尸', '衣'],
#  '属': ['丿', '尸', '禸'],
#  '屠': ['尸', '日', '老'],
#  '屡': ['女', '尸', '米'],
#  '層': ['尸', '日', '田', '丷'],
#  '履': ['夂', '尸', '彳', '日'],
#  '屬': ['勹', '尸', '网', '虫'],
#  '屯': ['丿', '乙', '凵'],
#  '屶': ['刀', '山'],
#  '屹': ['丿', '乙', '山'],
#  '岌': ['山', '及'],
#  '岐': ['十', '又', '山', '支'],
#  '岑': ['山', '个'],
#  '岔': ['八', '刀', '山'],
#  '岡': ['冂', '山', '丷'],
#  '岨': ['｜', '山', '目'],
#  '岩': ['口', '山', '石'],
#  '岫': ['｜', '山', '田'],
#  '岬': ['｜', '山', '日', '田'],
#  '岱': ['山', '弋', '亻'],
#  '岳': ['山', '斤'],
#  '岶': ['山', '白'],
#  '岷': ['口', '山', '氏'],
#  '岸': ['厂', '山', '干'],
#  '岻': ['山', '氏'],
#  '岼': ['｜', '二', '山', '干', '丷'],
#  '岾': ['卜', '口', '山'],
#  '峅': ['厶', '山', '廾'],
#  '峇': ['口', '山', '个'],
#  '峙': ['土', '寸', '山'],
#  '峠': ['｜', '卜', '山'],
#  '峡': ['二', '亠', '人', '大', '山', '丷'],
#  '峨': ['亅', '山', '戈', '手'],
#  '峩': ['亅', '山', '戈'],
#  '峪': ['八', '口', '山', '谷', '个'],
#  '峭': ['山', '月', '尚'],
#  '峯': ['｜', '夂', '山'],
#  '峰': ['｜', '夂', '山'],
#  '島': ['山', '白', '鳥'],
#  '峺': ['丿', '山', '田'],
#  '峻': ['儿', '厶', '夂', '山'],
#  '峽': ['人', '大', '山'],
#  '崇': ['宀', '山', '示'],
#  '崋': ['｜', '山'],
#  '崎': ['｜', '口', '大', '山'],
#  '崑': ['山', '日', '比'],
#  '崔': ['山', '隹'],
#  '崕': ['厂', '土', '山'],
#  '崖': ['厂', '土', '山'],
#  '崗': ['冂', '凵', '山', '丷', '岡'],
#  '崘': ['｜', '山', '个', '冊'],
#  '崙': ['｜', '山', '个', '冊'],
#  '崚': ['儿', '土', '夂', '山'],
#  '崛': ['｜', '尸', '山'],
#  '崟': ['山', '金'],
#  '崢': ['亅', '尸', '山', '彐', '爪'],
#  '崩': ['山', '月'],
#  '嵋': ['｜', '尸', '山', '目'],
#  '嵌': ['山', '欠', '甘'],
#  '嵎': ['山', '田', '禸'],
#  '嵐': ['山', '風'],
#  '嵒': ['口', '山', '品'],
#  '嵜': ['亅', '亠', '口', '大', '山', '立', '丷'],
#  '嵩': ['亠', '冂', '口', '山', '高'],
#  '嵬': ['儿', '匕', '山', '田', '鬼'],
#  '嵯': ['丿', '山', '工', '玉', '羊', '丷'],
#  '嵳': ['山', '工', '玉', '羊', '丷'],
#  '嵶': ['冫', '山', '弓'],
#  '嶂': ['十', '山', '日', '曰', '立', '音'],
#  '嶄': ['山', '斤', '車'],
#  '嶇': ['匚', '口', '山', '品'],
#  '嶋': ['山', '鳥', '灬'],
#  '嶌': ['山', '鳥', '灬'],
#  '嶐': ['夂', '山', '生', '阝.'],
#  '嶝': ['口', '山', '癶', '豆', '丷'],
#  '嶢': ['儿', '土', '山'],
#  '嶬': ['亅', '山', '戈', '玉', '羊', '丷'],
#  '嶮': ['人', '口', '山', '个'],
#  '嶷': ['匕', '山', '疋', '矢'],
#  '嶺': ['卩', '山', '貝', '頁', '个'],
#  '嶼': ['八', '山', '臼'],
#  '嶽': ['山', '犬', '言'],
#  '巉': ['丶', '儿', '勹', '口', '山', '比'],
#  '巌': ['厂', '山', '攴', '耳', '尚'],
#  '巍': ['儿', '匕', '女', '山', '田', '禾', '鬼'],
#  '巒': ['山', '糸', '言'],
#  '巓': ['八', '十', '山', '目', '貝', '頁'],
#  '巖': ['厂', '口', '山', '攴', '耳'],
#  '州': ['｜', '丶', '巛'],
#  '巡': ['巛', '辶'],
#  '巣': ['木', '田', '尚'],
#  '左': ['丿', '工'],
#  '巧': ['勹', '工'],
#  '巨': ['匚'],
#  '巫': ['人', '工'],
#  '差': ['丿', '工', '玉', '羊', '丷'],
#  '巴': ['乙', '己'],
#  '巵': ['厂', '巴'],
#  '巷': ['八', '己', '井'],
#  '巻': ['二', '大', '己', '丷'],
#  '巽': ['｜', '二', '八', '己'],
#  '巾': ['｜', '冂'],
#  '市': ['亠', '巾'],
#  '布': ['丿', '巾'],
#  '帆': ['丶', '几', '巾'],
#  '帋': ['巾', '氏'],
#  '希': ['丿', '巾'],
#  '帑': ['又', '女', '巾'],
#  '帖': ['卜', '口', '巾'],
#  '帙': ['丿', '二', '人', '大', '巾'],
#  '帚': ['冖', '巾', '彐'],
#  '帛': ['巾', '白'],
#  '帝': ['亠', '冖', '巾', '立', '丷'],
#  '帥': ['｜', '口', '巾'],
#  '師': ['｜', '口', '巾'],
#  '席': ['巾', '广'],
#  '帯': ['｜', '冖', '巾'],
#  '帰': ['冖', '巾', '彐', '刂'],
#  '帳': ['巾', '長'],
#  '帶': ['儿', '冖', '凵', '巾'],
#  '帷': ['巾', '隹'],
#  '常': ['冖', '口', '巾', '尚'],
#  '帽': ['巾', '日', '目'],
#  '幀': ['卜', '巾', '貝'],
#  '幃': ['口', '巾', '韋'],
#  '幄': ['厶', '土', '尸', '巾', '至'],
#  '幅': ['口', '巾', '田'],
#  '幇': ['土', '寸', '巾'],
#  '幌': ['儿', '巾', '日', '尚'],
#  '幎': ['亠', '八', '冖', '巾', '日'],
#  '幔': ['又', '巾', '日', '网'],
#  '幕': ['大', '巾', '日', '艹'],
#  '幗': ['口', '囗', '巾', '戈'],
#  '幟': ['巾', '戈', '日', '立', '音'],
#  '幡': ['巾', '田', '米', '釆'],
#  '幢': ['巾', '立', '里'],
#  '幣': ['冂', '巾', '攴', '丷'],
#  '幤': ['冂', '口', '巾', '攴', '尚'],
#  '干': ['十'],
#  '平': ['干', '丷'],
#  '年': ['丿', '干'],
#  '幵': ['干'],
#  '并': ['丿', '二', '干', '丷'],
#  '幸': ['亠', '十', '立', '辛'],
#  '幹': ['十', '干', '日', '个'],
#  '幻': ['幺'],
#  '幼': ['力', '幺'],
#  '幽': ['｜', '凵', '幺'],
#  '幾': ['丿', '幺', '戈'],
#  '庁': ['亅', '广'],
#  '広': ['厶', '广'],
#  '庄': ['土', '广'],
#  '庇': ['广', '比'],
#  '床': ['广', '木'],
#  '序': ['亅', '子', '广'],
#  '底': ['广', '氏'],
#  '庖': ['勹', '己', '广'],
#  '店': ['卜', '口', '广'],
#  '庚': ['人', '广', '彐'],
#  '府': ['寸', '广', '亻'],
#  '庠': ['广', '玉', '羊', '丷'],
#  '度': ['又', '广'],
#  '座': ['｜', '入', '土', '广'],
#  '庫': ['广', '車'],
#  '庭': ['广', '廴', '玉'],
#  '庵': ['大', '广', '田'],
#  '庶': ['广', '灬'],
#  '康': ['广', '彐', '水', '隶'],
#  '庸': ['广', '彐', '用', '聿'],
#  '廁': ['广', '貝', '刂'],
#  '廂': ['广', '木', '目'],
#  '廃': ['儿', '广', '癶'],
#  '廈': ['夂', '广', '自'],
#  '廉': ['｜', '八', '广', '彐', '丷'],
#  '廊': ['广', '艮', '.阝'],
#  '廏': ['广', '殳', '艮'],
#  '廐': ['广', '无', '艮'],
#  '廓': ['亅', '亠', '口', '子', '广', '.阝'],
#  '廖': ['冫', '广', '彡', '羽', '个'],
#  '廚': ['口', '士', '寸', '广', '豆', '丷'],
#  '廛': ['儿', '土', '广', '里'],
#  '廝': ['八', '广', '斤', '甘'],
#  '廟': ['十', '广', '日', '月'],
#  '廠': ['冂', '口', '广', '攴', '尚'],
#  '廡': ['｜', '广', '灬', '無'],
#  '廢': ['广', '弓', '殳', '癶'],
#  '廣': ['八', '广', '田', '黄'],
#  '廨': ['刀', '广', '牛', '角'],
#  '廩': ['亠', '口', '囗', '广', '禾'],
#  '廬': ['匕', '卜', '厂', '广', '田', '皿', '虍'],
#  '廰': ['十', '广', '心', '网', '耳'],
#  '廱': ['口', '巛', '广', '隹', '巴'],
#  '廳': ['十', '广', '心', '玉', '网', '耳'],
#  '延': ['廴', '止'],
#  '廷': ['士', '廴', '玉'],
#  '廸': ['｜', '廴', '日'],
#  '建': ['廴', '聿'],
#  '廻': ['口', '囗', '廴'],
#  '廼': ['廴', '襾'],
#  '廿': ['｜', '凵'],
#  '弁': ['厶', '廾'],
#  '弃': ['亠', '厶', '廾'],
#  '弄': ['廾', '玉'],
#  '弉': ['士', '廾', '爿'],
#  '弊': ['｜', '冂', '巾', '廾', '攴', '丷', '尚'],
#  '弌': ['弋'],
#  '弍': ['二', '弋'],
#  '式': ['工', '弋'],
#  '弐': ['二', '弋'],
#  '弑': ['工', '弋', '木'],
#  '弔': ['｜', '弓'],
#  '引': ['｜', '弓'],
#  '弖': ['弓'],
#  '弗': ['｜', '丿', '弓'],
#  '弘': ['厶', '弓'],
#  '弛': ['弓', '也'],
#  '弟': ['｜', '丿', '弓', '丷'],
#  '弥': ['丿', '亅', '小', '弓'],
#  '弦': ['亠', '幺', '弓', '玄'],
#  '弧': ['弓', '瓜'],
#  '弩': ['又', '女', '弓'],
#  '弭': ['弓', '耳'],
#  '弯': ['亠', '八', '弓', '赤'],
#  '弱': ['冫', '弓'],
#  '張': ['弓', '長'],
#  '強': ['厶', '弓', '虫'],
#  '弸': ['弓', '月'],
#  '弼': ['丿', '弓', '白'],
#  '弾': ['十', '弓', '田', '尚'],
#  '彁': ['亅', '口', '弓'],
#  '彈': ['｜', '十', '口', '弓', '田'],
#  '彊': ['弓', '田'],
#  '彌': ['｜', '八', '冂', '弓', '爻'],
#  '彎': ['弓', '糸', '言'],
#  '彑': ['彐'],
#  '当': ['彐', '尚'],
#  '彖': ['豕', '彑'],
#  '彗': ['二', '亠', '土', '彐'],
#  '彙': ['冖', '彐', '木', '田', '彑'],
#  '彜': ['刀', '廾', '彐', '米', '丷', '彑'],
#  '彝': ['廾', '彐', '米', '糸', '彑'],
#  '形': ['丿', '廾', '彡'],
#  '彦': ['亠', '厂', '彡', '立', '丷'],
#  '彩': ['彡', '木', '爪'],
#  '彪': ['儿', '匕', '卜', '厂', '彡', '虍'],
#  '彫': ['冂', '口', '土', '彡'],
#  '彬': ['彡', '木'],
#  '彭': ['口', '土', '彡', '豆', '丷'],
#  '彰': ['十', '彡', '日', '立', '音'],
#  '影': ['亠', '口', '小', '彡', '日'],
#  '彷': ['彳', '方'],
#  '役': ['彳', '殳'],
#  '彼': ['又', '彳', '皮'],
#  '彿': ['｜', '丿', '弓', '彳'],
#  '往': ['丶', '彳', '玉'],
#  '征': ['彳', '止'],
#  '徂': ['彳', '目'],
#  '徃': ['彳', '生'],
#  '径': ['又', '土', '彳'],
#  '待': ['土', '寸', '彳'],
#  '徇': ['勹', '彳', '日'],
#  '很': ['彳', '艮'],
#  '徊': ['口', '囗', '彳'],
#  '律': ['彳', '聿'],
#  '後': ['夂', '幺', '彳'],
#  '徐': ['彳', '禾', '个'],
#  '徑': ['巛', '工', '彳'],
#  '徒': ['土', '彳', '走'],
#  '従': ['彳', '疋', '丷'],
#  '得': ['寸', '彳', '日'],
#  '徘': ['彳', '非'],
#  '徙': ['彳', '止', '疋'],
#  '從': ['人', '彳', '疋'],
#  '徠': ['｜', '人', '八', '彳', '木'],
#  '御': ['丿', '卩', '彳', '止'],
#  '徨': ['彳', '玉', '白'],
#  '復': ['夂', '彳', '日'],
#  '循': ['十', '厂', '彳', '斤', '目'],
#  '徭': ['凵', '夕', '彳', '缶'],
#  '微': ['山', '彳', '攴'],
#  '徳': ['十', '彳', '心', '网'],
#  '徴': ['山', '彳', '攴', '玉'],
#  '徹': ['亠', '厶', '彳', '攴', '月'],
#  '徼': ['夂', '彳', '方', '白'],
#  '徽': ['夂', '山', '彳', '糸'],
#  '必': ['丿', '心'],
#  '忌': ['己', '心'],
#  '忍': ['丶', '刀', '心'],
#  '忖': ['寸', '忄'],
#  '志': ['士', '心'],
#  '忘': ['亠', '心', '亡'],
#  '忙': ['亠', '忄', '亡'],
#  '応': ['广', '心'],
#  '忝': ['丿', '大', '心'],
#  '忠': ['｜', '口', '心'],
#  '忤': ['丿', '十', '干', '忄'],
#  '快': ['二', '人', '大', '忄'],
#  '忰': ['十', '九', '忄'],
#  '忱': ['儿', '冖', '尢', '忄'],
#  '念': ['｜', '心', '个'],
#  '忸': ['｜', '忄'],
#  '忻': ['斤', '忄'],
#  '忽': ['勹', '心', '勿'],
#  '忿': ['八', '刀', '心'],
#  '怎': ['｜', '丿', '心'],
#  '怏': ['人', '冂', '大', '忄'],
#  '怐': ['勹', '口', '忄'],
#  '怒': ['又', '女', '心'],
#  '怕': ['白', '忄'],
#  '怖': ['丿', '巾', '忄'],
#  '怙': ['十', '口', '忄'],
#  '怛': ['日', '忄'],
#  '怜': ['卩', '个', '忄'],
#  '思': ['心', '田'],
#  '怠': ['厶', '口', '心'],
#  '怡': ['厶', '口', '忄'],
#  '急': ['勹', '彐', '心'],
#  '怦': ['干', '丷', '忄'],
#  '性': ['生', '忄'],
#  '怨': ['卩', '夕', '心'],
#  '怩': ['匕', '尸', '忄'],
#  '怪': ['又', '土', '忄'],
#  '怫': ['｜', '丿', '弓', '忄'],
#  '怯': ['厶', '土', '忄'],
#  '怱': ['丶', '丿', '勹', '心', '勿'],
#  '怺': ['丶', '水', '忄'],
#  '恁': ['丿', '士', '心', '亻'],
#  '恂': ['勹', '日', '忄'],
#  '恃': ['土', '寸', '忄'],
#  '恆': ['｜', '彑', '忄'],
#  '恊': ['力', '忄'],
#  '恋': ['亠', '八', '心'],
#  '恍': ['儿', '尚', '忄'],
#  '恐': ['丶', '几', '工', '心'],
#  '恒': ['日', '忄'],
#  '恕': ['口', '女', '心'],
#  '恙': ['心', '玉', '羊', '丷'],
#  '恚': ['土', '心'],
#  '恟': ['凵', '勹', '忄'],
#  '恠': ['丿', '土', '忄'],
#  '恢': ['厂', '火', '忄'],
#  '恣': ['冫', '心', '欠'],
#  '恤': ['皿', '血', '忄'],
#  '恥': ['心', '耳'],
#  '恨': ['艮', '忄'],
#  '恩': ['囗', '大', '心'],
#  '恪': ['口', '夂', '忄'],
#  '恫': ['冂', '口', '忄'],
#  '恬': ['口', '舌', '忄'],
#  '恭': ['八', '心', '井'],
#  '息': ['心', '自'],
#  '恰': ['口', '个', '忄'],
#  '恵': ['心', '田'],
#  '恷': ['心', '木', '亻'],
#  '悁': ['口', '月', '忄'],
#  '悃': ['囗', '木', '忄'],
#  '悄': ['月', '尚', '忄'],
#  '悉': ['丿', '心', '米', '釆'],
#  '悋': ['口', '文', '忄'],
#  '悌': ['｜', '丿', '弓', '丷', '忄'],
#  '悍': ['干', '日', '忄'],
#  '悒': ['口', '忄', '巴'],
#  '悔': ['毋', '忄'],
#  '悖': ['冖', '十', '子', '忄'],
#  '悗': ['儿', '忄', '免'],
#  '悚': ['｜', '八', '口', '木', '忄'],
#  '悛': ['儿', '厶', '夂', '忄'],
#  '悟': ['口', '忄'],
#  '悠': ['｜', '夂', '心', '攴', '亻'],
#  '患': ['｜', '口', '心'],
#  '悦': ['儿', '口', '丷', '忄'],
#  '悧': ['禾', '刂', '忄'],
#  '悩': ['凵', '尚', '忄'],
#  '悪': ['｜', '口', '心'],
#  '悲': ['心', '非'],
#  '悳': ['十', '心', '目'],
#  '悴': ['亠', '人', '十', '忄'],
#  '悵': ['長', '忄'],
#  '悶': ['心', '門'],
#  '悸': ['子', '禾', '忄'],
#  '悼': ['十', '卜', '日', '忄'],
#  '悽': ['女', '彐', '忄'],
#  '情': ['二', '亠', '土', '月', '青', '忄'],
#  '惆': ['冂', '口', '土', '忄'],
#  '惇': ['亠', '口', '子', '忄'],
#  '惑': ['口', '心', '戈'],
#  '惓': ['二', '大', '己', '丷', '忄'],
#  '惘': ['冂', '工', '丷', '忄'],
#  '惚': ['心', '忄', '勿'],
#  '惜': ['｜', '二', '日', '忄'],
#  '惟': ['隹', '忄'],
#  '惠': ['｜', '厶', '心', '日', '虫'],
#  '惡': ['二', '心'],
#  '惣': ['心', '牛', '勿'],
#  '惧': ['八', '目', '忄'],
#  '惨': ['厶', '彡', '忄'],
#  '惰': ['丿', '工', '月', '忄'],
#  '惱': ['囗', '巛', '忄'],
#  '想': ['心', '木', '目'],
#  '惴': ['山', '而', '忄'],
#  '惶': ['玉', '白', '忄'],
#  '惷': ['二', '大', '心', '日'],
#  '惹': ['丿', '口', '心', '艹'],
#  '惺': ['日', '生', '忄'],
#  '惻': ['貝', '刂', '忄'],
#  '愀': ['火', '禾', '忄'],
#  '愁': ['心', '火', '禾'],
#  '愃': ['二', '宀', '日', '忄'],
#  '愆': ['彳', '心', '行', '氵'],
#  '愈': ['心', '月', '个', '刂'],
#  '愉': ['月', '个', '刂', '忄'],
#  '愍': ['口', '心', '攴', '氏'],
#  '愎': ['夂', '日', '忄'],
#  '意': ['心', '日', '立', '音'],
#  '愕': ['二', '勹', '口', '忄'],
#  '愚': ['冂', '厶', '心', '田', '禸'],
#  '愛': ['冖', '夂', '心', '爪'],
#  '感': ['丿', '口', '心', '戈'],
#  '愡': ['丶', '丿', '心', '忄', '勿'],
#  '愧': ['儿', '匕', '田', '鬼', '忄'],
#  '愨': ['冖', '士', '心', '殳'],
#  '愬': ['屮', '心', '月', '丷'],
#  '愴': ['人', '口', '戸', '忄'],
#  '愼': ['八', '匕', '目', '忄'],
#  '愽': ['丶', '十', '寸', '田', '忄'],
#  '愾': ['气', '米', '忄'],
#  '愿': ['厂', '小', '心', '白'],
#  '慂': ['心', '用', 'マ', '氵'],
#  '慄': ['木', '襾', '忄'],
#  '慇': ['心', '日', '殳'],
#  '慈': ['幺', '心', '丷'],
#  '慊': ['｜', '彐', '丷', '忄'],
#  '態': ['匕', '厶', '心', '月'],
#  '慌': ['亠', '巛', '忄', '艹'],
#  '慍': ['日', '皿', '忄'],
#  '慎': ['八', '十', '目', '忄'],
#  '慓': ['示', '襾', '忄'],
#  '慕': ['大', '心', '日', '艹'],
#  '慘': ['厶', '彡', '个', '忄'],
#  '慙': ['心', '斤', '車'],
#  '慚': ['斤', '車', '忄'],
#  '慝': ['丿', '匚', '厂', '口', '心', '艹'],
#  '慟': ['｜', '丿', '力', '日', '忄'],
#  '慢': ['又', '日', '网', '忄'],
#  '慣': ['毋', '貝', '忄'],
#  '慥': ['口', '土', '忄', '辶'],
#  '慧': ['｜', '彐', '心'],
#  '慨': ['牙', '艮', '忄'],
#  '慫': ['彳', '心', '疋', '丷'],
#  '慮': ['匕', '卜', '厂', '心', '田', '虍'],
#  '慯': ['丿', '勹', '日', '忄'],
#  '慰': ['寸', '尸', '心', '示'],
#  '慱': ['亠', '十', '厶', '寸', '日', '虫', '忄'],
#  '慳': ['又', '土', '臣', '忄'],
#  '慴': ['冫', '白', '羽', '忄'],
#  '慵': ['冂', '广', '彐', '用', '聿', '忄'],
#  '慶': ['冖', '夂', '广', '心'],
#  '慷': ['广', '彐', '水', '隶', '忄'],
#  '慾': ['八', '口', '心', '欠', '谷', '个'],
#  '憂': ['冖', '夂', '心', '自'],
#  '憇': ['口', '心', '甘', '舌'],
#  '憊': ['厂', '心', '用', '亻', '艹'],
#  '憎': ['日', '田', '丷', '忄'],
#  '憐': ['夕', '米', '舛', '忄'],
#  '憑': ['冫', '心', '馬'],
#  '憔': ['隹', '忄', '灬'],
#  '憖': ['｜', '人', '八', '心', '木', '犬'],
#  '憙': ['八', '口', '士', '心', '豆'],
#  '憚': ['｜', '十', '口', '田', '忄'],
#  '憤': ['十', '貝', '忄', '艹'],
#  '憧': ['立', '里', '忄'],
#  '憩': ['口', '心', '自', '舌'],
#  '憫': ['文', '門', '忄'],
#  '憬': ['亠', '口', '小', '日', '忄'],
#  '憮': ['忄', '灬', '無'],
#  '憲': ['亠', '土', '宀', '心', '网'],
#  '憶': ['心', '日', '立', '音', '忄'],
#  '憺': ['儿', '勹', '厂', '言', '忄'],
#  '憾': ['丿', '口', '心', '戈', '忄'],
#  '懃': ['力', '心', '艹'],
#  '懆': ['口', '木', '忄', '品'],
#  '懇': ['心', '爪', '艮', '豸', '犭'],
#  '懈': ['刀', '牛', '角', '忄'],
#  '應': ['广', '心', '隹', '亻'],
#  '懊': ['冂', '大', '米', '忄'],
#  '懋': ['心', '木', '矛', 'マ'],
#  '懌': ['亠', '十', '土', '立', '网', '辛', '忄'],
#  '懍': ['亠', '口', '囗', '禾', '忄'],
#  '懐': ['十', '网', '衣', '忄'],
#  '懣': ['｜', '入', '冂', '凵', '心', '氵'],
#  '懦': ['而', '雨', '忄'],
#  '懲': ['山', '彳', '心', '攴', '玉'],
#  '懴': ['土', '戈', '韭', '忄'],
#  '懶': ['｜', '八', '口', '木', '貝', '頁', '忄'],
#  '懷': ['亠', '网', '衣', '忄'],
#  '懸': ['丿', '小', '心', '目', '糸'],
#  '懺': ['人', '戈', '韭', '忄'],
#  '懼': ['目', '隹', '忄'],
#  '懽': ['十', '口', '隹', '忄', '艹'],
#  '懾': ['耳', '忄'],
#  '懿': ['冖', '冫', '口', '士', '心', '欠', '豆', '丷'],
#  '戀': ['心', '糸', '言'],
#  '戉': ['戈'],
#  '戊': ['丿', '戈'],
#  '戌': ['丿', '戈'],
#  '戍': ['丶', '丿', '戈'],
#  '戎': ['戈'],
#  '成': ['丿', '戈'],
#  '我': ['亅', '戈', '手'],
#  '戒': ['廾', '戈'],
#  '戔': ['戈'],
#  '或': ['口', '戈'],
#  '戚': ['丿', '卜', '小', '戈'],
#  '戛': ['戈', '白', '自'],
#  '戝': ['戈', '貝'],
#  '戞': ['冖', '戈', '自'],
#  '戟': ['十', '戈', '日'],
#  '戡': ['儿', '匚', '戈', '甘'],
#  '戦': ['十', '戈', '田', '尚'],
#  '截': ['土', '戈', '隹'],
#  '戮': ['冫', '彡', '戈', '羽', '个'],
#  '戯': ['匕', '卜', '厂', '戈', '虍'],
#  '戰': ['｜', '十', '口', '戈', '田'],
#  '戲': ['匕', '卜', '厂', '口', '戈', '虍', '豆', '丷'],
#  '戳': ['彐', '戈', '隹'],
#  '戴': ['｜', '二', '八', '土', '戈', '田'],
#  '戻': ['大', '戸'],
#  '房': ['戸', '方'],
#  '所': ['戸', '斤'],
#  '扁': ['｜', '冂', '戸', '冊'],
#  '扇': ['冫', '戸', '羽'],
#  '扈': ['口', '戸', '.阝', '巴'],
#  '扉': ['戸', '非'],
#  '才': ['丿', '亅'],
#  '扎': ['乙', '扌'],
#  '打': ['亅', '扌'],
#  '払': ['厶', '扌'],
#  '托': ['丿', '乙', '扌'],
#  '扛': ['工', '扌'],
#  '扞': ['干', '扌'],
#  '扠': ['丶', '又', '扌'],
#  '扣': ['口', '扌'],
#  '扨': ['丶', '刀', '扌'],
#  '扮': ['八', '刀', '扌'],
#  '扱': ['扌', '及'],
#  '扶': ['二', '人', '大', '扌'],
#  '批': ['比', '扌'],
#  '扼': ['卩', '厂', '扌'],
#  '找': ['戈', '扌'],
#  '承': ['丿', '亅', '二', '手', 'マ'],
#  '技': ['十', '又', '支', '扌'],
#  '抂': ['玉', '扌'],
#  '抃': ['亠', '卜', '扌'],
#  '抄': ['丿', '小', '扌'],
#  '抉': ['二', '人', '大', 'ユ', '扌'],
#  '把': ['扌', '巴'],
#  '抑': ['卩', '扌'],
#  '抒': ['亅', '矛', 'マ', '扌'],
#  '抓': ['爪', '扌'],
#  '抔': ['｜', '丶', '丿', '扌'],
#  '投': ['殳', '扌'],
#  '抖': ['斗', '扌'],
#  '抗': ['亠', '几', '扌'],
#  '折': ['斤', '扌'],
#  '抛': ['丿', '力', '九', '扌'],
#  '抜': ['亠', '又', '夂', '扌'],
#  '択': ['尸', '扌'],
#  '披': ['又', '皮', '扌'],
#  '抬': ['厶', '口', '扌'],
#  '抱': ['勹', '己', '扌'],
#  '抵': ['氏', '扌'],
#  '抹': ['｜', '亠', '八', '木', '扌'],
#  '抻': ['｜', '日', '田', '扌'],
#  '押': ['｜', '日', '田', '扌'],
#  '抽': ['｜', '日', '田', '扌'],
#  '拂': ['｜', '丿', '弓', '扌'],
#  '担': ['日', '扌'],
#  '拆': ['丶', '斤', '扌'],
#  '拇': ['毋', '扌'],
#  '拈': ['卜', '口', '扌'],
#  '拉': ['立', '扌'],
#  '拊': ['寸', '亻', '扌'],
#  '拌': ['｜', '二', '十', '干', '丷', '尚', '扌'],
#  '拍': ['白', '扌'],
#  '拏': ['又', '女', '手'],
#  '拐': ['刀', '口', '扌'],
#  '拑': ['甘', '扌'],
#  '拒': ['匚', '扌', '巨'],
#  '拓': ['口', '石', '扌'],
#  '拔': ['丶', '丿', '扌'],
#  '拗': ['力', '幺', '扌'],
#  '拘': ['勹', '口', '扌'],
#  '拙': ['｜', '山', '扌'],
#  '招': ['刀', '口', '扌'],
#  '拜': ['丿', '干', '扌'],
#  '拝': ['｜', '干', '扌'],
#  '拠': ['几', '夂', '扌'],
#  '拡': ['厶', '广', '扌'],
#  '括': ['丿', '十', '口', '舌', '扌'],
#  '拭': ['工', '弋', '扌'],
#  '拮': ['口', '士', '扌'],
#  '拯': ['水', '扌'],
#  '拱': ['｜', '二', '八', '扌'],
#  '拳': ['大', '手', '丷'],
#  '拵': ['丿', '子', '扌'],
#  '拶': ['夕', '巛', '扌'],
#  '拷': ['老', '扌'],
#  '拾': ['口', '个', '扌'],
#  '拿': ['口', '手', '个'],
#  '持': ['土', '寸', '扌'],
#  '挂': ['土', '扌'],
#  '指': ['匕', '日', '扌'],
#  '挈': ['刀', '土', '手'],
#  '按': ['女', '宀', '扌'],
#  '挌': ['口', '夂', '扌'],
#  '挑': ['儿', '冫', '扌'],
#  '挙': ['八', '手', '尚'],
#  '挟': ['丶', '二', '亠', '人', '大', '丷', '扌'],
#  '挧': ['冫', '羽', '扌'],
#  '挨': ['厶', '矢', '扌'],
#  '挫': ['｜', '入', '土', '扌'],
#  '振': ['厂', '衣', '辰', '扌'],
#  '挺': ['廴', '玉', '扌'],
#  '挽': ['｜', '儿', '扌', '免'],
#  '挾': ['人', '大', '扌'],
#  '挿': ['｜', '丿', '十', '日', '田', '扌'],
#  '捉': ['口', '足', '扌'],
#  '捌': ['力', '口', '刂', '扌'],
#  '捍': ['干', '日', '扌'],
#  '捏': ['土', '日', '扌'],
#  '捐': ['口', '月', '扌'],
#  '捕': ['丶', '十', '用', '扌'],
#  '捗': ['丿', '小', '止', '扌'],
#  '捜': ['｜', '又', '日', '田', '扌'],
#  '捧': ['｜', '丿', '二', '人', '大', '扌'],
#  '捨': ['口', '土', '个', '扌'],
#  '捩': ['大', '戸', '扌'],
#  '捫': ['門', '扌'],
#  '据': ['十', '口', '尸', '扌'],
#  '捲': ['大', '己', '丷', '扌'],
#  '捶': ['｜', '丿', '二', '扌'],
#  '捷': ['彐', '疋', '扌'],
#  '捺': ['大', '示', '扌'],
#  '捻': ['｜', '心', '个', '扌'],
#  '掀': ['斤', '欠', '扌'],
#  '掃': ['冖', '巾', '彐', '扌'],
#  '授': ['冖', '又', '爪', '扌'],
#  '掉': ['十', '卜', '日', '曰', '扌'],
#  '掌': ['冖', '口', '手', '尚'],
#  '掎': ['亅', '口', '大', '扌'],
#  '掏': ['凵', '勹', '缶', '扌'],
#  '排': ['非', '扌'],
#  '掖': ['丶', '亠', '夂', '夕', '亻', '扌'],
#  '掘': ['｜', '尸', '山', '扌'],
#  '掛': ['卜', '土', '扌'],
#  '掟': ['宀', '疋', '扌'],
#  '掠': ['亠', '口', '小', '扌'],
#  '採': ['木', '爪', '扌'],
#  '探': ['儿', '冖', '木', '扌'],
#  '掣': ['凵', '巾', '手', '牛', '缶', '刂'],
#  '接': ['女', '立', '扌'],
#  '控': ['儿', '宀', '工', '穴', '扌'],
#  '推': ['隹', '扌'],
#  '掩': ['乙', '大', '日', '扌', '奄'],
#  '措': ['｜', '二', '日', '扌'],
#  '掫': ['又', '耳', '扌'],
#  '掬': ['勹', '米', '扌'],
#  '掲': ['勹', '匕', '日', '扌'],
#  '掴': ['丶', '囗', '玉', '扌'],
#  '掵': ['卩', '口', '个', '扌'],
#  '掻': ['又', '虫', '扌'],
#  '掾': ['彐', '豕', '扌'],
#  '揀': ['｜', '八', '日', '木', '扌'],
#  '揃': ['月', '丷', '刂', '扌'],
#  '揄': ['月', '个', '刂', '扌'],
#  '揆': ['二', '人', '大', '癶', '扌'],
#  '揉': ['木', '矛', 'マ', '扌'],
#  '描': ['田', '扌', '艹'],
#  '提': ['日', '疋', '扌'],
#  '插': ['丿', '十', '臼', '扌'],
#  '揖': ['口', '耳', '扌'],
#  '揚': ['日', '扌', '勿'],
#  '換': ['儿', '冂', '勹', '大', '扌'],
#  '握': ['厶', '土', '尸', '至', '扌'],
#  '揣': ['山', '而', '扌'],
#  '揩': ['比', '白', '扌'],
#  '揮': ['冖', '車', '扌'],
#  '援': ['丿', '又', '爪', '扌'],
#  '揶': ['耳', '扌', '.阝'],
#  '揺': ['凵', '干', '爪', '缶', '扌'],
#  '搆': ['｜', '八', '冂', '黄', '扌'],
#  '損': ['口', '貝', '扌'],
#  '搏': ['丶', '十', '寸', '田', '扌'],
#  '搓': ['工', '玉', '羊', '丷', '扌'],
#  '搖': ['凵', '夕', '缶', '扌'],
#  '搗': ['山', '鳥', '扌'],
#  '搜': ['｜', '十', '又', '支', '臼', '扌'],
#  '搦': ['冫', '弓', '扌'],
#  '搨': ['冫', '日', '羽', '扌'],
#  '搬': ['殳', '舟', '扌'],
#  '搭': ['口', '个', '扌', '艹'],
#  '搴': ['｜', '二', '八', '宀', '手'],
#  '搶': ['口', '戸', '个', '扌'],
#  '携': ['丿', '隹', '乃', '扌'],
#  '搾': ['｜', '丿', '儿', '宀', '穴', '扌'],
#  '摂': ['冫', '耳', '扌'],
#  '摎': ['冫', '彡', '羽', '个', '扌'],
#  '摘': ['亠', '冂', '十', '口', '立', '丷', '扌', '啇'],
#  '摧': ['山', '隹', '扌'],
#  '摩': ['广', '手', '木', '麻'],
#  '摯': ['丶', '丿', '十', '手', '立', '辛', '九'],
#  '摶': ['十', '厶', '寸', '日', '虫', '扌'],
#  '摸': ['大', '日', '扌', '艹'],
#  '摺': ['冫', '白', '羽', '扌'],
#  '撃': ['手', '殳', '車'],
#  '撈': ['冖', '力', '火', '扌'],
#  '撒': ['｜', '夂', '攴', '月', '扌'],
#  '撓': ['儿', '土', '扌'],
#  '撕': ['八', '斤', '甘', '扌'],
#  '撚': ['夕', '犬', '扌', '灬'],
#  '撞': ['立', '里', '扌'],
#  '撤': ['亠', '厶', '攴', '月', '扌'],
#  '撥': ['二', '儿', '癶', '扌'],
#  '撩': ['亠', '人', '大', '小', '日', '丷', '扌'],
#  '撫': ['｜', '丿', '扌', '灬', '無'],
#  '播': ['田', '米', '釆', '扌'],
#  '撮': ['又', '日', '耳', '扌'],
#  '撰': ['｜', '二', '八', '己', '扌'],
# ...
#  '雉': ['矢', '隹'],
#  '雋': ['亅', '冂', '凵', '隹'],
#  '雌': ['匕', '止', '隹'],
#  '雍': ['亠', '幺', '隹'],
#  '雎': ['目', '隹'],
#  '雑': ['木', '隹', '九'],
#  '雕': ['冂', '口', '士', '隹'],
#  '雖': ['口', '虫', '隹'],
#  '雙': ['又', '隹'],
#  '雛': ['勹', '屮', '隹'],
#  '雜': ['亠', '人', '木', '隹'],
#  '離': ['亠', '凵', '禸', '隹'],
#  '難': ['亠', '口', '大', '隹', '艹'],
#  '雪': ['彐', '雨'],
#  '雫': ['｜', '丶', '雨'],
#  '雰': ['八', '刀', '雨'],
#  '雲': ['二', '厶', '雨'],
#  '零': ['卩', '雨', '个'],
#  '雷': ['田', '雨'],
#  '雹': ['勹', '己', '雨'],
#  '電': ['乙', '田', '雨'],
#  '需': ['而', '雨'],
#  '霄': ['月', '雨', '尚'],
#  '霆': ['廴', '玉', '雨'],
#  '震': ['厂', '衣', '辰', '雨'],
#  '霈': ['亠', '巾', '雨', '氵'],
#  '霊': ['｜', '二', '雨'],
#  '霍': ['隹', '雨'],
#  '霎': ['女', '立', '雨'],
#  '霏': ['雨', '非'],
#  '霑': ['卜', '口', '雨', '氵'],
#  '霓': ['儿', '臼', '雨'],
#  '霖': ['木', '雨'],
#  '霙': ['冂', '大', '雨', '艹'],
#  '霜': ['木', '目', '雨'],
#  '霞': ['又', '雨'],
#  '霤': ['刀', '厶', '田', '雨'],
#  '霧': ['力', '夂', '矛', '雨'],
#  '霪': ['爪', '玉', '雨', '氵'],
#  '霰': ['｜', '二', '攴', '月', '雨'],
#  '露': ['口', '夂', '足', '雨'],
#  '霸': ['月', '雨', '革'],
#  '霹': ['十', '口', '尸', '立', '辛', '雨'],
#  '霽': ['亠', '雨', '齊'],
#  '霾': ['豸', '里', '雨'],
#  '靂': ['厂', '木', '止', '雨'],
#  '靄': ['勹', '匕', '日', '言', '雨'],
#  '靆': ['二', '厶', '彐', '水', '隶', '雨', '辶'],
#  '靈': ['人', '口', '工', '雨'],
#  '靉': ['二', '冖', '厶', '夂', '心', '爪', '雨'],
#  '青': ['二', '亠', '土', '月'],
#  '靖': ['二', '亠', '土', '月', '立', '青'],
#  '静': ['亅', '亠', '勹', '土', '彐', '月', '青'],
#  '靜': ['丿', '亅', '二', '亠', '土', '彐', '月', '爪', '青', '尚'],
#  '靠': ['丿', '口', '土', '非'],
#  '靡': ['广', '木', '非', '麻'],
#  '靤': ['勹', '己', '面'],
#  '靦': ['見', '面'],
#  '靨': ['厂', '日', '犬', '目', '面'],
#  '革': ['十', '口', '廾'],
#  '靫': ['丶', '又', '革'],
#  '靭': ['丶', '刀', '革'],
#  '靱': ['刀', '革'],
#  '靴': ['匕', '革', '亻'],
#  '靹': ['人', '冂', '革'],
#  '靺': ['｜', '亠', '八', '凵', '口', '木', '革'],
#  '靼': ['日', '革'],
#  '鞁': ['又', '皮', '革'],
#  '鞄': ['勹', '己', '革'],
#  '鞅': ['人', '冂', '凵', '口', '大', '革'],
#  '鞆': ['人', '冂', '革'],
#  '鞋': ['土', '革'],
#  '鞍': ['女', '宀', '革'],
#  '鞏': ['丶', '几', '工', '革'],
#  '鞐': ['卜', '革'],
#  '鞘': ['月', '革', '尚'],
#  '鞜': ['日', '水', '革'],
#  '鞠': ['勹', '米', '革'],
#  '鞣': ['｜', '凵', '口', '木', '矛', '革', 'マ'],
#  '鞦': ['火', '禾', '革'],
#  '鞨': ['勹', '匕', '日', '革'],
#  '鞫': ['勹', '言', '革'],
#  '鞭': ['丿', '日', '田', '革', '亻'],
#  '鞳': ['口', '革', '个', '艹'],
#  '鞴': ['厂', '用', '革', '艹'],
#  '韃': ['土', '玉', '羊', '革', '丷', '辶'],
#  '韆': ['八', '己', '襾', '革', '辶'],
#  '韈': ['丿', '戈', '网', '革', '艹'],
#  '韋': ['口'],
#  '韓': ['十', '口', '日', '韋'],
#  '韜': ['口', '爪', '臼', '韋'],
#  '韮': ['韭', '艹'],
#  '韲': ['亠', '韭', '齊'],
#  '音': ['日', '立'],
#  '韵': ['冫', '勹', '日', '立', '音'],
#  '韶': ['刀', '口', '日', '立', '音'],
#  '韻': ['口', '日', '立', '貝', '音'],
#  '響': ['幺', '日', '立', '艮', '音', '.阝'],
#  '頁': ['貝'],
#  '頂': ['亅', '貝', '頁'],
#  '頃': ['匕', '貝', '頁'],
#  '項': ['工', '貝', '頁'],
#  '順': ['巛', '貝', '頁'],
#  '須': ['彡', '貝', '頁'],
#  '頌': ['八', '厶', '貝', '頁'],
#  '頏': ['亠', '儿', '貝', '頁'],
#  '預': ['亅', '欠', '貝', '頁', 'マ'],
#  '頑': ['二', '儿', '貝', '頁', '元'],
#  '頒': ['八', '刀', '貝', '頁'],
#  '頓': ['貝', '頁', '屯'],
#  '頗': ['又', '皮', '貝', '頁'],
#  '領': ['卩', '貝', '頁', '个'],
#  '頚': ['又', '土', '貝', '頁'],
#  '頡': ['口', '士', '貝', '頁'],
#  '頤': ['匚', '臣', '貝', '頁'],
#  '頬': ['二', '人', '貝', '頁', '丷'],
#  '頭': ['口', '豆', '貝', '頁', '丷'],
#  '頴': ['匕', '示', '貝', '頁'],
#  '頷': ['口', '貝', '頁', '个'],
#  '頸': ['巛', '工', '貝', '頁'],
#  '頻': ['丿', '小', '止', '貝', '頁'],
#  '頼': ['｜', '八', '口', '木', '貝', '頁'],
#  '頽': ['几', '禾', '貝', '頁'],
#  '顆': ['｜', '日', '木', '田', '貝', '頁'],
#  '顋': ['心', '田', '貝', '頁'],
#  '題': ['日', '疋', '貝', '頁'],
#  '額': ['口', '夂', '宀', '貝', '頁'],
#  '顎': ['二', '勹', '口', '貝', '頁'],
#  '顏': ['厂', '彡', '文', '貝', '頁'],
#  '顔': ['亠', '八', '厂', '彡', '立', '貝', '頁'],
#  '顕': ['日', '貝', '頁'],
#  '願': ['厂', '小', '白', '貝', '頁'],
#  '顛': ['八', '十', '目', '貝', '頁'],
#  '類': ['大', '米', '貝', '頁'],
#  '顧': ['戸', '貝', '隹', '頁'],
#  '顫': ['亠', '口', '囗', '日', '貝', '頁'],
#  '顯': ['幺', '日', '貝', '頁', '灬'],
#  '顰': ['丿', '十', '小', '止', '田', '貝', '頁'],
#  '顱': ['匕', '卜', '厂', '田', '皿', '虍', '貝', '頁'],
#  '顳': ['耳', '貝', '頁'],
#  '顴': ['十', '口', '貝', '隹', '頁', '艹'],
#  '風': ['丿', '冂', '虫'],
#  '颪': ['卜', '風'],
#  '颯': ['立', '風'],
#  '颱': ['厶', '口', '風'],
#  '颶': ['八', '目', '風'],
#  '飃': ['示', '襾', '風'],
#  '飄': ['示', '襾', '風'],
#  '飆': ['犬', '風'],
#  '飜': ['田', '米', '釆', '飛'],
#  '飢': ['几', '食'],
#  '飩': ['食', '屯'],
#  '飫': ['丿', '大', '食'],
#  '飭': ['力', '食'],
#  '飮': ['｜', '欠', '食', '个'],
#  '飯': ['厂', '又', '食'],
#  '飲': ['欠', '食'],
#  '飴': ['厶', '口', '食'],
#  '飼': ['亅', '口', '艮', '食', '个'],
#  '飽': ['勹', '己', '食'],
#  '飾': ['丿', '巾', '食'],
#  '餃': ['亠', '父', '食'],
#  '餅': ['｜', '丿', '二', '廾', '食', '丷'],
#  '餉': ['冂', '口', '食'],
#  '養': ['玉', '羊', '食', '丷'],
#  '餌': ['耳', '艮', '食'],
#  '餐': ['又', '夕', '食'],
#  '餒': ['女', '爪', '食'],
#  '餓': ['亅', '戈', '手', '食'],
#  '餔': ['丶', '十', '用', '食'],
#  '餘': ['亅', '二', '八', '干', '食', '个'],
#  '餝': ['方', '食', '艹'],
#  '餞': ['戈', '食'],
#  '餠': ['｜', '干', '食'],
#  '餡': ['臼', '食'],
#  '餤': ['火', '食'],
#  '館': ['口', '宀', '食'],
#  '餬': ['十', '口', '月', '食'],
#  '餮': ['彡', '歹', '食', '个'],
#  '餽': ['儿', '匕', '田', '食', '鬼'],
#  '餾': ['卩', '厶', '田', '食'],
#  '饂': ['日', '皿', '食'],
#  '饅': ['又', '日', '网', '食'],
#  '饉': ['｜', '二', '食', '艹'],
#  '饋': ['｜', '口', '貝', '食'],
#  '饌': ['｜', '二', '八', '己', '食'],
#  '饐': ['冖', '口', '士', '豆', '食', '丷'],
#  '饑': ['丶', '幺', '戈', '食'],
#  '饒': ['儿', '土', '食'],
#  '饕': ['儿', '匕', '卜', '厂', '口', '虍', '食'],
#  '饗': ['幺', '艮', '食', '.阝'],
#  '首': ['目', '自', '丷'],
#  '馗': ['目', '自', '首', '丷', '九'],
#  '馘': ['口', '戈', '目', '自', '首', '丷'],
#  '香': ['日', '禾'],
#  '馥': ['夂', '日', '禾', '香'],
#  '馨': ['几', '又', '士', '日', '禾', '香'],
#  '馭': ['又', '馬'],
#  '馮': ['冫', '馬'],
#  '馳': ['馬', '也'],
#  '馴': ['巛', '馬', '鳥', '灬'],
#  '馼': ['文', '馬'],
#  '駁': ['爻', '馬'],
#  '駄': ['丶', '大', '馬'],
#  '駅': ['尸', '馬'],
#  '駆': ['丶', '丿', '匚', '馬'],
#  '駈': ['斤', '馬'],
#  '駐': ['丶', '玉', '馬'],
#  '駑': ['又', '女', '馬'],
#  '駒': ['勹', '口', '馬'],
#  '駕': ['力', '口', '馬'],
#  '駘': ['厶', '口', '馬'],
#  '駛': ['丿', '口', '馬'],
#  '駝': ['匕', '宀', '馬'],
#  '駟': ['儿', '囗', '馬'],
#  '駢': ['｜', '丿', '二', '廾', '馬', '丷'],
#  '駭': ['亠', '人', '馬'],
#  '駮': ['亠', '父', '馬'],
#  '駱': ['口', '夂', '馬'],
#  '駲': ['｜', '丶', '丿', '巛', '馬'],
#  '駸': ['冖', '又', '彐', '馬'],
#  '駻': ['干', '日', '馬'],
#  '駿': ['儿', '厶', '夂', '馬'],
#  '騁': ['｜', '勹', '日', '田', '馬'],
#  '騅': ['隹', '馬'],
#  '騎': ['亅', '口', '大', '馬'],
#  '騏': ['八', '甘', '馬'],
#  '騒': ['又', '虫', '馬'],
#  '験': ['人', '口', '馬', '个'],
#  '騙': ['｜', '冂', '戸', '馬', '冊'],
#  '騨': ['十', '田', '馬', '尚'],
#  '騫': ['｜', '八', '宀', '馬'],
#  '騰': ['月', '馬', '丷'],
#  '騷': ['丶', '又', '虫', '馬'],
#  '騾': ['田', '糸', '馬'],
#  '驀': ['大', '日', '馬', '艹'],
#  '驂': ['厶', '大', '彡', '馬'],
#  '驃': ['示', '襾', '馬'],
#  '驅': ['匚', '口', '馬', '品'],
#  '驍': ['儿', '土', '馬'],
#  '驕': ['丿', '冂', '口', '大', '馬'],
#  '驗': ['人', '口', '馬', '个'],
#  '驚': ['勹', '口', '夂', '攴', '馬', '艹'],
#  '驛': ['亠', '十', '立', '网', '辛', '馬'],
#  '驟': ['又', '耳', '衣', '馬'],
#  '驢': ['匕', '卜', '厂', '田', '皿', '虍', '馬'],
#  '驤': ['｜', '二', '亠', '八', '衣', '馬'],
#  '驥': ['｜', '二', '八', '匕', '爿', '田', '馬'],
#  '驩': ['十', '口', '隹', '馬', '艹'],
#  '驪': ['亠', '冂', '广', '比', '馬', '鹿'],
#  '驫': ['馬'],
#  '骨': ['冂', '冖', '月'],
#  '骭': ['冂', '冖', '干', '月', '骨'],
#  '骰': ['冂', '冖', '月', '殳', '骨'],
#  '骸': ['亠', '人', '冂', '冖', '月', '骨'],
#  '骼': ['冂', '冖', '口', '夂', '月', '骨'],
#  '髀': ['冂', '冖', '十', '月', '田', '骨'],
#  '髄': ['丿', '冖', '月', '骨', '辶'],
#  '髏': ['｜', '冂', '冖', '口', '女', '月', '骨'],
#  '髑': ['冂', '冖', '勹', '月', '网', '虫', '骨'],
#  '髓': ['丿', '冂', '冖', '工', '月', '骨', '辶'],
#  '體': ['｜', '冂', '冖', '口', '日', '月', '豆', '骨', '丷'],
#  '高': ['亠', '冂', '口'],
#  '髞': ['亠', '冂', '口', '木', '高', '品'],
#  '髟': ['彡', '長'],
#  '髢': ['匕', '彡', '長', '髟', '也'],
#  '髣': ['彡', '方', '長', '髟'],
#  '髦': ['彡', '毛', '長', '髟'],
#  '髪': ['夂', '彡', '長', '髟'],
#  '髫': ['刀', '口', '彡', '長', '髟'],
#  '髭': ['匕', '彡', '止', '長', '髟'],
#  '髮': ['又', '彡', '攴', '長', '髟'],
#  '髯': ['｜', '冂', '厶', '彡', '長', '髟'],
#  '髱': ['勹', '己', '彡', '長', '髟'],
#  '髴': ['｜', '丿', '弓', '彡', '長', '髟'],
#  '髷': ['｜', '厶', '彡', '日', '長', '髟'],
#  '髻': ['口', '士', '彡', '長', '髟'],
#  '鬆': ['八', '厶', '彡', '木', '長', '髟'],
#  '鬘': ['又', '彡', '日', '网', '長', '髟'],
#  '鬚': ['彡', '貝', '長', '頁', '髟'],
#  '鬟': ['口', '彡', '网', '衣', '長', '髟'],
#  '鬢': ['丿', '宀', '小', '彡', '貝', '長', '髟'],
#  '鬣': ['囗', '彡', '臼', '長', '髟', '鼠'],
#  '鬧': ['亠', '巾', '鬥'],
#  '鬨': ['｜', '亅', '二', '八', '鬥'],
#  '鬩': ['儿', '臼', '鬥'],
#  '鬪': ['口', '寸', '豆', '鬥', '丷'],
#  '鬮': ['鬥', '龜'],
#  '鬯': ['凵', '匕'],
#  '鬱': ['冖', '凵', '匕', '彡', '木', '缶'],
#  '鬲': ['儿', '冂', '口'],
#  '鬻': ['儿', '冂', '口', '弓', '米', '鬲'],
#  '鬼': ['儿', '匕', '厶', '田'],
#  '魁': ['儿', '厶', '斗', '田', '鬼'],
#  '魂': ['二', '儿', '匕', '厶', '田', '鬼'],
#  '魃': ['丶', '儿', '匕', '攴', '田', '鬼'],
#  '魄': ['儿', '匕', '田', '白', '鬼'],
#  '魅': ['｜', '二', '亠', '儿', '八', '匕', '木', '田', '鬼'],
#  '魍': ['儿', '冂', '匕', '田', '鬼', '丷', '亡'],
#  '魎': ['｜', '儿', '入', '冂', '厶', '田', '鬼'],
#  '魏': ['儿', '匕', '女', '田', '禾', '鬼'],
#  '魑': ['亠', '儿', '凵', '匕', '田', '禸', '鬼'],
#  '魔': ['儿', '匕', '广', '木', '田', '鬼', '麻'],
#  '魘': ['儿', '匕', '厂', '日', '月', '犬', '田', '鬼'],
#  '魚': ['田', '灬'],
#  '魯': ['日', '田', '魚', '灬'],
#  '魴': ['方', '田', '魚', '灬'],
#  '鮃': ['干', '田', '魚', '丷', '灬'],
#  '鮎': ['卜', '口', '田', '魚'],
#  '鮑': ['勹', '己', '田', '魚', '灬'],
#  '鮒': ['寸', '田', '魚', '亻', '灬'],
#  '鮓': ['｜', '丿', '田', '魚', '灬'],
#  '鮖': ['口', '田', '石', '魚', '灬'],
#  '鮗': ['冫', '夂', '田', '魚', '灬'],
#  '鮟': ['女', '宀', '田', '魚', '灬'],
#  '鮠': ['卩', '厂', '田', '隹', '魚', '灬'],
#  '鮨': ['匕', '日', '田', '魚', '灬'],
#  '鮪': ['丿', '月', '田', '魚', '灬'],
#  '鮫': ['亠', '父', '田', '魚', '灬'],
#  '鮭': ['土', '田', '魚', '灬'],
#  '鮮': ['玉', '田', '羊', '魚', '丷', '灬'],
#  '鮴': ['木', '田', '魚', '亻', '灬'],
#  '鮹': ['月', '田', '魚', '尚', '灬'],
#  '鯀': ['丿', '田', '糸', '魚', '灬'],
#  '鯆': ['丶', '十', '用', '田', '魚', '灬'],
#  '鯉': ['田', '里', '魚', '灬'],
#  '鯊': ['丿', '小', '田', '魚', '氵', '灬'],
#  '鯏': ['田', '禾', '魚', '刂', '灬'],
#  '鯑': ['丿', '巾', '田', '魚', '灬'],
#  '鯒': ['用', '田', '魚', '灬'],
#  '鯔': ['巛', '田', '魚', '灬'],
#  '鯖': ['二', '亠', '土', '月', '田', '青', '魚', '灬'],
#  '鯛': ['冂', '口', '土', '田', '魚', '灬'],
#  '鯡': ['田', '非', '魚', '灬'],
#  '鯢': ['儿', '田', '臼', '魚', '灬'],
#  '鯣': ['丿', '勹', '日', '田', '魚', '灬'],
#  '鯤': ['日', '比', '田', '魚', '灬'],
#  '鯨': ['亠', '口', '小', '田', '魚', '灬'],
#  '鯰': ['心', '田', '魚', '个', '灬'],
#  '鯱': ['儿', '匕', '卜', '厂', '田', '虍', '魚', '灬'],
#  '鯲': ['冫', '方', '田', '魚', '个', '灬'],
#  '鯵': ['厶', '大', '彡', '田', '魚', '灬'],
#  '鰄': ['丿', '女', '戈', '田', '魚', '灬'],
#  '鰆': ['二', '人', '大', '日', '田', '魚', '灬'],
#  '鰈': ['木', '田', '魚', '灬', '世'],
#  '鰉': ['玉', '田', '白', '魚', '灬'],
#  '鰊': ['｜', '口', '木', '田', '网', '魚', '丷', '灬'],
#  '鰌': ['八', '田', '酉', '魚', '灬'],
#  '鰍': ['火', '田', '禾', '魚', '灬'],
#  '鰐': ['二', '勹', '口', '田', '魚', '灬'],
#  '鰒': ['夂', '日', '田', '魚', '灬'],
#  '鰓': ['心', '田', '魚', '灬'],
#  '鰔': ['丿', '口', '戈', '田', '魚', '灬'],
#  '鰕': ['｜', '又', '口', '田', '魚', '灬'],
#  '鰛': ['日', '田', '皿', '魚', '灬'],
#  '鰡': ['刀', '厶', '田', '魚', '灬'],
#  '鰤': ['｜', '冂', '口', '巾', '田', '魚', '灬'],
#  '鰥': ['｜', '冫', '田', '网', '魚', '灬'],
#  '鰭': ['日', '田', '老', '魚', '灬'],
#  '鰮': ['人', '囗', '田', '皿', '魚', '灬'],
#  '鰯': ['冫', '弓', '田', '魚', '灬'],
#  '鰰': ['｜', '田', '魚', '灬', '礻'],
#  '鰲': ['土', '攴', '方', '田', '魚', '灬'],
#  '鰹': ['又', '土', '田', '臣', '魚', '灬'],
#  '鰺': ['厶', '彡', '田', '魚', '个', '灬'],
#  '鰻': ['又', '日', '田', '网', '魚', '灬'],
#  '鰾': ['田', '示', '襾', '魚', '灬'],
#  '鱆': ['十', '日', '田', '立', '音', '魚', '灬'],
#  '鱇': ['广', '彐', '水', '田', '隶', '魚', '灬'],
#  '鱈': ['彐', '田', '雨', '魚', '灬'],
#  '鱒': ['寸', '田', '酉', '魚', '丷', '灬'],
#  '鱗': ['夕', '田', '米', '舛', '魚', '灬'],
#  '鱚': ['十', '口', '士', '田', '豆', '魚', '丷', '灬'],
#  '鱠': ['日', '田', '网', '魚', '个', '灬'],
#  '鱧': ['｜', '日', '田', '豆', '魚', '灬'],
#  '鱶': ['玉', '田', '羊', '艮', '食', '魚', '丷', '灬'],
#  '鱸': ['匕', '卜', '厂', '田', '皿', '虍', '魚', '灬'],
#  '鳥': ['灬'],
#  '鳧': ['几', '鳥', '灬'],
#  '鳩': ['鳥', '九', '灬'],
#  '鳫': ['厂', '鳥', '灬'],
#  '鳬': ['几', '鳥'],
#  '鳰': ['入', '鳥', '灬'],
#  '鳳': ['几', '鳥', '灬'],
#  '鳴': ['口', '鳥', '灬'],
#  '鳶': ['弋', '鳥', '灬'],
#  '鴃': ['二', '人', '大', '鳥', '灬'],
#  '鴆': ['尢', '鳥', '灬'],
#  '鴇': ['匕', '十', '鳥', '灬'],
#  '鴈': ['厂', '鳥', '亻', '灬'],
#  '鴉': ['牙', '鳥', '灬'],
#  '鴎': ['丶', '丿', '匚', '鳥', '灬'],
#  '鴒': ['卩', '鳥', '个', '灬'],
#  '鴕': ['匕', '宀', '鳥', '灬'],
#  '鴛': ['卩', '夕', '鳥', '灬'],
#  '鴟': ['氏', '鳥', '灬'],
#  '鴣': ['十', '口', '鳥', '灬'],
#  '鴦': ['大', '鳥', '灬'],
#  '鴨': ['｜', '日', '田', '鳥', '灬'],
#  '鴪': ['八', '宀', '穴', '鳥', '灬'],
#  '鴫': ['田', '鳥', '灬'],
#  '鴬': ['冖', '鳥', '尚', '灬'],
#  '鴻': ['工', '鳥', '氵', '灬'],
#  '鴾': ['厶', '牛', '鳥', 'マ', '灬'],
#  '鴿': ['口', '鳥', '个', '灬'],
#  '鵁': ['亠', '父', '鳥', '灬'],
#  '鵄': ['厶', '土', '至', '鳥', '灬'],
#  '鵆': ['彳', '行', '鳥', '灬'],
#  '鵈': ['耳', '鳥', '灬'],
#  '鵐': ['人', '工', '鳥', '灬'],
#  '鵑': ['口', '月', '鳥', '灬'],
#  '鵙': ['貝', '鳥', '灬'],
#  '鵜': ['｜', '丿', '弓', '鳥', '丷', '灬'],
#  '鵝': ['亅', '戈', '鳥', '灬'],
#  '鵞': ['亅', '戈', '鳥', '灬'],
#  '鵠': ['丿', '口', '土', '鳥', '灬'],
#  '鵡': ['弋', '戈', '止', '鳥', '灬'],
#  '鵤': ['角', '鳥', '灬'],
#  '鵬': ['月', '鳥', '灬'],
#  '鵯': ['十', '田', '鳥', '灬'],
#  '鵲': ['｜', '日', '鳥'],
#  '鵺': ['亠', '夕', '衣', '鳥', '灬'],
#  '鶇': ['｜', '八', '日', '木', '田', '鳥', '灬'],
#  '鶉': ['亠', '口', '子', '鳥', '灬'],
#  '鶏': ['人', '土', '大', '爪', '鳥'],
#  '鶚': ['二', '勹', '口', '鳥', '灬'],
#  '鶤': ['冖', '車', '鳥', '灬'],
#  '鶩': ['攴', '矛', '鳥', '灬'],
#  '鶫': ['｜', '口', '木', '网', '鳥', '丷', '灬'],
#  '鶯': ['冖', '火', '鳥', '灬'],
#  '鶲': ['八', '冫', '厶', '羽', '鳥', '灬'],
#  '鶴': ['宀', '隹', '鳥', '灬'],
#  '鶸': ['冫', '弓', '鳥', '灬'],
#  '鶺': ['人', '冫', '月', '鳥', '灬'],
#  '鶻': ['冂', '冖', '月', '骨', '鳥', '灬'],
#  '鷁': ['皿', '鳥', '丷', '灬'],
#  '鷂': ['凵', '夕', '缶', '鳥', '灬'],
#  '鷄': ['大', '幺', '爪', '鳥', '灬'],
#  '鷆': ['八', '匕', '目', '鳥', '灬'],
#  '鷏': ['八', '十', '目', '鳥', '灬'],
#  '鷓': ['凵', '广', '鳥', '灬'],
#  '鷙': ['丶', '亠', '十', '立', '辛', '鳥', '九', '灬'],
#  '鷦': ['隹', '鳥', '灬'],
#  '鷭': ['田', '米', '釆', '鳥', '灬'],
#  '鷯': ['亠', '小', '日', '鳥', '个', '丷', '灬'],
#  '鷲': ['丶', '亠', '口', '小', '尢', '鳥', '灬', '尤'],
#  '鷸': ['儿', '冂', '口', '矛', '鳥', '灬'],
#  '鷹': ['广', '隹', '鳥', '亻', '灬'],
#  '鷺': ['口', '夂', '足', '鳥', '灬'],
#  '鷽': ['冖', '爻', '臼', '鳥', '灬'],
#  '鸚': ['女', '貝', '鳥', '灬'],
#  '鸛': ['十', '口', '隹', '鳥', '艹', '灬'],
#  '鸞': ['糸', '言', '鳥', '灬'],
#  '鹵': ['十', '囗'],
#  '鹸': ['人', '十', '口', '囗', '鹵', '个'],
#  '鹹': ['丿', '卜', '口', '囗', '戈', '鹵'],
#  '鹽': ['十', '囗', '皿', '臣', '鹵'],
#  '鹿': ['广', '比'],
#  '麁': ['勹', '广', '比', '鹿'],
#  '麈': ['丶', '广', '比', '玉', '鹿'],
#  '麋': ['广', '比', '米', '鹿'],
#  '麌': ['八', '口', '广', '比', '鹿'],
#  '麑': ['儿', '广', '比', '臼', '鹿'],
#  '麒': ['八', '广', '比', '甘', '鹿'],
#  '麓': ['广', '木', '比', '鹿'],
#  '麕': ['囗', '广', '比', '禾', '鹿'],
#  '麗': ['冂', '广', '比', '鹿'],
#  '麝': ['寸', '广', '比', '身', '鹿'],
#  '麟': ['夕', '广', '比', '米', '舛', '鹿'],
#  '麥': ['夂'],
#  '麦': ['夂'],
#  '麩': ['二', '人', '夂', '麥'],
#  '麪': ['夂', '止', '疋', '麥'],
#  '麭': ['勹', '夂', '己', '麥'],
#  '麸': ['二', '亠', '人', '土', '夂', '大', '麥'],
#  '麹': ['亠', '勹', '土', '夂', '米', '麥'],
#  '麺': ['夂', '面', '麥'],
#  '麻': ['广', '木'],
#  '麼': ['幺', '广', '木', '麻'],
#  '麾': ['广', '木', '毛', '麻'],
#  '麿': ['口', '广', '木', '麻'],
#  '黄': ['八', '田'],
#  '黌': ['八', '冖', '爻', '田', '臼', '黄'],
#  '黍': ['水', '禾'],
#  '黎': ['黍', '勿'],
#  '黏': ['卜', '口', '黍'],
#  '黐': ['亠', '凵', '禸', '黍'],
#  '黒': ['里', '灬'],
#  '黔': ['里', '黒', '个', '灬'],
#  '默': ['犬', '里', '黒', '灬'],
#  '黙': ['犬', '里', '黒', '灬'],
#  '黛': ['弋', '里', '黒', '亻', '灬'],
#  '黜': ['｜', '山', '里', '黒', '灬'],
#  '黝': ['力', '幺', '里', '黒', '灬'],
#  '點': ['卜', '口', '里', '黒', '灬'],
#  '黠': ['口', '士', '里', '黒', '灬'],
#  '黥': ['亠', '口', '小', '里', '黒', '灬'],
#  '黨': ['冖', '口', '里', '黒', '尚', '灬'],
#  '黯': ['日', '立', '里', '音', '黒', '灬'],
#  '黴': ['山', '彳', '攴', '里', '黒', '灬'],
#  '黶': ['厂', '日', '犬', '里', '黒', '灬'],
#  '黷': ['儿', '囗', '士', '貝', '里', '黒', '灬'],
#  '黹': ['八', '冂', '丷'],
#  '黻': ['丶', '八', '冂', '攴', '黹', '丷'],
#  '黼': ['丶', '八', '冂', '十', '用', '黹', '丷'],
#  '鼇': ['土', '攴', '方', '黽'],
#  '鼈': ['冂', '小', '攴', '黽', '尚'],
#  '鼎': ['｜', '爿', '片', '目'],
#  '鼓': ['十', '又', '口', '士', '支', '豆', '丷'],
#  '鼕': ['八', '冫', '十', '又', '口', '士', '夂', '支', '鼓'],
#  '鼠': ['臼'],
#  '鼡': ['臼'],
#  '鼬': ['｜', '日', '田', '臼', '鼠'],
#  '鼻': ['廾', '田', '自'],
#  '鼾': ['干', '廾', '田', '目', '自', '鼻'],
#  '齋': ['小', '齊', '元'],
#  '齎': ['亠', '貝', '齊'],
#  '齏': ['亠', '韭', '齊'],
#  '齒': ['人', '凵', '止'],
#  '齔': ['凵', '匕', '止', '米', '齒'],
#  '齟': ['凵', '止', '目', '米', '齒'],
#  '齠': ['凵', '刀', '口', '止', '米', '齒'],
#  '齡': ['人', '凵', '卩', '止', '齒', '个'],
#  '齢': ['凵', '卩', '止', '米', '齒', '个'],
#  '齣': ['凵', '勹', '口', '止', '米', '齒'],
#  '齦': ['凵', '止', '米', '艮', '齒'],
#  '齧': ['亠', '凵', '刀', '土', '止', '米', '齒'],
#  '齪': ['凵', '口', '止', '米', '足', '齒'],
#  '齬': ['凵', '口', '止', '米', '齒', '五'],
#  '齲': ['丿', '冂', '凵', '止', '禸', '米', '虫', '齒'],
#  '齶': ['二', '凵', '勹', '口', '止', '米', '齒'],
#  '齷': ['凵', '厶', '土', '尸', '止', '米', '至', '齒'],
#  '龍': ['月', '立'],
#  '龕': ['口', '月', '立', '个'],
#  '龝': ['禾', '龜'],
#  '龠': ['口', '个', '冊']}

# %% [markdown]
# ## Data Structure

# %% [markdown]
# ### Class

# %%
class KanjigenNode:
    def __init__(self, symbol: str, dtype: str, meaning: str):
        self.symbol  = symbol
        self.dtype   = dtype
        self.meaning = meaning        
        self.color = 'red' if dtype == 'kanji' else 'orange'
        
    def __repr__(self):
        return self.symbol + '*' + self.dtype + '*' + self.meaning
    
    def __str__(self):
        return self.symbol + '\n' + self.meaning

# %% [markdown]
# ### Node Manager

# %%
def convert_into_kanjigen_node(nodes, dtype):
    return [KanjigenNode(symbol, dtype, meaning) for symbol, meaning in nodes.items()]

# %%
kanjigen_kanji_list   = convert_into_kanjigen_node(data_kanji, 'kanji')
kanjigen_radical_list = convert_into_kanjigen_node(data_radical, 'radical')
kanjigen_nodes = kanjigen_kanji_list + kanjigen_radical_list

# %%
kanjigen_kanji = [n for n in kanjigen_nodes if n.dtype == 'kanji']
kanjigen_radical = [n for n in kanjigen_nodes if n.dtype == 'radical']

# %%
print("count kanji  = ", len(kanjigen_kanji))
print("count radical = ", len(kanjigen_radical))
# Out:
# count kanji  =  2136
# count radical =  255

# %%
print(len(kanjigen_nodes))
print(len(kanjigen_kanji) + len(kanjigen_radical))
print(len(set(kanjigen_nodes)))
# Out:
# 2391
# 2391
# 2391

# %%
def get_symbol_dtype(node_repr: str):
    symbol, dtype, meaning = node_repr.split('*')
    return symbol + '*' + dtype

# %%
kanjigen_nodes_map = {get_symbol_dtype(n.__repr__()):n for n in kanjigen_nodes}

# %%
kanjigen_nodes_map
# Out:
# {'亜*kanji': 亜*kanji*sub-,
#  '哀*kanji': 哀*kanji*pathetic,
#  '挨*kanji': 挨*kanji*push open,
#  '愛*kanji': 愛*kanji*love,
#  '曖*kanji': 曖*kanji*not clear,
#  '悪*kanji': 悪*kanji*bad,
#  '握*kanji': 握*kanji*grip,
#  '圧*kanji': 圧*kanji*pressure,
#  '扱*kanji': 扱*kanji*handle,
#  '宛*kanji': 宛*kanji*allocate,
#  '嵐*kanji': 嵐*kanji*storm,
#  '安*kanji': 安*kanji*cheap,
#  '案*kanji': 案*kanji*plan,
#  '暗*kanji': 暗*kanji*dark,
#  '以*kanji': 以*kanji*by means of,
#  '衣*kanji': 衣*kanji*clothes,
#  '位*kanji': 位*kanji*rank,
#  '囲*kanji': 囲*kanji*surround,
#  '医*kanji': 医*kanji*medicine,
#  '依*kanji': 依*kanji*reliant,
#  '委*kanji': 委*kanji*committee,
#  '威*kanji': 威*kanji*intimidate,
#  '為*kanji': 為*kanji*do,
#  '畏*kanji': 畏*kanji*fear,
#  '胃*kanji': 胃*kanji*stomach,
#  '尉*kanji': 尉*kanji*military officer,
#  '異*kanji': 異*kanji*uncommon,
#  '移*kanji': 移*kanji*shift,
#  '萎*kanji': 萎*kanji*wither,
#  '偉*kanji': 偉*kanji*admirable,
#  '椅*kanji': 椅*kanji*chair,
#  '彙*kanji': 彙*kanji*same kind,
#  '意*kanji': 意*kanji*idea,
#  '違*kanji': 違*kanji*differ,
#  '維*kanji': 維*kanji*fiber,
#  '慰*kanji': 慰*kanji*consolation,
#  '遺*kanji': 遺*kanji*bequeath,
#  '緯*kanji': 緯*kanji*horizontal,
#  '域*kanji': 域*kanji*range,
#  '育*kanji': 育*kanji*nurture,
#  '一*kanji': 一*kanji*one,
#  '壱*kanji': 壱*kanji*one (falsification prevention),
#  '逸*kanji': 逸*kanji*deviate,
#  '茨*kanji': 茨*kanji*thorn,
#  '芋*kanji': 芋*kanji*potato,
#  '引*kanji': 引*kanji*pull,
#  '印*kanji': 印*kanji*mark,
#  '因*kanji': 因*kanji*cause,
#  '咽*kanji': 咽*kanji*throat,
#  '姻*kanji': 姻*kanji*matrimony,
#  '員*kanji': 員*kanji*member,
#  '院*kanji': 院*kanji*institution,
#  '淫*kanji': 淫*kanji*lewdness,
#  '陰*kanji': 陰*kanji*shade,
#  '飲*kanji': 飲*kanji*drink,
#  '隠*kanji': 隠*kanji*conceal,
#  '韻*kanji': 韻*kanji*rhyme,
#  '右*kanji': 右*kanji*right (direction),
#  '宇*kanji': 宇*kanji*eaves,
#  '羽*kanji': 羽*kanji*feather,
#  '雨*kanji': 雨*kanji*rain,
#  '唄*kanji': 唄*kanji*song,
#  '鬱*kanji': 鬱*kanji*gloom,
#  '畝*kanji': 畝*kanji*furrow,
#  '浦*kanji': 浦*kanji*bay,
#  '運*kanji': 運*kanji*carry,
#  '雲*kanji': 雲*kanji*cloud,
#  '永*kanji': 永*kanji*eternity,
#  '泳*kanji': 泳*kanji*swim,
#  '英*kanji': 英*kanji*England,
#  '映*kanji': 映*kanji*reflect,
#  '栄*kanji': 栄*kanji*prosperity,
#  '営*kanji': 営*kanji*manage,
#  '詠*kanji': 詠*kanji*recitation,
#  '影*kanji': 影*kanji*shadow,
#  '鋭*kanji': 鋭*kanji*pointed,
#  '衛*kanji': 衛*kanji*defense,
#  '易*kanji': 易*kanji*easy,
#  '疫*kanji': 疫*kanji*epidemic,
#  '益*kanji': 益*kanji*benefit,
#  '液*kanji': 液*kanji*fluid,
#  '駅*kanji': 駅*kanji*station,
#  '悦*kanji': 悦*kanji*ecstasy,
#  '越*kanji': 越*kanji*cross over,
#  '謁*kanji': 謁*kanji*audience,
#  '閲*kanji': 閲*kanji*review,
#  '円*kanji': 円*kanji*round, yen,
#  '延*kanji': 延*kanji*prolong,
#  '沿*kanji': 沿*kanji*run alongside,
#  '炎*kanji': 炎*kanji*inflammation,
#  '怨*kanji': 怨*kanji*grudge,
#  '宴*kanji': 宴*kanji*banquet,
#  '媛*kanji': 媛*kanji*princess,
#  '援*kanji': 援*kanji*aid,
#  '園*kanji': 園*kanji*garden,
#  '煙*kanji': 煙*kanji*smoke,
#  '猿*kanji': 猿*kanji*monkey,
#  '遠*kanji': 遠*kanji*far,
#  '鉛*kanji': 鉛*kanji*lead,
#  '塩*kanji': 塩*kanji*salt,
#  '演*kanji': 演*kanji*perform,
#  '縁*kanji': 縁*kanji*affinity,
#  '艶*kanji': 艶*kanji*glossy,
#  '汚*kanji': 汚*kanji*dirty,
#  '王*kanji': 王*kanji*king,
#  '凹*kanji': 凹*kanji*concave,
#  '央*kanji': 央*kanji*center,
#  '応*kanji': 応*kanji*respond,
#  '往*kanji': 往*kanji*outward journey,
#  '押*kanji': 押*kanji*push,
#  '旺*kanji': 旺*kanji*flourishing,
#  '欧*kanji': 欧*kanji*Europe,
#  '殴*kanji': 殴*kanji*assault,
#  '桜*kanji': 桜*kanji*cherry tree,
#  '翁*kanji': 翁*kanji*venerable old man,
#  '奥*kanji': 奥*kanji*heart,
#  '横*kanji': 横*kanji*side,
#  '岡*kanji': 岡*kanji*hill,
#  '屋*kanji': 屋*kanji*roof,
#  '億*kanji': 億*kanji*hundred million,
#  '憶*kanji': 憶*kanji*recollection,
#  '臆*kanji': 臆*kanji*timidity,
#  '虞*kanji': 虞*kanji*uneasiness,
#  '乙*kanji': 乙*kanji*the latter,
#  '俺*kanji': 俺*kanji*I, we,
#  '卸*kanji': 卸*kanji*wholesale,
#  '音*kanji': 音*kanji*sound,
#  '恩*kanji': 恩*kanji*grace,
#  '温*kanji': 温*kanji*warm,
#  '穏*kanji': 穏*kanji*calm,
#  '下*kanji': 下*kanji*below,
#  '化*kanji': 化*kanji*change,
#  '火*kanji': 火*kanji*fire,
#  '加*kanji': 加*kanji*add,
#  '可*kanji': 可*kanji*possible,
#  '仮*kanji': 仮*kanji*temporary,
#  '何*kanji': 何*kanji*what,
#  '花*kanji': 花*kanji*flower,
#  '佳*kanji': 佳*kanji*excellent,
#  '価*kanji': 価*kanji*value,
#  '果*kanji': 果*kanji*fruit,
#  '河*kanji': 河*kanji*river,
#  '苛*kanji': 苛*kanji*torment,
#  '科*kanji': 科*kanji*section,
#  '架*kanji': 架*kanji*rack,
#  '夏*kanji': 夏*kanji*summer,
#  '家*kanji': 家*kanji*house,
#  '荷*kanji': 荷*kanji*luggage,
#  '華*kanji': 華*kanji*splendor,
#  '菓*kanji': 菓*kanji*confectionery,
#  '貨*kanji': 貨*kanji*freight,
#  '渦*kanji': 渦*kanji*whirlpool,
#  '過*kanji': 過*kanji*go beyond,
#  '嫁*kanji': 嫁*kanji*marry into,
#  '暇*kanji': 暇*kanji*spare time,
#  '禍*kanji': 禍*kanji*calamity,
#  '靴*kanji': 靴*kanji*shoes,
#  '寡*kanji': 寡*kanji*widow,
#  '歌*kanji': 歌*kanji*song,
#  '箇*kanji': 箇*kanji*counters for things,
#  '稼*kanji': 稼*kanji*earnings,
#  '課*kanji': 課*kanji*section,
#  '蚊*kanji': 蚊*kanji*mosquito,
#  '牙*kanji': 牙*kanji*tusk,
#  '瓦*kanji': 瓦*kanji*tile,
#  '我*kanji': 我*kanji*ego,
#  '画*kanji': 画*kanji*tableau,
#  '芽*kanji': 芽*kanji*bud,
#  '賀*kanji': 賀*kanji*congratulations,
#  '雅*kanji': 雅*kanji*gracious,
#  '餓*kanji': 餓*kanji*starve,
#  '介*kanji': 介*kanji*jammed in,
#  '回*kanji': 回*kanji*times,
#  '灰*kanji': 灰*kanji*ashes,
#  '会*kanji': 会*kanji*association,
#  '快*kanji': 快*kanji*cheerful,
#  '戒*kanji': 戒*kanji*commandment,
#  '改*kanji': 改*kanji*reformation,
#  '怪*kanji': 怪*kanji*suspicious,
#  '拐*kanji': 拐*kanji*kidnap,
#  '悔*kanji': 悔*kanji*repent,
#  '海*kanji': 海*kanji*sea,
#  '界*kanji': 界*kanji*world,
#  '皆*kanji': 皆*kanji*all,
#  '械*kanji': 械*kanji*contraption,
#  '絵*kanji': 絵*kanji*picture,
#  '開*kanji': 開*kanji*open,
#  '階*kanji': 階*kanji*floor of a building,
#  '塊*kanji': 塊*kanji*clod,
#  '楷*kanji': 楷*kanji*square character style,
#  '解*kanji': 解*kanji*untie,
#  '潰*kanji': 潰*kanji*crush,
#  '壊*kanji': 壊*kanji*demolition,
#  '懐*kanji': 懐*kanji*pocket,
#  '諧*kanji': 諧*kanji*harmony,
#  '貝*kanji': 貝*kanji*shellfish,
#  '外*kanji': 外*kanji*outside,
#  '劾*kanji': 劾*kanji*censure,
#  '害*kanji': 害*kanji*harm,
#  '崖*kanji': 崖*kanji*cliff,
#  '涯*kanji': 涯*kanji*horizon,
#  '街*kanji': 街*kanji*street,
#  '慨*kanji': 慨*kanji*rue,
#  '蓋*kanji': 蓋*kanji*cover,
#  '該*kanji': 該*kanji*above-stated,
#  '概*kanji': 概*kanji*outline,
#  '骸*kanji': 骸*kanji*dead remains,
#  '垣*kanji': 垣*kanji*hedge,
#  '柿*kanji': 柿*kanji*persimmon,
#  '各*kanji': 各*kanji*each,
#  '角*kanji': 角*kanji*angle,
#  '拡*kanji': 拡*kanji*broaden,
#  '革*kanji': 革*kanji*leather,
#  '格*kanji': 格*kanji*status,
#  '核*kanji': 核*kanji*nucleus,
#  '殻*kanji': 殻*kanji*husk,
#  '郭*kanji': 郭*kanji*enclosure,
#  '覚*kanji': 覚*kanji*memorize,
#  '較*kanji': 較*kanji*contrast,
#  '隔*kanji': 隔*kanji*isolate,
#  '閣*kanji': 閣*kanji*tall,
#  '確*kanji': 確*kanji*certain,
#  '獲*kanji': 獲*kanji*seize,
#  '嚇*kanji': 嚇*kanji*menacing,
#  '穫*kanji': 穫*kanji*harvest,
#  '学*kanji': 学*kanji*study,
#  '岳*kanji': 岳*kanji*point,
#  '楽*kanji': 楽*kanji*pleasure,
#  '額*kanji': 額*kanji*amount,
#  '顎*kanji': 顎*kanji*jaw,
#  '掛*kanji': 掛*kanji*hang,
#  '潟*kanji': 潟*kanji*lagoon,
#  '括*kanji': 括*kanji*fasten,
#  '活*kanji': 活*kanji*active,
#  '喝*kanji': 喝*kanji*hoarse,
#  '渇*kanji': 渇*kanji*thirst,
#  '割*kanji': 割*kanji*divide,
#  '葛*kanji': 葛*kanji*arrowroot,
#  '滑*kanji': 滑*kanji*slippery,
#  '褐*kanji': 褐*kanji*brown,
#  '轄*kanji': 轄*kanji*control,
#  '且*kanji': 且*kanji*moreover,
#  '株*kanji': 株*kanji*stocks,
#  '釜*kanji': 釜*kanji*kettle,
#  '鎌*kanji': 鎌*kanji*sickle,
#  '刈*kanji': 刈*kanji*reap,
#  '干*kanji': 干*kanji*dry,
#  '刊*kanji': 刊*kanji*publish,
#  '甘*kanji': 甘*kanji*sweet,
#  '汗*kanji': 汗*kanji*sweat,
#  '缶*kanji': 缶*kanji*tin can,
#  '完*kanji': 完*kanji*perfect,
#  '肝*kanji': 肝*kanji*liver,
#  '官*kanji': 官*kanji*government official,
#  '冠*kanji': 冠*kanji*crown,
#  '巻*kanji': 巻*kanji*scroll,
#  '看*kanji': 看*kanji*watch over,
#  '陥*kanji': 陥*kanji*collapse,
#  '乾*kanji': 乾*kanji*dry,
#  '勘*kanji': 勘*kanji*intuition,
#  '患*kanji': 患*kanji*afflicted,
#  '貫*kanji': 貫*kanji*pierce,
#  '寒*kanji': 寒*kanji*cold,
#  '喚*kanji': 喚*kanji*yell,
#  '堪*kanji': 堪*kanji*withstand,
#  '換*kanji': 換*kanji*interchange,
#  '敢*kanji': 敢*kanji*daring,
#  '棺*kanji': 棺*kanji*coffin,
#  '款*kanji': 款*kanji*goodwill,
#  '間*kanji': 間*kanji*interval,
#  '閑*kanji': 閑*kanji*leisure,
#  '勧*kanji': 勧*kanji*persuade,
#  '寛*kanji': 寛*kanji*tolerant,
#  '幹*kanji': 幹*kanji*tree-trunk,
#  '感*kanji': 感*kanji*feeling,
#  '漢*kanji': 漢*kanji*China,
#  '慣*kanji': 慣*kanji*accustomed,
#  '管*kanji': 管*kanji*pipe,
#  '関*kanji': 関*kanji*related,
#  '歓*kanji': 歓*kanji*delight,
#  '監*kanji': 監*kanji*oversee,
#  '緩*kanji': 緩*kanji*slacken,
#  '憾*kanji': 憾*kanji*remorse,
#  '還*kanji': 還*kanji*send back,
#  '館*kanji': 館*kanji*public building,
#  '環*kanji': 環*kanji*ring,
#  '簡*kanji': 簡*kanji*simplicity,
#  '観*kanji': 観*kanji*observe,
#  '韓*kanji': 韓*kanji*Korea,
#  '艦*kanji': 艦*kanji*warship,
#  '鑑*kanji': 鑑*kanji*specimen,
#  '丸*kanji': 丸*kanji*circle,
#  '含*kanji': 含*kanji*include,
#  '岸*kanji': 岸*kanji*beach,
#  '岩*kanji': 岩*kanji*boulder,
#  '玩*kanji': 玩*kanji*trifle with,
#  '眼*kanji': 眼*kanji*eyeball,
#  '頑*kanji': 頑*kanji*stubborn,
#  '顔*kanji': 顔*kanji*face,
#  '願*kanji': 願*kanji*request,
#  '企*kanji': 企*kanji*plan,
#  '伎*kanji': 伎*kanji*deed,
#  '危*kanji': 危*kanji*dangerous,
#  '机*kanji': 机*kanji*desk,
#  '気*kanji': 気*kanji*feeling,
#  '岐*kanji': 岐*kanji*branch off,
#  '希*kanji': 希*kanji*hope,
#  '忌*kanji': 忌*kanji*mourning,
#  '汽*kanji': 汽*kanji*steam,
#  '奇*kanji': 奇*kanji*strange,
#  '祈*kanji': 祈*kanji*pray,
#  '季*kanji': 季*kanji*seasons,
#  '紀*kanji': 紀*kanji*chronicle,
#  '軌*kanji': 軌*kanji*rut,
#  '既*kanji': 既*kanji*previously,
#  '記*kanji': 記*kanji*write down,
#  '起*kanji': 起*kanji*wake up,
#  '飢*kanji': 飢*kanji*hungry,
#  '鬼*kanji': 鬼*kanji*ghost,
#  '帰*kanji': 帰*kanji*return,
#  '基*kanji': 基*kanji*foundation,
#  '寄*kanji': 寄*kanji*approach,
#  '規*kanji': 規*kanji*rule,
#  '亀*kanji': 亀*kanji*turtle,
#  '喜*kanji': 喜*kanji*rejoice,
#  '幾*kanji': 幾*kanji*how many,
#  '揮*kanji': 揮*kanji*brandish,
#  '期*kanji': 期*kanji*period of time,
#  '棋*kanji': 棋*kanji*chess piece,
#  '貴*kanji': 貴*kanji*precious,
#  '棄*kanji': 棄*kanji*abandon,
#  '毀*kanji': 毀*kanji*destroy,
#  '旗*kanji': 旗*kanji*national flag,
#  '器*kanji': 器*kanji*container,
#  '畿*kanji': 畿*kanji*capital,
#  '輝*kanji': 輝*kanji*radiance,
#  '機*kanji': 機*kanji*machine,
#  '騎*kanji': 騎*kanji*equestrian,
#  '技*kanji': 技*kanji*skill,
#  '宜*kanji': 宜*kanji*best regards,
#  '偽*kanji': 偽*kanji*falsehood,
#  '欺*kanji': 欺*kanji*deceit,
#  '義*kanji': 義*kanji*righteousness,
#  '疑*kanji': 疑*kanji*doubt,
#  '儀*kanji': 儀*kanji*ceremony,
#  '戯*kanji': 戯*kanji*frolic,
#  '擬*kanji': 擬*kanji*mimic,
#  '犠*kanji': 犠*kanji*sacrifice,
#  '議*kanji': 議*kanji*deliberation,
#  '菊*kanji': 菊*kanji*chrysanthemum,
#  '吉*kanji': 吉*kanji*good luck,
#  '喫*kanji': 喫*kanji*consume,
#  '詰*kanji': 詰*kanji*packed,
#  '却*kanji': 却*kanji*instead,
#  '客*kanji': 客*kanji*guest,
#  '脚*kanji': 脚*kanji*leg,
#  '逆*kanji': 逆*kanji*inverted,
#  '虐*kanji': 虐*kanji*tyrannize,
#  '九*kanji': 九*kanji*nine,
#  '久*kanji': 久*kanji*long time,
#  '及*kanji': 及*kanji*reach out,
#  '弓*kanji': 弓*kanji*bow (archery, violin),
#  '丘*kanji': 丘*kanji*hill,
#  '旧*kanji': 旧*kanji*old times,
#  '休*kanji': 休*kanji*rest,
#  '吸*kanji': 吸*kanji*suck,
#  '朽*kanji': 朽*kanji*decay,
#  '臼*kanji': 臼*kanji*mortar,
#  '求*kanji': 求*kanji*request,
#  '究*kanji': 究*kanji*research,
#  '泣*kanji': 泣*kanji*cry,
#  '急*kanji': 急*kanji*hurry,
#  '級*kanji': 級*kanji*rank,
#  '糾*kanji': 糾*kanji*twist,
#  '宮*kanji': 宮*kanji*Shinto shrine,
#  '救*kanji': 救*kanji*salvation,
#  '球*kanji': 球*kanji*sphere,
#  '給*kanji': 給*kanji*salary,
#  '嗅*kanji': 嗅*kanji*smell,
#  '窮*kanji': 窮*kanji*hard up,
#  '牛*kanji': 牛*kanji*cow,
#  '去*kanji': 去*kanji*leave,
#  '巨*kanji': 巨*kanji*gigantic,
#  '居*kanji': 居*kanji*reside,
#  '拒*kanji': 拒*kanji*repel,
#  '拠*kanji': 拠*kanji*foothold,
#  '挙*kanji': 挙*kanji*raise,
#  '虚*kanji': 虚*kanji*void,
#  '許*kanji': 許*kanji*permit,
#  '距*kanji': 距*kanji*long-distance,
#  '魚*kanji': 魚*kanji*fish,
#  '御*kanji': 御*kanji*honorable,
#  '漁*kanji': 漁*kanji*fishing,
#  '凶*kanji': 凶*kanji*villain,
#  '共*kanji': 共*kanji*together,
#  '叫*kanji': 叫*kanji*shout,
#  '狂*kanji': 狂*kanji*lunatic,
#  '京*kanji': 京*kanji*capital,
#  '享*kanji': 享*kanji*receive,
#  '供*kanji': 供*kanji*offer,
#  '協*kanji': 協*kanji*cooperation,
#  '況*kanji': 況*kanji*condition,
#  '峡*kanji': 峡*kanji*gorge,
#  '挟*kanji': 挟*kanji*pinch,
#  '狭*kanji': 狭*kanji*cramped,
#  '恐*kanji': 恐*kanji*fear,
#  '恭*kanji': 恭*kanji*respect,
#  '胸*kanji': 胸*kanji*bosom,
#  '脅*kanji': 脅*kanji*threaten,
#  '強*kanji': 強*kanji*strong,
#  '教*kanji': 教*kanji*teach,
#  '郷*kanji': 郷*kanji*home town,
#  '境*kanji': 境*kanji*boundary,
#  '橋*kanji': 橋*kanji*bridge,
#  '矯*kanji': 矯*kanji*rectify,
#  '鏡*kanji': 鏡*kanji*mirror,
#  '競*kanji': 競*kanji*compete,
#  '響*kanji': 響*kanji*echo,
#  '驚*kanji': 驚*kanji*wonder,
#  '仰*kanji': 仰*kanji*face-up,
#  '暁*kanji': 暁*kanji*daybreak,
#  '業*kanji': 業*kanji*business,
#  '凝*kanji': 凝*kanji*congeal,
#  '曲*kanji': 曲*kanji*musical composition,
#  '局*kanji': 局*kanji*office,
#  '極*kanji': 極*kanji*poles,
#  '玉*kanji': 玉*kanji*ball,
#  '巾*kanji': 巾*kanji*towel,
#  '斤*kanji': 斤*kanji*axe,
#  '均*kanji': 均*kanji*level,
#  '近*kanji': 近*kanji*near,
#  '金*kanji': 金*kanji*gold,
#  '菌*kanji': 菌*kanji*germ,
#  '勤*kanji': 勤*kanji*diligence,
#  '琴*kanji': 琴*kanji*harp,
#  '筋*kanji': 筋*kanji*muscle,
#  '僅*kanji': 僅*kanji*a wee bit,
#  '禁*kanji': 禁*kanji*prohibition,
#  '緊*kanji': 緊*kanji*tense,
#  '錦*kanji': 錦*kanji*brocade,
#  '謹*kanji': 謹*kanji*discreet,
#  '襟*kanji': 襟*kanji*collar,
#  '吟*kanji': 吟*kanji*versify,
#  '銀*kanji': 銀*kanji*silver,
#  '区*kanji': 区*kanji*ward,
#  '句*kanji': 句*kanji*phrase,
#  '苦*kanji': 苦*kanji*suffer,
#  '駆*kanji': 駆*kanji*drive,
#  '具*kanji': 具*kanji*tool,
#  '惧*kanji': 惧*kanji*dread,
#  '愚*kanji': 愚*kanji*foolish,
#  '空*kanji': 空*kanji*sky,
#  '偶*kanji': 偶*kanji*accidentally,
#  '遇*kanji': 遇*kanji*interview,
#  '隅*kanji': 隅*kanji*corner,
#  '串*kanji': 串*kanji*skewer,
#  '屈*kanji': 屈*kanji*yield,
#  '掘*kanji': 掘*kanji*dig,
#  '窟*kanji': 窟*kanji*cavern,
#  '熊*kanji': 熊*kanji*bear,
#  '繰*kanji': 繰*kanji*winding,
#  '君*kanji': 君*kanji*you,
#  '訓*kanji': 訓*kanji*instruction,
#  '勲*kanji': 勲*kanji*meritorious deed,
#  '薫*kanji': 薫*kanji*fragrant,
#  '軍*kanji': 軍*kanji*army,
#  '郡*kanji': 郡*kanji*county,
#  '群*kanji': 群*kanji*flock,
#  '兄*kanji': 兄*kanji*older brother,
#  '刑*kanji': 刑*kanji*punish,
#  '形*kanji': 形*kanji*shape,
#  '系*kanji': 系*kanji*lineage,
#  '径*kanji': 径*kanji*diameter,
#  '茎*kanji': 茎*kanji*stalk,
#  '係*kanji': 係*kanji*person in charge,
#  '型*kanji': 型*kanji*model,
#  '契*kanji': 契*kanji*pledge,
#  '計*kanji': 計*kanji*measure,
#  '恵*kanji': 恵*kanji*favor,
#  '啓*kanji': 啓*kanji*disclose,
#  '掲*kanji': 掲*kanji*put up (a notice),
#  '渓*kanji': 渓*kanji*mountain stream,
#  '経*kanji': 経*kanji*manage,
#  '蛍*kanji': 蛍*kanji*lightning-bug,
#  '敬*kanji': 敬*kanji*respect,
#  '景*kanji': 景*kanji*scenery,
#  '軽*kanji': 軽*kanji*light,
#  '傾*kanji': 傾*kanji*lean,
#  '携*kanji': 携*kanji*portable,
#  '継*kanji': 継*kanji*inherit,
#  '詣*kanji': 詣*kanji*visit a temple,
#  '慶*kanji': 慶*kanji*jubilation,
#  '憬*kanji': 憬*kanji*long for,
#  '稽*kanji': 稽*kanji*consider,
#  '憩*kanji': 憩*kanji*recess,
#  '警*kanji': 警*kanji*guard against,
#  '鶏*kanji': 鶏*kanji*chicken,
#  '芸*kanji': 芸*kanji*art,
#  '迎*kanji': 迎*kanji*welcome,
#  '鯨*kanji': 鯨*kanji*whale,
#  '隙*kanji': 隙*kanji*fissure,
#  '劇*kanji': 劇*kanji*drama,
#  '撃*kanji': 撃*kanji*beat,
#  '激*kanji': 激*kanji*violent,
#  '桁*kanji': 桁*kanji*beam,
#  '欠*kanji': 欠*kanji*lack,
#  '穴*kanji': 穴*kanji*hole,
#  '血*kanji': 血*kanji*blood,
#  '決*kanji': 決*kanji*decide,
#  '結*kanji': 結*kanji*tie,
#  '傑*kanji': 傑*kanji*greatness,
#  '潔*kanji': 潔*kanji*undefiled,
#  '月*kanji': 月*kanji*month, moon,
#  '犬*kanji': 犬*kanji*dog,
#  '件*kanji': 件*kanji*affair,
#  '見*kanji': 見*kanji*see,
#  '券*kanji': 券*kanji*ticket,
#  '肩*kanji': 肩*kanji*shoulder,
#  '建*kanji': 建*kanji*build,
#  '研*kanji': 研*kanji*sharpen,
#  '県*kanji': 県*kanji*prefecture,
#  '倹*kanji': 倹*kanji*frugal,
#  '兼*kanji': 兼*kanji*concurrently,
#  '剣*kanji': 剣*kanji*sabre,
#  '拳*kanji': 拳*kanji*fist,
#  '軒*kanji': 軒*kanji*flats,
#  '健*kanji': 健*kanji*healthy,
#  '険*kanji': 険*kanji*precipitous,
#  '圏*kanji': 圏*kanji*sphere,
#  '堅*kanji': 堅*kanji*strict,
#  '検*kanji': 検*kanji*examine,
#  '嫌*kanji': 嫌*kanji*dislike,
#  '献*kanji': 献*kanji*offering,
#  '絹*kanji': 絹*kanji*silk,
#  '遣*kanji': 遣*kanji*dispatch,
#  '権*kanji': 権*kanji*rights,
#  '憲*kanji': 憲*kanji*constitution,
#  '賢*kanji': 賢*kanji*intelligent,
#  '謙*kanji': 謙*kanji*self-effacing,
#  '鍵*kanji': 鍵*kanji*key,
#  '繭*kanji': 繭*kanji*cocoon,
#  '顕*kanji': 顕*kanji*appear,
#  '験*kanji': 験*kanji*test,
#  '懸*kanji': 懸*kanji*suspend,
#  '元*kanji': 元*kanji*origin,
#  '幻*kanji': 幻*kanji*phantasm,
#  '玄*kanji': 玄*kanji*mysterious,
#  '言*kanji': 言*kanji*say,
#  '弦*kanji': 弦*kanji*bowstring,
#  '限*kanji': 限*kanji*limit,
#  '原*kanji': 原*kanji*field,
#  '現*kanji': 現*kanji*appear,
#  '舷*kanji': 舷*kanji*gunwale,
#  '減*kanji': 減*kanji*decrease,
#  '源*kanji': 源*kanji*origin,
#  '厳*kanji': 厳*kanji*strict,
#  '己*kanji': 己*kanji*self,
#  '戸*kanji': 戸*kanji*door,
#  '古*kanji': 古*kanji*old,
#  '呼*kanji': 呼*kanji*call,
#  '固*kanji': 固*kanji*hard,
#  '股*kanji': 股*kanji*crotch,
#  '虎*kanji': 虎*kanji*tiger,
#  '孤*kanji': 孤*kanji*orphan,
#  '弧*kanji': 弧*kanji*arc,
#  '故*kanji': 故*kanji*circumstances,
#  '枯*kanji': 枯*kanji*wither,
#  '個*kanji': 個*kanji*individual,
#  '庫*kanji': 庫*kanji*warehouse,
#  '湖*kanji': 湖*kanji*lake,
#  '雇*kanji': 雇*kanji*employ,
#  '誇*kanji': 誇*kanji*boast,
#  '鼓*kanji': 鼓*kanji*drum,
#  '錮*kanji': 錮*kanji*tie up,
#  '顧*kanji': 顧*kanji*look back,
#  '五*kanji': 五*kanji*five,
#  '互*kanji': 互*kanji*mutually,
#  '午*kanji': 午*kanji*noon,
#  '呉*kanji': 呉*kanji*give,
#  '後*kanji': 後*kanji*behind,
#  '娯*kanji': 娯*kanji*recreation,
#  '悟*kanji': 悟*kanji*enlightenment,
#  '碁*kanji': 碁*kanji*Go,
#  '語*kanji': 語*kanji*language,
#  '誤*kanji': 誤*kanji*mistake,
#  '護*kanji': 護*kanji*safeguard,
#  '口*kanji': 口*kanji*mouth,
#  '工*kanji': 工*kanji*craft,
#  '公*kanji': 公*kanji*public,
#  '勾*kanji': 勾*kanji*capture,
#  '孔*kanji': 孔*kanji*cavity,
#  '功*kanji': 功*kanji*achievement,
#  '巧*kanji': 巧*kanji*adroit,
#  '広*kanji': 広*kanji*wide,
#  '甲*kanji': 甲*kanji*armor,
#  '交*kanji': 交*kanji*mix,
#  '光*kanji': 光*kanji*ray,
#  '向*kanji': 向*kanji*over there,
#  '后*kanji': 后*kanji*empress,
#  '好*kanji': 好*kanji*like,
#  '江*kanji': 江*kanji*inlet,
#  '考*kanji': 考*kanji*think,
#  '行*kanji': 行*kanji*go,
#  '坑*kanji': 坑*kanji*pit,
#  '孝*kanji': 孝*kanji*filial piety,
#  '抗*kanji': 抗*kanji*confront,
#  '攻*kanji': 攻*kanji*aggression,
#  '更*kanji': 更*kanji*grow late,
#  '効*kanji': 効*kanji*effect,
#  '幸*kanji': 幸*kanji*happiness,
#  '拘*kanji': 拘*kanji*arrest,
#  '肯*kanji': 肯*kanji*agreement,
#  '侯*kanji': 侯*kanji*marquis,
#  '厚*kanji': 厚*kanji*thick,
#  '恒*kanji': 恒*kanji*constancy,
#  '洪*kanji': 洪*kanji*deluge,
#  '皇*kanji': 皇*kanji*emperor,
#  '紅*kanji': 紅*kanji*deep red,
#  '荒*kanji': 荒*kanji*laid waste,
#  '郊*kanji': 郊*kanji*outskirts,
#  '香*kanji': 香*kanji*incense,
#  '候*kanji': 候*kanji*climate,
#  '校*kanji': 校*kanji*school,
#  '耕*kanji': 耕*kanji*till,
#  '航*kanji': 航*kanji*cruise,
#  '貢*kanji': 貢*kanji*tribute,
#  '降*kanji': 降*kanji*descend,
#  '高*kanji': 高*kanji*tall, expensive,
#  '康*kanji': 康*kanji*health,
#  '控*kanji': 控*kanji*withdraw,
#  '梗*kanji': 梗*kanji*close up,
#  '黄*kanji': 黄*kanji*yellow,
#  '喉*kanji': 喉*kanji*throat,
#  '慌*kanji': 慌*kanji*disconcerted,
#  '港*kanji': 港*kanji*harbor,
#  '硬*kanji': 硬*kanji*stiff,
#  '絞*kanji': 絞*kanji*strangle,
#  '項*kanji': 項*kanji*paragraph,
#  '溝*kanji': 溝*kanji*gutter,
#  '鉱*kanji': 鉱*kanji*mineral,
#  '構*kanji': 構*kanji*construct,
#  '綱*kanji': 綱*kanji*hawser,
#  '酵*kanji': 酵*kanji*fermentation,
#  '稿*kanji': 稿*kanji*draft,
#  '興*kanji': 興*kanji*entertain,
#  '衡*kanji': 衡*kanji*equilibrium,
#  '鋼*kanji': 鋼*kanji*steel,
#  '講*kanji': 講*kanji*lecture,
#  '購*kanji': 購*kanji*subscription,
#  '乞*kanji': 乞*kanji*beg,
#  '号*kanji': 号*kanji*number,
#  '合*kanji': 合*kanji*fit,
#  '拷*kanji': 拷*kanji*torture,
#  '剛*kanji': 剛*kanji*sturdy,
#  '傲*kanji': 傲*kanji*be proud,
#  '豪*kanji': 豪*kanji*overpowering,
#  '克*kanji': 克*kanji*overcome,
#  '告*kanji': 告*kanji*tell,
#  '谷*kanji': 谷*kanji*valley,
#  '刻*kanji': 刻*kanji*engrave,
#  '国*kanji': 国*kanji*country,
#  '黒*kanji': 黒*kanji*black,
#  '穀*kanji': 穀*kanji*cereals,
#  '酷*kanji': 酷*kanji*cruel,
#  '獄*kanji': 獄*kanji*prison,
#  '骨*kanji': 骨*kanji*bone,
#  '駒*kanji': 駒*kanji*horse,
#  '込*kanji': 込*kanji*crowded,
#  '頃*kanji': 頃*kanji*times,
#  '今*kanji': 今*kanji*now,
#  '困*kanji': 困*kanji*become distressed,
#  '昆*kanji': 昆*kanji*descendants,
#  '恨*kanji': 恨*kanji*rancor,
#  '根*kanji': 根*kanji*root,
#  '婚*kanji': 婚*kanji*marriage,
#  '混*kanji': 混*kanji*mix,
#  '痕*kanji': 痕*kanji*mark,
#  '紺*kanji': 紺*kanji*dark blue,
#  '魂*kanji': 魂*kanji*soul,
#  '墾*kanji': 墾*kanji*ground-breaking,
#  '懇*kanji': 懇*kanji*sociable,
#  '左*kanji': 左*kanji*left (direction),
#  '佐*kanji': 佐*kanji*help,
#  '沙*kanji': 沙*kanji*sand,
#  '査*kanji': 査*kanji*investigate,
#  '砂*kanji': 砂*kanji*sand,
#  '唆*kanji': 唆*kanji*tempt,
#  '差*kanji': 差*kanji*distinction,
#  '詐*kanji': 詐*kanji*lie,
#  '鎖*kanji': 鎖*kanji*chain,
#  '座*kanji': 座*kanji*sit,
#  '挫*kanji': 挫*kanji*sprain,
#  '才*kanji': 才*kanji*genius,
#  '再*kanji': 再*kanji*again,
#  '災*kanji': 災*kanji*disaster,
#  '妻*kanji': 妻*kanji*wife,
#  '采*kanji': 采*kanji*form,
#  '砕*kanji': 砕*kanji*smash,
#  '宰*kanji': 宰*kanji*superintend,
#  '栽*kanji': 栽*kanji*plantation,
#  '彩*kanji': 彩*kanji*coloring,
#  '採*kanji': 採*kanji*pick,
#  '済*kanji': 済*kanji*settle,
#  '祭*kanji': 祭*kanji*festival,
#  '斎*kanji': 斎*kanji*purification,
#  '細*kanji': 細*kanji*thin,
#  '菜*kanji': 菜*kanji*vegetable,
#  '最*kanji': 最*kanji*most,
#  '裁*kanji': 裁*kanji*judge,
#  '債*kanji': 債*kanji*bond,
#  '催*kanji': 催*kanji*sponsor,
#  '塞*kanji': 塞*kanji*obstruct,
#  '歳*kanji': 歳*kanji*year-end,
#  '載*kanji': 載*kanji*ride,
#  '際*kanji': 際*kanji*occasion,
#  '埼*kanji': 埼*kanji*cape (geography),
#  '在*kanji': 在*kanji*exist,
#  '材*kanji': 材*kanji*lumber,
#  '剤*kanji': 剤*kanji*dose,
#  '財*kanji': 財*kanji*wealth,
#  '罪*kanji': 罪*kanji*guilt,
#  '崎*kanji': 崎*kanji*promontory,
#  '作*kanji': 作*kanji*make,
#  '削*kanji': 削*kanji*plane,
#  '昨*kanji': 昨*kanji*previous,
#  '柵*kanji': 柵*kanji*fence,
#  '索*kanji': 索*kanji*cord,
#  '策*kanji': 策*kanji*scheme,
#  '酢*kanji': 酢*kanji*vinegar,
#  '搾*kanji': 搾*kanji*squeeze,
#  '錯*kanji': 錯*kanji*confused,
#  '咲*kanji': 咲*kanji*blossom,
#  '冊*kanji': 冊*kanji*counter for books,
#  '札*kanji': 札*kanji*tag,
#  '刷*kanji': 刷*kanji*printing,
#  '刹*kanji': 刹*kanji*temple,
#  '拶*kanji': 拶*kanji*be imminent,
#  '殺*kanji': 殺*kanji*kill,
#  '察*kanji': 察*kanji*guess,
#  '撮*kanji': 撮*kanji*snapshot,
#  '擦*kanji': 擦*kanji*grate,
#  '雑*kanji': 雑*kanji*miscellaneous,
#  '皿*kanji': 皿*kanji*dish,
#  '三*kanji': 三*kanji*three,
#  '山*kanji': 山*kanji*mountain,
#  '参*kanji': 参*kanji*participate,
#  '桟*kanji': 桟*kanji*scaffold,
#  '蚕*kanji': 蚕*kanji*silkworm,
#  '惨*kanji': 惨*kanji*wretched,
#  '産*kanji': 産*kanji*give birth,
#  '傘*kanji': 傘*kanji*umbrella,
#  '散*kanji': 散*kanji*scatter,
#  '算*kanji': 算*kanji*calculate,
#  '酸*kanji': 酸*kanji*acid,
#  '賛*kanji': 賛*kanji*approve,
#  '残*kanji': 残*kanji*remainder,
#  '斬*kanji': 斬*kanji*kill by slicing,
#  '暫*kanji': 暫*kanji*temporarily,
#  '士*kanji': 士*kanji*gentleman,
#  '子*kanji': 子*kanji*child,
#  '支*kanji': 支*kanji*branch,
#  '止*kanji': 止*kanji*stop,
#  '氏*kanji': 氏*kanji*family name,
#  '仕*kanji': 仕*kanji*do,
#  '史*kanji': 史*kanji*history,
#  '司*kanji': 司*kanji*director,
#  '四*kanji': 四*kanji*four,
#  '市*kanji': 市*kanji*market,
#  '矢*kanji': 矢*kanji*arrow,
#  '旨*kanji': 旨*kanji*delicious,
#  '死*kanji': 死*kanji*death,
#  '糸*kanji': 糸*kanji*thread,
#  '至*kanji': 至*kanji*climax,
#  '伺*kanji': 伺*kanji*pay respects,
#  '志*kanji': 志*kanji*intention,
#  '私*kanji': 私*kanji*me,
#  '使*kanji': 使*kanji*use,
#  '刺*kanji': 刺*kanji*thorn,
#  '始*kanji': 始*kanji*begin,
#  '姉*kanji': 姉*kanji*older sister,
#  '枝*kanji': 枝*kanji*branch,
#  '祉*kanji': 祉*kanji*welfare,
#  '肢*kanji': 肢*kanji*limb,
#  '姿*kanji': 姿*kanji*figure,
#  '思*kanji': 思*kanji*think,
#  '指*kanji': 指*kanji*finger,
#  '施*kanji': 施*kanji*carry out,
#  '師*kanji': 師*kanji*expert,
#  '恣*kanji': 恣*kanji*selfish,
#  '紙*kanji': 紙*kanji*paper,
#  '脂*kanji': 脂*kanji*fat,
#  '視*kanji': 視*kanji*look at,
#  '紫*kanji': 紫*kanji*purple,
#  '詞*kanji': 詞*kanji*poetry,
#  '歯*kanji': 歯*kanji*tooth,
#  '嗣*kanji': 嗣*kanji*heir,
#  '試*kanji': 試*kanji*test,
#  '詩*kanji': 詩*kanji*poem,
#  '資*kanji': 資*kanji*resources,
#  '飼*kanji': 飼*kanji*domesticate,
#  '誌*kanji': 誌*kanji*document,
#  '雌*kanji': 雌*kanji*feminine,
#  '摯*kanji': 摯*kanji*seriousness,
#  '賜*kanji': 賜*kanji*grant,
#  '諮*kanji': 諮*kanji*consult with,
#  '示*kanji': 示*kanji*indicate,
#  '字*kanji': 字*kanji*letter,
#  '寺*kanji': 寺*kanji*Buddhist temple,
#  '次*kanji': 次*kanji*next,
#  '耳*kanji': 耳*kanji*ear,
#  '自*kanji': 自*kanji*oneself,
#  '似*kanji': 似*kanji*becoming,
#  '児*kanji': 児*kanji*child,
#  '事*kanji': 事*kanji*abstract thing,
#  '侍*kanji': 侍*kanji*waiter,
#  '治*kanji': 治*kanji*govern,
#  '持*kanji': 持*kanji*hold,
#  '時*kanji': 時*kanji*time,
#  '滋*kanji': 滋*kanji*nourishing,
#  '慈*kanji': 慈*kanji*mercy,
#  '辞*kanji': 辞*kanji*resign,
#  '磁*kanji': 磁*kanji*magnet,
#  '餌*kanji': 餌*kanji*bait,
#  '璽*kanji': 璽*kanji*emperor's seal,
#  '鹿*kanji': 鹿*kanji*deer,
#  '式*kanji': 式*kanji*style,
#  '識*kanji': 識*kanji*discriminating,
#  '軸*kanji': 軸*kanji*axis,
#  '七*kanji': 七*kanji*seven,
#  '𠮟*kanji': 𠮟*kanji*scold,
#  '失*kanji': 失*kanji*lose,
#  '室*kanji': 室*kanji*room,
#  '疾*kanji': 疾*kanji*rapidly,
#  '執*kanji': 執*kanji*tenacious,
#  '湿*kanji': 湿*kanji*damp,
#  '嫉*kanji': 嫉*kanji*envy,
#  '漆*kanji': 漆*kanji*lacquer,
#  '質*kanji': 質*kanji*quality,
#  '実*kanji': 実*kanji*truth,
#  '芝*kanji': 芝*kanji*turf,
#  '写*kanji': 写*kanji*copy,
#  '社*kanji': 社*kanji*company,
#  '車*kanji': 車*kanji*car,
#  '舎*kanji': 舎*kanji*cottage,
#  '者*kanji': 者*kanji*someone,
#  '射*kanji': 射*kanji*shoot,
#  '捨*kanji': 捨*kanji*throw away,
#  '赦*kanji': 赦*kanji*pardon,
#  '斜*kanji': 斜*kanji*diagonal,
#  '煮*kanji': 煮*kanji*boil,
#  '遮*kanji': 遮*kanji*intercept,
#  '謝*kanji': 謝*kanji*apologize,
#  '邪*kanji': 邪*kanji*wicked,
#  '蛇*kanji': 蛇*kanji*snake,
#  '尺*kanji': 尺*kanji*shaku,
#  '借*kanji': 借*kanji*borrow,
#  '酌*kanji': 酌*kanji*bartending,
#  '釈*kanji': 釈*kanji*explanation,
#  '爵*kanji': 爵*kanji*baron,
#  '若*kanji': 若*kanji*young,
#  '弱*kanji': 弱*kanji*weak,
#  '寂*kanji': 寂*kanji*loneliness,
#  '手*kanji': 手*kanji*hand,
#  '主*kanji': 主*kanji*master,
#  '守*kanji': 守*kanji*protect,
#  '朱*kanji': 朱*kanji*vermilion,
#  '取*kanji': 取*kanji*take,
#  '狩*kanji': 狩*kanji*hunt,
#  '首*kanji': 首*kanji*neck,
#  '殊*kanji': 殊*kanji*particularly,
#  '珠*kanji': 珠*kanji*pearl,
#  '酒*kanji': 酒*kanji*alcoholic drink,
#  '腫*kanji': 腫*kanji*tumor,
#  '種*kanji': 種*kanji*kind,
#  '趣*kanji': 趣*kanji*gist,
#  '寿*kanji': 寿*kanji*longevity,
#  '受*kanji': 受*kanji*accept,
#  '呪*kanji': 呪*kanji*curse,
#  '授*kanji': 授*kanji*instruct,
#  '需*kanji': 需*kanji*demand,
#  '儒*kanji': 儒*kanji*Confucian,
#  '樹*kanji': 樹*kanji*trees,
#  '収*kanji': 収*kanji*take in,
#  '囚*kanji': 囚*kanji*captured,
#  '州*kanji': 州*kanji*state,
#  '舟*kanji': 舟*kanji*boat,
#  '秀*kanji': 秀*kanji*excel,
#  '周*kanji': 周*kanji*circumference,
#  '宗*kanji': 宗*kanji*religion,
#  '拾*kanji': 拾*kanji*pick up,
#  '秋*kanji': 秋*kanji*autumn,
#  '臭*kanji': 臭*kanji*stinking,
#  '修*kanji': 修*kanji*discipline,
#  '袖*kanji': 袖*kanji*sleeve,
#  '終*kanji': 終*kanji*end,
#  '羞*kanji': 羞*kanji*feel ashamed,
#  '習*kanji': 習*kanji*learn,
#  '週*kanji': 週*kanji*week,
#  '就*kanji': 就*kanji*concerning,
#  '衆*kanji': 衆*kanji*masses,
#  '集*kanji': 集*kanji*collect,
#  '愁*kanji': 愁*kanji*distress,
#  '酬*kanji': 酬*kanji*repay,
#  '醜*kanji': 醜*kanji*ugly,
#  '蹴*kanji': 蹴*kanji*kick,
#  '襲*kanji': 襲*kanji*attack,
#  '十*kanji': 十*kanji*ten,
#  '汁*kanji': 汁*kanji*soup,
#  '充*kanji': 充*kanji*allot,
#  '住*kanji': 住*kanji*dwelling,
#  '柔*kanji': 柔*kanji*tender,
#  '重*kanji': 重*kanji*heavy,
#  '従*kanji': 従*kanji*obey,
#  '渋*kanji': 渋*kanji*astringent,
#  '銃*kanji': 銃*kanji*gun,
#  '獣*kanji': 獣*kanji*animal,
#  '縦*kanji': 縦*kanji*vertical,
#  '叔*kanji': 叔*kanji*uncle,
#  '祝*kanji': 祝*kanji*celebrate,
#  '宿*kanji': 宿*kanji*inn,
#  '淑*kanji': 淑*kanji*graceful,
#  '粛*kanji': 粛*kanji*solemn,
#  '縮*kanji': 縮*kanji*shrink,
#  '塾*kanji': 塾*kanji*cram school,
#  '熟*kanji': 熟*kanji*ripen,
#  '出*kanji': 出*kanji*exit,
#  '述*kanji': 述*kanji*mention,
#  '術*kanji': 術*kanji*art,
#  '俊*kanji': 俊*kanji*genius,
#  '春*kanji': 春*kanji*springtime,
#  '瞬*kanji': 瞬*kanji*wink,
#  '旬*kanji': 旬*kanji*10-day period (of the month),
#  '巡*kanji': 巡*kanji*patrol,
#  '盾*kanji': 盾*kanji*shield,
#  '准*kanji': 准*kanji*quasi-,
#  '殉*kanji': 殉*kanji*martyrdom,
#  '純*kanji': 純*kanji*genuine,
#  '循*kanji': 循*kanji*sequential,
#  '順*kanji': 順*kanji*obey,
#  '準*kanji': 準*kanji*standard,
#  '潤*kanji': 潤*kanji*wet,
#  '遵*kanji': 遵*kanji*abide by,
#  '処*kanji': 処*kanji*dispose,
#  '初*kanji': 初*kanji*first,
#  '所*kanji': 所*kanji*place,
#  '書*kanji': 書*kanji*write,
#  '庶*kanji': 庶*kanji*commoner,
#  '暑*kanji': 暑*kanji*hot,
#  '署*kanji': 署*kanji*government office,
#  '緒*kanji': 緒*kanji*thong,
#  '諸*kanji': 諸*kanji*various,
#  '女*kanji': 女*kanji*woman,
#  '如*kanji': 如*kanji*likeness,
#  '助*kanji': 助*kanji*help,
#  '序*kanji': 序*kanji*preface,
#  '叙*kanji': 叙*kanji*confer,
#  '徐*kanji': 徐*kanji*gradually,
#  '除*kanji': 除*kanji*exclude,
#  '小*kanji': 小*kanji*small,
#  '升*kanji': 升*kanji*measuring box,
#  '少*kanji': 少*kanji*few,
#  '召*kanji': 召*kanji*summon,
#  '匠*kanji': 匠*kanji*artisan,
#  '床*kanji': 床*kanji*bed,
#  '抄*kanji': 抄*kanji*extract,
#  '肖*kanji': 肖*kanji*resemblance,
#  '尚*kanji': 尚*kanji*esteem,
#  '招*kanji': 招*kanji*beckon,
#  '承*kanji': 承*kanji*acquiesce,
#  '昇*kanji': 昇*kanji*rise up,
#  '松*kanji': 松*kanji*pine,
#  '沼*kanji': 沼*kanji*marsh,
#  '昭*kanji': 昭*kanji*shining,
#  '宵*kanji': 宵*kanji*wee hours,
#  '将*kanji': 将*kanji*leader,
#  '消*kanji': 消*kanji*extinguish,
#  '症*kanji': 症*kanji*symptoms,
#  '祥*kanji': 祥*kanji*auspicious,
#  '称*kanji': 称*kanji*appellation,
#  '笑*kanji': 笑*kanji*laugh,
#  '唱*kanji': 唱*kanji*chant,
#  '商*kanji': 商*kanji*sell,
#  '渉*kanji': 渉*kanji*ford,
#  '章*kanji': 章*kanji*chapter,
#  '紹*kanji': 紹*kanji*introduce,
#  '訟*kanji': 訟*kanji*sue,
#  '勝*kanji': 勝*kanji*win,
#  '掌*kanji': 掌*kanji*manipulate,
#  '晶*kanji': 晶*kanji*sparkle,
#  '焼*kanji': 焼*kanji*bake,
#  '焦*kanji': 焦*kanji*char,
#  '硝*kanji': 硝*kanji*nitrate,
#  '粧*kanji': 粧*kanji*cosmetics,
#  '詔*kanji': 詔*kanji*imperial edict,
#  '証*kanji': 証*kanji*evidence,
#  '象*kanji': 象*kanji*elephant,
#  '傷*kanji': 傷*kanji*wound,
#  '奨*kanji': 奨*kanji*exhort,
#  '照*kanji': 照*kanji*illuminate,
#  '詳*kanji': 詳*kanji*detailed,
#  ...}

# %%
print(len(kanjigen_nodes_map))
# Out:
# 2391

# %%
def get_node(kanjigen_nodes, symbol, dtype):
    test_node = symbol + '*' + dtype
    if test_node in kanjigen_nodes_map:
        return kanjigen_nodes_map[test_node]
    return None

# %%
print(get_node(kanjigen_nodes, '唖', 'kanji'))
# Out:
# None

# %%
print(get_node(kanjigen_nodes, '人', 'kanji'))
# Out:
# 人
# person

# %% [markdown]
# ### Edges Manager

# %%
def convert_into_kanjigen_edges(data_edges: list):
    kanjigen_edges = []
    for kanji, radical_list in data_edges.items():
        kanji_node = get_node(kanjigen_nodes, kanji, 'kanji')
        if kanji_node == None:
            continue
        for r in radical_list:
            radical_node = get_node(kanjigen_nodes, r, 'radical')
            kanjigen_edges.append( (kanji_node, radical_node) )
    return kanjigen_edges

# %%
kanjigen_edges = convert_into_kanjigen_edges(data_edges)

# %%
print("len(kanjigen_edges) ", len(kanjigen_edges))
print("len(kanjigen_edges) ", len(set(kanjigen_edges)))
# Out:
# len(kanjigen_edges)  6756
# len(kanjigen_edges)  6753

# %% [markdown]
# ## Graph

# %%
import networkx as nx

# %%
G = nx.Graph()

G.add_edges_from(kanjigen_edges)
G.add_nodes_from(kanjigen_nodes)

print("nodes:", list(G.nodes())[:5])
print("edges:", list(G.edges())[:2])
# Out:
# nodes: [亜*kanji*sub-, ｜*radical*stick, 口*radical*mouth, 悪*kanji*bad, 心*radical*heart]
# edges: [(亜*kanji*sub-, ｜*radical*stick), (亜*kanji*sub-, 口*radical*mouth)]

# %% [markdown]
# ## Visualization

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Install Font

# %%
import matplotlib.font_manager as fm

# Reference: https://albertauyeung.github.io/2020/03/15/matplotlib-cjk-fonts.html
[f for f in fm.fontManager.ttflist if 'CJK JP' in f.name]
# Out:
# [<Font 'Noto Serif CJK JP' (NotoSerifCJK-Regular.ttc) normal normal 400 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Serif CJK JP' (NotoSerifCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Regular.ttc) normal normal 400 normal>]

# %%
def visualize_graph(Graph: nx.Graph, figsize: tuple=(15,15), color_map: List[str]=None, node_size: int=3000, with_labels: bool=True) -> None:
    if color_map == None:
        color_map = [n.color for n in Graph]  
    else:
        color_map = color_map
    
    plt.figure(1,figsize=figsize) 
    nx.draw_kamada_kawai(Graph, node_color=color_map, with_labels=with_labels, node_size=node_size, font_size=20,font_family="Noto Serif CJK JP")
    plt.show()

# %% [markdown]
# ### Sample Visualization

# %%
def get_sg_kanji_with() -> nx.Graph:
    sg = nx.Graph()
    p = get_node(kanjigen_nodes, '痘', 'kanji')
    radical_p = [n for n in G.neighbors(p)]
    sg.add_nodes_from(radical_p + [p])
    sg.add_edges_from([(p, rp) for rp in radical_p])
    return sg

# %%
sg = dict() # sample_graph
sg['full_graph'] = G
sg['sample_nodes'] = lambda size: G.subgraph(random.sample(G.nodes, size))
sg['kanji_plus_radical_neighbor'] = get_sg_kanji_with()

# %%
visualize_graph(Graph=sg['kanji_plus_radical_neighbor'], figsize=(10,10))

# %%
visualize_graph(Graph=sg['sample_nodes'](280), figsize=(15,15))

# %%
# visualize_graph(Graph=sg['full_graph'], node_size=1000, with_labels=False)

# %% [markdown]
# # Querying Knowledge Graph

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 2391
# Number of edges: 6753
# Average degree:   5.6487

# %%
# https://networkx.org/documentation/stable/reference/algorithms/component.html

print('number of connected components: ', nx.number_connected_components(G))

# To create the induced subgraph of each component use:
S = [G.subgraph(c).copy() for c in nx.connected_components(G)]
# Out:
# number of connected components:  109

# %%
kanjigen_nodes
# Out:
# [亜*kanji*sub-,
#  哀*kanji*pathetic,
#  挨*kanji*push open,
#  愛*kanji*love,
#  曖*kanji*not clear,
#  悪*kanji*bad,
#  握*kanji*grip,
#  圧*kanji*pressure,
#  扱*kanji*handle,
#  宛*kanji*allocate,
#  嵐*kanji*storm,
#  安*kanji*cheap,
#  案*kanji*plan,
#  暗*kanji*dark,
#  以*kanji*by means of,
#  衣*kanji*clothes,
#  位*kanji*rank,
#  囲*kanji*surround,
#  医*kanji*medicine,
#  依*kanji*reliant,
#  委*kanji*committee,
#  威*kanji*intimidate,
#  為*kanji*do,
#  畏*kanji*fear,
#  胃*kanji*stomach,
#  尉*kanji*military officer,
#  異*kanji*uncommon,
#  移*kanji*shift,
#  萎*kanji*wither,
#  偉*kanji*admirable,
#  椅*kanji*chair,
#  彙*kanji*same kind,
#  意*kanji*idea,
#  違*kanji*differ,
#  維*kanji*fiber,
#  慰*kanji*consolation,
#  遺*kanji*bequeath,
#  緯*kanji*horizontal,
#  域*kanji*range,
#  育*kanji*nurture,
#  一*kanji*one,
#  壱*kanji*one (falsification prevention),
#  逸*kanji*deviate,
#  茨*kanji*thorn,
#  芋*kanji*potato,
#  引*kanji*pull,
#  印*kanji*mark,
#  因*kanji*cause,
#  咽*kanji*throat,
#  姻*kanji*matrimony,
#  員*kanji*member,
#  院*kanji*institution,
#  淫*kanji*lewdness,
#  陰*kanji*shade,
#  飲*kanji*drink,
#  隠*kanji*conceal,
#  韻*kanji*rhyme,
#  右*kanji*right (direction),
#  宇*kanji*eaves,
#  羽*kanji*feather,
#  雨*kanji*rain,
#  唄*kanji*song,
#  鬱*kanji*gloom,
#  畝*kanji*furrow,
#  浦*kanji*bay,
#  運*kanji*carry,
#  雲*kanji*cloud,
#  永*kanji*eternity,
#  泳*kanji*swim,
#  英*kanji*England,
#  映*kanji*reflect,
#  栄*kanji*prosperity,
#  営*kanji*manage,
#  詠*kanji*recitation,
#  影*kanji*shadow,
#  鋭*kanji*pointed,
#  衛*kanji*defense,
#  易*kanji*easy,
#  疫*kanji*epidemic,
#  益*kanji*benefit,
#  液*kanji*fluid,
#  駅*kanji*station,
#  悦*kanji*ecstasy,
#  越*kanji*cross over,
#  謁*kanji*audience,
#  閲*kanji*review,
#  円*kanji*round, yen,
#  延*kanji*prolong,
#  沿*kanji*run alongside,
#  炎*kanji*inflammation,
#  怨*kanji*grudge,
#  宴*kanji*banquet,
#  媛*kanji*princess,
#  援*kanji*aid,
#  園*kanji*garden,
#  煙*kanji*smoke,
#  猿*kanji*monkey,
#  遠*kanji*far,
#  鉛*kanji*lead,
#  塩*kanji*salt,
#  演*kanji*perform,
#  縁*kanji*affinity,
#  艶*kanji*glossy,
#  汚*kanji*dirty,
#  王*kanji*king,
#  凹*kanji*concave,
#  央*kanji*center,
#  応*kanji*respond,
#  往*kanji*outward journey,
#  押*kanji*push,
#  旺*kanji*flourishing,
#  欧*kanji*Europe,
#  殴*kanji*assault,
#  桜*kanji*cherry tree,
#  翁*kanji*venerable old man,
#  奥*kanji*heart,
#  横*kanji*side,
#  岡*kanji*hill,
#  屋*kanji*roof,
#  億*kanji*hundred million,
#  憶*kanji*recollection,
#  臆*kanji*timidity,
#  虞*kanji*uneasiness,
#  乙*kanji*the latter,
#  俺*kanji*I, we,
#  卸*kanji*wholesale,
#  音*kanji*sound,
#  恩*kanji*grace,
#  温*kanji*warm,
#  穏*kanji*calm,
#  下*kanji*below,
#  化*kanji*change,
#  火*kanji*fire,
#  加*kanji*add,
#  可*kanji*possible,
#  仮*kanji*temporary,
#  何*kanji*what,
#  花*kanji*flower,
#  佳*kanji*excellent,
#  価*kanji*value,
#  果*kanji*fruit,
#  河*kanji*river,
#  苛*kanji*torment,
#  科*kanji*section,
#  架*kanji*rack,
#  夏*kanji*summer,
#  家*kanji*house,
#  荷*kanji*luggage,
#  華*kanji*splendor,
#  菓*kanji*confectionery,
#  貨*kanji*freight,
#  渦*kanji*whirlpool,
#  過*kanji*go beyond,
#  嫁*kanji*marry into,
#  暇*kanji*spare time,
#  禍*kanji*calamity,
#  靴*kanji*shoes,
#  寡*kanji*widow,
#  歌*kanji*song,
#  箇*kanji*counters for things,
#  稼*kanji*earnings,
#  課*kanji*section,
#  蚊*kanji*mosquito,
#  牙*kanji*tusk,
#  瓦*kanji*tile,
#  我*kanji*ego,
#  画*kanji*tableau,
#  芽*kanji*bud,
#  賀*kanji*congratulations,
#  雅*kanji*gracious,
#  餓*kanji*starve,
#  介*kanji*jammed in,
#  回*kanji*times,
#  灰*kanji*ashes,
#  会*kanji*association,
#  快*kanji*cheerful,
#  戒*kanji*commandment,
#  改*kanji*reformation,
#  怪*kanji*suspicious,
#  拐*kanji*kidnap,
#  悔*kanji*repent,
#  海*kanji*sea,
#  界*kanji*world,
#  皆*kanji*all,
#  械*kanji*contraption,
#  絵*kanji*picture,
#  開*kanji*open,
#  階*kanji*floor of a building,
#  塊*kanji*clod,
#  楷*kanji*square character style,
#  解*kanji*untie,
#  潰*kanji*crush,
#  壊*kanji*demolition,
#  懐*kanji*pocket,
#  諧*kanji*harmony,
#  貝*kanji*shellfish,
#  外*kanji*outside,
#  劾*kanji*censure,
#  害*kanji*harm,
#  崖*kanji*cliff,
#  涯*kanji*horizon,
#  街*kanji*street,
#  慨*kanji*rue,
#  蓋*kanji*cover,
#  該*kanji*above-stated,
#  概*kanji*outline,
#  骸*kanji*dead remains,
#  垣*kanji*hedge,
#  柿*kanji*persimmon,
#  各*kanji*each,
#  角*kanji*angle,
#  拡*kanji*broaden,
#  革*kanji*leather,
#  格*kanji*status,
#  核*kanji*nucleus,
#  殻*kanji*husk,
#  郭*kanji*enclosure,
#  覚*kanji*memorize,
#  較*kanji*contrast,
#  隔*kanji*isolate,
#  閣*kanji*tall,
#  確*kanji*certain,
#  獲*kanji*seize,
#  嚇*kanji*menacing,
#  穫*kanji*harvest,
#  学*kanji*study,
#  岳*kanji*point,
#  楽*kanji*pleasure,
#  額*kanji*amount,
#  顎*kanji*jaw,
#  掛*kanji*hang,
#  潟*kanji*lagoon,
#  括*kanji*fasten,
#  活*kanji*active,
#  喝*kanji*hoarse,
#  渇*kanji*thirst,
#  割*kanji*divide,
#  葛*kanji*arrowroot,
#  滑*kanji*slippery,
#  褐*kanji*brown,
#  轄*kanji*control,
#  且*kanji*moreover,
#  株*kanji*stocks,
#  釜*kanji*kettle,
#  鎌*kanji*sickle,
#  刈*kanji*reap,
#  干*kanji*dry,
#  刊*kanji*publish,
#  甘*kanji*sweet,
#  汗*kanji*sweat,
#  缶*kanji*tin can,
#  完*kanji*perfect,
#  肝*kanji*liver,
#  官*kanji*government official,
#  冠*kanji*crown,
#  巻*kanji*scroll,
#  看*kanji*watch over,
#  陥*kanji*collapse,
#  乾*kanji*dry,
#  勘*kanji*intuition,
#  患*kanji*afflicted,
#  貫*kanji*pierce,
#  寒*kanji*cold,
#  喚*kanji*yell,
#  堪*kanji*withstand,
#  換*kanji*interchange,
#  敢*kanji*daring,
#  棺*kanji*coffin,
#  款*kanji*goodwill,
#  間*kanji*interval,
#  閑*kanji*leisure,
#  勧*kanji*persuade,
#  寛*kanji*tolerant,
#  幹*kanji*tree-trunk,
#  感*kanji*feeling,
#  漢*kanji*China,
#  慣*kanji*accustomed,
#  管*kanji*pipe,
#  関*kanji*related,
#  歓*kanji*delight,
#  監*kanji*oversee,
#  緩*kanji*slacken,
#  憾*kanji*remorse,
#  還*kanji*send back,
#  館*kanji*public building,
#  環*kanji*ring,
#  簡*kanji*simplicity,
#  観*kanji*observe,
#  韓*kanji*Korea,
#  艦*kanji*warship,
#  鑑*kanji*specimen,
#  丸*kanji*circle,
#  含*kanji*include,
#  岸*kanji*beach,
#  岩*kanji*boulder,
#  玩*kanji*trifle with,
#  眼*kanji*eyeball,
#  頑*kanji*stubborn,
#  顔*kanji*face,
#  願*kanji*request,
#  企*kanji*plan,
#  伎*kanji*deed,
#  危*kanji*dangerous,
#  机*kanji*desk,
#  気*kanji*feeling,
#  岐*kanji*branch off,
#  希*kanji*hope,
#  忌*kanji*mourning,
#  汽*kanji*steam,
#  奇*kanji*strange,
#  祈*kanji*pray,
#  季*kanji*seasons,
#  紀*kanji*chronicle,
#  軌*kanji*rut,
#  既*kanji*previously,
#  記*kanji*write down,
#  起*kanji*wake up,
#  飢*kanji*hungry,
#  鬼*kanji*ghost,
#  帰*kanji*return,
#  基*kanji*foundation,
#  寄*kanji*approach,
#  規*kanji*rule,
#  亀*kanji*turtle,
#  喜*kanji*rejoice,
#  幾*kanji*how many,
#  揮*kanji*brandish,
#  期*kanji*period of time,
#  棋*kanji*chess piece,
#  貴*kanji*precious,
#  棄*kanji*abandon,
#  毀*kanji*destroy,
#  旗*kanji*national flag,
#  器*kanji*container,
#  畿*kanji*capital,
#  輝*kanji*radiance,
#  機*kanji*machine,
#  騎*kanji*equestrian,
#  技*kanji*skill,
#  宜*kanji*best regards,
#  偽*kanji*falsehood,
#  欺*kanji*deceit,
#  義*kanji*righteousness,
#  疑*kanji*doubt,
#  儀*kanji*ceremony,
#  戯*kanji*frolic,
#  擬*kanji*mimic,
#  犠*kanji*sacrifice,
#  議*kanji*deliberation,
#  菊*kanji*chrysanthemum,
#  吉*kanji*good luck,
#  喫*kanji*consume,
#  詰*kanji*packed,
#  却*kanji*instead,
#  客*kanji*guest,
#  脚*kanji*leg,
#  逆*kanji*inverted,
#  虐*kanji*tyrannize,
#  九*kanji*nine,
#  久*kanji*long time,
#  及*kanji*reach out,
#  弓*kanji*bow (archery, violin),
#  丘*kanji*hill,
#  旧*kanji*old times,
#  休*kanji*rest,
#  吸*kanji*suck,
#  朽*kanji*decay,
#  臼*kanji*mortar,
#  求*kanji*request,
#  究*kanji*research,
#  泣*kanji*cry,
#  急*kanji*hurry,
#  級*kanji*rank,
#  糾*kanji*twist,
#  宮*kanji*Shinto shrine,
#  救*kanji*salvation,
#  球*kanji*sphere,
#  給*kanji*salary,
#  嗅*kanji*smell,
#  窮*kanji*hard up,
#  牛*kanji*cow,
#  去*kanji*leave,
#  巨*kanji*gigantic,
#  居*kanji*reside,
#  拒*kanji*repel,
#  拠*kanji*foothold,
#  挙*kanji*raise,
#  虚*kanji*void,
#  許*kanji*permit,
#  距*kanji*long-distance,
#  魚*kanji*fish,
#  御*kanji*honorable,
#  漁*kanji*fishing,
#  凶*kanji*villain,
#  共*kanji*together,
#  叫*kanji*shout,
#  狂*kanji*lunatic,
#  京*kanji*capital,
#  享*kanji*receive,
#  供*kanji*offer,
#  協*kanji*cooperation,
#  況*kanji*condition,
#  峡*kanji*gorge,
#  挟*kanji*pinch,
#  狭*kanji*cramped,
#  恐*kanji*fear,
#  恭*kanji*respect,
#  胸*kanji*bosom,
#  脅*kanji*threaten,
#  強*kanji*strong,
#  教*kanji*teach,
#  郷*kanji*home town,
#  境*kanji*boundary,
#  橋*kanji*bridge,
#  矯*kanji*rectify,
#  鏡*kanji*mirror,
#  競*kanji*compete,
#  響*kanji*echo,
#  驚*kanji*wonder,
#  仰*kanji*face-up,
#  暁*kanji*daybreak,
#  業*kanji*business,
#  凝*kanji*congeal,
#  曲*kanji*musical composition,
#  局*kanji*office,
#  極*kanji*poles,
#  玉*kanji*ball,
#  巾*kanji*towel,
#  斤*kanji*axe,
#  均*kanji*level,
#  近*kanji*near,
#  金*kanji*gold,
#  菌*kanji*germ,
#  勤*kanji*diligence,
#  琴*kanji*harp,
#  筋*kanji*muscle,
#  僅*kanji*a wee bit,
#  禁*kanji*prohibition,
#  緊*kanji*tense,
#  錦*kanji*brocade,
#  謹*kanji*discreet,
#  襟*kanji*collar,
#  吟*kanji*versify,
#  銀*kanji*silver,
#  区*kanji*ward,
#  句*kanji*phrase,
#  苦*kanji*suffer,
#  駆*kanji*drive,
#  具*kanji*tool,
#  惧*kanji*dread,
#  愚*kanji*foolish,
#  空*kanji*sky,
#  偶*kanji*accidentally,
#  遇*kanji*interview,
#  隅*kanji*corner,
#  串*kanji*skewer,
#  屈*kanji*yield,
#  掘*kanji*dig,
#  窟*kanji*cavern,
#  熊*kanji*bear,
#  繰*kanji*winding,
#  君*kanji*you,
#  訓*kanji*instruction,
#  勲*kanji*meritorious deed,
#  薫*kanji*fragrant,
#  軍*kanji*army,
#  郡*kanji*county,
#  群*kanji*flock,
#  兄*kanji*older brother,
#  刑*kanji*punish,
#  形*kanji*shape,
#  系*kanji*lineage,
#  径*kanji*diameter,
#  茎*kanji*stalk,
#  係*kanji*person in charge,
#  型*kanji*model,
#  契*kanji*pledge,
#  計*kanji*measure,
#  恵*kanji*favor,
#  啓*kanji*disclose,
#  掲*kanji*put up (a notice),
#  渓*kanji*mountain stream,
#  経*kanji*manage,
#  蛍*kanji*lightning-bug,
#  敬*kanji*respect,
#  景*kanji*scenery,
#  軽*kanji*light,
#  傾*kanji*lean,
#  携*kanji*portable,
#  継*kanji*inherit,
#  詣*kanji*visit a temple,
#  慶*kanji*jubilation,
#  憬*kanji*long for,
#  稽*kanji*consider,
#  憩*kanji*recess,
#  警*kanji*guard against,
#  鶏*kanji*chicken,
#  芸*kanji*art,
#  迎*kanji*welcome,
#  鯨*kanji*whale,
#  隙*kanji*fissure,
#  劇*kanji*drama,
#  撃*kanji*beat,
#  激*kanji*violent,
#  桁*kanji*beam,
#  欠*kanji*lack,
#  穴*kanji*hole,
#  血*kanji*blood,
#  決*kanji*decide,
#  結*kanji*tie,
#  傑*kanji*greatness,
#  潔*kanji*undefiled,
#  月*kanji*month, moon,
#  犬*kanji*dog,
#  件*kanji*affair,
#  見*kanji*see,
#  券*kanji*ticket,
#  肩*kanji*shoulder,
#  建*kanji*build,
#  研*kanji*sharpen,
#  県*kanji*prefecture,
#  倹*kanji*frugal,
#  兼*kanji*concurrently,
#  剣*kanji*sabre,
#  拳*kanji*fist,
#  軒*kanji*flats,
#  健*kanji*healthy,
#  険*kanji*precipitous,
#  圏*kanji*sphere,
#  堅*kanji*strict,
#  検*kanji*examine,
#  嫌*kanji*dislike,
#  献*kanji*offering,
#  絹*kanji*silk,
#  遣*kanji*dispatch,
#  権*kanji*rights,
#  憲*kanji*constitution,
#  賢*kanji*intelligent,
#  謙*kanji*self-effacing,
#  鍵*kanji*key,
#  繭*kanji*cocoon,
#  顕*kanji*appear,
#  験*kanji*test,
#  懸*kanji*suspend,
#  元*kanji*origin,
#  幻*kanji*phantasm,
#  玄*kanji*mysterious,
#  言*kanji*say,
#  弦*kanji*bowstring,
#  限*kanji*limit,
#  原*kanji*field,
#  現*kanji*appear,
#  舷*kanji*gunwale,
#  減*kanji*decrease,
#  源*kanji*origin,
#  厳*kanji*strict,
#  己*kanji*self,
#  戸*kanji*door,
#  古*kanji*old,
#  呼*kanji*call,
#  固*kanji*hard,
#  股*kanji*crotch,
#  虎*kanji*tiger,
#  孤*kanji*orphan,
#  弧*kanji*arc,
#  故*kanji*circumstances,
#  枯*kanji*wither,
#  個*kanji*individual,
#  庫*kanji*warehouse,
#  湖*kanji*lake,
#  雇*kanji*employ,
#  誇*kanji*boast,
#  鼓*kanji*drum,
#  錮*kanji*tie up,
#  顧*kanji*look back,
#  五*kanji*five,
#  互*kanji*mutually,
#  午*kanji*noon,
#  呉*kanji*give,
#  後*kanji*behind,
#  娯*kanji*recreation,
#  悟*kanji*enlightenment,
#  碁*kanji*Go,
#  語*kanji*language,
#  誤*kanji*mistake,
#  護*kanji*safeguard,
#  口*kanji*mouth,
#  工*kanji*craft,
#  公*kanji*public,
#  勾*kanji*capture,
#  孔*kanji*cavity,
#  功*kanji*achievement,
#  巧*kanji*adroit,
#  広*kanji*wide,
#  甲*kanji*armor,
#  交*kanji*mix,
#  光*kanji*ray,
#  向*kanji*over there,
#  后*kanji*empress,
#  好*kanji*like,
#  江*kanji*inlet,
#  考*kanji*think,
#  行*kanji*go,
#  坑*kanji*pit,
#  孝*kanji*filial piety,
#  抗*kanji*confront,
#  攻*kanji*aggression,
#  更*kanji*grow late,
#  効*kanji*effect,
#  幸*kanji*happiness,
#  拘*kanji*arrest,
#  肯*kanji*agreement,
#  侯*kanji*marquis,
#  厚*kanji*thick,
#  恒*kanji*constancy,
#  洪*kanji*deluge,
#  皇*kanji*emperor,
#  紅*kanji*deep red,
#  荒*kanji*laid waste,
#  郊*kanji*outskirts,
#  香*kanji*incense,
#  候*kanji*climate,
#  校*kanji*school,
#  耕*kanji*till,
#  航*kanji*cruise,
#  貢*kanji*tribute,
#  降*kanji*descend,
#  高*kanji*tall, expensive,
#  康*kanji*health,
#  控*kanji*withdraw,
#  梗*kanji*close up,
#  黄*kanji*yellow,
#  喉*kanji*throat,
#  慌*kanji*disconcerted,
#  港*kanji*harbor,
#  硬*kanji*stiff,
#  絞*kanji*strangle,
#  項*kanji*paragraph,
#  溝*kanji*gutter,
#  鉱*kanji*mineral,
#  構*kanji*construct,
#  綱*kanji*hawser,
#  酵*kanji*fermentation,
#  稿*kanji*draft,
#  興*kanji*entertain,
#  衡*kanji*equilibrium,
#  鋼*kanji*steel,
#  講*kanji*lecture,
#  購*kanji*subscription,
#  乞*kanji*beg,
#  号*kanji*number,
#  合*kanji*fit,
#  拷*kanji*torture,
#  剛*kanji*sturdy,
#  傲*kanji*be proud,
#  豪*kanji*overpowering,
#  克*kanji*overcome,
#  告*kanji*tell,
#  谷*kanji*valley,
#  刻*kanji*engrave,
#  国*kanji*country,
#  黒*kanji*black,
#  穀*kanji*cereals,
#  酷*kanji*cruel,
#  獄*kanji*prison,
#  骨*kanji*bone,
#  駒*kanji*horse,
#  込*kanji*crowded,
#  頃*kanji*times,
#  今*kanji*now,
#  困*kanji*become distressed,
#  昆*kanji*descendants,
#  恨*kanji*rancor,
#  根*kanji*root,
#  婚*kanji*marriage,
#  混*kanji*mix,
#  痕*kanji*mark,
#  紺*kanji*dark blue,
#  魂*kanji*soul,
#  墾*kanji*ground-breaking,
#  懇*kanji*sociable,
#  左*kanji*left (direction),
#  佐*kanji*help,
#  沙*kanji*sand,
#  査*kanji*investigate,
#  砂*kanji*sand,
#  唆*kanji*tempt,
#  差*kanji*distinction,
#  詐*kanji*lie,
#  鎖*kanji*chain,
#  座*kanji*sit,
#  挫*kanji*sprain,
#  才*kanji*genius,
#  再*kanji*again,
#  災*kanji*disaster,
#  妻*kanji*wife,
#  采*kanji*form,
#  砕*kanji*smash,
#  宰*kanji*superintend,
#  栽*kanji*plantation,
#  彩*kanji*coloring,
#  採*kanji*pick,
#  済*kanji*settle,
#  祭*kanji*festival,
#  斎*kanji*purification,
#  細*kanji*thin,
#  菜*kanji*vegetable,
#  最*kanji*most,
#  裁*kanji*judge,
#  債*kanji*bond,
#  催*kanji*sponsor,
#  塞*kanji*obstruct,
#  歳*kanji*year-end,
#  載*kanji*ride,
#  際*kanji*occasion,
#  埼*kanji*cape (geography),
#  在*kanji*exist,
#  材*kanji*lumber,
#  剤*kanji*dose,
#  財*kanji*wealth,
#  罪*kanji*guilt,
#  崎*kanji*promontory,
#  作*kanji*make,
#  削*kanji*plane,
#  昨*kanji*previous,
#  柵*kanji*fence,
#  索*kanji*cord,
#  策*kanji*scheme,
#  酢*kanji*vinegar,
#  搾*kanji*squeeze,
#  錯*kanji*confused,
#  咲*kanji*blossom,
#  冊*kanji*counter for books,
#  札*kanji*tag,
#  刷*kanji*printing,
#  刹*kanji*temple,
#  拶*kanji*be imminent,
#  殺*kanji*kill,
#  察*kanji*guess,
#  撮*kanji*snapshot,
#  擦*kanji*grate,
#  雑*kanji*miscellaneous,
#  皿*kanji*dish,
#  三*kanji*three,
#  山*kanji*mountain,
#  参*kanji*participate,
#  桟*kanji*scaffold,
#  蚕*kanji*silkworm,
#  惨*kanji*wretched,
#  産*kanji*give birth,
#  傘*kanji*umbrella,
#  散*kanji*scatter,
#  算*kanji*calculate,
#  酸*kanji*acid,
#  賛*kanji*approve,
#  残*kanji*remainder,
#  斬*kanji*kill by slicing,
#  暫*kanji*temporarily,
#  士*kanji*gentleman,
#  子*kanji*child,
#  支*kanji*branch,
#  止*kanji*stop,
#  氏*kanji*family name,
#  仕*kanji*do,
#  史*kanji*history,
#  司*kanji*director,
#  四*kanji*four,
#  市*kanji*market,
#  矢*kanji*arrow,
#  旨*kanji*delicious,
#  死*kanji*death,
#  糸*kanji*thread,
#  至*kanji*climax,
#  伺*kanji*pay respects,
#  志*kanji*intention,
#  私*kanji*me,
#  使*kanji*use,
#  刺*kanji*thorn,
#  始*kanji*begin,
#  姉*kanji*older sister,
#  枝*kanji*branch,
#  祉*kanji*welfare,
#  肢*kanji*limb,
#  姿*kanji*figure,
#  思*kanji*think,
#  指*kanji*finger,
#  施*kanji*carry out,
#  師*kanji*expert,
#  恣*kanji*selfish,
#  紙*kanji*paper,
#  脂*kanji*fat,
#  視*kanji*look at,
#  紫*kanji*purple,
#  詞*kanji*poetry,
#  歯*kanji*tooth,
#  嗣*kanji*heir,
#  試*kanji*test,
#  詩*kanji*poem,
#  資*kanji*resources,
#  飼*kanji*domesticate,
#  誌*kanji*document,
#  雌*kanji*feminine,
#  摯*kanji*seriousness,
#  賜*kanji*grant,
#  諮*kanji*consult with,
#  示*kanji*indicate,
#  字*kanji*letter,
#  寺*kanji*Buddhist temple,
#  次*kanji*next,
#  耳*kanji*ear,
#  自*kanji*oneself,
#  似*kanji*becoming,
#  児*kanji*child,
#  事*kanji*abstract thing,
#  侍*kanji*waiter,
#  治*kanji*govern,
#  持*kanji*hold,
#  時*kanji*time,
#  滋*kanji*nourishing,
#  慈*kanji*mercy,
#  辞*kanji*resign,
#  磁*kanji*magnet,
#  餌*kanji*bait,
#  璽*kanji*emperor's seal,
#  鹿*kanji*deer,
#  式*kanji*style,
#  識*kanji*discriminating,
#  軸*kanji*axis,
#  七*kanji*seven,
#  𠮟*kanji*scold,
#  失*kanji*lose,
#  室*kanji*room,
#  疾*kanji*rapidly,
#  執*kanji*tenacious,
#  湿*kanji*damp,
#  嫉*kanji*envy,
#  漆*kanji*lacquer,
#  質*kanji*quality,
#  実*kanji*truth,
#  芝*kanji*turf,
#  写*kanji*copy,
#  社*kanji*company,
#  車*kanji*car,
#  舎*kanji*cottage,
#  者*kanji*someone,
#  射*kanji*shoot,
#  捨*kanji*throw away,
#  赦*kanji*pardon,
#  斜*kanji*diagonal,
#  煮*kanji*boil,
#  遮*kanji*intercept,
#  謝*kanji*apologize,
#  邪*kanji*wicked,
#  蛇*kanji*snake,
#  尺*kanji*shaku,
#  借*kanji*borrow,
#  酌*kanji*bartending,
#  釈*kanji*explanation,
#  爵*kanji*baron,
#  若*kanji*young,
#  弱*kanji*weak,
#  寂*kanji*loneliness,
#  手*kanji*hand,
#  主*kanji*master,
#  守*kanji*protect,
#  朱*kanji*vermilion,
#  取*kanji*take,
#  狩*kanji*hunt,
#  首*kanji*neck,
#  殊*kanji*particularly,
#  珠*kanji*pearl,
#  酒*kanji*alcoholic drink,
#  腫*kanji*tumor,
#  種*kanji*kind,
#  趣*kanji*gist,
#  寿*kanji*longevity,
#  受*kanji*accept,
#  呪*kanji*curse,
#  授*kanji*instruct,
#  需*kanji*demand,
#  儒*kanji*Confucian,
#  樹*kanji*trees,
#  収*kanji*take in,
#  囚*kanji*captured,
#  州*kanji*state,
#  舟*kanji*boat,
#  秀*kanji*excel,
#  周*kanji*circumference,
#  宗*kanji*religion,
#  拾*kanji*pick up,
#  秋*kanji*autumn,
#  臭*kanji*stinking,
#  修*kanji*discipline,
#  袖*kanji*sleeve,
#  終*kanji*end,
#  羞*kanji*feel ashamed,
#  習*kanji*learn,
#  週*kanji*week,
#  就*kanji*concerning,
#  衆*kanji*masses,
#  集*kanji*collect,
#  愁*kanji*distress,
#  酬*kanji*repay,
#  醜*kanji*ugly,
#  蹴*kanji*kick,
#  襲*kanji*attack,
#  十*kanji*ten,
#  汁*kanji*soup,
#  充*kanji*allot,
#  住*kanji*dwelling,
#  柔*kanji*tender,
#  重*kanji*heavy,
#  従*kanji*obey,
#  渋*kanji*astringent,
#  銃*kanji*gun,
#  獣*kanji*animal,
#  縦*kanji*vertical,
#  叔*kanji*uncle,
#  祝*kanji*celebrate,
#  宿*kanji*inn,
#  淑*kanji*graceful,
#  粛*kanji*solemn,
#  縮*kanji*shrink,
#  塾*kanji*cram school,
#  熟*kanji*ripen,
#  出*kanji*exit,
#  述*kanji*mention,
#  術*kanji*art,
#  俊*kanji*genius,
#  春*kanji*springtime,
#  瞬*kanji*wink,
#  旬*kanji*10-day period (of the month),
#  巡*kanji*patrol,
#  盾*kanji*shield,
#  准*kanji*quasi-,
#  殉*kanji*martyrdom,
#  純*kanji*genuine,
#  循*kanji*sequential,
#  順*kanji*obey,
#  準*kanji*standard,
#  潤*kanji*wet,
#  遵*kanji*abide by,
#  処*kanji*dispose,
#  初*kanji*first,
#  所*kanji*place,
#  書*kanji*write,
#  庶*kanji*commoner,
#  暑*kanji*hot,
#  署*kanji*government office,
#  緒*kanji*thong,
#  諸*kanji*various,
#  女*kanji*woman,
#  如*kanji*likeness,
#  助*kanji*help,
#  序*kanji*preface,
#  叙*kanji*confer,
#  徐*kanji*gradually,
#  除*kanji*exclude,
#  小*kanji*small,
#  升*kanji*measuring box,
#  少*kanji*few,
#  召*kanji*summon,
#  匠*kanji*artisan,
#  床*kanji*bed,
#  抄*kanji*extract,
#  肖*kanji*resemblance,
#  尚*kanji*esteem,
#  招*kanji*beckon,
#  承*kanji*acquiesce,
#  昇*kanji*rise up,
#  松*kanji*pine,
#  沼*kanji*marsh,
#  昭*kanji*shining,
#  宵*kanji*wee hours,
#  将*kanji*leader,
#  消*kanji*extinguish,
#  症*kanji*symptoms,
#  祥*kanji*auspicious,
#  称*kanji*appellation,
#  笑*kanji*laugh,
#  唱*kanji*chant,
#  商*kanji*sell,
#  渉*kanji*ford,
#  章*kanji*chapter,
#  紹*kanji*introduce,
#  訟*kanji*sue,
#  勝*kanji*win,
#  掌*kanji*manipulate,
#  晶*kanji*sparkle,
#  焼*kanji*bake,
#  焦*kanji*char,
#  硝*kanji*nitrate,
#  粧*kanji*cosmetics,
#  詔*kanji*imperial edict,
#  証*kanji*evidence,
#  象*kanji*elephant,
#  傷*kanji*wound,
#  奨*kanji*exhort,
#  照*kanji*illuminate,
#  詳*kanji*detailed,
#  ...]

# %%
# https://networkx.org/documentation/stable/reference/algorithms/isolates.html
# EDA + Preprocessing: Removing Isolated Nodes

print('number of isolated: ', nx.number_of_isolates(G))
isolated_nodes = [k for k in kanjigen_nodes if k not in nx.isolates(G)]
print(isolated_nodes)


G.remove_nodes_from(list(nx.isolates(G)))
# Out:
# number of isolated:  108
# [亜*kanji*sub-, 哀*kanji*pathetic, 挨*kanji*push open, 愛*kanji*love, 曖*kanji*not clear, 悪*kanji*bad, 握*kanji*grip, 圧*kanji*pressure, 扱*kanji*handle, 宛*kanji*allocate, 嵐*kanji*storm, 安*kanji*cheap, 案*kanji*plan, 暗*kanji*dark, 以*kanji*by means of, 衣*kanji*clothes, 位*kanji*rank, 囲*kanji*surround, 医*kanji*medicine, 依*kanji*reliant, 委*kanji*committee, 威*kanji*intimidate, 為*kanji*do, 畏*kanji*fear, 胃*kanji*stomach, 尉*kanji*military officer, 異*kanji*uncommon, 移*kanji*shift, 萎*kanji*wither, 偉*kanji*admirable, 椅*kanji*chair, 彙*kanji*same kind, 意*kanji*idea, 違*kanji*differ, 維*kanji*fiber, 慰*kanji*consolation, 遺*kanji*bequeath, 緯*kanji*horizontal, 域*kanji*range, 育*kanji*nurture, 壱*kanji*one (falsification prevention), 逸*kanji*deviate, 茨*kanji*thorn, 芋*kanji*potato, 引*kanji*pull, 印*kanji*mark, 因*kanji*cause, 咽*kanji*throat, 姻*kanji*matrimony, 員*kanji*member, 院*kanji*institution, 淫*kanji*lewdness, 陰*kanji*shade, 飲*kanji*drink, 隠*kanji*conceal, 韻*kanji*rhyme, 右*kanji*right (direction), 宇*kanji*eaves, 羽*kanji*feather, 唄*kanji*song, 鬱*kanji*gloom, 畝*kanji*furrow, 浦*kanji*bay, 運*kanji*carry, 雲*kanji*cloud, 永*kanji*eternity, 泳*kanji*swim, 英*kanji*England, 映*kanji*reflect, 栄*kanji*prosperity, 営*kanji*manage, 詠*kanji*recitation, 影*kanji*shadow, 鋭*kanji*pointed, 衛*kanji*defense, 易*kanji*easy, 疫*kanji*epidemic, 益*kanji*benefit, 液*kanji*fluid, 駅*kanji*station, 悦*kanji*ecstasy, 越*kanji*cross over, 謁*kanji*audience, 閲*kanji*review, 円*kanji*round, yen, 延*kanji*prolong, 沿*kanji*run alongside, 炎*kanji*inflammation, 怨*kanji*grudge, 宴*kanji*banquet, 媛*kanji*princess, 援*kanji*aid, 園*kanji*garden, 煙*kanji*smoke, 猿*kanji*monkey, 遠*kanji*far, 鉛*kanji*lead, 塩*kanji*salt, 演*kanji*perform, 縁*kanji*affinity, 艶*kanji*glossy, 汚*kanji*dirty, 凹*kanji*concave, 央*kanji*center, 応*kanji*respond, 往*kanji*outward journey, 押*kanji*push, 旺*kanji*flourishing, 欧*kanji*Europe, 殴*kanji*assault, 桜*kanji*cherry tree, 翁*kanji*venerable old man, 奥*kanji*heart, 横*kanji*side, 岡*kanji*hill, 屋*kanji*roof, 億*kanji*hundred million, 憶*kanji*recollection, 臆*kanji*timidity, 虞*kanji*uneasiness, 俺*kanji*I, we, 卸*kanji*wholesale, 音*kanji*sound, 恩*kanji*grace, 温*kanji*warm, 穏*kanji*calm, 下*kanji*below, 化*kanji*change, 加*kanji*add, 可*kanji*possible, 仮*kanji*temporary, 何*kanji*what, 花*kanji*flower, 佳*kanji*excellent, 価*kanji*value, 果*kanji*fruit, 河*kanji*river, 苛*kanji*torment, 科*kanji*section, 架*kanji*rack, 夏*kanji*summer, 家*kanji*house, 荷*kanji*luggage, 華*kanji*splendor, 菓*kanji*confectionery, 貨*kanji*freight, 渦*kanji*whirlpool, 過*kanji*go beyond, 嫁*kanji*marry into, 暇*kanji*spare time, 禍*kanji*calamity, 靴*kanji*shoes, 寡*kanji*widow, 歌*kanji*song, 箇*kanji*counters for things, 稼*kanji*earnings, 課*kanji*section, 蚊*kanji*mosquito, 我*kanji*ego, 画*kanji*tableau, 芽*kanji*bud, 賀*kanji*congratulations, 雅*kanji*gracious, 餓*kanji*starve, 介*kanji*jammed in, 回*kanji*times, 灰*kanji*ashes, 会*kanji*association, 快*kanji*cheerful, 戒*kanji*commandment, 改*kanji*reformation, 怪*kanji*suspicious, 拐*kanji*kidnap, 悔*kanji*repent, 海*kanji*sea, 界*kanji*world, 皆*kanji*all, 械*kanji*contraption, 絵*kanji*picture, 開*kanji*open, 階*kanji*floor of a building, 塊*kanji*clod, 楷*kanji*square character style, 解*kanji*untie, 潰*kanji*crush, 壊*kanji*demolition, 懐*kanji*pocket, 諧*kanji*harmony, 貝*kanji*shellfish, 外*kanji*outside, 劾*kanji*censure, 害*kanji*harm, 崖*kanji*cliff, 涯*kanji*horizon, 街*kanji*street, 慨*kanji*rue, 蓋*kanji*cover, 該*kanji*above-stated, 概*kanji*outline, 骸*kanji*dead remains, 垣*kanji*hedge, 柿*kanji*persimmon, 各*kanji*each, 角*kanji*angle, 拡*kanji*broaden, 革*kanji*leather, 格*kanji*status, 核*kanji*nucleus, 殻*kanji*husk, 郭*kanji*enclosure, 覚*kanji*memorize, 較*kanji*contrast, 隔*kanji*isolate, 閣*kanji*tall, 確*kanji*certain, 獲*kanji*seize, 嚇*kanji*menacing, 穫*kanji*harvest, 学*kanji*study, 岳*kanji*point, 楽*kanji*pleasure, 額*kanji*amount, 顎*kanji*jaw, 掛*kanji*hang, 潟*kanji*lagoon, 括*kanji*fasten, 活*kanji*active, 喝*kanji*hoarse, 渇*kanji*thirst, 割*kanji*divide, 葛*kanji*arrowroot, 滑*kanji*slippery, 褐*kanji*brown, 轄*kanji*control, 且*kan ...

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 2283
# Number of edges: 6753
# Average degree:   5.9159

# %%
visualize_graph(Graph=G.subgraph(random.sample(G.nodes, 300)), figsize=(15,15), node_size=2000)

# %% [markdown]
# ## User Input

# %%
kin = get_node(kanjigen_nodes, '怨', 'kanji')
kout = get_node(kanjigen_nodes, '浦', 'kanji')

result_shortest_path = nx.shortest_path(G, source=kin, target=kout)
print(result_shortest_path)
visualize_graph(Graph=result, color_map=get_node_color_result(MO_raw, MD_raw, result))
# Out:
# [怨*kanji*grudge, 心*radical*heart, 恐*kanji*fear, 丶*radical*dot, 浦*kanji*bay]

# %%
def generate_graph(nodes: List[KanjigenNode]) -> nx.Graph:
    R = nx.Graph()
    R.add_nodes_from(nodes)
    R.add_edges_from(nx.utils.pairwise(nodes))
    return R

# %%
def get_node_color_result(kinputs, koutputs, union_result):
    color_map = []
    for n in union_result:
        if n.symbol in kinputs:
            color_map.append("green")
        elif n.symbol in koutputs:
            color_map.append("blue")
        else:
            color_map.append(n.color)
    return color_map

# %% [markdown]
# ### Test Case

# %%
def get_tc(filepath: str):
    fullpath = f"testcase/{filepath}"
    with open(fullpath) as file:
        return [row.strip() for row in file.readlines()]
    return None

# %%
tc_kanji_raw = [(get_tc(f"{i}.in"),get_tc(f"{i}.out")) for i in range(1,11)]

# %%
tc_kanji_clean = [{
        'MOrig': [get_node(kanjigen_nodes, o, 'kanji') for o in tc[0]],
        'MDest': [get_node(kanjigen_nodes, o, 'kanji') for o in tc[1]]
    } for tc in tc_kanji_raw]

# %%
pp(tc_kanji_clean)
# Out:
# [{'MDest': [浦*kanji*bay, 奥*kanji*heart, 媛*kanji*princess],
#   'MOrig': [怨*kanji*grudge, 姻*kanji*matrimony, 桜*kanji*cherry tree]},
#  {'MDest': [二*kanji*two,
#             丁*kanji*ward,
#             None,
#             行*kanji*go,
#             寸*kanji*measurement,
#             寺*kanji*Buddhist temple,
#             時*kanji*time,
#             None,
#             上*kanji*up,
#             None,
#             刀*kanji*sword,
#             分*kanji*part, minute of time,
#             None,
#             None,
#             私*kanji*me,
#             中*kanji*middle,
#             None,
#             None,
#             事*kanji*abstract thing,
#             可*kanji*possible,
#             None,
#             何*kanji*what,
#             自*kanji*oneself,
#             None,
#             又*kanji*or again,
#             皮*kanji*skin,
#             彼*kanji*he,
#             None,
#             方*kanji*direction,
#             生*kanji*life,
#             月*kanji*month, moon,
#             門*kanji*gates,
#             間*kanji*interval,
#             None,
#             手*kanji*hand,
#             言*kanji*say,
#             女*kanji*woman,
#             本*kanji*book],
#   'MOrig': [人*kanji*person,
#             一*kanji*one,
#             None,
#             口*kanji*mouth,
#             日*kanji*day,
#             目*kanji*eye,
#             None,
#             見*kanji*see,
#             None,
#             山*kanji*mountain,
#             出*kanji*exit,
#             十*kanji*ten,
#             八*kanji*eight,
#             木*kanji*tree,
#             未*kanji*not yet,
#             None,
#             来*kanji*come,
#             大*kanji*large,
#             None,
#             了*kanji*finish,
#             子*kanji*child,
#             心*kanji*heart,
#             土*kanji*soil,
#             None,
#             田*kanji*rice paddy,
#             思*kanji*think]},
#  {'MDest': [新*kanji*new,
#             虫*kanji*insect,
#             None,
#             風*kanji*wind,
#             申*kanji*say,
#             None,
#             神*kanji*god,
#             重*kanji*heavy,
#             動*kanji*move,
#             部*kanji*part,
#             向*kanji*over there,
#             夜*kanji*night,
#             内*kanji*inside,
#             青*kanji*blue,
#             相*kanji*mutual,
#             体*kanji*body,
#             眼*kanji*eyeball,
#             味*kanji*flavor,
#             業*kanji*business,
#             僕*kanji*me,
#             多*kanji*many,
#             士*kanji*gentleman,
#             声*kanji*voice,
#             現*kanji*appear,
#             平*kanji*flat,
#             葉*kanji*leaf,
#             全*kanji*whole,
#             足*kanji*foot,
#             七*kanji*seven,
#             切*kanji*cut,
#             金*kanji*gold,
#             近*kanji*near,
#             None,
#             色*kanji*color,
#             None,
#             発*kanji*departure,
#             母*kanji*mother,
#             高*kanji*tall, expensive,
#             以*kanji*by means of,
#             None,
#             None,
#             死*kanji*death,
#             旦*kanji*daybreak,
#             得*kanji*acquire,
#             豆*kanji*beans,
#             頭*kanji*head,
#             欠*kanji*lack,
#             None,
#             次*kanji*next,
#             天*kanji*heaven,
#             夫*kanji*husband,
#             具*kanji*tool,
#             真*kanji*true,
#             甘*kanji*sweet,
#             None,
#             父*kanji*father,
#             親*kanji*parent,
#             巾*kanji*towel,
#             帰*kanji*return,
#             対*kanji*opposite,
#             美*kanji*beauty,
#             六*kanji*six,
#             引*kanji*pull,
#             予*kanji*in advance,
#             野*kanji*field,
#             笑*kanji*laugh,
#             表*kanji*express,
#             等*kanji*class,
#             None,
#             情*kanji*feelings,
#             歩*kanji*walk,
#             馬*kanji*horse,
#             形*kanji*shape,
#             太*kanji*thick,
#             川*kanji*river,
#             各*kanji*each,
#             None,
#             None,
#             落*kanji*fall,
#             性*kanji*gender,
#             食*kanji*eat, meal,
#             None,
#             有*kanji*have,
#             仕*kanji*do,
#             冊*kanji*counter for books,
#             論*kanji*theory,
#             最*kanji*most,
#             記*kanji*write down,
#             信*kanji*trust,
#             None,
#             初*kanji*first,
#             問*kanji*question,
#             None,
#             変*kanji*change,
#             直*kanji*straight,
#             達*kanji*attain],
#   'MOrig': [乙*kanji*the latter,
#             None,
#             気*kanji*feeling,
#             干*kanji*dry,
#             年*kanji*year,
#             三*kanji*three,
#             None,
#             者*kanji*someone,
#             None,
#             前*kanji*in front,
#             None,
#             None,
#             None,
#             None,
#             None,
#             家*kanji*house,
#             今*kanji*now,
#             下*kanji*below,
#             白*kanji*white,
#             None,
#             的*kanji*target,
#             None,
#             牛*kanji*cow,
#             物*kanji*thing,
#             立*kanji*stand up,
#             小*kanji*small,
#             文*kanji*writing,
#             矢*kanji*arrow,
#             知*kanji*know,
#             入*kanji*enter,
#             None,
#             作*kanji*make,
#             None,
#             書*kanji*write,
#             学*kanji*study,
#             合*kanji*fit,
#             None,
#             None,
#             後*kanji*behind,
#             持*kanji*hold,
#             古*kanji*old,
#             None,
#             居*kanji*reside,
#             None,
#             無*kanji*nothing,
#             水*kanji*water,
#             羊*kanji*sheep,
#             様*kanji*formal title,
#             音*kanji*sound,
#             意*kanji*idea,
#             None,
#             地*kanji*ground,
#             止*kanji*stop,
#             午*kanji*noon,
#             None,
#             卸*kanji*wholesale,
#             御*kanji*honorable,
#             至*kanji*climax,
#             屋*kanji*roof,
#             None,
#             None,
#             None,
#             None,
#             度*kanji*degrees,
#             同*kanji*same,
#             不*kanji*non-,
#             実*kanji*truth,
#             千*kanji*thousand,
#             舌*kanji*tongue,
#             話*kanji*talk,
#             身*kanji*body,
#             戸*kanji*door,
#             斤*kanji*axe,
#             所*kanji*place,
#             先*kanji*previous,
#             力*kanji*power,
#             五*kanji*five,
#             明*kanji*bright,
#             None,
#             代*kanji*substitute,
#             犬*kanji*dog,
#             然*kanji*so,
#             用*kanji*use,
#             None,
#             None,
#             通*kanji*pass through,
#             耳*kanji*ear,
#             聞*kanji*hear,
#             衣*kanji*clothes,
#             None,
#             長*kanji*long,
#             少*kanji*few,
#             己*kanji*self,
#             竹*kanji*bamboo,
#             弓*kanji*bow (archery, violin),
#             第*kanji*ordinal number prefix,
#             None,
#             感*kanji*feeling,
#             世*kanji*world,
#             工*kanji*craft,
#             穴*kanji*hole,
#             空*kanji*sky,
#             None,
#             四*kanji*four,
#             王*kanji*king,
#             里*kanji*village,
#             理*kanji*reason,
#             主*kanji*master,
#             久*kanji*long time,
#             夕*kanji*evening,
#             名*kanji*name,
#             面*kanji*face,
#             場*kanji*place,
#             None,
#             None,
#             貝*kanji*shellfish,
#             None,
#             顔*kanji*face,
#             君*kanji*you,
#             万*kanji*ten thousand,
#             成*kanji*become,
#             考*kanji*think,
#             首*kanji*neck,
#             道*kanji*road,
#             正*kanji*correct,
#             None,
#             郎*kanji*son,
#             当*kanji*hit,
#             男*kanji*male,
#             外*kanji*outside,
#             玉*kanji*ball,
#             国*kanji*country,
#             会*kanji*association,
#             取*kanji*take]},
#  {'MDest': [非*kanji*negative,
#             婦*kanji*lady,
#             寝*kanji*lie down,
#             None,
#             酒*kanji*alcoholic drink,
#             失*kanji*lose,
#             武*kanji*military,
#             判*kanji*judge,
#             支*kanji*branch,
#             加*kanji*add,
#             細*kanji*thin,
#             質*kanji*quality,
#             特*kanji*special,
#             祭*kanji*festival,
#             際*kanji*occasion,
#             路*kanji*road,
#             政*kanji*politics,
#             告*kanji*tell,
#             列*kanji*row,
#             例*kanji*example,
#             客*kanji*guest,
#             貴*kanji*precious,
#             雨*kanji*rain,
#             雪*kanji*snow,
#             能*kanji*ability,
#             位*kanji*rank,
#             暗*kanji*dark,
#             芸*kanji*art,
#             None,
#             振*kanji*shake,
#             片*kanji*one-sided,
#             難*kanji*difficult,
#             井*kanji*well,
#             乗*kanji*ride,
#             茶*kanji*tea,
#             故*kanji*circumstances,
#             準*kanji*standard,
#             宮*kanji*Shinto shrine,
#             店*kanji*shop,
#             冬*kanji*winter,
#             終*kanji*end,
#             息*kanji*breath,
#             電*kanji*electricity,
#             丸*kanji*circle,
#             勢*kanji*power,
#             衛*kanji*defense,
#             None,
#             None,
#             亡*kanji*deceased,
#             望*kanji*hope,
#             春*kanji*springtime,
#             旨*kanji*delicious,
#             指*kanji*finger,
#             配*kanji*distribute,
#             役*kanji*service,
#             幸*kanji*happiness,
#             階*kanji*floor of a building,
#             景*kanji*scenery,
#             影*kanji*shadow,
#             渡*kanji*transit,
#             None,
#             夢*kanji*dream,
#             巻*kanji*scroll,
#             凶*kanji*villain,
#             胸*kanji*bosom,
#             制*kanji*control,
#             極*kanji*poles,
#             臣*kanji*retainer,
#             蔵*kanji*warehouse,
#             奥*kanji*heart,
#             都*kanji*metropolis,
#             None,
#             掛*kanji*hang,
#             段*kanji*steps,
#             態*kanji*condition,
#             江*kanji*inlet,
#             悲*kanji*sad,
#             限*kanji*limit,
#             肖*kanji*resemblance,
#             消*kanji*extinguish,
#             絶*kanji*discontinue,
#             追*kanji*follow,
#             勝*kanji*win,
#             離*kanji*detach,
#             精*kanji*refined,
#             与*kanji*give,
#             守*kanji*protect,
#             None,
#             藤*kanji*wisteria,
#             類*kanji*sort,
#             妻*kanji*wife,
#             素*kanji*elementary,
#             官*kanji*government official,
#             None,
#             館*kanji*public building,
#             史*kanji*history,
#             那*kanji*what,
#             谷*kanji*valley,
#             容*kanji*contain,
#             None,
#             敷*kanji*spread,
#             答*kanji*answer,
#             住*kanji*dwelling,
#             折*kanji*fold,
#             宿*kanji*inn,
#             遊*kanji*play,
#             計*kanji*measure,
#             召*kanji*summon,
#             昭*kanji*shining,
#             注*kanji*pour,
#             造*kanji*create,
#             放*kanji*release,
#             None,
#             廷*kanji*courts,
#             庭*kanji*garden,
#             為*kanji*do,
#             波*kanji*wave,
#             断*kanji*cut off,
#             働*kanji*work,
#             格*kanji*status,
#             北*kanji*north,
#             背*kanji*back,
#             旅*kanji*trip,
#             続*kanji*continue,
#             広*kanji*wide,
#             泉*kanji*spring,
#             線*kanji*line,
#             斗*kanji*Big Dipper,
#             科*kanji*section,
#             句*kanji*phrase,
#             敬*kanji*respect,
#             驚*kanji*wonder,
#             忘*kanji*forget,
#             炎*kanji*inflammation,
#             談*kanji*discuss,
#             産*kanji*give birth,
#             降*kanji*descend,
#             志*kanji*intention,
#             鳥*kanji*bird,
#             鳴*kanji*chirp,
#             越*kanji*cross over,
#             争*kanji*conflict,
#             静*kanji*quiet,
#             押*kanji*push,
#             市*kanji*market,
#             None,
#             舞*kanji*dance,
#             None,
#             俺*kanji*I, we,
#             奴*kanji*guy,
#             泣*kanji*cry,
#             則*kanji*rule,
#             側*kanji*side,
#             象*kanji*elephant,
#             像*kanji*statue,
#             洋*kanji*ocean,
#             号*kanji*number,
#             浮*kanji*floating,
#             束*kanji*bundle,
#             頼*kanji*trust,
#             房*kanji*tassel,
#             送*kanji*send,
#             詩*kanji*poem,
#             参*kanji*participate,
#             異*kanji*uncommon,
#             買*kanji*buy,
#             従*kanji*obey,
#             南*kanji*south,
#             清*kanji*pure,
#             系*kanji*lineage,
#             係*kanji*person in charge,
#             諸*kanji*various,
#             熱*kanji*heat,
#             服*kanji*clothes,
#             似*kanji*becoming,
#             河*kanji*river,
#             怪*kanji*suspicious,
#             秋*kanji*autumn,
#             晩*kanji*nightfall,
#             将*kanji*leader,
#             林*kanji*woods,
#             件*kanji*affair,
#             城*kanji*castle,
#             皿*kanji*dish,
#             血*kanji*blood,
#             徳*kanji*benevolence,
#             腹*kanji*abdomen,
#             組*kanji*association,
#             満*kanji*full,
#             妙*kanji*exquisite,
#             昔*kanji*long ago,
#             料*kanji*fee,
#             円*kanji*round, yen,
#             独*kanji*alone,
#             雲*kanji*cloud,
#             尺*kanji*shaku,
#             沢*kanji*swamp,
#             雑*kanji*miscellaneous,
#             許*kanji*permit,
#             窓*kanji*window,
#             往*kanji*outward journey,
#             兆*kanji*portent, trillion,
#             逃*kanji*escape,
#             喜*kanji*rejoice,
#             肉*kanji*meat,
#             暮*kanji*livelihood,
#             博*kanji*Dr.,
#             吹*kanji*blow,
#             更*kanji*grow late,
#             困*kanji*become distressed,
#             派*kanji*sect,
#             曲*kanji*musical composition,
#             傍*kanji*bystander,
#             縁*kanji*affinity,
#             None,
#             橋*kanji*bridge,
#             臼*kanji*mortar,
#             興*kanji*entertain,
#             附*kanji*affixed,
#             並*kanji*line-up,
#             期*kanji*period of time,
#             None,
#             毎*kanji*every,
#             抜*kanji*slip out,
#             岸*kanji*beach,
#             求*kanji*request,
#             労*kanji*labour,
#             薄*kanji*dilute,
#             黙*kanji*silence,
#             None,
#             端*kanji*edge,
#             None,
#             劇*kanji*drama,
#             確*kanji*certain,
#             末*kanji*end,
#             弟*kanji*younger brother,
#             絵*kanji*picture,
#             裏*kanji*back,
#             改*kanji*reformation,
#             令*kanji*orders,
#             冷*kanji*cool,
#             None,
#             及*kanji*reach out,
#             訳*kanji*translate,
#             飲*kanji*drink,
#             None,
#             保*kanji*preserve,
#             途*kanji*route,
#             完*kanji*perfect,
#             院*kanji*institution,
#             辺*kanji*environs,
#             殿*kanji*Mr.,
#             包*kanji*wrap,
#             抱*kanji*embrace,
#             状*kanji*form,
#             評*kanji*evaluate,
#             玄*kanji*mysterious,
#             刻*kanji*engrave,
#             散*kanji*scatter,
#             None,
#             仰*kanji*face-up,
#             None,
#             疑*kanji*doubt,
#             痛*kanji*pain,
#             破*kanji*rend,
#             再*kanji*again,
#             構*kanji*construct,
#             案*kanji*plan,
#             差*kanji*distinction,
#             族*kanji*tribe,
#             緒*kanji*thong,
#             銀*kanji*silver,
#             軽*kanji*light,
#             版*kanji*printing block,
#             堂*kanji*public chamber,
#             福*kanji*luck,
#             刃*kanji*blade,
#             忍*kanji*endure,
#             認*kanji*recognize,
#             恋*kanji*romance,
#             建*kanji*build,
#             衆*kanji*masses,
#             毛*kanji*hair,
#             察*kanji*guess,
#             腰*kanji*loins,
#             快*kanji*cheerful,
#             煙*kanji*smoke,
#             敵*kanji*enemy,
#             負*kanji*lose,
#             探*kanji*grope,
#             究*kanji*research,
#             岩*kanji*boulder,
#             歳*kanji*year-end,
#             隠*kanji*conceal,
#             None,
#             伸*kanji*lengthen,
#             応*kanji*respond,
#             団*kanji*group,
#             歴*kanji*curriculum,
#             員*kanji*member,
#             候*kanji*climate,
#             微*kanji*delicate,
#             筆*kanji*writing brush,
#             礼*kanji*thanks,
#             源*kanji*origin,
#             昨*kanji*previous,
#             羽*kanji*feather,
#             宗*kanji*religion,
#             尾*kanji*tail,
#             眺*kanji*stare,
#             転*kanji*revolve,
#             商*kanji*sell,
#             州*kanji*state,
#             投*kanji*throw,
#             願*kanji*request,
#             研*kanji*sharpen,
#             永*kanji*eternity,
#             留*kanji*detain,
#             雄*kanji*male,
#             憂*kanji*melancholy,
#             優*kanji*superior,
#             佐*kanji*help,
#             器*kanji*container,
#             証*kanji*evidence,
#             回*kanji*times,
#             鹿*kanji*deer,
#             仏*kanji*Buddha,
#             髪*kanji*hair of the head,
#             致*kanji*(to) do,
#             叫*kanji*shout,
#             演*kanji*perform,
#             退*kanji*retreat,
#             眠*kanji*sleep,
#             弱*kanji*weak,
#             固*kanji*hard,
#             個*kanji*individual,
#             枝*kanji*branch,
#             罪*kanji*guilt,
#             央*kanji*center,
#             験*kanji*test,
#             夏*kanji*summer,
#             職*kanji*employment,
#             視*kanji*look at,
#             報*kanji*report,
#             即*kanji*instant,
#             節*kanji*node,
#             富*kanji*rich,
#             骨*kanji*bone,
#             善*kanji*good,
#             斉*kanji*adjusted,
#             済*kanji*settle,
#             写*kanji*copy,
#             育*kanji*nurture,
#             約*kanji*promise,
#             密*kanji*secrecy,
#             弁*kanji*valve,
#             床*kanji*bed,
#             戻*kanji*re-,
#             涙*kanji*tears,
#             給*kanji*salary,
#             唯*kanji*solely,
#             仲*kanji*relationship,
#             None,
#             焼*kanji*bake,
#             宛*kanji*allocate,
#             腕*kanji*arm,
#             陽*kanji*sunshine,
#             到*kanji*arrival,
#             倒*kanji*overthrow,
#             響*kanji*echo,
#             坂*kanji*slope,
#             権*kanji*rights,
#             苗*kanji*seedling,
#             描*kanji*sketch,
#             勧*kanji*persuade,
#             乱*kanji*riot,
#             警*kanji*guard against,
#             養*kanji*foster,
#             岡*kanji*hill,
#             姉*kanji*older sister,
#             価*kanji*value,
#             鼻*kanji*nose,
#             条*kanji*clause,
#             寒*kanji*cold,
#             坊*kanji*boy,
#             隊*kanji*group,
#             None,
#             籠*kanji*basket,
#             囲*kanji*surround,
#             星*kanji*star,
#             兼*kanji*concurrently,
#             嫌*kanji*dislike,
#             登*kanji*climb,
#             接*kanji*contact,
#             旧*kanji*old times,
#             児*kanji*child,
#             街*kanji*street,
#             任*kanji*responsibility,
#             祖*kanji*ancestor,
#             刷*kanji*printing,
#             飯*kanji*meal,
#             医*kanji*medicine,
#             板*kanji*board,
#             毒*kanji*poison,
#             照*kanji*illuminate,
#             局*kanji*office,
#             肩*kanji*shoulder,
#             盛*kanji*prosper,
#             森*kanji*forest,
#             辛*kanji*spicy,
#             壁*kanji*wall,
#             None,
#             婚*kanji*marriage,
#             矛*kanji*halberd,
#             務*kanji*duty,
#             露*kanji*dew,
#             丈*kanji*length,
#             鉄*kanji*iron,
#             易*kanji*easy,
#             郷*kanji*home town,
#             僧*kanji*Buddhist priest,
#             駄*kanji*burdensome,
#             狂*kanji*lunatic,
#             織*kanji*weave,
#             境*kanji*boundary,
#             英*kanji*England,
#             布*kanji*linen,
#             帯*kanji*sash,
#             習*kanji*learn,
#             因*kanji*cause,
#             踏*kanji*step,
#             湯*kanji*hot water,
#             移*kanji*shift,
#             倉*kanji*warehouse,
#             低*kanji*low,
#             責*kanji*blame,
#             積*kanji*accumulate,
#             婆*kanji*old woman,
#             仮*kanji*temporary,
#             津*kanji*haven,
#             訪*kanji*visit,
#             鬼*kanji*ghost,
#             麻*kanji*hemp,
#             魔*kanji*witch,
#             儀*kanji*ceremony,
#             魚*kanji*fish,
#             怒*kanji*angry,
#             映*kanji*reflect,
#             枚*kanji*sheet of...,
#             None,
#             修*kanji*discipline,
#             印*kanji*mark,
#             荒*kanji*laid waste,
#             晴*kanji*clear up,
#             None,
#             軒*kanji*flats,
#             樹*kanji*trees,
#             尊*kanji*revered,
#             None,
#             屯*kanji*barracks,
#             純*kanji*genuine,
#             休*kanji*rest,
#             府*kanji*urban prefecture,
#             怖*kanji*dreadful,
#             香*kanji*incense,
#             None,
#             充*kanji*allot,
#             統*kanji*unite,
#             園*kanji*garden,
#             述*kanji*mention,
#             None,
#             沈*kanji*sink,
#             紅*kanji*deep red,
#             著*kanji*renowned,
#             普*kanji*universal,
#             払*kanji*pay,
#             群*kanji*flock,
#             欲*kanji*longing,
#             隻*kanji*vessels,
#             護*kanji*safeguard,
#             銭*kanji*coin,
#             皇*kanji*emperor,
#             呉*kanji*give,
#             秘*kanji*secret,
#             酔*kanji*drunk,
#             捨*kanji*throw away,
#             害*kanji*harm,
#             割*kanji*divide,
#             柄*kanji*design,
#             厄*kanji*unlucky,
#             危*kanji*dangerous,
#             匹*kanji*equal,
#             甚*kanji*tremendously,
#             便*kanji*convenience,
#             騒*kanji*boisterous,
#             聴*kanji*listen,
#             短*kanji*short,
#             席*kanji*seat,
#             哲*kanji*philosophy,
#             承*kanji*acquiesce,
#             遣*kanji*dispatch,
#             資*kanji*resources,
#             灯*kanji*lamp,
#             徒*kanji*junior,
#             舎*kanji*cottage,
#             章*kanji*chapter,
#             鏡*kanji*mirror,
#             就*kanji*concerning,
#             値*kanji*value,
#             農*kanji*farming,
#             傷*kanji*wound,
#             None,
#             朱*kanji*vermilion,
#             殊*kanji*particularly,
#             勇*kanji*courage,
#             温*kanji*warm,
#             妹*kanji*younger sister,
#             般*kanji*generally,
#             筋*kanji*muscle,
#             領*kanji*territory,
#             激*kanji*violent,
#             None,
#             None,
#             曽*kanji*formerly,
#             増*kanji*increase,
#             迷*kanji*astray,
#             技*kanji*skill,
#             頂*kanji*place on the head,
#             昼*kanji*daytime,
#             備*kanji*provide,
#             霊*kanji*spirits,
#             否*kanji*negate,
#             薬*kanji*medicine,
#             None,
#             互*kanji*mutually,
#             隣*kanji*neighboring,
#             選*kanji*choose,
#             跡*kanji*tracks,
#             傾*kanji*lean,
#             壮*kanji*robust,
#             装*kanji*attire,
#             試*kanji*test,
#             速*kanji*fast,
#             挙*kanji*raise,
#             層*kanji*stratum,
#             芝*kanji*turf,
#             詰*kanji*packed,
#             量*kanji*quantity,
#             復*kanji*again,
#             随*kanji*follow,
#             俗*kanji*vulgar,
#             奉*kanji*observance,
#             浅*kanji*shallow,
#             提*kanji*present,
#             浪*kanji*wandering,
#             貧*kanji*poor,
#             杯*kanji*counter for cupfuls,
#             批*kanji*criticism,
#             紀*kanji*chronicle,
#             吸*kanji*suck,
#             幕*kanji*curtain,
#             借*kanji*borrow,
#             None,
#             既*kanji*previously,
#             総*kanji*whole,
#             輪*kanji*wheel,
#             迎*kanji*welcome,
#             屈*kanji*yield,
#             脱*kanji*undress,
#             尋*kanji*inquire,
#             忠*kanji*loyalty,
#             滅*kanji*destroy,
#             荷*kanji*luggage,
#             遺*kanji*bequeath,
#             箱*kanji*box,
#             宅*kanji*home,
#             叔*kanji*uncle,
#             柳*kanji*willow,
#             魂*kanji*soul,
#             埋*kanji*bury,
#             依*kanji*reliant,
#             帝*kanji*sovereign,
#             捕*kanji*catch,
#             級*kanji*rank,
#             秀*kanji*excel,
#             池*kanji*pond,
#             植*kanji*plant,
#             陰*kanji*shade,
#             刺*kanji*thorn,
#             伏*kanji*prostrated,
#             撃*kanji*beat,
#             懸*kanji*suspend,
#             触*kanji*contact,
#             伯*kanji*chief,
#             懐*kanji*pocket,
#             隅*kanji*corner,
#             暴*kanji*outburst,
#             胃*kanji*stomach,
#             None,
#             珍*kanji*rare,
#             区*kanji*ward,
#             洗*kanji*wash,
#             梅*kanji*ume (Japanese apricot),
#             None,
#             迫*kanji*urge,
#             健*kanji*healthy,
#             惑*kanji*beguile,
#             基*kanji*foundation,
#             翌*kanji*the following,
#             才*kanji*genius,
#             称*kanji*appellation,
#             膝*kanji*knee,
#             豊*kanji*bountiful,
#             崎*kanji*promontory,
#             剣*kanji*sabre,
#             敢*kanji*daring,
#             厳*kanji*strict,
#             納*kanji*settlement,
#             展*kanji*expand,
#             恥*kanji*shame,
#             棒*kanji*rod,
#             額*kanji*amount,
#             伴*kanji*consort,
#             逆*kanji*inverted,
#             閉*kanji*closed,
#             射*kanji*shoot,
#             憶*kanji*recollection,
#             瞬*kanji*wink,
#             威*kanji*intimidate,
#             哀*kanji*pathetic,
#             堪*kanji*withstand,
#             None,
#             寂*kanji*loneliness,
#             被*kanji*incur,
#             斎*kanji*purification,
#             趣*kanji*gist,
#             却*kanji*instead,
#             脚*kanji*leg,
#             講*kanji*lecture,
#             握*kanji*grip,
#             姓*kanji*surname,
#             疲*kanji*exhausted,
#             染*kanji*dye,
#             斬*kanji*kill by slicing,
#             暫*kanji*temporarily,
#             犯*kanji*crime,
#             辞*kanji*resign,
#             砂*kanji*sand,
#             牙*kanji*tusk,
#             邪*kanji*wicked,
#             油*kanji*oil,
#             闇*kanji*darkness,
#             概*kanji*outline,
#             遂*kanji*consummate,
#             聖*kanji*holy,
#             汽*kanji*steam,
#             順*kanji*obey,
#             憎*kanji*hate,
#             益*kanji*benefit,
#             泊*kanji*overnight,
#             陣*kanji*camp,
#             慮*kanji*prudence,
#             弾*kanji*bullet,
#             勤*kanji*diligence,
#             推*kanji*infer,
#             卓*kanji*eminent,
#             誌*kanji*document,
#             仙*kanji*hermit,
#             陸*kanji*land,
#             None,
#             拠*kanji*foothold,
#             嬢*kanji*lass,
#             省*kanji*government ministry,
#             障*kanji*hurt,
#             虚*kanji*void,
#             戯*kanji*frolic,
#             尽*kanji*exhaust,
#             併*kanji*join,
#             惜*kanji*pity,
#             畳*kanji*tatami mat,
#             姫*kanji*princess,
#             検*kanji*examine,
#             党*kanji*group,
#             製*kanji*manufacture,
#             誤*kanji*mistake,
#             呂*kanji*spine,
#             執*kanji*tenacious,
#             華*kanji*splendor,
#             袋*kanji*sack,
#             減*kanji*decrease,
#             輩*kanji*comrade,
#             浜*kanji*seacoast,
#             創*kanji*create,
#             None,
#             墓*kanji*grave,
#             救*kanji*salvation,
#             模*kanji*imitation,
#             燃*kanji*burn,
#             刑*kanji*punish,
#             型*kanji*model,
#             杉*kanji*cedar,
#             咲*kanji*blossom,
#             昆*kanji*descendants,
#             混*kanji*mix,
#             麗*kanji*lovely,
#             亭*kanji*pavilion,
#             侍*kanji*waiter,
#             査*kanji*investigate,
#             震*kanji*quake,
#             曜*kanji*day of the week,
#             尚*kanji*esteem,
#             鶴*kanji*crane,
#             敗*kanji*failure,
#             乞*kanji*beg,
#             None,
#             功*kanji*achievement,
#             宜*kanji*best regards,
#             費*kanji*expense,
#             延*kanji*prolong,
#             除*kanji*exclude,
#             栄*kanji*prosperity,
#             踊*kanji*jump,
#             繰*kanji*winding,
#             貫*kanji*pierce,
#             慣*kanji*accustomed,
#             看*kanji*watch over,
#             賀*kanji*congratulations,
#             険*kanji*precipitous,
#             猫*kanji*cat,
#             適*kanji*suitable,
#             尼*kanji*nun,
#             泥*kanji*mud,
#             録*kanji*record,
#             歯*kanji*tooth,
#             漢*kanji*China,
#             飾*kanji*decorate,
#             机*kanji*desk,
#             椅*kanji*chair,
#             冒*kanji*risk,
#             帽*kanji*cap,
#             載*kanji*ride,
#             俳*kanji*haiku,
#             設*kanji*establish,
#             帳*kanji*account book,
#             浴*kanji*bathe,
#             吐*kanji*spit,
#             瀬*kanji*rapids,
#             慢*kanji*ridicule,
#             宝*kanji*treasure,
#             竜*kanji*dragon,
#             扉*kanji*front door,
#             拝*kanji*worship,
#             簡*kanji*simplicity,
#             菊*kanji*chrysanthemum,
#             愚*kanji*foolish,
#             律*kanji*law,
#             革*kanji*leather,
#             編*kanji*compile,
#             勘*kanji*intuition,
#             規*kanji*rule,
#             司*kanji*director,
#             釈*kanji*explanation,
#             弥*kanji*all the more,
#             童*kanji*juvenile,
#             袖*kanji*sleeve,
#             揚*kanji*hoist,
#             None,
#             宇*kanji*eaves,
#             換*kanji*interchange,
#             材*kanji*lumber,
#             悟*kanji*enlightenment,
#             努*kanji*toil,
#             廊*kanji*corridor,
#             維*kanji*fiber,
#             羅*kanji*gauze,
#             盗*kanji*steal,
#             覧*kanji*perusal,
#             輝*kanji*radiance,
#             球*kanji*sphere,
#             添*kanji*annexed,
#             闘*kanji*fight,
#             烈*kanji*ardent,
#             畑*kanji*farm,
#             詞*kanji*poetry,
#             None,
#             None,
#             収*kanji*take in,
#             乳*kanji*milk,
#             柱*kanji*pillar,
#             摩*kanji*chafe,
#             None,
#             釣*kanji*angling,
#             導*kanji*guide,
#             濃*kanji*concentrated],
#   'MOrig': [去*kanji*leave,
#             法*kanji*method,
#             活*kanji*active,
#             込*kanji*crowded,
#             村*kanji*village,
#             None,
#             語*kanji*language,
#             孝*kanji*filial piety,
#             None,
#             教*kanji*teach,
#             着*kanji*wear,
#             社*kanji*company,
#             別*kanji*separate,
#             None,
#             光*kanji*ray,
#             好*kanji*like,
#             亜*kanji*sub-,
#             悪*kanji*bad,
#             和*kanji*peace,
#             右*kanji*right (direction),
#             若*kanji*young,
#             化*kanji*change,
#             花*kanji*flower,
#             氏*kanji*family name,
#             底*kanji*bottom,
#             吉*kanji*good luck,
#             糸*kanji*thread,
#             結*kanji*tie,
#             処*kanji*dispose,
#             原*kanji*field,
#             兄*kanji*older brother,
#             説*kanji*theory,
#             車*kanji*car,
#             走*kanji*run,
#             起*kanji*wake up,
#             字*kanji*letter,
#             流*kanji*stream,
#             占*kanji*fortune telling,
#             点*kanji*point,
#             他*kanji*other,
#             想*kanji*concept,
#             交*kanji*mix,
#             校*kanji*school,
#             我*kanji*ego,
#             義*kanji*righteousness,
#             爪*kanji*claw,
#             愛*kanji*love,
#             百*kanji*hundred,
#             None,
#             置*kanji*put,
#             None,
#             命*kanji*fate,
#             None,
#             違*kanji*differ,
#             如*kanji*likeness,
#             早*kanji*early,
#             朝*kanji*morning,
#             反*kanji*anti-,
#             返*kanji*return,
#             関*kanji*related,
#             米*kanji*rice,
#             数*kanji*number,
#             石*kanji*stone,
#             海*kanji*sea,
#             None,
#             常*kanji*normal,
#             付*kanji*attach,
#             九*kanji*nine,
#             角*kanji*angle,
#             解*kanji*untie,
#             東*kanji*east,
#             火*kanji*fire,
#             None,
#             西*kanji*west,
#             要*kanji*need,
#             苦*kanji*suffer,
#             過*kanji*go beyond,
#             定*kanji*decide,
#             町*kanji*town,
#             安*kanji*cheap,
#             庫*kanji*warehouse,
#             且*kanji*moreover,
#             助*kanji*help,
#             頃*kanji*times,
#             None,
#             民*kanji*people,
#             半*kanji*half,
#             None,
#             集*kanji*collect,
#             誰*kanji*who (question word),
#             共*kanji*together,
#             供*kanji*offer,
#             升*kanji*measuring box,
#             飛*kanji*fly,
#             在*kanji*exist,
#             丘*kanji*hill,
#             兵*kanji*soldier,
#             開*kanji*open,
#             草*kanji*grass,
#             強*kanji*strong,
#             紙*kanji*paper,
#             深*kanji*deep,
#             待*kanji*wait,
#             幾*kanji*how many,
#             機*kanji*machine,
#             None,
#             決*kanji*decide,
#             遠*kanji*far,
#             是*kanji*just so,
#             題*kanji*topic,
#             楽*kanji*pleasure,
#             利*kanji*profit,
#             張*kanji*stretch,
#             示*kanji*indicate,
#             余*kanji*leave over,
#             比*kanji*compare,
#             皆*kanji*all,
#             必*kanji*without fail,
#             歌*kanji*song,
#             打*kanji*hit,
#             呼*kanji*call,
#             根*kanji*root,
#             覚*kanji*memorize,
#             老*kanji*old man,
#             京*kanji*capital,
#             由*kanji*reason,
#             品*kanji*article,
#             台*kanji*pedestal,
#             治*kanji*govern,
#             周*kanji*circumference,
#             調*kanji*investigate,
#             姿*kanji*figure,
#             売*kanji*sell,
#             読*kanji*read,
#             丙*kanji*third class,
#             None,
#             病*kanji*sick,
#             種*kanji*kind,
#             連*kanji*take along,
#             甲*kanji*armor,
#             単*kanji*simple,
#             戦*kanji*war,
#             始*kanji*begin,
#             念*kanji*thought,
#             室*kanji*room,
#             公*kanji*public,
#             急*kanji*hurry,
#             島*kanji*island,
#             左*kanji*left (direction),
#             黒*kanji*black,
#             突*kanji*stab,
#             介*kanji*jammed in,
#             界*kanji*world,
#             術*kanji*art,
#             None,
#             座*kanji*sit,
#             受*kanji*accept,
#             丹*kanji*cinnabar,
#             舟*kanji*boat,
#             船*kanji*boat,
#             元*kanji*origin,
#             観*kanji*observe,
#             吏*kanji*officer,
#             使*kanji*use,
#             経*kanji*manage,
#             図*kanji*diagram,
#             進*kanji*advance,
#             残*kanji*remainder,
#             画*kanji*tableau,
#             松*kanji*pine,
#             凡*kanji*mediocre,
#             恐*kanji*fear,
#             赤*kanji*red,
#             None,
#             殺*kanji*kill,
#             式*kanji*style,
#             None,
#             番*kanji*one's turn,
#             呈*kanji*display,
#             程*kanji*extent,
#             師*kanji*expert,
#             存*kanji*suppose,
#             伝*kanji*transmit,
#             軍*kanji*army,
#             運*kanji*carry,
#             果*kanji*fruit,
#             良*kanji*good,
#             娘*kanji*daughter,
#             識*kanji*discriminating,
#             奇*kanji*strange,
#             寄*kanji*approach,
#             両*kanji*both,
#             None,
#             黄*kanji*yellow,
#             横*kanji*side,
#             議*kanji*deliberation,
#             友*kanji*friend]},
#  {'MDest': [鬱*kanji*gloom,
#             環*kanji*ring,
#             綿*kanji*cotton,
#             紳*kanji*sire,
#             None,
#             貌*kanji*appearance,
#             None,
#             襟*kanji*collar,
#             縫*kanji*sew,
#             涼*kanji*refreshing,
#             催*kanji*sponsor,
#             盤*kanji*tray,
#             銃*kanji*gun,
#             拍*kanji*clap,
#             戴*kanji*be crowned with,
#             裾*kanji*cuff,
#             菓*kanji*confectionery,
#             顕*kanji*appear,
#             担*kanji*shouldering,
#             飽*kanji*sated,
#             鎌*kanji*sickle,
#             None,
#             臓*kanji*entrails,
#             粗*kanji*coarse,
#             訓*kanji*instruction,
#             委*kanji*committee,
#             謀*kanji*conspire,
#             None,
#             遍*kanji*everywhere,
#             粋*kanji*chic,
#             崖*kanji*cliff,
#             硝*kanji*nitrate,
#             盾*kanji*shield,
#             詳*kanji*detailed,
#             誉*kanji*reputation,
#             炉*kanji*hearth,
#             没*kanji*drown,
#             潔*kanji*undefiled,
#             峰*kanji*summit,
#             芳*kanji*perfume,
#             洞*kanji*den,
#             掃*kanji*sweep,
#             昇*kanji*rise up,
#             None,
#             縛*kanji*truss,
#             喉*kanji*throat,
#             税*kanji*tax,
#             刊*kanji*publish,
#             珠*kanji*pearl,
#             冠*kanji*crown,
#             滝*kanji*waterfall,
#             預*kanji*deposit,
#             幅*kanji*breadth,
#             企*kanji*plan,
#             銅*kanji*copper,
#             縄*kanji*straw rope,
#             瓶*kanji*flower pot,
#             陳*kanji*exhibit,
#             脈*kanji*vein,
#             呪*kanji*curse,
#             覆*kanji*capsize,
#             窟*kanji*cavern,
#             宵*kanji*wee hours,
#             抽*kanji*pluck,
#             署*kanji*government office,
#             献*kanji*offering,
#             脇*kanji*aside,
#             墨*kanji*black ink,
#             紛*kanji*distract,
#             渉*kanji*ford,
#             緊*kanji*tense,
#             筒*kanji*cylinder,
#             None,
#             畜*kanji*livestock,
#             翼*kanji*wing,
#             煩*kanji*anxiety,
#             沿*kanji*run alongside,
#             控*kanji*withdraw,
#             泰*kanji*peaceful,
#             盲*kanji*blind,
#             蔑*kanji*ignore,
#             征*kanji*subjugate,
#             域*kanji*range,
#             餅*kanji*mochi rice cake,
#             漂*kanji*drift,
#             施*kanji*carry out,
#             None,
#             亀*kanji*turtle,
#             串*kanji*skewer,
#             患*kanji*afflicted,
#             伺*kanji*pay respects,
#             賃*kanji*fare,
#             艶*kanji*glossy,
#             None,
#             冗*kanji*superfluous,
#             忌*kanji*mourning,
#             箇*kanji*counters for things,
#             傘*kanji*umbrella,
#             扇*kanji*fan,
#             還*kanji*send back,
#             蹴*kanji*kick,
#             翻*kanji*flip,
#             None,
#             索*kanji*cord,
#             琴*kanji*harp,
#             跳*kanji*hop,
#             飼*kanji*domesticate,
#             辱*kanji*embarrass,
#             艇*kanji*rowboat,
#             痩*kanji*get thin,
#             浄*kanji*clean,
#             芽*kanji*bud,
#             騎*kanji*equestrian,
#             峠*kanji*mountain peak,
#             欧*kanji*Europe,
#             罰*kanji*penalty,
#             魅*kanji*fascination,
#             醒*kanji*be disillusioned,
#             促*kanji*stimulate,
#             頓*kanji*suddenly,
#             沖*kanji*open sea,
#             幹*kanji*tree-trunk,
#             履*kanji*footgear,
#             圏*kanji*sphere,
#             蒸*kanji*steam,
#             慶*kanji*jubilation,
#             妖*kanji*bewitching,
#             鍵*kanji*key,
#             汁*kanji*soup,
#             盆*kanji*basin,
#             霜*kanji*frost,
#             距*kanji*long-distance,
#             譲*kanji*defer,
#             渋*kanji*astringent,
#             鑑*kanji*specimen,
#             泳*kanji*swim,
#             齢*kanji*age,
#             穂*kanji*ear,
#             怨*kanji*grudge,
#             括*kanji*fasten,
#             None,
#             塀*kanji*fence,
#             獲*kanji*seize,
#             None,
#             絡*kanji*entwine,
#             汰*kanji*luxury,
#             痴*kanji*stupid,
#             None,
#             賛*kanji*approve,
#             蜂*kanji*bee,
#             None,
#             頻*kanji*repeatedly,
#             None,
#             籍*kanji*enroll,
#             None,
#             倫*kanji*ethics,
#             穏*kanji*calm,
#             肯*kanji*agreement,
#             贈*kanji*presents,
#             牲*kanji*animal sacrifice,
#             嘲*kanji*ridicule,
#             疾*kanji*rapidly,
#             誓*kanji*vow,
#             航*kanji*cruise,
#             盟*kanji*alliance,
#             None,
#             慌*kanji*disconcerted,
#             漠*kanji*vague,
#             啓*kanji*disclose,
#             頑*kanji*stubborn,
#             膚*kanji*skin,
#             怠*kanji*neglect,
#             None,
#             鈍*kanji*dull,
#             摘*kanji*pinch,
#             柿*kanji*persimmon,
#             詮*kanji*discussion,
#             契*kanji*pledge,
#             喫*kanji*consume,
#             咽*kanji*throat,
#             蚊*kanji*mosquito,
#             邦*kanji*home country,
#             鎖*kanji*chain,
#             粒*kanji*grains,
#             None,
#             均*kanji*level,
#             胴*kanji*trunk,
#             罵*kanji*insult,
#             鍋*kanji*pot,
#             雅*kanji*gracious,
#             憲*kanji*constitution,
#             喚*kanji*yell,
#             鎮*kanji*tranquilize,
#             楼*kanji*watchtower,
#             肝*kanji*liver,
#             欄*kanji*column,
#             浸*kanji*immersed,
#             噴*kanji*erupt,
#             漫*kanji*cartoon,
#             徐*kanji*gradually,
#             挿*kanji*insert,
#             詣*kanji*visit a temple,
#             None,
#             None,
#             悠*kanji*permanence,
#             捉*kanji*capture,
#             股*kanji*crotch,
#             None,
#             璃*kanji*glassy,
#             None,
#             傑*kanji*greatness,
#             耐*kanji*resistant,
#             宴*kanji*banquet,
#             診*kanji*checkup,
#             朗*kanji*melodious,
#             剛*kanji*sturdy,
#             陶*kanji*pottery,
#             卵*kanji*egg,
#             幣*kanji*cash,
#             吟*kanji*versify,
#             狩*kanji*hunt,
#             謙*kanji*self-effacing,
#             励*kanji*encourage,
#             犠*kanji*sacrifice,
#             宰*kanji*superintend,
#             None,
#             礎*kanji*cornerstone,
#             渦*kanji*whirlpool,
#             潰*kanji*crush,
#             耕*kanji*till,
#             療*kanji*heal,
#             弄*kanji*tamper with,
#             崇*kanji*adore,
#             囚*kanji*captured,
#             銘*kanji*inscription,
#             旋*kanji*rotation,
#             豚*kanji*pork,
#             禅*kanji*Zen,
#             None,
#             瞳*kanji*pupil,
#             粧*kanji*cosmetics,
#             掲*kanji*put up (a notice),
#             錯*kanji*confused,
#             晶*kanji*sparkle,
#             拳*kanji*fist,
#             慕*kanji*pining,
#             架*kanji*rack,
#             諦*kanji*abandon,
#             潤*kanji*wet,
#             堤*kanji*dike,
#             砕*kanji*smash,
#             刈*kanji*reap,
#             塞*kanji*obstruct,
#             岐*kanji*branch off,
#             None,
#             援*kanji*aid,
#             殖*kanji*augment,
#             None,
#             欺*kanji*deceit,
#             排*kanji*repudiate,
#             暦*kanji*calendar,
#             脅*kanji*threaten,
#             痕*kanji*mark,
#             叙*kanji*confer,
#             酌*kanji*bartending,
#             慄*kanji*fear,
#             猟*kanji*game-hunting,
#             臆*kanji*timidity,
#             瑠*kanji*lapis lazuli,
#             滴*kanji*drip,
#             但*kanji*however,
#             None,
#             塊*kanji*clod,
#             妨*kanji*disturb,
#             顎*kanji*jaw,
#             謡*kanji*noh chanting,
#             嵐*kanji*storm,
#             溝*kanji*gutter,
#             None,
#             慎*kanji*humility,
#             疎*kanji*alienate,
#             貢*kanji*tribute,
#             撲*kanji*slap,
#             絞*kanji*strangle,
#             嫉*kanji*envy,
#             凍*kanji*frozen,
#             輸*kanji*transport,
#             析*kanji*chop,
#             株*kanji*stocks,
#             秩*kanji*regularity,
#             愁*kanji*distress,
#             妬*kanji*jealousy,
#             郵*kanji*mail,
#             葛*kanji*arrowroot,
#             蓄*kanji*amass,
#             侮*kanji*scorn,
#             液*kanji*fluid,
#             畏*kanji*fear,
#             None,
#             鉛*kanji*lead,
#             慨*kanji*rue,
#             詠*kanji*recitation,
#             僚*kanji*colleague,
#             拒*kanji*repel,
#             藻*kanji*seaweed,
#             稚*kanji*immature,
#             緩*kanji*slacken,
#             庸*kanji*commonplace,
#             錦*kanji*brocade,
#             携*kanji*portable,
#             弦*kanji*bowstring,
#             癒*kanji*healing,
#             滞*kanji*stagnate,
#             穀*kanji*cereals,
#             暁*kanji*daybreak,
#             況*kanji*condition,
#             None,
#             伐*kanji*fell,
#             擦*kanji*grate,
#             芋*kanji*potato,
#             恭*kanji*respect,
#             庁*kanji*government office,
#             懇*kanji*sociable,
#             績*kanji*exploits,
#             泡*kanji*bubbles,
#             None,
#             堕*kanji*degenerate,
#             把*kanji*grasp,
#             瞭*kanji*clear,
#             撮*kanji*snapshot,
#             箸*kanji*chopsticks,
#             湿*kanji*damp,
#             賭*kanji*gamble,
#             謎*kanji*riddle,
#             稼*kanji*earnings,
#             偏*kanji*partial,
#             釜*kanji*kettle,
#             None,
#             奔*kanji*bustle,
#             侵*kanji*encroach,
#             蔽*kanji*cover,
#             鍛*kanji*forge,
#             桑*kanji*mulberry,
#             狙*kanji*aim at,
#             融*kanji*dissolve,
#             脂*kanji*fat,
#             餌*kanji*bait,
#             苛*kanji*torment,
#             逐*kanji*pursue,
#             刹*kanji*temple,
#             麓*kanji*foot of a mountain,
#             径*kanji*diameter,
#             騰*kanji*inflation,
#             薫*kanji*fragrant,
#             溶*kanji*melt,
#             藍*kanji*indigo,
#             羨*kanji*envy,
#             削*kanji*plane,
#             酸*kanji*acid,
#             庶*kanji*commoner,
#             遮*kanji*intercept,
#             None,
#             紺*kanji*dark blue,
#             嗅*kanji*smell,
#             蛮*kanji*barbarian,
#             漬*kanji*pickling,
#             糧*kanji*provisions,
#             郊*kanji*outskirts,
#             糖*kanji*sugar,
#             粛*kanji*solemn,
#             遭*kanji*encounter,
#             None,
#             棟*kanji*ridgepole,
#             昧*kanji*foolish,
#             塾*kanji*cram school,
#             硬*kanji*stiff,
#             坪*kanji*two-mat area,
#             貼*kanji*paste,
#             朴*kanji*crude,
#             蜜*kanji*honey,
#             侶*kanji*companion,
#             飢*kanji*hungry,
#             貯*kanji*savings,
#             弧*kanji*arc,
#             餓*kanji*starve,
#             択*kanji*choose,
#             碑*kanji*tombstone,
#             渓*kanji*mountain stream,
#             后*kanji*empress,
#             妄*kanji*delusion,
#             俵*kanji*bag,
#             喪*kanji*miss,
#             虐*kanji*tyrannize,
#             褒*kanji*praise,
#             託*kanji*consign,
#             伎*kanji*deed,
#             None,
#             殻*kanji*husk,
#             廉*kanji*bargain,
#             副*kanji*vice,
#             克*kanji*overcome,
#             戚*kanji*grieve,
#             項*kanji*paragraph,
#             None,
#             薪*kanji*fuel,
#             腸*kanji*intestines,
#             棺*kanji*coffin,
#             炊*kanji*cook,
#             爽*kanji*refreshing,
#             禍*kanji*calamity,
#             漏*kanji*leak,
#             None,
#             肺*kanji*lungs,
#             唾*kanji*saliva,
#             碁*kanji*Go,
#             湾*kanji*gulf,
#             玩*kanji*trifle with,
#             沸*kanji*seethe,
#             陵*kanji*mausoleum,
#             憾*kanji*remorse,
#             韻*kanji*rhyme,
#             擁*kanji*embrace,
#             雰*kanji*atmosphere,
#             婿*kanji*bridegroom,
#             賜*kanji*grant,
#             媒*kanji*mediator,
#             扶*kanji*aid,
#             鉱*kanji*mineral,
#             坑*kanji*pit,
#             斑*kanji*blemish,
#             諾*kanji*consent,
#             践*kanji*tread,
#             隷*kanji*slave,
#             淫*kanji*lewdness,
#             None,
#             None,
#             謹*kanji*discreet,
#             赦*kanji*pardon,
#             誕*kanji*nativity,
#             篤*kanji*fervent,
#             佳*kanji*excellent,
#             None,
#             挟*kanji*pinch,
#             None,
#             喝*kanji*hoarse,
#             渇*kanji*thirst,
#             髄*kanji*marrow,
#             溺*kanji*drown,
# ...
#             零*kanji*zero,
#             貪*kanji*covet,
#             弊*kanji*abuse,
#             諭*kanji*rebuke,
#             脊*kanji*stature,
#             衡*kanji*equilibrium,
#             酬*kanji*repay,
#             遷*kanji*transition,
#             朽*kanji*decay,
#             冶*kanji*melting,
#             諧*kanji*harmony,
#             柵*kanji*fence,
#             軸*kanji*axis,
#             None,
#             None,
#             羞*kanji*feel ashamed,
#             None,
#             班*kanji*squad,
#             拓*kanji*clear (the land),
#             桟*kanji*scaffold,
#             洪*kanji*deluge,
#             捻*kanji*twist,
#             冥*kanji*dark,
#             濯*kanji*laundry,
#             懲*kanji*penal,
#             胎*kanji*womb,
#             摂*kanji*vicarious,
#             None,
#             郭*kanji*enclosure,
#             譜*kanji*musical score,
#             虹*kanji*rainbow,
#             軟*kanji*soft,
#             措*kanji*set aside,
#             訂*kanji*revise,
#             憧*kanji*desire,
#             核*kanji*nucleus,
#             披*kanji*expose,
#             墜*kanji*crash,
#             殴*kanji*assault,
#             None,
#             倣*kanji*emulate,
#             億*kanji*hundred million,
#             磁*kanji*magnet,
#             椎*kanji*oak,
#             症*kanji*symptoms,
#             挑*kanji*challenge,
#             鯨*kanji*whale,
#             剖*kanji*divide,
#             遜*kanji*humble,
#             凹*kanji*concave,
#             雌*kanji*feminine,
#             萎*kanji*wither,
#             募*kanji*recruit,
#             棋*kanji*chess piece,
#             娯*kanji*recreation,
#             寮*kanji*dormitory,
#             傲*kanji*be proud,
#             勅*kanji*imperial order,
#             妃*kanji*queen,
#             妥*kanji*gentle,
#             迅*kanji*swift,
#             茎*kanji*stalk,
#             煎*kanji*broil,
#             擬*kanji*mimic,
#             峡*kanji*gorge,
#             韓*kanji*Korea,
#             繕*kanji*darning,
#             寡*kanji*widow,
#             嚇*kanji*menacing,
#             濫*kanji*excessive,
#             腫*kanji*tumor,
#             None,
#             漆*kanji*lacquer,
#             陛*kanji*highness,
#             罷*kanji*quit,
#             抄*kanji*extract,
#             燥*kanji*parch,
#             剤*kanji*dose,
#             租*kanji*tariff,
#             簿*kanji*register,
#             None,
#             惰*kanji*lazy,
#             購*kanji*subscription,
#             券*kanji*ticket,
#             繊*kanji*slender,
#             閲*kanji*review,
#             奨*kanji*exhort,
#             粘*kanji*sticky,
#             勃*kanji*rise,
#             累*kanji*accumulate,
#             栽*kanji*plantation,
#             岬*kanji*headland,
#             梗*kanji*close up,
#             駐*kanji*stop-over,
#             貿*kanji*trade,
#             毀*kanji*destroy,
#             窃*kanji*stealth,
#             賦*kanji*levy,
#             潟*kanji*lagoon,
#             債*kanji*bond,
#             曖*kanji*not clear,
#             虜*kanji*captive,
#             穫*kanji*harvest,
#             喩*kanji*metaphor,
#             肢*kanji*limb,
#             搾*kanji*squeeze,
#             匿*kanji*hide,
#             None,
#             肘*kanji*elbow,
#             軌*kanji*rut,
#             厘*kanji*thousandth,
#             膜*kanji*membrane,
#             褐*kanji*brown,
#             槽*kanji*vat,
#             祥*kanji*auspicious,
#             腎*kanji*kidney,
#             淑*kanji*graceful,
#             販*kanji*marketing,
#             None,
#             勲*kanji*meritorious deed,
#             堆*kanji*piled high,
#             睦*kanji*harmonious,
#             抹*kanji*rub,
#             枠*kanji*frame,
#             舗*kanji*pavement,
#             剰*kanji*surplus,
#             詐*kanji*lie,
#             None,
#             None,
#             錬*kanji*tempering,
#             薦*kanji*recommend,
#             閥*kanji*clique,
#             培*kanji*cultivate,
#             憩*kanji*recess,
#             None,
#             逝*kanji*departed,
#             勾*kanji*capture,
#             墳*kanji*tomb,
#             菌*kanji*germ,
#             鋼*kanji*steel,
#             挫*kanji*sprain,
#             鋳*kanji*casting,
#             覇*kanji*hegemony,
#             賓*kanji*V.I.P.,
#             滋*kanji*nourishing,
#             凸*kanji*convex,
#             茨*kanji*thorn,
#             None,
#             唆*kanji*tempt,
#             殉*kanji*martyrdom,
#             阻*kanji*thwart,
#             桁*kanji*beam,
#             訟*kanji*sue,
#             None,
#             搬*kanji*conveyor,
#             嗣*kanji*heir,
#             旺*kanji*flourishing,
#             妊*kanji*pregnancy,
#             娠*kanji*with child,
#             酢*kanji*vinegar,
#             None,
#             綻*kanji*rip,
#             帥*kanji*commander,
#             舶*kanji*liner,
#             None,
#             尿*kanji*urine,
#             賄*kanji*bribe,
#             汎*kanji*pan-,
#             栓*kanji*plug,
#             硫*kanji*sulphur,
#             蛍*kanji*lightning-bug,
#             醸*kanji*brew,
#             肪*kanji*obese,
#             疫*kanji*epidemic,
#             惧*kanji*dread,
#             遡*kanji*go upstream,
#             緯*kanji*horizontal,
#             辣*kanji*bitter,
#             媛*kanji*princess,
#             窒*kanji*plug up,
#             弐*kanji*two (falsification prevention),
#             拷*kanji*torture,
#             嫡*kanji*legitimate wife,
#             礁*kanji*reef,
#             窯*kanji*kiln,
#             虞*kanji*uneasiness,
#             逮*kanji*apprehend,
#             麺*kanji*noodles,
#             該*kanji*above-stated,
#             循*kanji*sequential,
#             壱*kanji*one (falsification prevention),
#             拐*kanji*kidnap,
#             撤*kanji*remove,
#             矯*kanji*rectify,
#             俸*kanji*salary,
#             踪*kanji*remains,
#             紡*kanji*spinning,
#             酎*kanji*sake,
#             糾*kanji*twist,
#             枢*kanji*hinge,
#             阜*kanji*mound,
#             悼*kanji*lament,
#             姻*kanji*matrimony,
#             拉*kanji*crush,
#             耗*kanji*decrease,
#             痢*kanji*diarrhea,
#             塁*kanji*bases,
#             芯*kanji*core,
#             栃*kanji*horse chestnut,
#             丼*kanji*bowl of food,
#             璧*kanji*sphere,
#             捗*kanji*make progress,
#             箋*kanji*paper,
#             彙*kanji*same kind,
#             泌*kanji*ooze,
#             彰*kanji*patent,
#             埼*kanji*cape (geography),
#             嘱*kanji*entrust,
#             畿*kanji*capital,
#             壌*kanji*lot,
#             None,
#             賂*kanji*bribe,
#             轄*kanji*control,
#             逓*kanji*relay,
#             酵*kanji*fermentation,
#             賠*kanji*compensation,
#             准*kanji*quasi-,
#             腺*kanji*gland,
#             搭*kanji*board,
#             哺*kanji*suckle,
#             瘍*kanji*boil (medical),
#             祉*kanji*welfare],
#   'MOrig': [算*kanji*calculate,
#             含*kanji*include,
#             襲*kanji*attack,
#             旗*kanji*national flag,
#             熊*kanji*bear,
#             嫁*kanji*marry into,
#             策*kanji*scheme,
#             圧*kanji*pressure,
#             寧*kanji*rather,
#             専*kanji*specialty,
#             財*kanji*wealth,
#             揺*kanji*swing,
#             鮮*kanji*fresh,
#             防*kanji*prevent,
#             偶*kanji*accidentally,
#             None,
#             築*kanji*fabricate,
#             誘*kanji*entice,
#             希*kanji*hope,
#             垂*kanji*droop,
#             阪*kanji*heights,
#             停*kanji*halt,
#             孫*kanji*grandchild,
#             鉢*kanji*bowl,
#             潮*kanji*tide,
#             操*kanji*maneuver,
#             免*kanji*excuse,
#             None,
#             康*kanji*health,
#             唐*kanji*T'ang,
#             針*kanji*needle,
#             乏*kanji*scarce,
#             略*kanji*abbreviation,
#             枕*kanji*pillow,
#             蛇*kanji*snake,
#             裕*kanji*abundant,
#             紫*kanji*purple,
#             序*kanji*preface,
#             獄*kanji*prison,
#             練*kanji*practice,
#             抵*kanji*resist,
#             遅*kanji*slow,
#             避*kanji*evade,
#             癖*kanji*mannerism,
#             幼*kanji*infancy,
#             澄*kanji*lucidity,
#             駆*kanji*drive,
#             None,
#             扱*kanji*handle,
#             緑*kanji*green,
#             敏*kanji*cleverness,
#             繁*kanji*luxuriant,
#             隆*kanji*hump,
#             巧*kanji*adroit,
#             誠*kanji*sincerity,
#             狭*kanji*cramped,
#             遇*kanji*interview,
#             None,
#             厚*kanji*thick,
#             綱*kanji*hawser,
#             鋭*kanji*pointed,
#             透*kanji*transparent,
#             None,
#             替*kanji*exchange,
#             潜*kanji*submerge,
#             封*kanji*seal,
#             愉*kanji*pleasure,
#             牧*kanji*breed,
#             None,
#             巡*kanji*patrol,
#             票*kanji*ballot,
#             標*kanji*signpost,
#             None,
#             裁*kanji*judge,
#             壇*kanji*podium,
#             靴*kanji*shoes,
#             授*kanji*instruct,
#             典*kanji*code,
#             幽*kanji*seclude,
#             唇*kanji*lips,
#             茂*kanji*overgrown,
#             届*kanji*deliver,
#             戒*kanji*commandment,
#             械*kanji*contraption,
#             奪*kanji*rob,
#             拾*kanji*pick up,
#             属*kanji*belong,
#             挨*kanji*push open,
#             汚*kanji*dirty,
#             拶*kanji*be imminent,
#             帆*kanji*sail,
#             抗*kanji*confront,
#             奈*kanji*what,
#             卒*kanji*graduate,
#             監*kanji*oversee,
#             鈴*kanji*small bell,
#             討*kanji*chastise,
#             None,
#             垣*kanji*hedge,
#             膳*kanji*tray,
#             駒*kanji*horse,
#             卑*kanji*lowly,
#             眉*kanji*eyebrow,
#             閣*kanji*tall,
#             営*kanji*manage,
#             粉*kanji*flour,
#             拭*kanji*wipe,
#             範*kanji*pattern,
#             猿*kanji*monkey,
#             暑*kanji*hot,
#             恵*kanji*favor,
#             祈*kanji*pray,
#             謝*kanji*apologize,
#             浦*kanji*bay,
#             較*kanji*contrast,
#             乾*kanji*dry,
#             奮*kanji*stirred up,
#             管*kanji*pipe,
#             汗*kanji*sweat,
#             祝*kanji*celebrate,
#             札*kanji*tag,
#             匠*kanji*artisan,
#             勉*kanji*exertion,
#             None,
#             湖*kanji*lake,
#             貨*kanji*freight,
#             臭*kanji*stinking,
#             悩*kanji*trouble,
#             偉*kanji*admirable,
#             砲*kanji*cannon,
#             尻*kanji*buttocks,
#             氷*kanji*ice,
#             嘆*kanji*sigh,
#             貞*kanji*upright,
#             孔*kanji*cavity,
#             濁*kanji*voiced,
#             駅*kanji*station,
#             堅*kanji*strict,
#             None,
#             唱*kanji*chant,
#             塔*kanji*pagoda,
#             None,
#             曹*kanji*cadet,
#             率*kanji*rate,
#             涯*kanji*horizon,
#             None,
#             灰*kanji*ashes,
#             棄*kanji*abandon,
#             貸*kanji*lend,
#             None,
#             枯*kanji*wither,
#             徴*kanji*indications,
#             招*kanji*beckon,
#             暇*kanji*spare time,
#             邸*kanji*residence,
#             柔*kanji*tender,
#             宣*kanji*proclaim,
#             俊*kanji*genius,
#             賞*kanji*prize,
#             霧*kanji*fog,
#             週*kanji*week,
#             禁*kanji*prohibition,
#             豪*kanji*overpowering,
#             None,
#             棚*kanji*shelf,
#             塩*kanji*salt,
#             漸*kanji*steadily,
#             郡*kanji*county,
#             躍*kanji*leap,
#             整*kanji*put in order,
#             紋*kanji*family crest,
#             塗*kanji*paint,
#             恩*kanji*grace,
#             稽*kanji*consider,
#             縦*kanji*vertical,
#             翁*kanji*venerable old man,
#             匂*kanji*scent,
#             効*kanji*effect,
#             凝*kanji*congeal,
#             崩*kanji*crumble,
#             縮*kanji*shrink,
#             掘*kanji*dig,
#             衝*kanji*collide,
#             唄*kanji*song,
#             桜*kanji*cherry tree,
#             麦*kanji*wheat,
#             None,
#             斥*kanji*reject,
#             訴*kanji*sue,
#             損*kanji*loss,
#             裂*kanji*split,
#             滑*kanji*slippery,
#             沙*kanji*sand,
#             淡*kanji*thin,
#             徹*kanji*penetrate,
#             None,
#             幻*kanji*phantasm,
#             堀*kanji*ditch,
#             誇*kanji*boast,
#             悔*kanji*repent,
#             藩*kanji*clan,
#             笛*kanji*flute,
#             享*kanji*receive,
#             熟*kanji*ripen,
#             締*kanji*tighten,
#             暖*kanji*warmth,
#             葬*kanji*interment,
#             稿*kanji*draft,
#             偵*kanji*spy,
#             None,
#             孤*kanji*orphan,
#             None,
#             逸*kanji*deviate,
#             骸*kanji*dead remains,
#             爵*kanji*baron,
#             None,
#             課*kanji*section,
#             県*kanji*prefecture,
#             尉*kanji*military officer,
#             慰*kanji*consolation,
#             巨*kanji*gigantic,
#             仁*kanji*humanity,
#             憤*kanji*aroused,
#             攻*kanji*aggression,
#             超*kanji*transcend,
#             忙*kanji*busy,
#             裸*kanji*naked,
#             須*kanji*by all means,
#             鼓*kanji*drum,
#             None,
#             猛*kanji*fierce,
#             荘*kanji*villa,
#             恨*kanji*rancor,
#             惨*kanji*wretched,
#             寛*kanji*tolerant,
#             None,
#             僅*kanji*a wee bit,
#             稲*kanji*rice plant,
#             凄*kanji*uncanny,
#             雇*kanji*employ,
#             顧*kanji*look back,
#             肥*kanji*fertilizer,
#             閑*kanji*leisure,
#             腐*kanji*rot,
#             倍*kanji*double,
#             季*kanji*seasons,
#             艦*kanji*warship,
#             岳*kanji*point,
#             采*kanji*form,
#             菜*kanji*vegetable,
#             寿*kanji*longevity,
#             焦*kanji*char,
#             拘*kanji*arrest,
#             None,
#             脳*kanji*brain,
#             協*kanji*cooperation,
#             壊*kanji*demolition,
#             沼*kanji*marsh,
#             慈*kanji*mercy,
#             拙*kanji*bungling,
#             宙*kanji*mid-air,
#             煮*kanji*boil,
#             肌*kanji*texture,
#             符*kanji*token,
#             賢*kanji*intelligent,
#             据*kanji*set,
#             斜*kanji*diagonal,
#             None,
#             拡*kanji*broaden,
#             請*kanji*solicit,
#             鶏*kanji*chicken,
#             賊*kanji*burglar,
#             彩*kanji*coloring,
#             虎*kanji*tiger,
#             需*kanji*demand,
#             None,
#             悦*kanji*ecstasy,
#             酷*kanji*cruel,
#             窮*kanji*hard up,
#             紹*kanji*introduce,
#             獣*kanji*animal,
#             爆*kanji*explode,
#             測*kanji*fathom,
#             督*kanji*coach,
#             抑*kanji*repress,
#             競*kanji*compete,
#             絹*kanji*silk,
#             蓋*kanji*cover,
#             継*kanji*inherit,
#             胆*kanji*gall bladder,
#             採*kanji*pick,
#             曇*kanji*cloudy weather,
#             掌*kanji*manipulate,
#             None,
#             桃*kanji*peach tree,
#             鐘*kanji*bell,
#             審*kanji*examine,
#             彫*kanji*carve,
#             瓦*kanji*tile,
#             捜*kanji*search,
#             隔*kanji*isolate,
#             隙*kanji*fissure,
#             炭*kanji*charcoal,
#             醜*kanji*ugly,
#             湧*kanji*boil,
#             猶*kanji*furthermore,
#             偽*kanji*falsehood,
#             巣*kanji*nest,
#             災*kanji*disaster,
#             衰*kanji*decline,
#             複*kanji*duplicate,
#             双*kanji*pair,
#             陥*kanji*collapse,
#             None,
#             港*kanji*harbor,
#             劣*kanji*inferiority,
#             歓*kanji*delight,
#             廃*kanji*abolish,
#             None,
#             臨*kanji*look to,
#             漁*kanji*fishing,
#             奏*kanji*play music,
#             補*kanji*supplement,
#             睡*kanji*drowsy,
#             揮*kanji*brandish,
#             侯*kanji*marquis,
#             塚*kanji*hillock,
#             網*kanji*netting,
#             某*kanji*so-and-so,
#             磨*kanji*grind,
#             雷*kanji*thunder,
#             缶*kanji*tin can]},
#  {'MDest': [], 'MOrig': []},
#  {'MDest': [], 'MOrig': []},
#  {'MDest': [], 'MOrig': []},
#  {'MDest': [], 'MOrig': []},
#  {'MDest': [], 'MOrig': []}]

# %% [markdown]
# ## Brute Force Algorithm

# %%
def find_path_bf(MOrig: List[KanjigenNode], MDest: List[KanjigenNode]) -> nx.Graph:
    
    result = []
    
    for kin in MOrig:
        for kout in MDest:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
MOrig = tc_kanji_clean[1]['MOrig']
MDest = tc_kanji_clean[1]['MDest']

# %%
MOrig = [k for k in MOrig if k is not None]
MDest = [k for k in MDest if k is not None]

# %%
print(MOrig, MDest)
# Out:
# [人*kanji*person, 一*kanji*one, 口*kanji*mouth, 日*kanji*day, 目*kanji*eye, 見*kanji*see, 山*kanji*mountain, 出*kanji*exit, 十*kanji*ten, 八*kanji*eight, 木*kanji*tree, 未*kanji*not yet, 来*kanji*come, 大*kanji*large, 了*kanji*finish, 子*kanji*child, 心*kanji*heart, 土*kanji*soil, 田*kanji*rice paddy, 思*kanji*think] [二*kanji*two, 丁*kanji*ward, 行*kanji*go, 寸*kanji*measurement, 寺*kanji*Buddhist temple, 時*kanji*time, 上*kanji*up, 刀*kanji*sword, 分*kanji*part, minute of time, 私*kanji*me, 中*kanji*middle, 事*kanji*abstract thing, 可*kanji*possible, 何*kanji*what, 自*kanji*oneself, 又*kanji*or again, 皮*kanji*skin, 彼*kanji*he, 方*kanji*direction, 生*kanji*life, 月*kanji*month, moon, 門*kanji*gates, 間*kanji*interval, 手*kanji*hand, 言*kanji*say, 女*kanji*woman, 本*kanji*book]

# %%
[(k.symbol, k in G.nodes(), k in isolated_nodes, k in kanjigen_nodes) for k in MOrig]
# Out:
# [('人', False, False, True),
#  ('一', False, False, True),
#  ('口', True, True, True),
#  ('日', False, False, True),
#  ('目', False, False, True),
#  ('見', True, True, True),
#  ('山', False, False, True),
#  ('出', True, True, True),
#  ('十', False, False, True),
#  ('八', False, False, True),
#  ('木', False, False, True),
#  ('未', True, True, True),
#  ('来', True, True, True),
#  ('大', False, False, True),
#  ('了', True, True, True),
#  ('子', False, False, True),
#  ('心', False, False, True),
#  ('土', False, False, True),
#  ('田', False, False, True),
#  ('思', True, True, True)]

# %%
result = find_path_bf(MOrig, MDest)
result.nodes()

# %%
visualize_graph(Graph=result, color_map=get_node_color_result(MO_raw, MD_raw, result))

# %% [markdown]
# ## All-at-Once

# %%
def find_path_bf(MO: List[KanjigenNode], MD: List[KanjigenNode]) -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %% [markdown]
# ## Heuristic Algorithm

# %%
def find_path_heuristic(MO: List[KanjigenNode], MD: List[KanjigenNode], dist_func: 'function(o,d)') -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.astar_path(G, source=kin, target=kout, heuristic=dist_func)
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
centrality_degree = nx.degree_centrality(G)

# %%
def dist_func(orig: KanjigenNode, dest: KanjigenNode) -> float:
    a = centrality_degree[orig]
    b = centrality_degree[dest]
    return (abs(a-b)) ** 0.5

# %%
result = find_path_heuristic(MO, MD, dist_func)
result.nodes()

# %% [markdown]
# ## Evaluation

# %%
# https://networkx.org/documentation/stable/reference/algorithms/similarity.html

# %%
# https://networkx.org/documentation/stable/reference/algorithms/centrality.html
