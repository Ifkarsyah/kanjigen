# %%
from pprint import pprint as pp
from typing import Dict, List, Tuple

import random
import csv

# %% [markdown]
# # Building Knowledge Graph

# %% [markdown]
# ## Extract Data from CSV

# %%
def get_csv_data(filepath, handle_row_func):
    data = dict()
    with open(filepath) as file:
        next(file)
        rows = csv.reader(file, delimiter=",")
        for row in rows:
            handle_row_func(data, row)
    return data

# %%
def handle_csv_kanji_func(data, row):
    kanji,*meanings = row
    if len(meanings) >= 2:
        meanings = ",".join(meanings)
    else:
        meanings = meanings[0]
    meanings = meanings.split(":")
    meanings = meanings[0]
    data[kanji] = meanings

# %%
data_kanji = get_csv_data("dataset/s5_kanjis_output.csv", handle_csv_kanji_func)
print("len(data_kanji) = ", len(data_kanji))
pp(data_kanji)
# Out:
# len(data_kanji) =  6215
# {'丁': 'street',
#  '七': 'seven',
#  '万': 'ten thousand',
#  '丈': 'length',
#  '三': 'three',
#  '上': 'above',
#  '下': 'below',
#  '不': 'negative',
#  '与': 'bestow',
#  '丐': 'beggar',
#  '丑': 'sign of the ox or cow',
#  '且': 'moreover',
#  '丕': 'large',
#  '世': 'generation',
#  '丗': 'thirty',
#  '丘': 'hill',
#  '丙': 'third class',
#  '丞': 'help',
#  '両': 'both',
#  '並': 'row',
#  '个': 'counter for articles',
#  '中': 'in',
#  '丱': 'saguaro-like kanji',
#  '串': 'spit',
#  '丸': 'round',
#  '丹': 'rust-colored',
#  '主': 'lord',
#  '丼': 'bowl',
#  '乂': 'mow',
#  '乃': 'from',
#  '久': 'long time',
#  '之': 'of',
#  '乍': 'though',
#  '乎': 'question mark',
#  '乏': 'destitution',
#  '乕': 'tiger',
#  '乖': 'oppose',
#  '乗': 'ride',
#  '乘': 'power',
#  '乞': 'beg',
#  '也': 'to be (classical)',
#  '乢': 'mountain saddle',
#  '乱': 'riot',
#  '乳': 'milk',
#  '乾': 'drought',
#  '亀': 'tortoise',
#  '亂': 'war',
#  '了': 'complete',
#  '予': 'beforehand',
#  '争': 'contend',
#  '亊': 'affair',
#  '事': 'matter',
#  '于': 'going',
#  '云': 'say',
#  '互': 'mutually',
#  '五': 'five',
#  '井': 'well',
#  '亘': 'span',
#  '亙': 'range',
#  '些': 'a little bit',
#  '亜': 'Asia',
#  '亞': 'rank',
#  '亟': 'fast',
#  '亡': 'deceased',
#  '亢': 'high spirits',
#  '交': 'mingle',
#  '亥': 'sign of the hog',
#  '亦': 'also',
#  '亨': 'pass through',
#  '享': 'enjoy',
#  '京': 'capital',
#  '亭': 'pavilion',
#  '亮': 'clear',
#  '亰': 'capital city',
#  '亳': 'an ancient Chinese capital',
#  '亶': 'truly',
#  '什': 'utensil',
#  '仁': 'humanity',
#  '仂': 'surplus or excess',
#  '仄': 'be seen dimly',
#  '仆': 'fall',
#  '仇': 'foe',
#  '今': 'now',
#  '介': 'jammed in',
#  '仍': 'therefore',
#  '从': 'two people',
#  '仏': 'Buddha',
#  '仔': 'offspring (animal)',
#  '仕': 'attend',
#  '他': 'other',
#  '仗': 'cane',
#  '付': 'adhere',
#  '仙': 'hermit',
#  '仞': 'fathom',
#  '仟': 'thousand',
#  '代': 'substitute',
#  '令': 'orders',
#  '以': 'by means of',
#  '仭': 'fathom',
#  '仮': 'sham',
#  '仰': 'face-up',
#  '仲': 'go-between',
#  '件': 'affair',
#  '价': 'man with shellfish kanji',
#  '任': 'responsibility',
#  '企': 'undertake',
#  '伉': 'same kind',
#  '伊': 'Italy',
#  '伍': 'five',
#  '伎': 'deed',
#  '伏': 'prostrated',
#  '伐': 'fell',
#  '休': 'rest',
#  '会': 'meeting',
#  '伜': 'son',
#  '伝': 'transmit',
#  '伯': 'chief',
#  '估': 'price',
#  '伴': 'consort',
#  '伶': 'actor',
#  '伸': 'expand',
#  '伺': 'pay respects',
#  '似': 'becoming',
#  '伽': 'nursing',
#  '佃': 'cultivated rice field',
#  '但': 'however',
#  '佇': 'stop',
#  '位': 'rank',
#  '低': 'lower',
#  '住': 'dwell',
#  '佐': 'assistant',
#  '佑': 'help',
#  '体': 'body',
#  '何': 'what',
#  '佗': 'proud',
#  '余': 'too much',
#  '佚': 'lost',
#  '佛': 'France',
#  '作': 'make',
#  '佝': 'foolish',
#  '佞': 'flattery',
#  '佩': 'wear',
#  '佯': 'pretend',
#  '佰': 'hundred',
#  '佳': 'excellent',
#  '併': 'join',
#  '佶': 'healthy',
#  '佻': 'frivolity',
#  '佼': 'beautiful',
#  '使': 'use',
#  '侃': 'strong',
#  '來': 'come',
#  '侈': 'luxury',
#  '例': 'example',
#  '侍': 'waiter',
#  '侏': 'actor',
#  '侑': 'urge to eat',
#  '侖': 'think',
#  '侘': 'proud',
#  '供': 'submit',
#  '依': 'reliant',
#  '侠': 'tomboy',
#  '価': 'value',
#  '侫': 'flattery',
#  '侭': 'as it is',
#  '侮': 'scorn',
#  '侯': 'marquis',
#  '侵': 'encroach',
#  '侶': 'companion',
#  '便': 'convenience',
#  '係': 'person in charge',
#  '促': 'stimulate',
#  '俄': 'sudden',
#  '俊': 'sagacious',
#  '俎': 'altar of sacrifice',
#  '俐': 'clever',
#  '俑': 'effigy',
#  '俔': 'compare',
#  '俗': 'vulgar',
#  '俘': 'captive',
#  '俚': 'rustic',
#  '俛': 'look down',
#  '保': 'protect',
#  '俟': 'wait',
#  '信': 'faith',
#  '俣': 'crotch',
#  '俤': '(kokuji)',
#  '俥': 'jinricksha',
#  '修': 'discipline',
#  '俯': 'bend down',
#  '俳': 'haiku',
#  '俵': 'bag',
#  '俶': 'beginning',
#  '俸': 'stipend',
#  '俺': 'I',
#  '俾': 'tutor',
#  '倅': 'son',
#  '倆': 'skill',
#  '倉': 'godown',
#  '個': 'individual',
#  '倍': 'double',
#  '倏': 'quick',
#  '們': 'plural suffix',
#  '倒': 'overthrow',
#  '倔': 'stubborn',
#  '倖': 'happiness',
#  '候': 'climate',
#  '倚': 'lean on',
#  '借': 'borrow',
#  '倡': 'prostitute',
#  '倣': 'emulate',
#  '値': 'price',
#  '倥': 'boorish',
#  '倦': 'lose interest in',
#  '倨': 'pride',
#  '倩': 'carefully',
#  '倪': 'stare',
#  '倫': 'ethics',
#  '倬': 'large',
#  '倭': 'Yamato',
#  '倶': 'both',
#  '倹': 'frugal',
#  '偃': 'dam',
#  '假': 'temporary',
#  '偈': 'verse in praise of Buddha',
#  '偉': 'admirable',
#  '偏': 'partial',
#  '偐': 'fake',
#  '偕': 'together',
#  '偖': 'well',
#  '做': 'make',
#  '停': 'halt',
#  '健': 'healthy',
#  '偬': 'feel pain',
#  '偲': 'recollect',
#  '側': 'side',
#  '偵': 'spy',
#  '偶': 'accidentally',
#  '偸': 'steal',
#  '偽': 'falsehood',
#  '傀': 'large',
#  '傅': 'tutor',
#  '傍': 'bystander',
#  '傑': 'greatness',
#  '傘': 'umbrella',
#  '備': 'equip',
#  '傚': 'imitate',
#  '催': 'sponsor',
#  '傭': 'employ',
#  '傲': 'be proud',
#  '傳': 'summon',
#  '傴': 'bend over',
#  '債': 'bond',
#  '傷': 'wound',
#  '傾': 'lean',
#  '僂': 'bend over',
#  '僅': 'a wee bit',
#  '僉': 'all',
#  '僊': 'hermit',
#  '働': 'work',
#  '像': 'statue',
#  '僑': 'temporary home',
#  '僕': 'me',
#  '僖': 'enjoyment',
#  '僚': 'colleague',
#  '僞': 'lie',
#  '僣': 'boastfully usurp',
#  '僥': 'luck',
#  '僧': 'Buddhist priest',
#  '僭': 'boastfully usurp',
#  '僮': 'child',
#  '僵': 'fall down',
#  '價': 'price',
#  '僻': 'prejudice',
#  '儀': 'ceremony',
#  '儁': 'excellence',
#  '儂': 'I',
#  '億': 'hundred million',
#  '儉': 'economy',
#  '儒': 'Confucian',
#  '儔': 'companion',
#  '儕': 'companion',
#  '儖': 'ugly',
#  '儘': 'as it is',
#  '儚': 'fleeting',
#  '償': 'reparation',
#  '儡': 'defeat',
#  '優': 'tenderness',
#  '儲': 'be profitable',
#  '儷': 'companion',
#  '儺': 'exorcism',
#  '儻': 'excel',
#  '儼': 'serious',
#  '兀': 'high & level',
#  '允': 'license',
#  '元': 'beginning',
#  '兄': 'elder brother',
#  '充': 'allot',
#  '兆': 'portent',
#  '兇': 'wickedness',
#  '先': 'before',
#  '光': 'ray',
#  '克': 'overcome',
#  '兌': 'exchange',
#  '免': 'excuse',
#  '兎': 'rabbit',
#  '児': 'newborn babe',
#  '兒': 'child',
#  '兔': 'rabbit',
#  '党': 'party',
#  '兜': 'helmet',
#  '兢': 'discreet',
#  '全': 'whole',
#  '兩': 'old Japanese coin',
#  '兪': 'affirmative response',
#  '公': 'public',
#  '六': 'six',
#  '兮': 'auxiliary word for euphony or emphasis',
#  '共': 'together',
#  '兵': 'soldier',
#  '其': 'that',
#  '具': 'tool',
#  '典': 'code',
#  '兼': 'concurrently',
#  '冀': 'hope for',
#  '内': 'inside',
#  '円': 'circle',
#  '冉': 'red',
#  '冊': 'tome',
#  '册': 'counter for books',
#  '再': 'again',
#  '冏': 'light',
#  '冐': 'risk',
#  '冑': 'helmet',
#  '冒': 'risk',
#  '冓': 'put together',
#  '冕': 'crown',
#  '冗': 'superfluous',
#  '写': 'copy',
#  '冠': 'crown',
#  '冢': 'mound',
#  '冤': 'false charge',
#  '冥': 'dark',
#  '冦': 'foe',
#  '冨': 'enrich',
#  '冩': 'write',
#  '冪': 'power',
#  '冬': 'winter',
#  '冰': 'ice',
#  '冱': 'freeze',
#  '冲': 'offing',
#  '决': 'decide',
#  '冴': 'be clear',
#  '况': 'still more',
#  '冶': 'melting',
#  '冷': 'cool',
#  '冽': 'cold',
#  '凄': 'uncanny',
#  '凅': 'wither',
#  '准': 'quasi-',
#  '凉': 'nice and cool',
#  '凋': 'wither',
#  '凌': 'endure',
#  '凍': 'frozen',
#  '凖': 'correspond to',
#  '凛': 'cold',
#  '凜': 'cold',
#  '凝': 'congeal',
#  '凡': 'commonplace',
#  '処': 'dispose',
#  '凧': 'kite',
#  '凩': 'wintry wind',
#  '凪': 'lull',
#  '凭': 'lean on',
#  '凰': 'female phoenix bird',
#  '凱': 'victory song',
#  '凶': 'villain',
#  '凸': 'convex',
#  '凹': 'concave',
#  '出': 'exit',
#  '函': 'box (archaic)',
#  '凾': 'box',
#  '刃': 'blade',
#  '刄': 'blade',
#  '分': 'part',
#  '切': 'cut',
#  '刈': 'reap',
#  '刊': 'publish',
#  '刋': 'cut',
#  '刎': 'decapitate',
#  '刑': 'punish',
#  '刔': 'scoop out',
#  '列': 'file',
#  '初': 'first time',
#  '判': 'judgement',
#  '別': 'separate',
#  '刧': 'threat',
#  '利': 'profit',
#  '刪': 'cut down',
#  '刮': 'scrape off',
#  '到': 'arrival',
#  '刳': 'clear',
#  '制': 'system',
#  '刷': 'printing',
#  '券': 'ticket',
#  '刹': 'temple',
#  '刺': 'thorn',
#  '刻': 'engrave',
#  '剃': 'shave',
#  '剄': 'beheading',
#  '則': 'rule',
#  '削': 'plane',
#  '剋': 'victory',
#  '剌': 'opposed',
#  '前': 'in front',
#  '剏': 'begin',
#  '剔': 'cutting',
#  '剖': 'divide',
#  '剛': 'sturdy',
#  '剞': 'carve',
#  '剣': 'sabre',
#  '剤': 'dose',
#  '剥': 'come off',
#  '剩': 'leftovers',
#  '剪': 'clip',
#  '副': 'vice-',
#  '剰': 'surplus',
#  '剱': 'sword',
#  '割': 'proportion',
#  '剳': 'sickle',
#  '剴': 'scythe',
#  '創': 'genesis',
#  '剽': 'threat',
#  '剿': 'destroy',
#  '劃': 'divide',
#  '劇': 'drama',
#  '劈': 'break',
#  '劉': 'weapon of war',
#  '劍': 'sword',
#  '劑': 'medicine',
#  '劒': 'sword',
#  '劔': 'sword',
#  '功': 'achievement',
#  '加': 'add',
#  '劣': 'inferiority',
#  '助': 'help',
#  '努': 'toil',
#  '劫': 'threat',
#  '劬': 'become tired',
#  '劭': 'recommend',
#  '励': 'encourage',
#  '労': 'labor',
#  '劵': 'become fatigued',
#  '効': 'merit',
#  '劼': 'be careful',
#  '劾': 'censure',
#  '勁': 'strong',
#  '勃': 'suddenness',
#  '勅': 'imperial order',
#  '勇': 'courage',
#  '勉': 'exertion',
#  '勍': 'strong',
#  '勒': 'halter and bit',
#  '動': 'move',
#  '勗': 'be diligent',
#  '勘': 'intuition',
#  '務': 'task',
#  '勝': 'victory',
#  '勞': 'thank for',
#  '募': 'recruit',
#  '勠': 'combine',
#  '勢': 'forces',
#  '勣': 'merit',
#  '勤': 'diligence',
#  '勦': 'destroy',
#  '勧': 'persuade',
#  '勲': 'meritorious deed',
#  '勳': 'meritorious deed',
#  '勵': 'strive',
#  '勸': 'persuade',
#  '勺': 'ladle',
#  '勾': 'be bent',
#  '勿': 'not',
#  '匁': 'monme',
#  '匂': 'fragrant',
#  '包': 'wrap',
#  '匆': 'rush',
#  '匈': 'turmoil',
#  '匍': 'crawl',
#  '匏': 'gourd',
#  '匐': 'crawl',
#  '化': 'change',
#  '北': 'north',
#  '匙': 'spoon',
#  '匝': 'go around',
#  '匠': 'artisan',
#  '匡': 'correct',
#  '匣': 'box',
#  '匪': 'negation',
#  '匯': 'whirl',
#  '匱': 'chest',
#  '匳': 'cosmetics box',
#  '匹': 'equal',
#  '区': 'ward',
#  '医': 'doctor',
#  '匿': 'hide',
#  '區': 'ward',
#  '千': 'thousand',
#  '卅': 'thirty',
#  '卆': 'soldier',
#  '升': 'measuring box',
#  '午': 'noon',
#  '卉': 'grass',
#  '半': 'half',
#  '卍': 'swastika',
#  '卑': 'lowly',
#  '卒': 'graduate',
#  '卓': 'eminent',
#  '協': 'co-',
#  '南': 'south',
#  '単': 'simple',
#  '博': 'Dr.',
#  '卞': 'law',
#  '占': 'fortune-telling',
#  '卦': 'a divination sign',
#  '卮': 'large goblet',
#  '卯': 'sign of the hare or rabbit',
#  '印': 'stamp',
#  '危': 'dangerous',
#  '即': 'instant',
#  '却': 'instead',
#  '卵': 'egg',
#  '卷': 'volume',
#  '卸': 'wholesale',
#  '卻': 'instead',
#  '卿': 'you',
#  '厄': 'unlucky',
#  '厖': 'large',
#  '厘': 'rin',
#  '厚': 'thick',
#  '原': 'meadow',
#  '厠': 'privy',
#  '厥': 'that',
#  '厦': 'house',
#  '厨': 'kitchen',
#  '厩': 'barn',
#  '厭': 'get tired of',
#  '厮': 'cut',
#  '厰': 'workshop',
#  '厳': 'stern',
#  '去': 'gone',
#  '参': 'nonplussed',
#  '參': 'three',
#  '叉': 'fork in road',
#  '及': 'reach out',
#  '友': 'friend',
#  '双': 'pair',
#  '反': 'anti-',
#  '収': 'income',
#  '叔': 'uncle',
#  '取': 'take',
#  '受': 'accept',
#  '叙': 'confer',
#  '叛': 'disobey',
#  '叟': 'old person',
#  '叡': 'intelligence',
#  '叢': 'plexus',
#  '口': 'mouth',
#  '古': 'old',
#  '句': 'phrase',
#  '叨': 'truly',
#  '叩': 'strike',
#  '只': 'only',
#  '叫': 'shout',
#  '召': 'seduce',
#  '叭': 'open',
#  '叮': 'courtesy',
#  '可': 'can',
#  '台': 'pedestal',
#  '叱': 'scold',
#  '史': 'history',
#  '右': 'right',
#  '叶': 'grant',
#  '号': 'nickname',
#  '司': 'director',
#  '叺': 'straw bag',
#  '吁': 'exclamation',
#  '吃': 'stammer',
#  '各': 'each',
#  '合': 'fit',
#  '吉': 'good luck',
#  '吊': 'suspend',
#  '吋': 'inch',
#  '同': 'same',
#  '名': 'name',
#  '后': 'empress',
#  '吏': 'officer',
#  '吐': 'spit',
#  '向': 'yonder',
#  '君': 'mister',
#  '吝': 'miserly',
#  '吟': 'versify',
#  '吠': 'bark',
#  '否': 'negate',
#  '吩': 'give an order',
#  '含': 'contain',
#  '听': 'open-mouthed laughter',
#  '吭': 'throat',
#  '吮': 'suck',
#  '吶': 'stutter',
#  '吸': 'suck',
#  '吹': 'blow',
#  '吻': 'proboscis',
#  '吼': 'bark',
#  '吽': 'bark',
#  '吾': 'I',
#  '呀': "open one's mouth",
#  '呂': 'spine',
#  '呆': 'be amazed',
#  '呈': 'display',
#  '呉': 'give',
#  '告': 'revelation',
#  '呎': 'foot',
#  '呑': 'drink',
#  '呟': 'mutter',
#  '周': 'circumference',
#  '呪': 'spell',
#  '呰': 'blame',
#  '呱': 'cry',
#  '味': 'flavor',
#  '呵': 'scold',
#  '呶': 'noisy',
#  '呷': 'sip',
#  '呻': 'moan',
#  '呼': 'call',
#  '命': 'fate',
#  '咀': 'bite',
#  '咄': 'exclamation of surprise',
#  '咆': 'bark',
#  '咋': 'shout',
#  '和': 'harmony',
#  '咎': 'blame',
#  '咏': 'recitation',
#  '咐': 'blow',
#  '咒': 'spell',
#  '咢': 'outspokenly',
#  '咤': 'clicking (with tongue)',
#  '咥': 'laugh',
#  '咨': 'investigate',
#  '咫': 'short',
#  '咬': 'bite',
#  '咯': 'quarrel',
#  '咲': 'blossom',
#  '咳': 'cough',
#  '咸': 'all',
#  '咼': 'crooked mouth',
#  '咽': 'throat',
#  '咾': 'voice',
#  '哀': 'pathetic',
#  '品': 'goods',
#  '哂': 'derisive laugh',
#  '哄': 'resound',
#  '哇': "fawning child's voice",
#  '哈': 'school of fish',
#  '哉': 'how',
#  '哘': '(kokuji)',
#  '員': 'employee',
#  '哢': 'chirp',
#  '哥': 'big brother',
#  '哦': 'sing',
#  '哨': 'scout',
#  '哩': 'mile',
#  '哭': 'weep',
#  '哮': 'roar',
#  '哲': 'philosophy',
#  '哺': 'nurse',
#  '哽': 'sob',
#  '唄': 'song',
#  '唆': 'tempt',
#  '唇': 'lips',
#  '唏': 'lament',
#  '唐': "T'ang",
#  '唔': 'reading voice',
#  '唖': 'mute',
#  '售': 'sell',
#  '唯': 'solely',
#  '唱': 'chant',
#  '唳': 'cry',
#  '唸': 'groan',
#  '唹': 'laugh',
#  '唾': 'saliva',
#  '啀': 'wrangle',
#  '啄': 'peck',
#  '啅': 'noisy',
#  '商': 'make a deal',
#  '啌': 'angry voice',
#  '問': 'question',
#  '啓': 'disclose',
#  '啖': 'eat',
#  '啗': 'allure',
#  '啜': 'suck',
#  '啝': 'follow',
#  '啣': 'hold in mouth or between teeth',
#  '啻': 'incomparable',
#  '啼': 'bark',
#  '啾': 'cry',
#  '喀': 'vomit',
#  '喃': 'chatter',
#  '善': 'virtuous',
#  '喇': 'chatter',
#  '喉': 'throat',
#  '喊': 'cry',
#  '喋': 'talk',
#  '喘': 'pant',
#  '喙': 'beak',
#  '喚': 'yell',
#  '喜': 'rejoice',
#  '喝': 'hoarse',
#  '喞': 'speak resentfully',
#  '喟': 'moan',
#  '喧': 'noisy',
#  '喨': 'clear voice',
#  '喩': 'metaphor',
#  '喪': 'miss',
#  '喫': 'consume',
#  '喬': 'high',
#  '單': 'one',
#  '喰': 'eat',
#  '営': 'occupation',
#  '嗄': 'hoarse',
#  '嗅': 'smell',
#  '嗇': 'miserly',
#  '嗔': 'be angry',
#  '嗚': 'weep',
#  '嗜': 'like',
#  '嗟': 'lament',
#  '嗣': 'heir',
#  '嗤': 'laugh',
#  '嗷': 'noisy',
#  '嗹': 'voluble',
#  '嗽': 'rinse',
#  '嗾': "sic'em",
#  '嘆': 'sigh',
#  '嘉': 'applaud',
#  '嘔': 'vomit',
#  '嘖': 'scold',
#  '嘗': 'once',
#  '嘘': 'lie',
#  '嘛': 'wheat',
#  '嘩': 'noisy',
#  '嘯': 'roar',
#  '嘱': 'entrust',
#  '嘲': 'ridicule',
#  '嘴': 'beak',
#  '嘶': 'neigh',
#  '嘸': 'how',
#  '噂': 'rumor',
#  '噌': 'boisterous',
#  '噎': 'choke',
#  '噐': 'vessel',
#  '噛': 'chew',
#  '噤': 'shut up',
#  '器': 'utensil',
#  '噪': 'be noisy',
#  '噫': 'exclamation',
#  '噬': 'bite',
#  '噴': 'erupt',
#  '噸': 'tonnage',
#  '噺': 'talk',
#  '嚀': 'kindness',
#  '嚆': 'call',
#  '嚇': 'menacing',
#  '嚊': 'breathing through the nose',
#  '嚏': 'sneeze',
#  '嚔': 'sneeze',
#  '嚠': 'a clear sound',
#  '嚢': 'pouch',
#  '嚥': 'swallow',
#  '嚮': 'guide',
#  '嚴': 'strictness',
#  '嚶': 'chirping',
#  '嚼': 'bite',
#  '囀': 'sing',
#  '囁': 'whisper',
#  '囂': 'noisy',
#  '囃': 'play (music)',
#  '囈': 'foolish talk',
#  '囎': 'used in place names',
#  '囑': 'request',
#  '囓': 'gnaw',
#  '囘': 'round',
#  '囚': 'captured',
#  '四': 'four',
#  '回': '-times',
#  '因': 'cause',
#  '団': 'group',
#  '囮': 'decoy',
#  '困': 'quandary',
#  '囲': 'surround',
#  '図': 'map',
#  '囹': 'prison',
#  '固': 'harden',
#  '国': 'country',
#  '囿': 'game preserve',
#  '圀': 'country',
#  '圃': 'garden',
#  '圄': 'prison',
#  '圈': 'sphere',
#  '圉': 'prison',
#  '國': 'country',
#  '圍': 'enclose',
#  '圏': 'sphere',
#  '園': 'park',
#  '圓': 'yen',
#  '圖': 'drawing',
#  '團': 'association',
#  '圜': 'round',
#  '圦': 'sluice',
#  '圧': 'pressure',
#  '在': 'exist',
#  '圭': 'square jewel',
#  '地': 'ground',
#  '圷': 'low-lying land',
#  '圸': 'steep slope',
#  '圻': 'region surrounding the capital',
#  '址': 'ruins',
#  '坂': 'slope',
#  '均': 'level',
#  '坊': 'boy',
#  '坎': 'pitfall',
#  '坏': 'bowl',
#  '坐': 'sit',
#  '坑': 'pit',
#  '坡': 'dike',
#  '坤': 'divination sign',
#  '坦': 'level',
#  '坩': 'jar',
#  '坪': 'two-mat area',
#  '坿': 'slope',
#  '垂': 'droop',
#  '垈': 'swamp',
#  '垉': 'collapse',
#  '型': 'mould',
#  '垓': 'border',
#  '垠': 'limit',
#  '垢': 'dirt',
#  '垣': 'hedge',
#  '垤': 'anthill',
#  '垪': 'used in proper names',
#  '垰': 'mountain pass',
#  '垳': 'cliff',
#  '埀': 'let down',
#  '埃': 'dust',
#  '埆': 'barren land',
#  '埋': 'bury',
#  '城': 'castle',
#  '埒': 'picket',
#  '埓': 'pale',
#  '埔': 'used in Chinese place names',
#  '埖': 'garbage',
#  '埜': 'open country',
#  '域': 'range',
#  '埠': 'wharf',
#  '埣': 'barren land',
#  '埴': 'clay',
#  '執': 'tenacious',
#  '培': 'cultivate',
#  '基': 'fundamentals',
#  '埼': 'cape',
#  '堀': 'ditch',
#  '堂': 'public chamber',
#  '堅': 'strict',
#  '堆': 'piled high',
#  '堊': 'whitewash',
#  '堋': 'bury',
#  '堕': 'degenerate',
#  '堙': 'close up',
#  '堝': 'crucible',
#  '堡': 'fort',
#  '堤': 'dike',
#  '堪': 'withstand',
#  '堯': 'high',
#  '堰': 'dam',
#  '報': 'report',
#  '場': 'location',
#  '堵': 'fence',
#  '堺': 'world',
#  '堽': 'mound',
#  '塀': 'fence',
#  '塁': 'bases',
#  '塊': 'clod',
#  '塋': 'cemetery',
#  '塑': 'model',
#  '塒': 'roost',
#  '塔': 'pagoda',
#  '塗': 'paint',
#  '塘': 'dike',
#  '塙': 'projecting tableland or mountain',
#  '塚': 'hillock',
#  '塞': 'close',
#  '塢': 'fortress embankment',
#  '塩': 'salt',
#  '填': 'fill in',
#  '塰': 'title of a Noh play',
#  '塲': 'open space',
#  '塵': 'dust',
#  '塹': 'moat',
#  '塾': 'cram school',
#  '境': 'boundary',
#  '墅': 'shed',
#  '墓': 'grave',
#  '増': 'increase',
#  '墜': 'crash',
#  '墟': 'ruins',
#  '墨': 'black ink',
#  '墫': 'cup',
#  '墮': 'descend to',
#  '墳': 'tomb',
#  '墸': 'hesitate',
#  '墹': 'steep slope',
#  '墺': 'land',
#  '墻': 'fence',
#  '墾': 'ground-breaking',
#  '壁': 'wall',
#  '壅': 'plug up',
#  '壇': 'podium',
#  '壊': 'demolition',
#  '壌': 'lot',
#  '壑': 'valley',
#  '壓': 'pressure',
#  '壕': 'trench',
#  '壗': 'steep slope',
#  '壘': 'fort',
#  '壙': 'hole',
#  '壜': 'bottle',
#  '壞': 'demolition',
#  '壟': 'mound',
#  '壤': 'soil',
#  '壥': 'fine residence',
#  '壬': '9th calendar sign',
#  '壮': 'robust',
#  '壯': 'big',
#  '声': 'voice',
#  '壱': 'one (in documents)',
#  '売': 'sell',
#  '壷': 'jar',
#  '壹': 'number one',
#  '壺': 'jar',
#  '壻': 'son-in-law',
#  '壼': 'palace corridor or passageway',
#  '壽': 'longevity',
#  '夂': 'late',
#  '変': 'unusual',
#  '夊': 'winter variant radical (no. 34)',
#  '夏': 'summer',
#  '夐': 'far',
#  '外': 'outside',
#  '夘': 'sign of the hare or rabbit',
#  '夙': 'bright and early',
#  '多': 'many',
#  '夛': 'much',
#  '夜': 'night',
#  '夢': 'dream',
#  '夥': 'immense',
#  '天': 'heavens',
#  '太': 'plump',
#  '夫': 'husband',
#  '夬': 'decide',
#  '夭': 'early death',
#  '央': 'center',
#  '失': 'lose',
#  '夲': 'advance quickly',
#  '夷': 'barbarian',
#  '夸': 'boast',
#  '夾': 'insert between',
#  '奄': 'cover',
#  '奇': 'strange',
#  '奈': 'Nara',
#  '奉': 'observance',
#  '奎': 'star',
#  '奏': 'play music',
#  '奐': 'clear',
#  '契': 'pledge',
#  '奔': 'run',
#  '奕': 'large',
#  '套': 'accumulate',
#  '奘': 'large',
#  '奚': 'servant',
#  '奠': 'decision',
#  '奢': 'extravagance',
#  '奥': 'heart',
#  '奧': 'heart',
#  '奨': 'exhort',
#  '奩': "lady's vanity case",
#  '奪': 'rob',
#  '奬': 'prize',
#  '奮': 'stirred up',
#  '奴': 'guy',
#  '奸': 'wickedness',
#  '好': 'fond',
#  '妁': 'go-between',
#  '如': 'likeness',
#  '妃': 'queen',
#  '妄': 'delusion',
#  '妊': 'pregnancy',
#  '妍': 'beauty',
#  '妓': 'stretch',
#  '妖': 'attractive',
#  '妙': 'exquisite',
#  '妛': 'despise',
#  '妝': 'dress up',
#  '妣': 'mother',
#  '妥': 'gentle',
#  '妨': 'disturb',
#  '妬': 'jealous',
#  '妲': 'female proper name',
#  '妹': 'younger sister',
#  '妻': 'wife',
#  '妾': 'concubine',
#  '姆': 'wet nurse',
#  '姉': 'elder sister',
#  '始': 'commence',
#  '姐': 'elder sister',
#  '姑': 'mother-in-law',
#  '姓': 'surname',
#  '委': 'committee',
#  '姙': 'be(come) pregnant',
#  '姚': 'beautiful',
#  '姜': 'Chinese surname',
#  '姥': 'old woman',
#  '姦': 'wicked',
#  '姨': 'younger sister',
#  '姪': 'niece',
#  '姫': 'princess',
#  '姶': 'good-looking',
#  '姻': 'matrimony',
#  '姿': 'figure',
#  '威': 'intimidate',
#  '娃': 'beautiful',
#  '娉': "ask after a woman's name",
#  '娑': 'old woman',
#  '娘': 'daughter',
#  '娚': 'loud talking',
#  '娜': 'graceful',
#  '娟': 'beauty of face',
#  '娠': 'with child',
#  '娥': 'beautiful',
#  '娩': 'bear (children)',
#  '娯': 'recreation',
#  '娵': 'marry',
#  '娶': 'marry',
#  '娼': 'prostitute',
#  '婀': 'charm',
#  '婁': 'frequently',
#  '婆': 'old woman',
#  '婉': 'graceful',
#  '婚': 'marriage',
#  '婢': 'maidservant',
#  '婦': 'lady',
#  '婪': 'covet',
#  '婬': 'lewdness',
#  '婿': 'bridegroom',
#  '媒': 'mediator',
#  '媚': 'flatter',
#  '媛': 'beautiful woman',
#  '媼': 'mother',
#  '媽': 'mother',
#  '媾': 'association',
#  '嫁': 'marry into',
#  '嫂': "elder brother's wife",
#  '嫉': 'jealous',
#  '嫋': 'supple',
#  '嫌': 'dislike',
#  '嫐': 'frolic',
#  '嫖': 'wanton',
#  '嫗': 'old woman',
#  '嫡': 'legitimate wife',
#  '嫣': 'beauty',
#  '嫦': 'proper name',
#  '嫩': 'young',
#  '嫺': 'refined',
#  '嫻': 'elegant',
#  '嬉': 'glad',
#  '嬋': 'beautiful',
#  '嬌': 'attractive',
#  '嬖': 'agreeable person',
#  '嬢': 'lass',
#  '嬪': 'bride',
#  '嬬': 'mistress',
#  '嬰': 'sharp (music)',
#  '嬲': 'sport with',
#  '嬶': 'wife (vulg)',
#  '嬾': 'lazy',
#  '孀': 'widow',
#  '孃': 'girl',
#  '孅': 'delicate',
#  '孔': 'cavity',
#  '孕': 'become pregnant',
#  '字': 'character',
#  '存': 'exist',
#  '孚': 'sincere',
#  '孛': 'comet',
#  '孜': 'industriousness',
#  '孝': 'filial piety',
#  '孟': 'chief',
#  '季': 'seasons',
#  '孤': 'orphan',
#  '孥': 'child',
#  '学': 'study',
#  '孩': 'baby',
#  '孫': 'grandchild',
#  '孰': 'which',
#  '孱': 'weak',
#  '孳': 'increase',
#  '孵': 'hatch',
#  '學': 'learning',
#  '孺': 'child',
#  '它': 'other',
#  '宅': 'home',
#  '宇': 'eaves',
#  '守': 'guard',
#  '安': 'relax',
#  '宋': 'dwell',
#  '完': 'perfect',
#  '宍': 'muscles',
#  '宏': 'wide',
#  '宕': 'cave',
#  '宗': 'religion',
#  '官': 'bureaucrat',
#  '宙': 'mid-air',
#  '定': 'determine',
#  '宛': 'address',
#  '宜': 'best regards',
#  '宝': 'treasure',
#  '実': 'reality',
#  '客': 'guest',
#  '宣': 'proclaim',
#  '室': 'room',
#  '宥': 'soothe',
#  '宦': 'official',
#  '宮': 'Shinto shrine',
#  '宰': 'superintend',
#  '害': 'harm',
#  '宴': 'banquet',
#  '宵': 'wee hours',
#  '家': 'house',
#  '宸': 'eaves',
#  '容': 'contain',
#  '宿': 'inn',
#  '寂': 'loneliness',
#  '寃': 'grievance',
#  '寄': 'draw near',
#  '寅': 'sign of the tiger',
#  '密': 'secrecy',
#  '寇': 'bandits',
#  '寉': 'crane (bird)',
#  '富': 'wealth',
#  '寐': 'sleep',
#  '寒': 'cold',
#  '寓': 'temporary abode',
#  '寔': 'real',
#  '寛': 'tolerant',
#  '寝': 'lie down',
#  '寞': 'lonely',
#  '察': 'guess',
#  '寡': 'widow',
#  '寢': 'sleep',
#  '寤': 'awake',
#  '寥': 'lonely',
#  '實': 'truth',
#  '寧': 'rather',
#  '寨': 'fort',
#  '審': 'hearing',
#  '寫': 'be photographed',
#  '寮': 'dormitory',
#  '寰': 'imperial domain',
#  '寳': 'treasure',
#  '寵': 'affection',
#  '寶': 'treasure',
#  '寺': 'Buddhist temple',
#  '対': 'vis-a-vis',
#  '寿': 'longevity',
#  '封': 'seal',
#  '専': 'specialty',
#  '射': 'shoot',
#  '尅': 'subdue',
#  '将': 'leader',
#  '將': 'commander',
#  '專': 'specialty',
#  '尉': 'military officer',
#  '尊': 'revered',
#  '尋': 'inquire',
#  '對': 'correct',
#  '導': 'guidance',
#  '少': 'few',
#  '尓': 'you',
#  '尖': 'be pointed',
#  '尚': 'esteem',
#  '尠': 'at least',
#  '尤': 'reasonable',
#  '尨': 'shaggy hair or dog',
#  '尭': 'high',
#  '就': 'concerning',
#  '尹': 'an official rank',
#  '尺': 'shaku',
#  '尻': 'buttocks',
#  '尼': 'nun',
#  '尽': 'exhaust',
#  '尾': 'tail',
#  '尿': 'urine',
#  '局': 'bureau',
#  '屁': 'fart',
#  '居': 'reside',
#  '屆': 'reach',
#  '屈': 'yield',
#  '届': 'deliver',
#  '屋': 'roof',
#  '屍': 'corpse',
#  '屎': 'shit',
#  '屏': 'wall',
#  '屐': 'clog',
#  '屑': 'rubbish',
#  '屓': 'exerting strength',
#  '展': 'unfold',
#  '属': 'belong',
#  '屠': 'slaughter',
#  '屡': 'often',
#  '層': 'stratum',
#  '履': 'perform',
#  '屬': 'genus',
#  '屯': 'barracks',
#  '屶': 'used in proper names',
#  '屹': 'towering mountains',
#  '岌': 'high',
#  '岐': 'branch off',
#  '岑': 'peak',
#  '岔': 'fork in a road',
#  '岡': 'mount',
#  '岨': 'a rocky mountain',
#  '岩': 'boulder',
#  '岫': 'gorge',
#  '岬': 'headland',
#  '岱': 'old name for a Chinese mountain',
#  '岳': 'point',
#  '岶': 'dense mountain vegetation',
#  '岷': 'name of a Chinese river',
#  '岸': 'beach',
#  '岻': 'name of a mountain',
#  '岼': 'level spot part-way up a mountain',
#  '岾': 'mountain',
#  '峅': 'shrine in the mountains',
#  '峇': 'mountain cave',
#  '峙': 'tower',
#  '峠': 'mountain peak',
#  '峡': 'gorge',
#  '峨': 'high mountain',
#  '峩': 'lofty',
#  '峪': 'ravine',
#  '峭': 'high & steep',
#  '峯': 'peak',
#  '峰': 'summit',
#  '島': 'island',
#  '峺': 'obstruct',
#  '峻': 'high',
#  '峽': 'gorge',
#  '崇': 'adore',
#  '崋': 'name of mountain',
#  '崎': 'promontory',
#  '崑': 'place name',
#  '崔': 'cliff',
#  '崕': 'cliff',
#  '崖': 'cliff',
#  '崗': 'hill',
#  '崘': 'Kunlun mountains in Jiangsu',
#  '崙': 'place name',
#  '崚': 'mountains towering in a row',
#  '崛': 'high & lofty (mountains)',
#  '崟': 'peak',
#  '崢': 'high',
#  '崩': 'crumble',
#  '嵋': 'place name',
#  '嵌': 'go into',
#  '嵎': 'mountain recesses',
#  '嵐': 'storm',
#  '嵒': 'rock',
#  '嵜': 'steep',
#  '嵩': 'be aggravated',
#  '嵬': 'high and flat',
#  '嵯': 'steep',
#  '嵳': 'high',
#  '嵶': 'mountain pass',
#  '嶂': 'steep',
#  '嶄': 'steep or high mountain',
#  '嶇': 'steep',
#  '嶋': 'island',
#  '嶌': 'island',
#  '嶐': 'shape of a mountain',
#  '嶝': 'hill',
#  '嶢': 'high',
#  '嶬': 'high',
#  '嶮': 'inaccessible place',
#  '嶷': 'wise',
#  '嶺': 'peak',
#  '嶼': 'island',
#  '嶽': 'peak',
#  '巉': 'rising precipitously',
#  '巌': 'rock',
#  '巍': 'high',
#  '巒': 'small peak',
#  '巓': 'summit',
#  '巖': 'rock',
#  '州': 'state',
#  '巡': 'patrol',
#  '巣': 'nest',
#  '左': 'left',
#  '巧': 'adroit',
#  '巨': 'gigantic',
#  '巫': 'sorcerer',
#  '差': 'distinction',
#  '巴': 'comma-design',
#  '巵': 'large winecup',
#  '巷': 'fork in road',
#  '巻': 'scroll',
#  '巽': 'southeast',
#  '巾': 'towel',
#  '市': 'market',
#  '布': 'linen',
#  '帆': 'sail',
#  '帋': 'paper',
#  '希': 'hope',
#  '帑': 'money repository',
#  '帖': 'quire (of paper)',
#  '帙': 'Japanese book cover',
#  '帚': 'broom',
#  '帛': 'cloth',
#  '帝': 'sovereign',
#  '帥': 'commander',
#  '師': 'expert',
#  '席': 'seat',
#  '帯': 'sash',
#  '帰': 'homecoming',
#  '帳': 'notebook',
#  '帶': 'belt',
#  '帷': 'curtain',
#  '常': 'usual',
#  '帽': 'cap',
#  '幀': 'making books or scrolls',
#  '幃': 'bag',
#  '幄': 'curtain',
#  '幅': 'hanging scroll',
#  '幇': 'help',
#  '幌': 'canopy',
#  '幎': 'cloth covering',
#  '幔': 'curtain',
#  '幕': 'curtain',
#  '幗': "woman's head covering",
#  '幟': 'flag',
#  '幡': 'flag',
#  '幢': 'flag',
#  '幣': 'cash',
#  '幤': 'Shinto zigzag paper offerings',
#  '干': 'dry',
#  '平': 'even',
#  '年': 'year',
#  '幵': 'put together',
#  '并': 'put together',
#  '幸': 'happiness',
#  '幹': 'tree trunk',
#  '幻': 'phantasm',
#  '幼': 'infancy',
#  '幽': 'seclude',
#  '幾': 'how many',
#  '庁': 'government office',
#  '広': 'wide',
#  '庄': 'level',
#  '庇': 'protect',
#  '床': 'bed',
#  '序': 'preface',
#  '底': 'bottom',
#  '庖': 'kitchen',
#  '店': 'store',
#  '庚': '7th',
#  '府': 'borough',
#  '庠': 'school',
#  '度': 'degrees',
#  '座': 'squat',
#  '庫': 'warehouse',
#  '庭': 'courtyard',
#  '庵': 'hermitage',
#  '庶': 'commoner',
#  '康': 'ease',
#  '庸': 'commonplace',
#  '廁': 'toilet',
#  '廂': 'eaves',
#  '廃': 'abolish',
#  '廈': 'house',
#  '廉': 'bargain',
#  '廊': 'corridor',
#  '廏': 'barn',
#  '廐': 'barn',
#  '廓': 'enclosure',
#  '廖': 'empty',
#  '廚': 'kitchen',
#  '廛': 'fine residence',
#  '廝': 'servant',
#  '廟': 'mausoleum',
#  '廠': 'workshop',
#  '廡': 'walking under the eaves',
#  '廢': 'abrogate',
#  '廣': 'broad',
#  '廨': 'government office',
#  '廩': 'rice storehouse',
#  '廬': 'hermitage',
#  '廰': 'government office',
#  '廱': 'mild',
#  '廳': 'hall',
#  '延': 'prolong',
#  '廷': 'courts',
#  '廸': 'path',
#  '建': 'build',
#  '廻': 'round',
#  '廼': 'in other words',
#  '廿': 'twenty',
#  '弁': 'valve',
#  '弃': 'reject',
#  '弄': 'play with',
#  '弉': 'large',
#  '弊': 'abuse',
#  '弌': 'one',
#  '弍': 'two',
#  '式': 'style',
#  '弐': 'II',
#  '弑': "murder one's lord or father",
#  '弔': 'condolences',
#  '引': 'pull',
#  '弖': 'phoneme only',
#  '弗': 'dollar',
#  '弘': 'vast',
#  '弛': 'slacken',
#  '弟': 'younger brother',
#  '弥': 'all the more',
#  '弦': 'bowstring',
#  '弧': 'arc',
#  '弩': 'bow (arrow)',
#  '弭': 'stop',
#  '弯': 'curve',
#  '弱': 'weak',
#  '張': 'lengthen',
#  '強': 'strong',
#  '弸': 'strong bow',
#  '弼': 'help',
#  '弾': 'bullet',
#  '彁': '(no known meaning; S&H uses jabberwocky words)',
#  '彈': 'bullet',
#  '彊': 'strong',
#  '彌': 'extensive',
#  '彎': 'curve',
#  '彑': "pig's head radical variant (no. 58)",
#  '当': 'hit',
#  '彖': 'divination',
#  '彗': 'comet',
#  '彙': 'same kind',
#  '彜': 'moral principle',
#  '彝': 'moral principle',
#  '形': 'shape',
#  '彦': 'lad',
#  '彩': 'coloring',
#  '彪': 'spotted',
#  '彫': 'carve',
#  '彬': 'refined',
#  '彭': 'swelling',
#  '彰': 'patent',
#  '影': 'shadow',
#  '彷': 'stray',
#  '役': 'duty',
#  '彼': 'he',
#  '彿': 'dimly',
#  '往': 'journey',
#  '征': 'subjugate',
#  '徂': 'go',
#  '徃': 'journey',
#  '径': 'diameter',
#  '待': 'wait',
#  '徇': 'herald',
#  '很': 'disobey',
#  '徊': 'wandering',
#  '律': 'rhythm',
#  '後': 'behind',
#  '徐': 'gradually',
#  '徑': 'path',
#  '徒': 'on foot',
#  '従': 'accompany',
#  '得': 'gain',
#  '徘': 'wander',
#  '徙': 'move',
#  '從': 'from',
#  '徠': 'induce',
#  '御': 'honorable',
#  '徨': 'wandering',
#  '復': 'restore',
#  '循': 'sequential',
#  '徭': 'compulsory service to the state',
#  '微': 'delicate',
#  '徳': 'benevolence',
#  '徴': 'indications',
#  '徹': 'penetrate',
#  '徼': 'seek',
#  '徽': 'good',
#  '必': 'invariably',
#  '忌': 'mourning',
#  '忍': 'endure',
#  '忖': 'conjecture',
#  '志': 'intention',
#  '忘': 'forget',
#  '忙': 'busy',
#  '応': 'apply',
#  '忝': 'grateful',
#  '忠': 'loyalty',
#  '忤': 'insubordinate',
#  '快': 'cheerful',
#  '忰': 'suffer',
#  '忱': 'sincere',
#  '念': 'wish',
#  '忸': 'shame',
#  '忻': 'rejoice',
#  '忽': 'in a moment',
#  '忿': 'be angry',
#  '怎': 'why',
#  '怏': 'dissatisfaction',
#  '怐': 'foolish',
#  '怒': 'angry',
#  '怕': 'oak',
#  '怖': 'dreadful',
#  '怙': 'depend',
#  '怛': 'be sad',
#  '怜': 'wise',
#  '思': 'think',
#  '怠': 'neglect',
#  '怡': 'rejoice',
#  '急': 'hurry',
#  '怦': 'in a hurry',
#  '性': 'sex',
#  '怨': 'grudge',
#  '怩': 'shame',
#  '怪': 'suspicious',
#  '怫': 'anger',
#  '怯': 'cowardice',
#  '怱': 'rush',
#  '怺': 'endure',
#  '恁': 'like this',
#  '恂': 'sincere',
#  '恃': 'depend on',
#  '恆': 'constant',
#  '恊': 'threaten',
#  '恋': 'romance',
#  '恍': 'unclear',
#  '恐': 'fear',
#  '恒': 'constancy',
#  '恕': 'excuse',
#  '恙': 'illness',
#  '恚': 'anger',
#  '恟': 'fear',
#  '恠': 'suspicious',
#  '恢': 'wide',
#  '恣': 'selfish',
#  '恤': 'relieve',
#  '恥': 'shame',
#  '恨': 'regret',
#  '恩': 'grace',
#  '恪': 'carefulness',
#  '恫': 'painful',
#  '恬': 'composure',
#  '恭': 'respect',
#  '息': 'breath',
#  '恰': 'just as',
#  '恵': 'favor',
#  '恷': 'be contrary to',
#  '悁': 'anger',
#  '悃': 'sincerity',
#  '悄': 'anxiety',
#  '悉': 'all',
#  '悋': 'stingy',
#  '悌': 'serving our elders',
#  '悍': 'rough',
#  '悒': 'be depressed',
#  '悔': 'repent',
#  '悖': 'be contrary',
#  '悗': 'be perplexed',
#  '悚': 'fear',
#  '悛': 'amend',
#  '悟': 'enlightenment',
#  '悠': 'permanence',
#  '患': 'afflicted',
#  '悦': 'ecstasy',
#  '悧': 'clever',
#  '悩': 'trouble',
#  '悪': 'bad',
#  '悲': 'grieve',
#  '悳': 'ethics',
#  '悴': 'becoming emaciated',
#  '悵': 'be sad',
#  '悶': 'be in agony',
#  '悸': 'pulsate',
#  '悼': 'lament',
#  '悽': 'be sad',
#  '情': 'feelings',
#  '惆': 'grieve over',
#  '惇': 'sincere',
#  '惑': 'beguile',
#  '惓': 'be respectful',
#  '惘': 'unclear',
#  '惚': 'fall in love with',
#  '惜': 'pity',
#  '惟': 'consider',
#  '惠': 'blessing',
#  '惡': 'bad',
#  '惣': 'all',
#  '惧': 'fear',
#  '惨': 'wretched',
#  '惰': 'lazy',
#  '惱': 'angered',
#  '想': 'concept',
#  '惴': 'fear',
#  '惶': 'fear',
#  '惷': 'confusion',
#  '惹': 'attract',
#  '惺': 'realize',
#  '惻': 'be sad',
#  '愀': 'respect',
#  '愁': 'distress',
#  '愃': 'abundant',
#  '愆': 'mistake',
#  '愈': 'be superior',
#  '愉': 'pleasure',
#  '愍': 'pity',
#  '愎': 'go against',
#  '意': 'idea',
#  '愕': 'surprised',
#  '愚': 'foolish',
#  '愛': 'love',
#  '感': 'emotion',
#  '愡': 'meaningless',
#  '愧': 'feel ashamed',
#  '愨': 'respectful',
#  '愬': 'complain of',
#  '愴': 'sad',
#  '愼': 'care',
#  '愽': 'grieving',
#  '愾': 'anger',
#  '愿': 'respectful',
#  '慂': 'direct',
#  '慄': 'fear',
#  '慇': 'courtesy',
#  '慈': 'mercy',
#  '慊': 'satisfaction',
#  '態': 'attitude',
#  '慌': 'disconcerted',
#  '慍': 'be angry (excited)',
#  '慎': 'humility',
#  '慓': 'fast',
#  '慕': 'pining',
#  '慘': 'sad',
#  '慙': 'ashamed',
#  '慚': 'feel ashamed',
#  '慝': 'bad',
#  '慟': 'be sad',
#  '慢': 'ridicule',
#  '慣': 'accustomed',
#  '慥': 'certainly',
#  '慧': 'wise',
#  '慨': 'rue',
#  '慫': 'advise',
#  '慮': 'prudence',
#  '慯': 'be sad',
#  '慰': 'consolation',
#  '慱': 'grieving',
#  '慳': 'regret',
#  '慴': 'fear',
#  '慵': 'languid',
#  '慶': 'jubilation',
#  '慷': 'weep',
#  '慾': 'covetousness',
#  '憂': 'melancholy',
#  '憇': 'rest',
#  '憊': 'fatigue',
#  '憎': 'hate',
#  '憐': 'pity',
#  '憑': 'depend',
#  '憔': 'get thin',
#  '憖': 'thoughtlessly',
#  '憙': 'rejoice',
#  '憚': 'hesitate',
#  '憤': 'aroused',
#  '憧': 'yearn after',
#  '憩': 'recess',
#  '憫': 'anxiety',
#  '憬': 'yearn for',
#  '憮': 'disappointment',
#  '憲': 'constitution',
#  '憶': 'recollection',
#  '憺': 'calm',
#  '憾': 'remorse',
#  '懃': 'courtesy',
#  '懆': 'unease',
#  '懇': 'sociable',
#  '懈': 'laziness',
#  '應': 'answer',
#  '懊': 'in distress',
#  '懋': 'strive',
#  '懌': 'rejoice',
#  '懍': 'fear',
#  '懐': 'pocket',
#  '懣': 'worry',
#  '懦': 'weakness',
#  '懲': 'penal',
#  '懴': 'remorse',
#  '懶': 'languid',
#  '懷': 'pocket',
#  '懸': 'state of suspension',
#  '懺': 'regret',
#  '懼': 'fear',
#  '懽': 'rejoice',
#  '懾': 'fear',
#  '懿': 'beautiful',
#  '戀': 'in love',
#  '戉': 'warrior',
#  '戊': '5th calendar sign',
#  '戌': 'sign of the dog',
#  '戍': 'protection',
#  '戎': 'warrior',
#  '成': 'turn into',
#  '我': 'ego',
#  '戒': 'commandment',
#  '戔': 'damage',
#  '或': 'some',
#  '戚': 'grieve',
#  '戛': 'halberd',
#  '戝': 'pirate',
#  '戞': 'lance',
#  '戟': 'halbert',
#  '戡': 'victory',
#  '戦': 'war',
#  '截': 'cut off',
#  '戮': 'kill',
#  '戯': 'frolic',
#  '戰': 'war',
#  '戲': 'play',
#  '戳': 'poke',
#  '戴': 'be crowned with',
#  '戻': 're-',
#  '房': 'tassel',
#  '所': 'place',
#  '扁': 'level',
#  '扇': 'fan',
#  '扈': 'follow',
#  '扉': 'front door',
#  '才': 'genius',
#  '扎': 'pull',
#  '打': 'strike',
#  '払': 'pay',
#  '托': 'requesting',
#  '扛': 'raise',
#  '扞': 'restrain',
#  '扠': 'well',
#  '扣': 'knock',
#  '扨': 'well',
#  '扮': 'impersonate',
#  '扱': 'handle',
#  '扶': 'aid',
#  '批': 'criticism',
#  '扼': 'command',
#  '找': 'look for',
#  '承': 'acquiesce',
#  '技': 'skill',
#  '抂': 'disorder',
#  '抃': 'strike with hand',
#  '抄': 'extract',
#  '抉': 'gouge',
#  '把': 'grasp',
#  '抑': 'repress',
#  '抒': 'tell',
#  '抓': 'pick',
#  '抔': 'and so forth',
#  '投': 'throw',
#  '抖': 'shake',
#  '抗': 'confront',
#  '折': 'fold',
#  '抛': 'hurl',
#  '抜': 'slip out',
#  '択': 'choose',
#  '披': 'expose',
#  '抬': 'lift',
#  '抱': 'embrace',
#  '抵': 'resist',
#  '抹': 'rub',
#  '抻': 'stretch',
#  '押': 'push',
#  '抽': 'pluck',
#  '拂': 'clear out',
#  '担': 'shouldering',
#  '拆': 'to split apart',
#  '拇': 'thumb',
#  '拈': 'twirl',
#  '拉': 'Latin',
#  '拊': 'slap',
#  '拌': 'stir and mix',
#  '拍': 'clap',
#  '拏': 'catch',
#  '拐': 'kidnap',
#  '拑': "shut one's mouth",
#  '拒': 'repel',
#  '拓': 'clear (the land)',
#  '拔': 'extract',
#  '拗': 'crooked',
#  '拘': 'arrest',
#  '拙': 'bungling',
#  '招': 'beckon',
#  '拜': 'worship',
#  '拝': 'worship',
#  '拠': 'foothold',
#  '拡': 'broaden',
#  '括': 'fasten',
#  '拭': 'wipe',
#  '拮': 'be imminent',
#  '拯': 'help',
#  '拱': 'arch',
#  '拳': 'fist',
#  '拵': 'make',
#  '拶': 'be imminent',
#  '拷': 'torture',
#  '拾': 'pick up',
#  '拿': 'catch',
#  '持': 'hold',
#  '挂': 'hang',
#  '指': 'finger',
#  '挈': 'carry by hand',
#  '按': 'hold',
#  '挌': 'strike',
#  '挑': 'challenge',
#  '挙': 'raise',
#  '挟': 'pinch',
#  '挧': 'Japanese horse chestnut',
#  '挨': 'approach',
#  '挫': 'crush',
#  '振': 'shake',
#  '挺': 'counter for guns, inksticks, palanquins, rickshaws',
#  '挽': 'saw',
#  '挾': 'put between',
#  '挿': 'insert',
#  '捉': 'catch',
#  '捌': 'handle',
#  '捍': 'defend',
#  '捏': 'knead',
#  '捐': 'throw away',
#  '捕': 'catch',
#  '捗': 'make progress',
#  '捜': 'search',
#  '捧': 'lift up',
#  '捨': 'discard',
#  '捩': 'screw',
#  '捫': 'to stroke',
#  '据': 'set',
#  '捲': 'roll',
#  '捶': 'strike',
#  '捷': 'victory',
#  '捺': 'press',
#  '捻': 'twirl',
#  '掀': 'raise',
#  '掃': 'sweep',
#  '授': 'impart',
#  '掉': 'shake & move',
#  '掌': 'manipulate',
#  '掎': 'pull',
#  '掏': 'pickpocket',
#  '排': 'repudiate',
#  '掖': 'side (of body)',
#  '掘': 'dig',
#  '掛': 'hang',
#  '掟': 'law',
#  '掠': 'pillage',
#  '採': 'pick',
#  '探': 'grope',
#  '掣': 'pull back',
#  '接': 'touch',
#  '控': 'withdraw',
#  '推': 'conjecture',
#  '掩': 'cover',
#  '措': 'set aside',
#  '掫': 'night watch',
#  '掬': 'scoop up water with the hand',
#  '掲': 'put up (a notice)',
#  '掴': 'catch',
#  '掵': 'alluvial terraced land',
#  '掻': 'scratch',
#  '掾': 'help',
#  '揀': 'select',
#  '揃': 'be complete',
#  '揄': 'pull',
#  '揆': 'category',
#  '揉': 'rub',
#  '描': 'sketch',
#  '提': 'propose',
#  '插': 'insert',
#  '揖': 'bow with arms folded',
#  '揚': 'raise',
#  '換': 'interchange',
#  '握': 'grip',
#  '揣': 'conjecture',
#  '揩': 'wipe',
#  '揮': 'brandish',
#  '援': 'abet',
#  '揶': 'tease',
#  '揺': 'swing',
#  '搆': 'pull',
#  '損': 'damage',
#  '搏': 'seize',
#  '搓': 'braid',
#  '搖': 'wag',
#  '搗': 'pound',
#  '搜': 'search',
#  '搦': 'bind',
#  '搨': 'trace',
#  '搬': 'conveyor',
#  '搭': 'board',
#  '搴': 'take',
#  '搶': 'thrust',
#  '携': 'portable',
#  '搾': 'squeeze',
#  '摂': 'vicarious',
#  '摎': 'tie into a bundle',
#  '摘': 'pinch',
#  '摧': 'break',
#  '摩': 'chafe',
#  '摯': 'gift',
#  '摶': 'roll into a ball',
#  '摸': 'search',
#  '摺': 'rub',
#  '撃': 'beat',
#  '撈': 'catch fish',
#  '撒': 'scatter',
#  '撓': 'bend',
#  '撕': 'warn against',
#  '撚': 'twist',
#  '撞': 'thrust',
#  '撤': 'remove',
#  '撥': 'brush up',
#  '撩': 'disorder',
#  '撫': 'stroke',
#  '播': 'plant',
#  '撮': 'snapshot',
#  '撰': 'composing',
#  '撲': 'slap',
#  '撹': 'disturb',
#  '撻': 'whip',
#  '撼': 'move',
#  '擁': 'hug',
#  '擂': 'grind',
#  '擅': 'self-indulgent',
#  '擇': 'select',
#  '操': 'maneuver',
#  '擒': 'capture',
#  '擔': 'carry',
#  '擘': 'tear up',
#  '據': 'to occupy',
#  '擠': 'push aside',
#  '擡': 'lift',
#  '擢': 'excel in',
#  '擣': 'pound',
#  '擦': 'grate',
#  '擧': 'raise',
#  '擬': 'mimic',
#  '擯': 'push (people) back',
#  '擱': 'lay down',
#  '擲': 'hit',
#  '擴': 'broaden',
#  '擶': 'straighten (an arrow)',
#  '擺': 'push open',
#  '擽': 'tickle',
#  '擾': 'disturb',
#  '攀': 'climb',
#  '攅': 'gather',
#  '攘': 'chase away',
#  '攜': 'carry (in hand)',
#  '攝': 'surrogate',
#  '攣': 'crooked',
#  '攤': 'open',
#  '攪': 'disturb',
#  '攫': 'abduct',
#  '攬': 'hold (in hand)',
#  '支': 'branch',
#  '收': 'income',
#  '攷': 'examine',
#  '攸': 'relaxed',
#  '改': 'reformation',
#  '攻': 'aggression',
#  '放': 'set free',
#  '政': 'politics',
#  '故': 'happenstance',
#  '效': 'result',
#  '敍': 'express',
#  '敏': 'cleverness',
#  '救': 'salvation',
#  '敕': 'an imperial order or decree',
#  '敖': 'play',
#  '敗': 'failure',
#  '敘': 'express',
#  '教': 'teach',
#  '敝': 'be worn-out',
#  '敞': 'high and flat',
#  '敢': 'daring',
#  '散': 'scatter',
#  '敦': 'industry',
#  '敬': 'awe',
#  '数': 'number',
#  '敲': 'strike',
#  '整': 'organize',
#  '敵': 'enemy',
#  '敷': 'spread',
#  '數': 'number',
#  '斂': 'tighten',
#  '斃': 'kill',
#  '斈': 'learning',
#  '斉': 'adjusted',
#  '斌': 'beautiful',
#  '斎': 'purification',
#  '斐': 'beautiful',
#  '斑': 'spot',
#  '料': 'fee',
#  '斛': 'measure',
#  '斜': 'diagonal',
#  '斟': 'dip water',
#  '斡': 'go around',
#  '斥': 'reject',
#  '斧': 'ax',
#  '斫': 'cut with a sword',
#  '斬': 'beheading',
#  '断': 'severance',
#  '斯': 'this',
#  '新': 'new',
#  '斷': 'sever',
#  '於': 'at',
#  '施': 'give',
#  '旁': 'RHS of character',
#  '旃': 'woollen cloth',
#  '旄': 'tassel on a flag',
#  '旅': 'trip',
#  '旆': 'flag',
#  '旋': 'rotation',
#  '旌': 'flag',
#  '族': 'tribe',
#  '旒': 'counter for flags',
#  '旗': 'national flag',
#  '旙': 'a pennant',
#  '旛': 'flag',
#  '既': 'previously',
#  '旦': 'daybreak',
#  '旧': 'old times',
#  '旨': 'delicious',
#  '早': 'early',
#  '旬': 'decameron',
#  '旭': 'rising sun',
#  '旱': 'drought',
#  '旺': 'flourishing',
#  '旻': 'the autumn sky',
#  '昂': 'rise',
#  '昃': 'decline',
#  '昆': 'descendants',
#  '昇': 'rise up',
#  '昊': 'sky',
#  '昌': 'prosperous',
#  '明': 'bright',
#  '昏': 'dark',
#  '易': 'easy',
#  '昔': 'once upon a time',
#  '昜': 'open',
#  '星': 'star',
#  '映': 'reflect',
#  '春': 'springtime',
#  '昧': 'dark',
#  '昨': 'yesterday',
#  '昭': 'shining',
#  '是': 'just so',
#  '昴': 'the Pleiades',
#  '昵': 'reconcile',
#  '昶': 'long day',
#  '昼': 'daytime',
#  '昿': 'extensive',
#  '晁': 'proper name',
#  '時': 'time',
#  '晃': 'clear',
#  '晄': 'clear',
#  '晉': 'advance',
#  '晋': 'advance',
#  '晏': 'late',
#  '晒': 'bleach',
#  '晝': 'daytime',
#  '晞': 'dry out',
#  '晟': 'clear',
#  '晢': 'light of stars',
#  '晤': 'clear',
#  '晦': 'dark',
#  '晧': 'bright',
#  '晨': 'morning',
#  '晩': 'nightfall',
#  '普': 'universal',
#  '景': 'scenery',
#  '晰': 'clear',
#  '晴': 'clear up',
#  '晶': 'sparkle',
#  '智': 'wisdom',
#  '暁': 'daybreak',
#  '暃': 'be separated',
#  '暄': 'warm weather',
#  '暇': 'spare time',
#  '暈': 'halo',
#  '暉': 'shine',
#  '暎': 'sun beginning decline',
#  '暑': 'sultry',
#  '暖': 'warmth',
#  '暗': 'darkness',
#  '暘': 'sunrise',
#  '暝': 'dark',
#  '暢': 'stretch',
#  '暦': 'calendar',
#  '暫': 'temporarily',
#  '暮': 'evening',
#  '暴': 'outburst',
#  '暸': 'clear',
#  '暹': 'sunrise',
#  '暼': 'setting sun',
#  '暾': 'sunrise',
#  '曁': 'and',
#  '曄': 'shine',
#  '曇': 'cloudy weather',
#  '曉': 'dawn',
#  '曖': 'dark',
#  '曙': 'dawn',
#  '曚': 'darkness',
#  '曜': 'weekday',
#  '曝': 'bleach',
#  '曠': 'wide',
#  '曦': 'the sun',
#  '曩': 'before',
#  '曲': 'bend',
#  '曳': 'pull',
#  '更': 'grow late',
#  '曵': 'trail',
#  '曷': 'why',
#  '書': 'write',
#  '曹': 'office',
#  '曼': 'wide',
#  '曽': 'formerly',
#  '曾': 'once',
#  '替': 'exchange',
#  '最': 'utmost',
#  '會': 'meet',
#  '有': 'possess',
#  '朋': 'companion',
#  '服': 'clothing',
#  '朏': 'new moon',
#  '朔': 'conjunction (astronomy)',
#  '朕': 'majestic plural',
#  '朖': 'clear',
#  '朗': 'melodious',
#  '望': 'ambition',
#  '朝': 'morning',
#  '朞': 'one period',
#  '期': 'period',
#  '朦': 'dim',
#  '朧': 'haziness',
#  '未': 'un-',
#  '末': 'end',
#  '本': 'book',
#  '札': 'tag',
#  '朮': 'a type of millet',
#  '朱': 'vermilion',
#  '朴': 'crude',
#  '朶': 'branch',
#  '朷': 'type of tree',
#  '朸': 'carrying pole',
#  '机': 'desk',
#  '朽': 'decay',
#  '朿': 'thorn',
#  '杁': 'sluice',
#  '杆': 'shield',
#  '杉': 'cedar',
#  '李': 'plum',
#  '杏': 'apricot',
#  '材': 'lumber',
#  '村': 'village',
#  '杓': 'ladle',
#  '杖': 'staff',
#  '杙': 'stake',
#  '杜': 'woods',
#  '杞': 'river willow',
#  '束': 'bundle',
#  '杠': 'lever',
#  '条': 'article',
#  '杢': 'woodworker',
#  '杣': 'timber',
#  '杤': 'type of oak',
#  '来': 'come',
#  '杪': 'twig',
#  '杭': 'stake',
#  '杯': 'counter for cupfuls',
#  '杰': 'hero',
#  '東': 'east',
#  '杲': 'clear',
#  '杳': 'darkness',
#  '杵': 'wooden pestle',
#  '杷': 'kind of rake',
#  '杼': 'shuttle',
#  '松': 'pine tree',
#  '板': 'plank',
#  '枅': 'rafter',
#  '枇': 'loquat',
#  '枉': 'bend',
#  '枋': 'raft',
#  '枌': 'pine tree',
#  '析': 'chop',
#  '枕': 'pillow',
#  '林': 'grove',
#  '枚': 'sheet of...',
#  '果': 'fruit',
#  '枝': 'bough',
#  '枠': 'frame',
#  '枡': 'measuring box',
#  '枢': 'hinge',
#  '枦': 'wax tree',
#  '枩': 'pine tree',
#  '枯': 'wither',
#  '枳': 'trifoliate orange tree',
#  '枴': 'cane',
#  '架': 'erect',
#  '枷': 'shackles',
#  '枸': 'quince tree',
#  '枹': 'gong stick',
#  '柁': 'rudder',
#  '柄': 'design',
#  '柆': 'bent tree',
#  '柊': 'holly',
#  '柎': 'raft',
#  '柏': 'oak',
#  '某': 'so-and-so',
#  '柑': 'citrus',
#  '染': 'dye',
#  '柔': 'tender',
#  '柘': 'wild mulberry',
#  '柚': 'citron',
#  '柝': 'sounding sticks',
#  '柞': 'type of oak',
#  '柢': 'root',
#  '柤': 'railing',
#  '柧': 'corner',
#  '柩': 'bier',
#  '柬': 'select',
#  '柮': 'to cut',
#  '柯': 'handle',
#  '柱': 'pillar',
#  '柳': 'willow',
#  '柴': 'brush',
#  '柵': 'stockade',
#  '査': 'investigate',
#  '柾': 'straight grain',
#  '柿': 'persimmon',
#  '栂': 'hemlock',
#  '栃': 'horse chestnut',
#  '栄': 'flourish',
#  '栓': 'plug',
#  '栖': 'nest',
#  '栗': 'chestnut',
#  '栞': 'bookmark',
#  '校': 'exam',
#  '栢': 'oak',
#  '栩': 'type of oak',
#  '株': 'stocks',
#  '栫': 'weir',
#  '栲': 'sumac',
#  '栴': 'maple tree',
#  '核': 'nucleus',
#  '根': 'root',
#  '格': 'status',
#  '栽': 'plantation',
#  '桀': 'measuring box',
#  '桁': 'beam',
#  '桂': 'Japanese Judas-tree',
#  '桃': 'peach',
#  '框': 'framework',
#  '案': 'plan',
#  '桍': 'type of tree',
#  '桎': 'fetters',
#  '桐': 'paulownia',
#  '桑': 'mulberry',
#  '桓': 'marking post',
#  '桔': 'used in plant names',
#  '桙': 'halberd',
#  '桜': 'cherry',
#  '桝': 'measuring box',
#  '桟': 'scaffold',
#  '档': 'bookshelf',
#  '桧': 'Japanese cypress',
#  '桴': 'drumstick',
#  '桶': 'tub',
#  '桷': 'rafter',
#  '桾': 'type of fruit tree',
#  '桿': 'shield',
#  '梁': 'weir',
#  '梃': 'lever',
#  '梅': 'plum',
#  '梍': 'sickle handle',
#  '梏': 'manacles',
#  '梓': 'catalpa tree',
#  '梔': 'gardenia',
#  '梗': 'for the most part',
#  '梛': 'type of tall evergreen tree',
#  '條': 'article',
#  '梟': 'owl',
#  '梠': 'a kind of quince',
#  '梢': 'treetops',
#  '梦': 'dream',
#  '梧': 'Chinese parasol tree',
#  '梨': 'pear tree',
#  '梭': 'shuttle',
#  '梯': 'ladder',
#  '械': 'contraption',
#  '梱': 'pack',
#  '梳': 'comb (hair)',
#  '梵': 'Sanskrit',
#  '梶': 'sculling oar',
#  '梹': 'areca nut',
#  '梺': 'base of a mountain',
#  '梼': 'block of wood',
#  '棄': 'abandon',
#  '棆': 'camphor tree',
#  '棉': 'cotton',
#  '棊': 'Japanese chess',
#  '棋': 'chess piece',
#  '棍': 'a cane',
#  '棒': 'rod',
#  '棔': 'silk tree',
#  '棕': 'hemp palm',
#  '棗': 'jujube',
#  '棘': 'thorn',
#  '棚': 'shelf',
#  '棟': 'ridgepole',
#  '棠': 'wild pear tree',
#  '棡': 'mast crossbeam',
#  '棣': 'flowering almond',
#  '棧': 'crosspiece',
#  '森': 'forest',
#  '棯': 'type of fruit tree',
#  '棲': 'live',
#  '棹': 'pole a boat',
#  '棺': 'coffin',
#  '椀': 'wooden or lacquered bowl',
#  '椁': 'outer box for a coffin',
#  '椄': 'graft',
#  '椅': 'chair',
#  '椈': 'oak',
#  '椋': 'type of deciduous tree',
#  '椌': 'type of ancient musical instrument',
#  '植': 'plant',
#  '椎': 'chinquapin',
#  '椏': 'crotch of a tree',
#  '椒': 'Japanese pepper tree',
#  '椙': 'Japanese cedar',
#  '椚': 'oak used for charcoal',
#  '椛': 'autumn foliage',
#  '検': 'examination',
#  '椡': 'type of oak',
#  '椢': 'bottom',
#  '椣': 'type of deciduous birch tree',
#  '椥': 'type of evergreen tree',
#  '椦': 'wickerwork',
#  '椨': 'type of evergreen camphor tree',
#  '椪': 'name of a place in India',
#  '椰': 'coconut tree',
#  '椴': 'fir',
#  '椶': 'hemp palm',
#  '椹': 'type of cypress',
#  '椽': 'rafter',
#  '椿': 'camellia',
#  '楊': 'willow',
#  '楓': 'maple',
#  '楔': 'wedge',
#  '楕': 'ellipse',
#  '楙': 'name of plant',
#  '楚': 'whip',
#  '楜': 'pepper',
#  '楝': 'Japanese bead tree',
#  '楞': 'corner',
#  '楠': 'camphor tree',
#  '楡': 'elm',
#  '楢': 'oak',
#  '楪': 'lacquered dish',
#  '楫': 'sculling oar',
#  '業': 'business',
#  '楮': 'paper mulberry',
#  '楯': 'shield',
#  '楳': 'plum',
#  '楴': 'ornamental hairpin',
#  '極': 'poles',
#  '楷': 'square character style',
#  '楸': 'Japanese catalpa',
#  '楹': 'pillar',
#  '楼': 'watchtower',
#  '楽': 'music',
#  '楾': 'container for pouring water',
#  '榁': 'needle juniper',
#  '概': 'outline',
#  '榊': 'sacred Shinto tree',
#  '榎': 'lotus tree',
#  '榑': 'unbarked lumber',
#  '榔': 'betel palm tree',
#  '榕': 'evergreen mulberry',
#  '榛': 'hazelnut',
#  '榜': 'rudder',
#  '榠': 'type of tree',
#  '榧': 'Japanese nutmeg',
#  '榮': 'flourish',
#  '榱': 'rafter',
#  '榲': 'quince',
#  '榴': 'pomegranate',
#  '榻': 'chair',
#  '榾': 'chip (of wood)',
#  '榿': 'alder',
#  '槁': 'die (vegetation)',
#  '槃': 'tub',
#  '槇': 'twig',
#  '槊': 'halberd',
#  '構': 'posture',
#  '槌': 'hammer',
#  '槍': 'spear',
#  '槎': 'raft',
#  '槐': 'type of Japanese pagoda tree',
#  '槓': 'lever',
#  '様': 'Esq.',
#  '槙': 'twig',
#  '槝': 'oak',
#  '槞': 'cage',
#  '槧': 'printed book',
#  '槨': 'outer box for a coffin',
#  '槫': 'hearse',
#  '槭': 'maple tree',
#  '槲': 'oak',
#  '槹': 'well sweep',
#  '槻': 'Zelkova tree',
#  '槽': 'vat',
#  '槿': 'rose of Sharon',
#  '樂': 'music',
#  '樅': 'fir',
#  '樊': 'cage',
#  '樋': 'water pipe',
#  '樌': 'grove',
#  '樒': 'tree whose branches are placed on Buddhist graves',
#  '樓': 'tower',
#  '樔': 'nest',
#  '樗': 'Japanese bead tree',
#  '標': 'signpost',
#  '樛': 'bend',
#  '樞': 'pivot',
#  '樟': 'camphor',
#  '模': 'imitation',
#  '樢': 'type of bird',
#  '樣': 'Esq.',
#  '権': 'authority',
#  '横': 'sideways',
#  '樫': 'evergreen oak',
#  '樮': 'a type of tree',
#  '樵': 'woodcutting',
#  '樶': 'knot in wood',
#  '樸': 'bark of a tree',
#  '樹': 'timber',
#  '樺': 'birch',
#  '樽': 'barrel',
#  '橄': 'olive',
#  '橇': 'sled',
#  '橈': 'oar',
#  '橋': 'bridge',
#  '橘': 'mandarin orange',
#  '橙': 'bitter orange',
#  '機': 'loom',
#  '橡': 'horse chestnut',
#  '橢': 'ellipse',
#  '橦': 'pole',
#  '橲': 'Japanese storax',
#  '橸': 'straight grain',
#  '橿': 'oak',
#  '檀': 'cedar',
#  '檄': 'written appeal',
#  '檍': 'ilex',
#  '檎': 'apple',
#  '檐': 'eaves',
#  '檗': 'Amur or Chinese cork tree',
#  '檜': 'Japanese cypress',
#  '檠': 'straighten a bow',
#  '檢': 'check',
#  '檣': 'mast',
#  '檪': 'oak used for charcoal',
#  '檬': 'lemon tree',
#  '檮': 'stump',
#  '檳': 'betel-nut palm',
#  '檸': 'lemon tree',
#  '檻': 'pen',
#  '櫁': 'Japanese star anise',
#  '櫂': 'oar',
#  '櫃': 'chest',
#  '櫑': 'decorated wine cask',
#  '櫓': 'oar',
#  '櫚': 'kind of quince',
#  '櫛': 'comb',
#  '櫞': 'kind of lemon tree',
#  '櫟': 'oak for charcoal',
#  '櫨': 'wax tree',
#  '櫪': 'manger',
#  '櫺': 'latticework',
#  '櫻': 'cherry',
#  '欄': 'column',
#  '欅': 'keyaki',
#  '權': 'authority',
#  '欒': 'chinaberry tree',
#  '欖': 'Chinese olive tree',
#  '欝': 'gloom',
#  '欟': 'keyaki',
#  '欠': 'lack',
#  '次': 'next',
#  '欣': 'take pleasure in',
#  '欧': 'Europe',
#  '欲': 'longing',
#  '欷': 'cry',
#  '欸': 'exclamation',
#  '欹': "prick up (one's ears)",
#  '欺': 'deceit',
#  '欽': 'respect',
#  '款': 'goodwill',
#  '歃': 'sip',
#  '歇': 'exhausted',
#  '歉': 'insufficiency',
#  '歌': 'song',
#  '歎': 'grief',
#  '歐': 'Europe',
#  '歓': 'delight',
#  '歔': 'cry',
#  '歙': 'come together',
#  '歛': 'tighten',
#  '歟': 'interrogative particle',
#  '歡': 'delight',
#  '正': 'correct',
#  '此': 'this',
#  '武': 'warrior',
#  '歩': 'walk',
#  '歪': 'warp',
#  '歯': 'tooth',
#  '歳': 'year-end',
#  '歴': 'curriculum',
#  '歸': 'homecoming',
#  '死': 'death',
#  '歿': 'die',
#  '殀': 'dying young',
#  '殃': 'misfortune',
#  '殄': 'all',
#  '殆': 'almost',
#  '殉': 'martyrdom',
#  '殊': 'particularly',
#  '残': 'remainder',
#  '殍': 'dying of starvation',
#  '殕': 'grow mouldy',
#  '殖': 'augment',
#  '殘': 'leftover',
#  '殞': 'fall',
#  '殤': 'dying at a young age',
#  '殪': 'die',
#  '殫': 'become exhausted',
#  '殯': 'lying in state',
#  '殱': 'massacre',
#  '殲': 'massacre',
#  '殴': 'assault',
#  '段': 'grade',
#  '殷': 'flourishing',
#  '殺': 'kill',
#  '殻': 'husk',
#  '殼': 'husk',
#  '殿': 'Mr.',
#  '毀': 'break',
#  '毅': 'strong',
#  '毆': 'beat',
#  '毎': 'every',
#  '毒': 'poison',
#  '毓': 'bring up',
#  '毘': 'help',
#  '毟': 'pluck',
#  '毫': 'fine hair',
#  '毬': 'burr',
#  '毯': 'wool rug',
#  '毳': 'nap',
#  '氈': 'woollen cloth or rug',
#  '民': 'people',
#  '氓': 'people',
#  '気': 'spirit',
#  '氛': 'air',
#  '氣': 'spirit',
#  '氤': 'spirited',
#  '氷': 'icicle',
#  '永': 'eternity',
#  '氾': 'spread out',
#  '汀': "water's edge",
#  '汁': 'soup',
#  '求': 'request',
#  '汎': 'pan-',
#  '汐': 'eventide',
#  '汕': 'fish swimming',
#  '汗': 'sweat',
#  '汚': 'dirty',
#  '汝': 'you',
#  '汞': 'mercury',
#  '江': 'creek',
#  '池': 'pond',
#  '汢': 'wetland',
#  '汨': 'to sink',
#  '汪': 'flowing full',
#  '汰': 'washing',
#  '汲': 'draw (water)',
#  '汳': 'proper name',
#  '決': 'decide',
#  '汽': 'vapor',
#  '汾': 'name of a Chinese river',
#  '沁': 'penetrate',
#  '沂': 'name of a Chinese river',
#  '沃': 'fertility',
#  '沈': 'sink',
#  '沌': 'primeval chaos',
#  '沍': 'close up',
#  '沐': 'wash',
#  '沒': 'not',
#  '沓': 'shoes',
#  '沖': 'open sea',
#  '沙': 'sand',
#  '沚': 'shore',
#  '沛': 'big rain',
#  '没': 'drown',
#  '沢': 'swamp',
#  '沫': 'splash',
#  '沮': 'stop',
#  '沱': 'flowing of tears',
#  '河': 'river',
#  '沸': 'seethe',
#  '油': 'oil',
#  '沺': 'vast surging waters',
#  '治': 'reign',
#  '沼': 'marsh',
#  '沽': 'price',
#  '沾': 'moisten',
#  '沿': 'run alongside',
#  '況': 'condition',
#  '泄': 'leak',
#  '泅': 'swim',
#  '泉': 'spring',
#  '泊': 'overnight stay',
#  '泌': 'ooze',
#  '泓': 'deep clear water',
#  '法': 'method',
#  '泗': 'name of a Chinese river',
#  '泙': 'surging water',
#  '泛': 'to drift',
#  '泝': 'go upstream',
#  '泡': 'bubbles',
#  '波': 'waves',
#  '泣': 'cry',
#  '泥': 'mud',
#  '注': 'pour',
#  '泪': 'tears',
#  '泯': 'die out',
#  '泰': 'peaceful',
#  '泱': 'billowy clouds',
#  '泳': 'swim',
#  '洋': 'ocean',
#  '洌': 'pure',
#  '洒': 'wash',
#  '洗': 'wash',
#  '洙': 'name of a Chinese river',
#  '洛': 'Kyoto',
#  '洞': 'den',
#  '洟': 'tear',
#  '津': 'haven',
#  '洩': 'leak',
#  '洪': 'deluge',
#  '洫': 'ditch',
#  '洲': 'continent',
#  '洳': 'wet',
#  '洵': 'alike',
#  '洶': 'gush forth',
#  '洸': 'sparkling water',
#  '活': 'lively',
#  '洽': 'far and wide',
#  '派': 'faction',
#  '流': 'current',
#  '浄': 'clean',
#  '浅': 'shallow',
#  '浙': 'name of a Chinese river',
#  '浚': 'dredge',
#  '浜': 'seacoast',
#  '浣': 'wash',
#  '浤': 'rising waters',
#  '浦': 'bay',
#  '浩': 'wide expanse',
#  '浪': 'wandering',
# ...
#  '鄰': 'neighbor',
#  '鄲': 'place name',
#  '酊': 'intoxication',
#  '酋': 'chieftain',
#  '酌': 'bar-tending',
#  '配': 'distribute',
#  '酎': 'sake',
#  '酒': 'sake',
#  '酔': 'drunk',
#  '酖': 'addiction',
#  '酘': 'rebrew',
#  '酢': 'vinegar',
#  '酣': 'height of',
#  '酥': 'milk',
#  '酩': 'sweet sake',
#  '酪': 'dairy products',
#  '酬': 'repay',
#  '酲': 'hangover',
#  '酳': 'drunken babbling',
#  '酵': 'fermentation',
#  '酷': 'cruel',
#  '酸': 'acid',
#  '醂': 'remove astringency',
#  '醇': "pure sake'",
#  '醉': 'get drunk',
#  '醋': 'vinegar',
#  '醍': 'whey',
#  '醐': 'boiled butter',
#  '醒': 'awake',
#  '醗': 'fermentation',
#  '醜': 'ugly',
#  '醢': 'salted meat',
#  '醤': 'a kind of miso',
#  '醪': 'unrefined sake or shoyu',
#  '醫': 'medicine',
#  '醯': 'vinegar',
#  '醴': 'sweet sake',
#  '醵': 'contribution for a feast (potluck)',
#  '醸': 'brew',
#  '醺': 'hunger',
#  '釀': 'brew',
#  '釁': 'smear with blood',
#  '釆': 'separate',
#  '采': 'dice',
#  '釈': 'explanation',
#  '釉': 'glaze',
#  '釋': 'explain',
#  '重': 'heavy',
#  '野': 'plains',
#  '量': 'quantity',
#  '釐': 'few',
#  '釖': 'knife',
#  '釘': 'nail',
#  '釛': 'gold',
#  '釜': 'kettle',
#  '針': 'needle',
#  '釟': 'forge',
#  '釡': 'kettle',
#  '釣': 'angling',
#  '釦': 'button',
#  '釧': 'bracelet',
#  '釵': 'ornamental hairpin',
#  '釶': 'halberd',
#  '釼': 'sword',
#  '釿': 'hatchet',
#  '鈍': 'dull',
#  '鈎': 'hook',
#  '鈑': 'sheet metal',
#  '鈔': 'selection',
#  '鈕': 'button',
#  '鈞': 'equal',
#  '鈩': 'hearth',
#  '鈬': 'bell',
#  '鈴': 'small bell',
#  '鈷': 'cobalt',
#  '鈿': 'ornamental hairpiece',
#  '鉄': 'iron',
#  '鉅': 'big',
#  '鉈': 'hatchet',
#  '鉉': 'handle',
#  '鉋': "carpenter's plane",
#  '鉐': 'brass',
#  '鉗': 'shut up',
#  '鉚': 'gold',
#  '鉛': 'lead',
#  '鉞': 'battleaxe',
#  '鉢': 'bowl',
#  '鉤': 'hook',
#  '鉦': 'bell',
#  '鉱': 'mineral',
#  '鉾': 'halberd',
#  '銀': 'silver',
#  '銃': 'gun',
#  '銅': 'copper',
#  '銑': 'pig iron',
#  '銓': 'measure',
#  '銕': 'iron',
#  '銖': 'measuring unit, 1/16 of a ryou',
#  '銘': 'inscription',
#  '銚': 'sake bottle',
#  '銛': 'harpoon',
#  '銜': "horse's bit",
#  '銭': 'coin',
#  '銷': 'erase',
#  '銹': 'rust',
#  '鋏': 'scissors',
#  '鋒': 'dagger',
#  '鋤': 'spade up',
#  '鋩': 'sword point',
#  '鋪': 'shop',
#  '鋭': 'pointed',
#  '鋲': 'rivet',
#  '鋳': 'casting',
#  '鋸': 'saw (cuts wood)',
#  '鋺': 'metal bowl',
#  '鋼': 'steel',
#  '錆': 'rust',
#  '錏': 'armour havelock',
#  '錐': 'auger',
#  '錘': 'weight',
#  '錙': 'unit of weight',
#  '錚': 'gong',
#  '錠': 'lock',
#  '錢': '100th of yen',
#  '錣': 'armor neckplates',
#  '錦': 'brocade',
#  '錨': 'anchor',
#  '錫': 'copper',
#  '錬': 'tempering',
#  '錮': 'confinement',
#  '錯': 'confused',
#  '録': 'record',
#  '錵': 'holmium',
#  '錺': 'metal jewelry',
#  '錻': 'tin plate',
#  '鍄': 'kind of percussion instrument',
#  '鍋': 'pot',
#  '鍍': 'plating',
#  '鍔': 'sword guard',
#  '鍖': 'unsatisfactory',
#  '鍛': 'forge',
#  '鍜': 'armour neck plates',
#  '鍠': 'sound of bells and drums',
#  '鍬': 'hoe with long blade at acute angle',
#  '鍮': 'brass',
#  '鍵': 'key',
#  '鍼': 'needle',
#  '鍾': 'spindle',
#  '鎌': 'sickle',
#  '鎔': 'fuse',
#  '鎖': 'chain',
#  '鎗': 'spear',
#  '鎚': 'hammer',
#  '鎧': 'put on armor',
#  '鎬': 'sword-blade ridges',
#  '鎭': 'ancient peace-preservation centers',
#  '鎮': 'tranquilize',
#  '鎰': 'unit of weight',
#  '鎹': 'clamp',
#  '鏃': 'arrowhead',
#  '鏈': 'chain',
#  '鏐': 'gold',
#  '鏑': 'arrowhead',
#  '鏖': 'massacre',
#  '鏗': 'clinking sound',
#  '鏘': 'tinkling of jade or metal pendants',
#  '鏝': 'soldering iron',
#  '鏡': 'mirror',
#  '鏤': 'inlay',
#  '鏥': 'rust',
#  '鏨': 'cold chisel',
#  '鐃': 'gong',
#  '鐇': 'hatchet',
#  '鐐': 'silver',
#  '鐓': 'ferrule',
#  '鐔': 'sword guard',
#  '鐘': 'bell',
#  '鐙': 'stirrup',
#  '鐚': 'coin of smallest value',
#  '鐡': 'iron',
#  '鐫': 'carve',
#  '鐵': 'iron',
#  '鐶': 'metal ring',
#  '鐸': 'large hand bell',
#  '鐺': 'chain',
#  '鑁': 'name',
#  '鑄': 'cast',
#  '鑑': 'specimen',
#  '鑒': 'take warning from',
#  '鑓': 'spear',
#  '鑚': 'make fire by rubbing sticks',
#  '鑛': 'ore',
#  '鑞': 'solder',
#  '鑠': 'melt',
#  '鑢': 'file',
#  '鑪': 'hearth',
#  '鑰': 'lock',
#  '鑵': 'steam boiler',
#  '鑷': 'pluck hair',
#  '鑼': 'gong',
#  '鑽': 'make fire by rubbing sticks',
#  '鑾': "bells on emperor's carriage",
#  '鑿': 'chisel',
#  '钁': 'hoe',
#  '閂': 'gate bar',
#  '閃': 'flash',
#  '閇': 'shut',
#  '閉': 'closed',
#  '閊': 'to be obstructed',
#  '開': 'open',
#  '閏': 'intercalation',
#  '閑': 'leisure',
#  '間': 'interval',
#  '閔': 'grieve',
#  '閖': 'shake while rinsing',
#  '閘': 'water gate',
#  '閙': 'noisy',
#  '閠': 'intercalation',
#  '関': 'connection',
#  '閣': 'tower',
#  '閤': 'small side gate',
#  '閥': 'clique',
#  '閧': 'war cry',
#  '閨': 'bedroom',
#  '閭': 'rural area',
#  '閲': 'review',
#  '閹': 'eunuch',
#  '閻': 'town',
#  '閼': 'obstruct',
#  '閾': 'threshold',
#  '闃': 'quiet',
#  '闇': 'get dark',
#  '闊': 'wide',
#  '闌': 'rise high',
#  '闍': 'watchtower',
#  '闔': 'doors',
#  '闕': 'lack',
#  '闖': 'inquire about',
#  '闘': 'fight',
#  '關': 'connection',
#  '闡': 'clarify',
#  '闢': 'open',
#  '闥': 'gate',
#  '阜': 'hill',
#  '阡': 'thousand',
#  '阨': 'obstruct',
#  '阪': 'heights',
#  '阮': 'place name',
#  '阯': 'foundation',
#  '防': 'ward off',
#  '阻': 'thwart',
#  '阿': 'Africa',
#  '陀': 'steep',
#  '陂': 'levee',
#  '附': 'affixed',
#  '陋': 'narrowness',
#  '陌': 'east-west path between paddies',
#  '降': 'descend',
#  '陏': 'melon',
#  '限': 'limit',
#  '陛': 'highness',
#  '陜': 'narrow',
#  '陝': 'place name',
#  '陞': 'go up',
#  '陟': 'climb',
#  '院': 'Inst.',
#  '陣': 'camp',
#  '除': 'exclude',
#  '陥': 'collapse',
#  '陦': 'island',
#  '陪': 'obeisance',
#  '陬': 'corner',
#  '陰': 'shade',
#  '陲': 'boundary',
#  '陳': 'exhibit',
#  '陵': 'mausoleum',
#  '陶': 'pottery',
#  '陷': 'fall into',
#  '陸': 'land',
#  '険': 'precipitous',
#  '陽': 'sunshine',
#  '隅': 'corner',
#  '隆': 'hump',
#  '隈': 'corner',
#  '隊': 'regiment',
#  '隋': 'name of a Chinese dynasty',
#  '隍': 'dry moat',
#  '階': 'storey',
#  '随': 'follow',
#  '隔': 'isolate',
#  '隕': 'fall',
#  '隗': 'high',
#  '隘': 'narrow',
#  '隙': 'crevice',
#  '際': 'occasion',
#  '障': 'hinder',
#  '隠': 'conceal',
#  '隣': 'neighboring',
#  '隧': 'fall',
#  '隨': 'at the mercy of (the waves)',
#  '險': 'inaccessible place',
#  '隰': 'be moist',
#  '隱': 'hide',
#  '隲': 'stallion',
#  '隴': 'hill',
#  '隶': 'extend',
#  '隷': 'slave',
#  '隸': 'servant',
#  '隻': 'vessels',
#  '隼': 'falcon',
#  '雀': 'sparrow',
#  '雁': 'wild goose',
#  '雄': 'masculine',
#  '雅': 'gracious',
#  '集': 'gather',
#  '雇': 'employ',
#  '雉': 'pheasant',
#  '雋': 'excel',
#  '雌': 'feminine',
#  '雍': 'softening',
#  '雎': 'osprey',
#  '雑': 'miscellaneous',
#  '雕': 'carving',
#  '雖': 'although',
#  '雙': 'pair',
#  '雛': 'chick',
#  '雜': 'mixed',
#  '離': 'detach',
#  '難': 'difficult',
#  '雪': 'snow',
#  '雫': 'drop',
#  '雰': 'atmosphere',
#  '雲': 'cloud',
#  '零': 'zero',
#  '雷': 'thunder',
#  '雹': 'hail',
#  '電': 'electricity',
#  '需': 'demand',
#  '霄': 'sky',
#  '霆': 'lightning',
#  '震': 'quake',
#  '霈': 'big rain',
#  '霊': 'spirits',
#  '霍': 'quick',
#  '霎': 'light rain',
#  '霏': 'falling rain or snow',
#  '霑': 'moisten',
#  '霓': 'rainbow',
#  '霖': 'long rainy spell',
#  '霙': 'sleet',
#  '霜': 'frost',
#  '霞': 'be hazy',
#  '霤': 'raindrops falling from the eaves',
#  '霧': 'fog',
#  '霪': 'rain lasting at least ten days',
#  '霰': 'hail',
#  '露': 'dew',
#  '霸': 'supremacy',
#  '霹': 'thunder',
#  '霽': 'clear up',
#  '霾': 'wind-blown dust falling like rain',
#  '靂': 'violent',
#  '靄': 'mist',
#  '靆': 'cloud cover',
#  '靈': 'soul',
#  '靉': 'clouds',
#  '青': 'blue',
#  '靖': 'peaceful',
#  '静': 'quiet',
#  '靜': 'quiet',
#  '靠': 'lean on',
#  '靡': 'flutter',
#  '靤': 'pimple',
#  '靦': 'unashamed',
#  '靨': 'dimple',
#  '革': 'leather',
#  '靫': 'quiver',
#  '靭': 'soft',
#  '靱': 'soft',
#  '靴': 'shoes',
#  '靹': "archer's arm protector",
#  '靺': 'leather tabi',
#  '靼': 'tanned leather',
#  '鞁': 'reins',
#  '鞄': 'suitcase',
#  '鞅': 'martingale',
#  '鞆': "archer's arm protector",
#  '鞋': 'straw sandals',
#  '鞍': 'saddle',
#  '鞏': 'hard',
#  '鞐': 'clamp',
#  '鞘': 'sheath',
#  '鞜': 'shoes',
#  '鞠': 'ball',
#  '鞣': 'tanned leather',
#  '鞦': 'swing',
#  '鞨': 'leather boots',
#  '鞫': 'investigate a crime',
#  '鞭': 'whip',
#  '鞳': 'rumbling',
#  '鞴': 'bellows',
#  '韃': 'whip',
#  '韆': 'swing',
#  '韈': 'tabi',
#  '韋': 'tanned leather radical (no. 178)',
#  '韓': 'Korea',
#  '韜': 'bag',
#  '韮': 'leek',
#  '韲': 'dress (salad) vegetables',
#  '音': 'sound',
#  '韵': 'rhyme',
#  '韶': 'beautiful',
#  '韻': 'rhyme',
#  '響': 'echo',
#  '頁': 'page',
#  '頂': 'place on the head',
#  '頃': 'time',
#  '項': 'paragraph',
#  '順': 'obey',
#  '須': 'ought',
#  '頌': 'eulogy',
#  '頏': 'alight',
#  '預': 'deposit',
#  '頑': 'stubborn',
#  '頒': 'distribute',
#  '頓': 'suddenly',
#  '頗': 'prejudiced',
#  '領': 'jurisdiction',
#  '頚': 'neck',
#  '頡': 'take wing',
#  '頤': 'chin',
#  '頬': 'cheeks',
#  '頭': 'head',
#  '頴': 'heads of grain',
#  '頷': 'nod approval',
#  '頸': 'neck',
#  '頻': 'repeatedly',
#  '頼': 'trust',
#  '頽': 'decline',
#  '顆': 'grain (e.g. rice)',
#  '顋': 'lower part of face',
#  '題': 'topic',
#  '額': 'forehead',
#  '顎': 'jaw',
#  '顏': 'face',
#  '顔': 'face',
#  '顕': 'appear',
#  '願': 'petition',
#  '顛': 'overturn',
#  '類': 'sort',
#  '顧': 'look back',
#  '顫': 'shudder',
#  '顯': 'manifest',
#  '顰': 'scowl',
#  '顱': 'head',
#  '顳': 'temple (of head)',
#  '顴': 'cheekbone',
#  '風': 'wind',
#  '颪': 'wind from mountains',
#  '颯': 'sudden',
#  '颱': 'typhoon',
#  '颶': 'storm',
#  '飃': 'whirlwind',
#  '飄': 'turn over',
#  '飆': 'whirlwind',
#  '飜': 'flip over',
#  '飢': 'hungry',
#  '飩': 'Japanese noodles',
#  '飫': 'satiety',
#  '飭': 'correct',
#  '飮': 'drink',
#  '飯': 'meal',
#  '飲': 'drink',
#  '飴': 'rice jelly',
#  '飼': 'domesticate',
#  '飽': 'sated',
#  '飾': 'decorate',
#  '餃': 'gyoza',
#  '餅': 'mochi rice cake',
#  '餉': '(dried) boiled rice',
#  '養': 'foster',
#  '餌': 'food',
#  '餐': 'eat',
#  '餒': 'hunger',
#  '餓': 'starve',
#  '餔': 'eat',
#  '餘': 'surplus',
#  '餝': 'decorate',
#  '餞': 'farewell gift',
#  '餠': 'rice cake',
#  '餡': 'bean jam',
#  '餤': 'eat',
#  '館': 'building',
#  '餬': 'rice broth',
#  '餮': 'voracious',
#  '餽': 'give',
#  '餾': 'steaming rice',
#  '饂': 'Japanese noodles',
#  '饅': 'bean-jam dumpling',
#  '饉': 'hunger',
#  '饋': 'give',
#  '饌': 'food',
#  '饐': 'go bad',
#  '饑': 'hunger',
#  '饒': 'abundant',
#  '饕': 'be greedy',
#  '饗': 'banquet',
#  '首': 'neck',
#  '馗': 'road',
#  '馘': 'behead',
#  '香': 'incense',
#  '馥': 'perfume',
#  '馨': 'fragrant',
#  '馭': 'driving (horse)',
#  '馮': 'displeasure',
#  '馳': 'run',
#  '馴': 'get used to',
#  '馼': 'zebra with yellow eyes and red mane',
#  '駁': 'refutation',
#  '駄': 'burdensome',
#  '駅': 'station',
#  '駆': 'drive',
#  '駈': 'run',
#  '駐': 'stop-over',
#  '駑': 'slow horse',
#  '駒': 'pony',
#  '駕': 'vehicle',
#  '駘': 'stupid',
#  '駛': 'run fast',
#  '駝': 'hunchback',
#  '駟': 'four horses',
#  '駢': 'two-horse carriage',
#  '駭': 'be surprised',
#  '駮': 'spots',
#  '駱': 'white horse',
#  '駲': "horse's buttocks",
#  '駸': 'speed',
#  '駻': 'rage',
#  '駿': 'a good horse',
#  '騁': 'run fast',
#  '騅': 'grey horse',
#  '騎': 'equestrian',
#  '騏': 'fast horse',
#  '騒': 'boisterous',
#  '験': 'verification',
#  '騙': 'deceive',
#  '騨': 'dappled grey horse',
#  '騫': 'lift up',
#  '騰': 'leaping up',
#  '騷': 'harass',
#  '騾': 'mule',
#  '驀': 'going straight forward',
#  '驂': 'extra driver or horse',
#  '驃': 'white horse',
#  '驅': 'spur a horse on',
#  '驍': 'strong',
#  '驕': 'pride',
#  '驗': 'verification',
#  '驚': 'wonder',
#  '驛': 'station',
#  '驟': 'run',
#  '驢': 'donkey',
#  '驤': "lift one's head",
#  '驥': 'fast horse',
#  '驩': 'greetings',
#  '驪': 'black horse',
#  '驫': 'many horses',
#  '骨': 'skeleton',
#  '骭': 'leg',
#  '骰': 'dice',
#  '骸': 'bone',
#  '骼': 'bleached bones',
#  '髀': 'thigh',
#  '髄': 'marrow',
#  '髏': 'skull',
#  '髑': 'skull',
#  '髓': 'marrow',
#  '體': 'the body',
#  '高': 'tall',
#  '髞': 'hurry',
#  '髟': 'hair hanging long',
#  '髢': 'wig',
#  '髣': 'dimly',
#  '髦': 'bangs',
#  '髪': 'hair of the head',
#  '髫': "children's long hair",
#  '髭': 'beard',
#  '髮': 'hair',
#  '髯': 'beard',
#  '髱': 'topknot',
#  '髴': 'dimly',
#  '髷': 'topknot',
#  '髻': 'samurai topknot',
#  '鬆': 'loose',
#  '鬘': 'wig',
#  '鬚': 'beard',
#  '鬟': 'topknot',
#  '鬢': 'sideburns',
#  '鬣': 'mane',
#  '鬧': 'quarrel',
#  '鬨': 'fight',
#  '鬩': 'quarrel',
#  '鬪': 'fighting',
#  '鬮': 'lottery',
#  '鬯': 'fragrant herbs',
#  '鬱': 'gloom',
#  '鬲': 'tripod',
#  '鬻': 'sell',
#  '鬼': 'ghost',
#  '魁': 'charging ahead of others',
#  '魂': 'soul',
#  '魃': '(god of) drought',
#  '魄': 'soul',
#  '魅': 'fascination',
#  '魍': 'spirits of mountains and streams',
#  '魎': 'spirits of trees and rocks',
#  '魏': 'high',
#  '魑': 'mountain spirits',
#  '魔': 'witch',
#  '魘': 'have a nightmare',
#  '魚': 'fish',
#  '魯': 'foolish',
#  '魴': 'type of sea bream',
#  '鮃': 'flounder',
#  '鮎': 'freshwater trout',
#  '鮑': 'abalone',
#  '鮒': 'carp',
#  '鮓': 'sushi',
#  '鮖': 'bullhead',
#  '鮗': 'gizzard shad',
#  '鮟': 'angler-fish',
#  '鮠': 'dace (carp)',
#  '鮨': 'sushi',
#  '鮪': 'tuna',
#  '鮫': 'shark',
#  '鮭': 'salmon',
#  '鮮': 'fresh',
#  '鮴': 'bullhead',
#  '鮹': 'octopus',
#  '鯀': 'large mythical fish',
#  '鯆': 'type of herring',
#  '鯉': 'carp',
#  '鯊': 'goby (fish)',
#  '鯏': 'short necked clam',
#  '鯑': 'yellow fish (herring) eggs (sushi)',
#  '鯒': 'flathead (fish)',
#  '鯔': 'mullet (fish)',
#  '鯖': 'mackerel',
#  '鯛': 'sea bream',
#  '鯡': 'herring',
#  '鯢': 'salamander',
#  '鯣': 'cuttlefish',
#  '鯤': 'large mythical fish',
#  '鯨': 'whale',
#  '鯰': 'fresh-water catfish',
#  '鯱': 'fabulous dolphin-like fish',
#  '鯲': 'loach',
#  '鯵': 'horse mackerel',
#  '鰄': 'a type of fish',
#  '鰆': 'Spanish mackerel',
#  '鰈': 'sole',
#  '鰉': 'sturgeon',
#  '鰊': 'herring',
#  '鰌': 'loach (fish)',
#  '鰍': 'bullhead',
#  '鰐': 'alligator',
#  '鰒': 'abalone',
#  '鰓': 'gills',
#  '鰔': 'flatfish',
#  '鰕': 'shrimp',
#  '鰛': 'sardine',
#  '鰡': 'type of fish',
#  '鰤': 'yellowtail',
#  '鰥': 'widower',
#  '鰭': 'fin',
#  '鰮': 'sardine',
#  '鰯': 'sardine',
#  '鰰': 'sandfish',
#  '鰲': 'huge sea turtle',
#  '鰹': 'bonito',
#  '鰺': 'horse mackerel',
#  '鰻': 'eel',
#  '鰾': 'fish bladder',
#  '鱆': 'octopus',
#  '鱇': 'anglerfish',
#  '鱈': 'codfish',
#  '鱒': 'salmon trout',
#  '鱗': 'scales (fish)',
#  '鱚': 'sillaginoid',
#  '鱠': 'lizard fish',
#  '鱧': 'conger',
#  '鱶': 'shark',
#  '鱸': 'sea bass',
#  '鳥': 'bird',
#  '鳧': 'wild duck',
#  '鳩': 'pigeon',
#  '鳫': 'wild goose',
#  '鳬': 'wild duck',
#  '鳰': 'grebe',
#  '鳳': 'male mythical bird',
#  '鳴': 'chirp',
#  '鳶': 'black kite',
#  '鴃': 'shrike',
#  '鴆': 'a poisonous Chinese bird',
#  '鴇': 'wild goose',
#  '鴈': 'wild goose',
#  '鴉': 'crow',
#  '鴎': 'seagull',
#  '鴒': 'wagtail',
#  '鴕': 'Chinese ostrich',
#  '鴛': 'male mandarin duck',
#  '鴟': 'kite',
#  '鴣': 'partridge',
#  '鴦': 'female mandarin duck',
#  '鴨': 'wild duck',
#  '鴪': 'flying fast',
#  '鴫': 'snipe',
#  '鴬': 'nightingale',
#  '鴻': 'large bird',
#  '鴾': 'crested ibis',
#  '鴿': 'dove',
#  '鵁': 'night heron',
#  '鵄': 'kite',
#  '鵆': 'plover',
#  '鵈': 'kite (bird)',
#  '鵐': 'unmottled quail',
#  '鵑': 'cuckoo',
#  '鵙': 'shrike',
#  '鵜': 'cormorant',
#  '鵝': 'goose',
#  '鵞': 'goose',
#  '鵠': 'swan',
#  '鵡': 'cockatoo',
#  '鵤': 'grosbeak',
#  '鵬': 'phoenix',
#  '鵯': 'brown eared bulbul',
#  '鵲': 'magpie',
#  '鵺': 'fabulous night bird',
#  '鶇': 'thrush',
#  '鶉': 'quail',
#  '鶏': 'chicken',
#  '鶚': 'osprey',
#  '鶤': 'type of black songbird',
#  '鶩': 'domestic duck',
#  '鶫': 'thrush',
#  '鶯': 'nightingale',
#  '鶲': 'crested flycatcher',
#  '鶴': 'crane',
#  '鶸': 'siskin',
#  '鶺': 'wagtail',
#  '鶻': 'falcon',
#  '鷁': 'waterfowl which flies high but not against the wind',
#  '鷂': 'sparrow hawk',
#  '鷄': 'chicken',
#  '鷆': 'yellow-white mottled songbird',
#  '鷏': 'yellow-white mottled songbird',
#  '鷓': 'partridge',
#  '鷙': 'bird of prey',
#  '鷦': 'wren',
#  '鷭': 'water hen',
#  '鷯': 'wren',
#  '鷲': 'eagle',
#  '鷸': 'kingfisher',
#  '鷹': 'hawk',
#  '鷺': 'heron',
#  '鷽': 'long-tailed bird',
#  '鸚': 'parrot',
#  '鸛': 'Japanese stork',
#  '鸞': 'fabulous mythical bird',
#  '鹵': 'salt',
#  '鹸': 'saltiness',
#  '鹹': 'salty',
#  '鹽': 'salt',
#  '鹿': 'deer',
#  '麁': 'rough',
#  '麈': 'moose',
#  '麋': 'reindeer',
#  '麌': 'stag',
#  '麑': 'fawn',
#  '麒': 'Chinese unicorn',
#  '麓': 'foot of a mountain',
#  '麕': 'roe deer',
#  '麗': 'lovely',
#  '麝': 'musk deer',
#  '麟': 'Chinese unicorn',
#  '麥': 'wheat',
#  '麦': 'barley',
#  '麩': 'light wheat-gluten bread',
#  '麪': 'noodles',
#  '麭': 'sticky rice ball',
#  '麸': 'light wheat-gluten bread',
#  '麹': 'malt',
#  '麺': 'noodles',
#  '麻': 'hemp',
#  '麼': 'rope',
#  '麾': 'beckon to',
#  '麿': 'I',
#  '黄': 'yellow',
#  '黌': 'school',
#  '黍': 'millet',
#  '黎': 'dark',
#  '黏': 'stick to',
#  '黐': 'bird-lime',
#  '黒': 'black',
#  '黔': 'black',
#  '默': 'silent',
#  '黙': 'silence',
#  '黛': 'blackened eyebrows',
#  '黜': 'draw back',
#  '黝': 'black',
#  '點': 'point',
#  '黠': 'crafty',
#  '黥': 'tatooing',
#  '黨': 'party',
#  '黯': 'black',
#  '黴': 'mold',
#  '黶': 'mole',
#  '黷': 'make dirty',
#  '黹': 'sewing radical (no. 204)',
#  '黻': 'lap robe',
#  '黼': 'embroidery',
#  '鼇': 'great sea turtle',
#  '鼈': 'snapping turtle',
#  '鼎': 'three legged kettle',
#  '鼓': 'drum',
#  '鼕': 'beating of drums',
#  '鼠': 'rat',
#  '鼡': 'rat',
#  '鼬': 'weasel',
#  '鼻': 'nose',
#  '鼾': 'snoring',
#  '齋': 'Buddhist food',
#  '齎': 'bring',
#  '齏': 'dishes seasoned with vinegar or miso',
#  '齒': 'tooth',
#  '齔': 'losing baby teeth',
#  '齟': 'uneven',
#  '齠': 'baby teeth',
#  '齡': 'age',
#  '齢': 'age',
#  '齣': 'a paragraph',
#  '齦': 'gums',
#  '齧': 'gnaw',
#  '齪': 'grating the teeth',
#  '齬': 'irregular teeth',
#  '齲': 'decayed tooth',
#  '齶': 'jaw',
#  '齷': 'grating the teeth',
#  '龍': 'dragon',
#  '龕': 'alcove for an image',
#  '龝': 'autumn',
#  '龠': 'flute'}

# %%
def handle_csv_radical_func(data, row):
    radical,meaning,_ = row
    data[radical] = meaning

# %%
data_radical = get_csv_data("dataset/s7_nodes_radical_meaning.csv", handle_csv_radical_func)
print("len(data_radical) = ", len(data_radical))
pp(data_radical)
# Out:
# len(data_radical) =  255
# {'.阝': 'right village',
#  'マ': 'kana ma',
#  'ユ': 'kana yu',
#  '世': 'generation',
#  '个': 'human roof (top)',
#  '丶': 'dot',
#  '丷': 'eight-head',
#  '丿': 'kana no',
#  '乃': 'from',
#  '久': 'long time',
#  '乙': 'fish hook',
#  '九': 'nine',
#  '也': 'to be',
#  '亅': 'feathered stick',
#  '二': 'two',
#  '五': 'five',
#  '井': 'well',
#  '亠': 'lid',
#  '亡': 'deceased',
#  '人': 'person',
#  '亻': 'person',
#  '儿': 'human legs',
#  '元': 'beginning',
#  '免': 'excuse',
#  '入': 'enter',
#  '八': 'eight',
#  '冂': 'upside down box',
#  '冊': 'tome',
#  '冖': 'crown shaped wa',
#  '冫': 'ice',
#  '几': 'table',
#  '凵': 'open box',
#  '刀': 'sword',
#  '刂': 'sword',
#  '力': 'strong',
#  '勹': 'wrapping',
#  '勿': 'not',
#  '匕': 'spoon',
#  '匚': 'sideways box',
#  '匸': 'hiding',
#  '十': 'cross',
#  '卜': 'divining rod',
#  '卩': 'seal',
#  '厂': 'cliff',
#  '厶': 'myself',
#  '又': 'again',
#  '及': 'reach out',
#  '口': 'mouth',
#  '品': 'goods',
#  '啇': 'antique',
#  '囗': 'box',
#  '土': 'earth',
#  '士': 'samurai',
#  '夂': 'winter',
#  '夊': 'go slowly',
#  '夕': 'evening',
#  '大': 'big',
#  '奄': 'cover',
#  '女': 'woman',
#  '子': 'child',
#  '宀': 'crown',
#  '寸': 'inch',
#  '小': 'little',
#  '尚': 'small (top)',
#  '尢': 'crooked leg',
#  '尤': 'reasonable',
#  '尸': 'flag',
#  '屮': 'old grass',
#  '屯': 'barracks',
#  '山': 'mountain',
#  '岡': 'mount',
#  '巛': 'crooked river',
#  '工': 'craft',
#  '巨': 'gigantic',
#  '己': 'snake',
#  '巴': 'comma-design',
#  '巾': 'cloth',
#  '干': 'dry',
#  '幺': 'short thread',
#  '广': 'dotted cliff',
#  '廴': 'long stride',
#  '廾': 'twenty legs',
#  '弋': 'ceremony',
#  '弓': 'bow',
#  '彐': 'pig head',
#  '彑': 'pig head',
#  '彡': 'short hair',
#  '彳': 'going man',
#  '心': 'heart',
#  '忄': 'heart',
#  '戈': 'tasseled spear',
#  '戸': 'door',
#  '手': 'hand',
#  '扌': 'hand',
#  '支': 'branch',
#  '攴': 'folding chair',
#  '文': 'sentence',
#  '斗': 'dipper',
#  '斤': 'axe',
#  '方': 'direction',
#  '无': 'crooked heaven',
#  '日': 'sun',
#  '曰': 'flat sun',
#  '月': 'moon',
#  '木': 'tree',
#  '欠': 'yawn',
#  '止': 'stop',
#  '歹': 'death',
#  '殳': 'windy again',
#  '毋': 'mother',
#  '比': 'race',
#  '毛': 'wool',
#  '氏': 'clan',
#  '气': 'spirit',
#  '水': 'water',
#  '氵': 'water',
#  '火': 'fire',
#  '灬': 'fire',
#  '無': 'nothingness',
#  '爪': 'claw',
#  '父': 'father',
#  '爻': 'double x',
#  '爿': 'left-side kata',
#  '片': 'one-sided leaf sheet',
#  '牙': 'fang',
#  '牛': 'cow',
#  '犬': 'dog',
#  '犭': 'dog',
#  '玄': 'mysterious',
#  '玉': 'jewel',
#  '瓜': 'melon',
#  '瓦': 'tile',
#  '甘': 'sweet',
#  '生': 'life',
#  '用': 'use',
#  '田': 'rice field',
#  '疋': 'head count',
#  '疒': 'sick',
#  '癶': 'dotted tent',
#  '白': 'white',
#  '皮': 'skin',
#  '皿': 'dish',
#  '目': 'eye',
#  '矛': 'halberd',
#  '矢': 'arrow',
#  '石': 'stone',
#  '示': 'show',
#  '礻': 'show',
#  '禸': 'mu in box',
#  '禾': 'two branch tree',
#  '穴': 'hole',
#  '立': 'stand',
#  '竜': 'dragon',
#  '竹': 'bamboo',
#  '米': 'rice',
#  '糸': 'thread',
#  '缶': 'can',
#  '网': 'net crown',
#  '羊': 'sheep',
#  '羽': 'feathers',
#  '老': 'old man',
#  '而': 'rake',
#  '耒': 'three branch tree',
#  '耳': 'ear',
#  '聿': 'writing brush',
#  '肉': 'meat',
#  '臣': 'retainer',
#  '自': 'oneself',
#  '至': 'climax',
#  '臼': 'mortar',
#  '舌': 'tongue',
#  '舛': 'dancing',
#  '舟': 'ship',
#  '艮': 'good',
#  '色': 'color',
#  '艸': 'grass',
#  '艹': 'grass',
#  '虍': 'tiger crown',
#  '虫': 'bug',
#  '血': 'blood',
#  '行': 'journey',
#  '衣': 'clothing',
#  '衤': 'clothing',
#  '襾': 'west',
#  '見': 'see',
#  '角': 'corner',
#  '言': 'say',
#  '谷': 'valley',
#  '豆': 'bean',
#  '豕': 'pig',
#  '豸': 'badger',
#  '貝': 'shellfish',
#  '赤': 'red',
#  '走': 'run',
#  '足': 'foot',
#  '身': 'body',
#  '車': 'car',
#  '辛': 'spicy hot',
#  '辰': 'sign of the dragon',
#  '辵': 'road',
#  '辶': 'road',
#  '邑': 'right village',
#  '酉': 'sake',
#  '釆': 'topped rice',
#  '里': 'village',
#  '金': 'metal',
#  '長': 'long',
#  '門': 'gate',
#  '阜': 'left village',
#  '阝.': 'left village',
#  '隶': 'slave',
#  '隹': 'old bird',
#  '雨': 'rain',
#  '青': 'blue',
#  '非': 'injustice',
#  '面': 'face',
#  '革': 'leather pelt',
#  '韋': 'tanned leather',
#  '韭': 'leek',
#  '音': 'sound',
#  '頁': 'page',
#  '風': 'wind',
#  '飛': 'flying',
#  '食': 'food',
#  '首': 'neck',
#  '香': 'smell',
#  '馬': 'horse',
#  '骨': 'bone',
#  '高': 'high',
#  '髟': 'long hair',
#  '鬥': 'broken gate',
#  '鬯': 'fragrant herbs',
#  '鬲': 'tripod',
#  '鬼': 'devil',
#  '魚': 'fish',
#  '鳥': 'bird',
#  '鹵': 'salt',
#  '鹿': 'deer',
#  '麥': 'wheat',
#  '麻': 'hemp',
#  '黄': 'yellow',
#  '黍': 'millet',
#  '黒': 'black',
#  '黹': 'sewing',
#  '黽': 'green frog',
#  '鼎': 'three legged kettle',
#  '鼓': 'drum beat',
#  '鼠': 'mouse',
#  '鼻': 'nose',
#  '齊': 'equal',
#  '齒': 'tooth',
#  '龍': 'dragon',
#  '龜': 'turtle',
#  '龠': 'flute',
#  '｜': 'stick'}

# %%
def handle_csv_edges_func(data, row):
    kanji,radical_list = row
    data[kanji] = radical_list.split(':')

# %%
data_edges = get_csv_data("dataset/s7_edges_kanji_radical.csv", handle_csv_edges_func)
print("len(data_edges) = ", len(data_edges))
pp(data_edges)
# Out:
# len(data_edges) =  6215
# {'丁': ['亅'],
#  '七': ['丿', '乙', '匕'],
#  '万': ['｜', '丿'],
#  '丈': ['丶', '丿'],
#  '三': ['二'],
#  '上': ['卜'],
#  '下': ['｜', '卜'],
#  '不': ['｜', '丶', '丿'],
#  '与': ['勹', '卜'],
#  '丐': ['弓', '止', '疋'],
#  '丑': ['｜', '丿'],
#  '且': ['目'],
#  '丕': ['｜', '丶', '丿'],
#  '世': ['｜'],
#  '丗': ['｜', '十', '山'],
#  '丘': ['斤'],
#  '丙': ['人', '冂'],
#  '丞': ['丿', '亅', 'マ'],
#  '両': ['｜', '冂', '山'],
#  '並': ['｜', '二', '丷'],
#  '个': ['｜'],
#  '中': ['｜', '口'],
#  '丱': ['｜', '丿'],
#  '串': ['｜', '口'],
#  '丸': ['丶', '九'],
#  '丹': ['丶', '丿', '亅'],
#  '主': ['丶', '玉'],
#  '丼': ['｜', '丶', '丿', '二', '廾', '井'],
#  '乂': ['丿'],
#  '乃': ['｜', '丿'],
#  '久': ['丿', '入'],
#  '之': ['丶', '乙', '亠', '廴'],
#  '乍': ['｜', '丿'],
#  '乎': ['丿', '亅', '丷'],
#  '乏': ['丶', '丿', '乙', '亠'],
#  '乕': ['｜', '丿', '厂', '巾'],
#  '乖': ['丿', '匕', '十', '爿'],
#  '乗': ['｜', '丿', '八', '禾'],
#  '乘': ['丿', '八', '匕', '十', '爿'],
#  '乞': ['丿', '乙'],
#  '也': ['｜', '乙', '匕'],
#  '乢': ['乙', '山'],
#  '乱': ['乙', '口', '舌'],
#  '乳': ['乙', '子', '爪'],
#  '乾': ['乙', '十', '日'],
#  '亀': ['乙', '勹', '田', '龜'],
#  '亂': ['乙', '冂', '厶', '爪'],
#  '了': ['亅'],
#  '予': ['亅', 'マ'],
#  '争': ['亅', '勹', '彐'],
#  '亊': ['亅', '彐', '丷'],
#  '事': ['亅', '口', '彐'],
#  '于': ['亅', '二'],
#  '云': ['二', '厶'],
#  '互': ['彐', '彑'],
#  '五': ['二'],
#  '井': ['｜', '丿', '二'],
#  '亘': ['二', '日'],
#  '亙': ['丶', '丿', '二'],
#  '些': ['二', '匕', '止'],
#  '亜': ['｜', '口'],
#  '亞': ['二'],
#  '亟': ['二', '又', '口'],
#  '亡': ['亠'],
#  '亢': ['亠', '几'],
#  '交': ['亠', '父'],
#  '亥': ['亠', '人'],
#  '亦': ['丿', '亅', '亠', '八'],
#  '亨': ['亠', '口'],
#  '享': ['亠', '口', '子'],
#  '京': ['亠', '口', '小'],
#  '亭': ['亅', '亠', '冖', '口'],
#  '亮': ['亠', '儿', '冖', '口'],
#  '亰': ['亠', '小', '日'],
#  '亳': ['丿', '乙', '亠', '冖', '口'],
#  '亶': ['亠', '口', '囗', '日'],
#  '什': ['十', '亻'],
#  '仁': ['二', '亻'],
#  '仂': ['力', '亻'],
#  '仄': ['人', '厂'],
#  '仆': ['卜', '亻'],
#  '仇': ['亻', '九'],
#  '今': ['个'],
#  '介': ['八', '个'],
#  '仍': ['丿', '亻', '乃'],
#  '从': ['人'],
#  '仏': ['厶', '亻'],
#  '仔': ['子', '亻'],
#  '仕': ['士', '亻'],
#  '他': ['亻', '也'],
#  '仗': ['丿', '亻'],
#  '付': ['寸', '亻'],
#  '仙': ['山', '亻'],
#  '仞': ['丶', '刀', '亻'],
#  '仟': ['丿', '十', '亻'],
#  '代': ['弋', '亻'],
#  '令': ['卩', '个'],
#  '以': ['｜', '丶', '人'],
#  '仭': ['丶', '刀', '亻'],
#  '仮': ['厂', '又', '亻'],
#  '仰': ['卩', '亻'],
#  '仲': ['｜', '口', '亻'],
#  '件': ['牛', '亻'],
#  '价': ['儿', '个', '亻'],
#  '任': ['丿', '士', '玉', '亻'],
#  '企': ['止', '个'],
#  '伉': ['亠', '几', '亻'],
#  '伊': ['｜', '彐', '亻'],
#  '伍': ['亻'],
#  '伎': ['十', '又', '支', '亻'],
#  '伏': ['犬', '亻'],
#  '伐': ['戈', '亻'],
#  '休': ['木', '亻'],
#  '会': ['二', '厶', '个'],
#  '伜': ['十', '亻', '九'],
#  '伝': ['二', '厶', '亻'],
#  '伯': ['白', '亻'],
#  '估': ['十', '口', '亻'],
#  '伴': ['｜', '二', '十', '亻', '丷'],
#  '伶': ['二', '士', '小', '彐', '水'],
#  '伸': ['｜', '日', '田', '亻'],
#  '伺': ['亅', '口', '亻'],
#  '似': ['丶', '人', '亻'],
#  '伽': ['力', '口', '亻'],
#  '佃': ['田', '亻'],
#  '但': ['日', '亻'],
#  '佇': ['亅', '宀', '亻'],
#  '位': ['立', '亻'],
#  '低': ['氏', '亻'],
#  '住': ['丶', '玉', '亻'],
#  '佐': ['丿', '工', '亻'],
#  '佑': ['丿', '口', '亻'],
#  '体': ['木', '亻'],
#  '何': ['亅', '口', '亻'],
#  '佗': ['匕', '宀', '亻'],
#  '余': ['亅', '二', '八', '示', '个'],
#  '佚': ['丿', '二', '人', '大', '亻'],
#  '佛': ['｜', '丿', '弓', '亻'],
#  '作': ['｜', '丿', '亻'],
#  '佝': ['勹', '口', '亻'],
#  '佞': ['二', '女', '亻'],
#  '佩': ['几', '巾', '亻'],
#  '佯': ['玉', '羊', '亻', '丷'],
#  '佰': ['白', '亻'],
#  '佳': ['土', '亻'],
#  '併': ['｜', '丿', '二', '廾', '亻', '丷'],
#  '佶': ['口', '士', '亻'],
#  '佻': ['儿', '冫', '亻'],
#  '佼': ['亠', '父', '亻'],
#  '使': ['丿', '口', '亻'],
#  '侃': ['口', '巛', '亻'],
#  '來': ['｜', '人', '八', '十', '木'],
#  '侈': ['夕', '亻'],
#  '例': ['歹', '亻', '刂'],
#  '侍': ['土', '寸', '亻'],
#  '侏': ['丿', '八', '木', '牛', '亻'],
#  '侑': ['丿', '月', '亻'],
#  '侖': ['冂', '廾', '个', '冊'],
#  '侘': ['丿', '乙', '宀', '亻'],
#  '供': ['｜', '二', '八', '亻'],
#  '依': ['亠', '衣', '亻'],
#  '侠': ['二', '亠', '人', '大', '亻', '丷'],
#  '価': ['襾', '亻'],
#  '侫': ['女', '亻', '亡'],
#  '侭': ['尸', '亻'],
#  '侮': ['毋', '亻'],
#  '侯': ['矢', '亻'],
#  '侵': ['冖', '又', '彐', '亻'],
#  '侶': ['｜', '口', '亻'],
#  '便': ['｜', '丿', '日', '田', '亻'],
#  '係': ['丿', '糸', '亻'],
#  '促': ['口', '足', '亻'],
#  '俄': ['亅', '戈', '手', '亻'],
#  '俊': ['儿', '厶', '夂', '亻'],
#  '俎': ['人', '目'],
#  '俐': ['禾', '亻', '刂'],
#  '俑': ['用', '亻', 'マ'],
#  '俔': ['見', '亻'],
#  '俗': ['八', '口', '谷', '个', '亻'],
#  '俘': ['子', '爪', '亻'],
#  '俚': ['里', '亻'],
#  '俛': ['儿', '亻', '免'],
#  '保': ['口', '木', '亻'],
#  '俟': ['厶', '矢', '亻'],
#  '信': ['言', '亻'],
#  '俣': ['二', '口', '大', '亻'],
#  '俤': ['｜', '丿', '弓', '亻', '丷'],
#  '俥': ['車', '亻'],
#  '修': ['｜', '彡', '攴', '亻'],
#  '俯': ['寸', '广', '亻'],
#  '俳': ['非', '亻'],
#  '俵': ['士', '衣', '亻'],
#  '俶': ['卜', '又', '小', '亻'],
#  '俸': ['｜', '丿', '二', '人', '大', '亻'],
#  '俺': ['乙', '大', '亻', '奄'],
#  '俾': ['十', '田', '亻'],
#  '倅': ['亠', '人', '十', '亻'],
#  '倆': ['｜', '人', '冂', '亻'],
#  '倉': ['丿', '口', '个'],
#  '個': ['十', '口', '囗', '亻'],
#  '倍': ['口', '立', '亻'],
#  '倏': ['夂', '攴', '犬', '亻'],
#  '們': ['門', '亻'],
#  '倒': ['厶', '土', '至', '亻', '刂'],
#  '倔': ['｜', '尸', '山', '亻'],
#  '倖': ['亠', '十', '立', '辛', '亻'],
#  '候': ['｜', '矢', '亻'],
#  '倚': ['亅', '口', '大', '亻'],
#  '借': ['日', '亻'],
#  '倡': ['日', '亻'],
#  '倣': ['攴', '方', '亻'],
#  '値': ['｜', '十', '目', '亻'],
#  '倥': ['儿', '宀', '工', '穴', '亻'],
#  '倦': ['大', '己', '亻'],
#  '倨': ['十', '口', '尸', '亻'],
#  '倩': ['二', '亠', '土', '月', '青', '亻'],
#  '倪': ['儿', '臼', '亻'],
#  '倫': ['｜', '亅', '个', '亻', '冊'],
#  '倬': ['十', '卜', '日', '曰', '亻'],
#  '倭': ['女', '禾', '亻'],
#  '倶': ['八', '目', '亻'],
#  '倹': ['人', '口', '个', '亻'],
#  '偃': ['匚', '女', '日', '亻'],
#  '假': ['｜', '又', '亻'],
#  '偈': ['勹', '匕', '日', '亻'],
#  '偉': ['口', '韋', '亻'],
#  '偏': ['｜', '冂', '戸', '亻', '冊'],
#  '偐': ['亠', '厂', '彡', '立', '亻', '丷'],
#  '偕': ['比', '白', '亻'],
#  '偖': ['日', '老', '亻'],
#  '做': ['十', '口', '攴', '亻'],
#  '停': ['亅', '亠', '冖', '口', '亻'],
#  '健': ['廴', '聿', '亻'],
#  '偬': ['丶', '心', '亻', '勿'],
#  '偲': ['心', '田', '亻'],
#  '側': ['貝', '亻', '刂'],
#  '偵': ['卜', '貝', '亻'],
#  '偶': ['冂', '厶', '田', '禸', '亻'],
#  '偸': ['月', '个', '亻', '刂'],
#  '偽': ['丶', '亻', '灬'],
#  '傀': ['儿', '匕', '厶', '田', '鬼', '亻'],
#  '傅': ['丶', '寸', '田', '亻'],
#  '傍': ['亠', '冖', '方', '立', '亻', '丷'],
#  '傑': ['夕', '木', '舛', '亻'],
#  '傘': ['人', '十', '个'],
#  '備': ['厂', '用', '亻', '艹'],
#  '傚': ['亠', '攴', '父', '亻'],
#  '催': ['山', '隹', '亻'],
#  '傭': ['广', '彐', '用', '亻'],
#  '傲': ['土', '攴', '方', '亻'],
#  '傳': ['厶', '寸', '田', '亻'],
#  '傴': ['匚', '口', '亻', '品'],
#  '債': ['亠', '土', '貝', '亻'],
#  '傷': ['丿', '日', '亻', '勿'],
#  '傾': ['匕', '貝', '頁', '亻'],
#  '僂': ['十', '女', '亻'],
#  '僅': ['口', '土', '亻', '艹'],
#  '僉': ['人', '口', '个'],
#  '僊': ['大', '己', '襾', '亻'],
#  '働': ['｜', '力', '日', '亻'],
#  '像': ['勹', '口', '豕', '亻'],
#  '僑': ['丿', '冂', '口', '大', '亻'],
#  '僕': ['玉', '羊', '亻', '丷'],
#  '僖': ['十', '口', '士', '豆', '亻', '丷'],
#  '僚': ['小', '日', '亻'],
#  '僞': ['爪', '亻', '灬'],
#  '僣': ['人', '土', '日', '亻'],
#  '僥': ['儿', '土', '亻'],
#  '僧': ['日', '田', '亻', '丷'],
#  '僭': ['亠', '无', '日', '亻'],
#  '僮': ['立', '里', '亻'],
#  '僵': ['二', '田', '亻'],
#  '價': ['襾', '貝', '亻'],
#  '僻': ['十', '口', '尸', '立', '辛', '亻'],
#  '儀': ['亅', '戈', '手', '玉', '羊', '亻', '丷'],
#  '儁': ['隹', '亻'],
#  '儂': ['｜', '辰', '亻'],
#  '億': ['心', '日', '立', '音', '亻'],
#  '儉': ['人', '口', '个', '亻'],
#  '儒': ['而', '雨', '亻'],
#  '儔': ['口', '士', '寸', '工', '亻'],
#  '儕': ['亠', '刀', '齊', '亻'],
#  '儖': ['二', '皿', '臣', '亻'],
#  '儘': ['彐', '皿', '亻', '灬'],
#  '儚': ['冖', '夕', '网', '亻', '艹'],
#  '償': ['冖', '口', '貝', '亻', '尚'],
#  '儡': ['田', '亻'],
#  '優': ['冖', '夂', '心', '白', '亻'],
#  '儲': ['日', '老', '言', '亻'],
#  '儷': ['冂', '广', '比', '鹿', '亻'],
#  '儺': ['隹', '亻', '艹'],
#  '儻': ['冖', '口', '里', '黒', '亻', '尚', '灬'],
#  '儼': ['厂', '口', '攴', '耳', '亻'],
#  '兀': ['儿'],
#  '允': ['儿', '厶'],
#  '元': ['二', '儿'],
#  '兄': ['儿', '口'],
#  '充': ['亠', '儿', '厶'],
#  '兆': ['儿', '冫'],
#  '兇': ['丶', '丿', '儿', '凵'],
#  '先': ['丿', '儿', '土'],
#  '光': ['儿', '尚'],
#  '克': ['儿', '十', '口'],
#  '兌': ['儿', '口', '丷'],
#  '免': ['｜', '儿', '勹', '口'],
#  '兎': ['｜', '丶', '丿', '儿', '口'],
#  '児': ['｜', '儿', '日'],
#  '兒': ['儿', '臼'],
#  '兔': ['丶', '儿', '免'],
#  '党': ['儿', '冖', '口', '尚'],
#  '兜': ['儿', '白'],
#  '兢': ['儿', '十', '口'],
#  '全': ['八', '玉'],
#  '兩': ['｜', '入', '冂'],
#  '兪': ['入', '月', '个'],
#  '公': ['八', '厶'],
#  '六': ['亠', '八'],
#  '兮': ['八', '弓'],
#  '共': ['八'],
#  '兵': ['八', '斤'],
#  '其': ['八', '甘'],
#  '具': ['八', '目'],
#  '典': ['｜', '八', '日'],
#  '兼': ['｜', '八', '彐', '丷'],
#  '冀': ['二', '八', '匕', '爿', '田'],
#  '内': ['人', '冂'],
#  '円': ['亠', '冂'],
#  '冉': ['｜', '冂'],
#  '冊': ['｜', '亅', '冂', '廾'],
#  '册': ['冂'],
#  '再': ['｜', '冂', '玉'],
#  '冏': ['儿', '冂', '口'],
#  '冐': ['二', '冂', '月'],
#  '冑': ['二', '冂', '月', '田'],
#  '冒': ['日', '目'],
#  '冓': ['｜', '冂'],
#  '冕': ['二', '儿', '冂', '月', '免'],
#  '冗': ['冖', '几'],
#  '写': ['冖', '勹'],
#  '冠': ['儿', '冖', '寸'],
#  '冢': ['冖', '豕'],
#  '冤': ['丶', '儿', '冖', '免'],
#  '冥': ['亠', '八', '冖', '日'],
#  '冦': ['二', '儿', '冖', '卜', '又'],
#  '冨': ['冖', '口', '田'],
#  '冩': ['冖', '勹', '臼', '灬'],
#  '冪': ['冖', '大', '巾', '日', '艹'],
#  '冬': ['丶', '夂', '攴'],
#  '冰': ['冫', '水'],
#  '冱': ['二', '冫'],
#  '冲': ['｜', '冫', '口'],
#  '决': ['丿', '人', '冫', '大', 'ユ'],
#  '冴': ['冫', '牙'],
#  '况': ['儿', '冫', '口'],
#  '冶': ['冫', '厶', '口'],
#  '冷': ['冫', '卩', '个'],
#  '冽': ['冫', '歹', '刂'],
#  '凄': ['冫', '十', '女', '彐'],
#  '凅': ['冫', '十', '口', '囗'],
#  '准': ['冫', '隹'],
#  '凉': ['亠', '冫', '口', '小'],
#  '凋': ['冂', '冫', '口', '土'],
#  '凌': ['儿', '冫', '土', '夂'],
#  '凍': ['｜', '冫', '日', '木', '田'],
#  '凖': ['冫', '十', '隹'],
#  '凛': ['亠', '冫', '口', '囗', '示'],
#  '凜': ['亠', '冫', '口', '禾'],
#  '凝': ['冫', '匕', '疋', '矢', 'マ'],
#  '凡': ['丶', '几'],
#  '処': ['几', '夂', '攴'],
#  '凧': ['｜', '冂', '几', '巾'],
#  '凩': ['几', '木'],
#  '凪': ['几', '止'],
#  '凭': ['丿', '几', '士', '亻'],
#  '凰': ['几', '玉', '白'],
#  '凱': ['几', '口', '山', '豆', '丷'],
#  '凶': ['丶', '丿', '凵'],
#  '凸': ['｜', '冂', '凵'],
#  '凹': ['凵'],
#  '出': ['｜', '山'],
#  '函': ['凵', '水'],
#  '凾': ['凵', '又', '口'],
#  '刃': ['丶', '刀'],
#  '刄': ['刀'],
#  '分': ['八', '刀'],
#  '切': ['刀', '匕'],
#  '刈': ['刂'],
#  '刊': ['干', '刂'],
#  '刋': ['丿', '十', '刂'],
#  '刎': ['勹', '刂', '勿'],
#  '刑': ['丿', '廾', '刂'],
#  '刔': ['人', '大', '刂', 'ユ'],
#  '列': ['歹', '刂'],
#  '初': ['刀', '衤'],
#  '判': ['｜', '二', '十', '丷', '刂'],
#  '別': ['力', '口', '刂'],
#  '刧': ['刀', '厶', '土'],
#  '利': ['禾', '刂'],
#  '刪': ['冂', '刂', '冊'],
#  '刮': ['口', '舌', '刂'],
#  '到': ['厶', '土', '至', '刂'],
#  '刳': ['二', '勹', '大', '刂'],
#  '制': ['丿', '二', '巾', '牛', '刂'],
#  '刷': ['尸', '巾', '刂'],
#  '券': ['二', '人', '刀', '大', '大', '丷'],
#  '刹': ['木', '刂'],
#  '刺': ['｜', '亅', '八', '冂', '巾', '木', '刂'],
#  '刻': ['亠', '刂'],
#  '剃': ['｜', '丿', '弓', '丷', '刂'],
#  '剄': ['巛', '工', '刂'],
#  '則': ['貝', '刂'],
#  '削': ['月', '刂', '尚'],
#  '剋': ['儿', '十', '口', '刂'],
#  '剌': ['｜', '八', '口', '木', '刂'],
#  '前': ['月', '丷', '刂'],
#  '剏': ['｜', '丿', '二', '刀', '廾', '丷'],
#  '剔': ['日', '刂', '勿'],
#  '剖': ['口', '立', '刂'],
#  '剛': ['冂', '山', '丷', '刂', '岡'],
#  '剞': ['亅', '口', '大', '刂'],
#  '剣': ['人', '口', '个', '刂'],
#  '剤': ['｜', '丿', '廾', '文', '齊', '刂'],
#  '剥': ['彐', '水', '刂'],
#  '剩': ['｜', '匕', '爿', '刂'],
#  '剪': ['刀', '月', '丷', '刂'],
#  '副': ['口', '田', '刂'],
#  '剰': ['｜', '丿', '刂'],
#  '剱': ['丶', '人', '刀', '口', '个'],
#  '割': ['亠', '口', '土', '宀', '刂'],
#  '剳': ['口', '个', '刂', '艹'],
#  '剴': ['口', '山', '豆', '丷', '刂'],
#  '創': ['口', '个', '刂'],
#  '剽': ['示', '襾', '刂'],
#  '剿': ['木', '田', '刂', '尚'],
#  '劃': ['田', '聿', '刂'],
#  '劇': ['匕', '卜', '厂', '虍', '豕', '刂'],
#  '劈': ['刀', '十', '口', '尸', '立', '辛'],
#  '劉': ['厶', '金', '刂'],
#  '劍': ['人', '口', '个', '刂'],
#  '劑': ['亠', '齊', '刂'],
#  '劒': ['丶', '人', '刀', '口', '个'],
#  '劔': ['丶', '人', '刀', '口', '个'],
#  '功': ['力', '工'],
#  '加': ['力', '口'],
#  '劣': ['丿', '力', '小'],
#  '助': ['力', '目'],
#  '努': ['力', '又', '女'],
#  '劫': ['力', '厶', '土'],
#  '劬': ['力', '勹', '口'],
#  '劭': ['刀', '力', '口'],
#  '励': ['力', '厂', '斤'],
#  '労': ['冖', '力', '尚'],
#  '劵': ['二', '人', '八', '力', '大'],
#  '効': ['亠', '力', '父'],
#  '劼': ['力', '口', '士'],
#  '劾': ['亠', '人', '力'],
#  '勁': ['力', '巛', '工'],
#  '勃': ['冖', '力', '十', '子'],
#  '勅': ['｜', '力', '口', '木'],
#  '勇': ['力', '田', 'マ'],
#  '勉': ['儿', '力', '免'],
#  '勍': ['亠', '力', '口', '小'],
#  '勒': ['力', '革'],
#  '動': ['｜', '力', '日', '里'],
#  '勗': ['力', '日', '目'],
#  '勘': ['儿', '力', '匚', '甘'],
#  '務': ['力', '夂', '矛'],
#  '勝': ['二', '人', '力', '大', '月', '丷'],
#  '勞': ['冖', '力', '火'],
#  '募': ['力', '大', '日', '艹'],
#  '勠': ['冫', '力', '彡', '羽', '个'],
#  '勢': ['丶', '儿', '力', '土', '九'],
#  '勣': ['亠', '力', '土', '貝'],
#  '勤': ['力', '口', '土', '艹'],
#  '勦': ['力', '木', '田', '尚'],
#  '勧': ['丿', '力', '矢', '隹'],
#  '勲': ['｜', '丿', '力', '日', '田', '灬'],
#  '勳': ['｜', '力', '灬'],
#  '勵': ['力', '厂', '田', '禸'],
#  '勸': ['力', '十', '口', '隹', '艹'],
#  '勺': ['丶', '勹'],
#  '勾': ['勹', '厶'],
#  '勿': ['丿', '勹'],
#  '匁': ['丶', '丿', '勹'],
#  '匂': ['勹', '匕'],
#  '包': ['勹', '己'],
#  '匆': ['丶', '勹', '勿'],
#  '匈': ['凵', '勹'],
#  '匍': ['丶', '勹', '十', '用'],
#  '匏': ['二', '勹', '大', '己'],
#  '匐': ['勹', '口', '田'],
#  '化': ['匕', '亻'],
#  '北': ['匕', '爿'],
#  '匙': ['匕', '日'],
#  '匝': ['匚', '巾'],
#  '匠': ['匚', '斤'],
#  '匡': ['匚', '玉'],
#  '匣': ['｜', '匚', '田'],
#  '匪': ['匚', '非'],
#  '匯': ['匚', '隹', '氵'],
#  '匱': ['匚', '貝'],
#  '匳': ['人', '匚', '口', '个'],
#  '匹': ['儿', '匚'],
#  '区': ['丶', '丿', '匚'],
#  '医': ['匚', '矢'],
#  '匿': ['丿', '匚', '口', '艹'],
#  '區': ['匚', '口', '品'],
#  '千': ['丿', '十'],
#  '卅': ['｜', '丿', '十', '巛'],
#  '卆': ['十', '九'],
#  '升': ['丿', '十', '廾'],
#  '午': ['丿', '十', '干'],
#  '卉': ['十', '廾'],
#  '半': ['｜', '二', '十', '丷'],
#  '卍': ['｜', '十'],
#  '卑': ['十', '田'],
#  '卒': ['亠', '人', '十'],
#  '卓': ['十', '卜', '日'],
#  '協': ['力', '十'],
#  '南': ['冂', '十', '干', '丷'],
#  '単': ['十', '田', '尚'],
#  '博': ['丶', '十', '寸', '田'],
#  '卞': ['亠', '卜'],
#  '占': ['卜', '口'],
#  '卦': ['卜', '土'],
#  '卮': ['卩', '厂'],
#  '卯': ['卩'],
#  '印': ['｜', '卩'],
#  '危': ['勹', '厂'],
#  '即': ['卩', '艮'],
#  '却': ['卩', '厶', '土'],
#  '卵': ['丶', '丿', '卜'],
#  '卷': ['二', '人', '八', '卩', '大'],
#  '卸': ['丿', '卩', '止'],
#  '卻': ['八', '卩', '口', '谷'],
#  '卿': ['卩', '艮'],
#  '厄': ['卩', '厂'],
#  '厖': ['丶', '厂', '尢', '彡', '尤'],
#  '厘': ['厂', '里'],
#  '厚': ['厂', '子', '日'],
#  '原': ['厂', '小', '白'],
#  '厠': ['厂', '貝', '刂'],
#  '厥': ['厂', '屮', '欠', '丷'],
#  '厦': ['厂', '夂', '自'],
#  '厨': ['厂', '口', '寸', '豆', '丷'],
#  '厩': ['儿', '厂', '牙', '艮'],
#  '厭': ['厂', '日', '月', '犬'],
#  '厮': ['八', '厂', '斤', '甘'],
#  '厰': ['冂', '厂', '口', '攴', '尚'],
#  '厳': ['厂', '攴', '耳', '尚'],
#  '去': ['厶', '土'],
#  '参': ['厶', '彡'],
#  '參': ['厶', '彡', '个'],
#  '叉': ['丶', '又'],
#  '及': ['丶', '乃'],
#  '友': ['丿', '又'],
#  '双': ['丶', '又'],
#  '反': ['厂', '又'],
#  '収': ['｜', '又'],
#  '叔': ['卜', '又', '小'],
#  '取': ['又', '耳'],
#  '受': ['冖', '又', '爪'],
#  '叙': ['又', '禾', '个'],
#  '叛': ['厂', '又', '丷'],
#  '叟': ['十', '又', '支', '臼'],
#  '叡': ['八', '冖', '卜', '又', '目'],
#  '叢': ['又', '玉', '羊', '耳', '丷'],
#  '口': ['囗'],
#  '古': ['十', '口'],
#  '句': ['勹', '口'],
#  '叨': ['刀', '口'],
#  '叩': ['卩', '口'],
#  '只': ['八', '口'],
#  '叫': ['｜', '十', '口'],
#  '召': ['刀', '口'],
#  '叭': ['八', '口'],
#  '叮': ['亅', '口'],
#  '可': ['亅', '口'],
#  '台': ['厶', '口'],
#  '叱': ['匕', '口'],
#  '史': ['丿', '口'],
#  '右': ['丿', '口'],
#  '叶': ['十', '口'],
#  '号': ['勹', '口'],
#  '司': ['亅', '口'],
#  '叺': ['入', '口'],
#  '吁': ['亅', '二', '口'],
#  '吃': ['乙', '口'],
#  '各': ['口', '夂', '攴'],
#  '合': ['口', '个'],
#  '吉': ['口', '士'],
#  '吊': ['口', '巾'],
#  '吋': ['口', '寸'],
#  '同': ['冂', '口'],
#  '名': ['口', '夕'],
#  '后': ['丿', '亅', '厂', '口', '斤'],
#  '吏': ['丶', '丿', '口'],
#  '吐': ['口', '土'],
#  '向': ['冂', '口'],
#  '君': ['丿', '口', '日'],
#  '吝': ['口', '文'],
#  '吟': ['口', '个'],
#  '吠': ['口', '犬'],
#  '否': ['丿', '口'],
#  '吩': ['八', '刀', '口'],
#  '含': ['口', '个'],
#  '听': ['口', '斤'],
#  '吭': ['亠', '几', '口'],
#  '吮': ['儿', '厶', '口'],
#  '吶': ['人', '冂', '口'],
#  '吸': ['丿', '口', '及'],
#  '吹': ['口', '欠'],
#  '吻': ['勹', '口', '勿'],
#  '吼': ['乙', '口', '子'],
#  '吽': ['｜', '二', '口', '牛'],
#  '吾': ['口', '五'],
#  '呀': ['口', '牙'],
#  '呂': ['口'],
#  '呆': ['口', '木'],
#  '呈': ['口', '玉'],
#  '呉': ['八', '口'],
#  '告': ['丿', '口', '土'],
#  '呎': ['口', '尸'],
#  '呑': ['丿', '口', '大'],
#  '呟': ['亠', '口', '幺', '玄'],
#  '周': ['冂', '口', '土'],
#  '呪': ['儿', '口'],
#  '呰': ['匕', '口', '止'],
#  '呱': ['口', '瓜'],
#  '味': ['｜', '二', '亠', '八', '口', '木'],
#  '呵': ['亅', '口'],
#  '呶': ['又', '口', '女'],
#  '呷': ['｜', '口', '田'],
#  '呻': ['｜', '口', '田'],
#  '呼': ['丿', '亅', '口', '丷'],
#  '命': ['卩', '口', '个'],
#  '咀': ['口', '目'],
#  '咄': ['｜', '口', '山'],
#  '咆': ['勹', '口', '己'],
#  '咋': ['｜', '丿', '口'],
#  '和': ['口', '禾'],
#  '咎': ['人', '口', '夂'],
#  '咏': ['丶', '丿', '口', '水'],
#  '咐': ['口', '寸', '亻'],
#  '咒': ['几', '口'],
#  '咢': ['二', '勹', '口'],
#  '咤': ['丿', '乙', '口', '宀'],
#  '咥': ['厶', '口', '土', '至'],
#  '咨': ['冫', '口', '欠'],
#  '咫': ['八', '口', '尸'],
#  '咬': ['亠', '口', '父'],
#  '咯': ['口', '夂'],
#  '咲': ['二', '人', '口', '大', '丷'],
#  '咳': ['亠', '人', '口'],
#  '咸': ['丿', '口', '戈'],
#  '咼': ['冂', '口'],
#  '咽': ['口', '囗', '大'],
#  '咾': ['口', '老'],
#  '哀': ['亠', '口', '衣'],
#  '品': ['口'],
#  '哂': ['口', '襾'],
#  '哄': ['｜', '二', '八', '口'],
#  '哇': ['口', '土'],
#  '哈': ['口', '个'],
#  '哉': ['口', '土', '戈'],
#  '哘': ['口', '彳', '行'],
#  '員': ['口', '貝'],
#  '哢': ['口', '廾', '玉'],
#  '哥': ['亅', '口'],
#  '哦': ['亅', '口', '戈'],
#  '哨': ['口', '月', '尚'],
#  '哩': ['口', '里'],
#  '哭': ['口', '犬'],
#  '哮': ['口', '子', '老'],
#  '哲': ['口', '斤', '扌'],
#  '哺': ['丶', '十', '口', '用'],
#  '哽': ['丿', '口', '田'],
#  '唄': ['口', '貝'],
#  '唆': ['儿', '厶', '口', '夂'],
#  '唇': ['厂', '口', '衣', '辰'],
#  '唏': ['丿', '口', '巾'],
#  '唐': ['｜', '口', '广', '彐'],
#  '唔': ['口', '五'],
#  '唖': ['｜', '口', '刂'],
#  '售': ['口', '隹'],
#  '唯': ['口', '隹'],
#  '唱': ['口', '日'],
#  '唳': ['口', '大', '戸'],
#  '唸': ['口', '心', '个'],
#  '唹': ['冫', '口', '方', '个'],
#  '唾': ['｜', '丿', '口'],
#  '啀': ['厂', '口', '土'],
#  '啄': ['口', '豕'],
#  '啅': ['十', '卜', '口', '日'],
#  '商': ['亠', '儿', '冂', '口', '立', '丷'],
#  '啌': ['儿', '口', '宀', '工', '穴'],
#  '問': ['口', '門'],
#  '啓': ['口', '戸', '攴'],
#  '啖': ['口', '火'],
#  '啗': ['勹', '口', '臼'],
#  '啜': ['又', '口'],
#  '啝': ['口', '禾'],
#  '啣': ['凵', '卩', '口', '止', '缶'],
#  '啻': ['亠', '冖', '口', '巾', '立', '丷'],
#  '啼': ['亠', '冖', '口', '巾', '立', '丷'],
#  '啾': ['口', '火', '禾'],
#  '喀': ['口', '夂', '宀'],
#  '喃': ['冂', '十', '口', '干', '丷'],
#  '善': ['口', '玉', '羊', '丷'],
#  '喇': ['｜', '亠', '八', '口', '木', '刂'],
#  '喉': ['口', '矢', '亻'],
#  '喊': ['丿', '口', '戈'],
#  '喋': ['口', '木', '世'],
#  '喘': ['｜', '冂', '口', '山', '而'],
#  '喙': ['口', '彐', '豕'],
#  '喚': ['儿', '冂', '勹', '口', '大'],
#  '喜': ['口', '士', '豆', '丷'],
#  '喝': ['勹', '匕', '口', '日'],
#  '喞': ['卩', '口', '艮'],
#  '喟': ['口', '月', '田'],
#  '喧': ['口', '宀', '日'],
#  '喨': ['亠', '儿', '冖', '口'],
#  '喩': ['口', '月', '个', '刂'],
#  '喪': ['｜', '口', '衣'],
#  '喫': ['亠', '刀', '口', '土', '大'],
#  '喬': ['丿', '冂', '口', '大'],
#  '單': ['十', '口', '田'],
#  '喰': ['口', '食'],
#  '営': ['冖', '口', '尚'],
#  '嗄': ['口', '夂', '自'],
#  '嗅': ['口', '大', '自'],
#  '嗇': ['人', '口', '囗', '土'],
#  '嗔': ['八', '十', '口', '目'],
#  '嗚': ['口', '鳥', '灬'],
#  '嗜': ['口', '日', '老'],
#  '嗟': ['丿', '口', '工', '玉', '羊', '丷'],
#  '嗣': ['｜', '亅', '冂', '口'],
#  '嗤': ['口', '山', '虫'],
#  '嗷': ['口', '土', '攴', '方'],
#  '嗹': ['口', '車', '辶'],
#  '嗽': ['｜', '八', '口', '木', '欠'],
#  '嗾': ['口', '方', '矢'],
#  '嘆': ['丿', '口', '艹'],
#  '嘉': ['力', '口', '士'],
#  '嘔': ['匚', '口', '品'],
#  '嘖': ['亠', '口', '土', '貝'],
#  '嘗': ['冖', '匕', '口', '日', '尚'],
#  '嘘': ['匕', '卜', '厂', '口', '虍'],
#  '嘛': ['口', '广', '木', '麻'],
#  '嘩': ['｜', '口', '艹'],
#  '嘯': ['｜', '丿', '口', '彐', '水', '米', '聿', '隶'],
#  '嘱': ['口', '尸', '禸'],
#  '嘲': ['十', '口', '日', '月'],
#  '嘴': ['匕', '口', '止', '角'],
#  '嘶': ['八', '口', '斤', '甘'],
#  '嘸': ['｜', '丿', '口', '灬', '無'],
#  '噂': ['口', '寸', '襾', '丷'],
#  '噌': ['口', '日', '田', '丷'],
#  '噎': ['冖', '口', '士', '豆', '丷'],
#  '噐': ['口', '工'],
#  '噛': ['口', '止', '米', '齒'],
#  '噤': ['口', '木', '示'],
#  '器': ['口', '大'],
#  '噪': ['口', '木', '品'],
#  '噫': ['口', '心', '日', '立', '音'],
#  '噬': ['人', '口', '工', '竹'],
#  '噴': ['十', '口', '貝', '艹'],
#  '噸': ['口', '貝', '頁', '屯'],
#  '噺': ['亠', '十', '口', '斤', '木', '立', '辛', '丷'],
#  '嚀': ['口', '宀', '心', '网'],
#  '嚆': ['亠', '冂', '口', '高', '艹'],
#  '嚇': ['口', '土', '赤'],
#  '嚊': ['口', '廾', '田', '自', '鼻'],
#  '嚏': ['冖', '十', '口', '田', '疋'],
#  '嚔': ['冖', '十', '口', '田', '疋'],
#  '嚠': ['厶', '口', '金', '刂'],
#  '嚢': ['｜', '亠', '八', '冖', '口', '衣'],
#  '嚥': ['凵', '匕', '口', '爿', '灬'],
#  '嚮': ['冂', '口', '艮', '.阝'],
#  '嚴': ['厂', '口', '攴', '耳'],
#  '嚶': ['口', '女', '貝'],
#  '嚼': ['口', '寸', '爪', '网', '艮'],
#  '囀': ['十', '厶', '口', '寸', '田', '車'],
#  '囁': ['口', '耳'],
#  '囂': ['八', '口', '自'],
#  '囃': ['亠', '人', '口', '木', '隹'],
#  '囈': ['丶', '二', '儿', '厶', '口', '土', '九', '艹'],
#  '囎': ['八', '口', '日', '田', '貝', '丷'],
#  '囑': ['勹', '口', '尸', '网', '虫'],
#  '囓': ['亠', '凵', '刀', '口', '土', '止', '米', '齒'],
#  '囘': ['冂', '己'],
#  '囚': ['人', '囗'],
#  '四': ['儿', '囗'],
#  '回': ['口', '囗'],
#  '因': ['囗', '大'],
#  '団': ['囗', '寸'],
#  '囮': ['匕', '囗', '亻'],
#  '困': ['囗', '木'],
#  '囲': ['囗', '井'],
#  '図': ['囗', '斗'],
#  '囹': ['刀', '囗', '个'],
#  '固': ['十', '口', '囗'],
#  '国': ['丶', '囗', '玉'],
#  '囿': ['丿', '囗', '月'],
#  '圀': ['儿', '囗', '方'],
#  '圃': ['丶', '十', '囗', '用'],
#  '圄': ['口', '囗', '五'],
#  '圈': ['二', '人', '卩', '囗', '大', '丷'],
#  '圉': ['亠', '十', '囗', '土', '干', '立', '辛'],
#  '國': ['口', '囗', '戈'],
#  '圍': ['口', '囗', '韋'],
#  '圏': ['二', '人', '囗', '大', '大', '己', '丷'],
#  '園': ['口', '囗', '土', '衣'],
#  '圓': ['口', '囗', '貝'],
#  '圖': ['口', '囗'],
#  '團': ['十', '厶', '囗', '寸'],
#  '圜': ['口', '囗', '网', '衣'],
#  '圦': ['入', '土'],
#  '圧': ['厂', '土'],
#  '在': ['｜', '丿', '土'],
#  '圭': ['土'],
#  '地': ['土', '也'],
#  '圷': ['卜', '土'],
#  '圸': ['土', '山'],
#  '圻': ['土', '斤'],
#  '址': ['土', '止'],
#  '坂': ['厂', '又', '土'],
#  '均': ['二', '冫', '勹', '土'],
#  '坊': ['土', '方'],
#  '坎': ['土', '欠'],
#  '坏': ['｜', '丶', '丿', '土'],
#  '坐': ['｜', '人', '入', '土'],
#  '坑': ['亠', '几', '土'],
#  '坡': ['又', '土', '皮'],
#  '坤': ['｜', '土', '日', '田'],
#  '坦': ['土', '日'],
#  '坩': ['土', '甘'],
#  '坪': ['土', '干', '丷'],
#  '坿': ['土', '寸', '亻'],
#  '垂': ['｜', '丿'],
#  '垈': ['土', '弋', '亻'],
#  '垉': ['勹', '土', '己'],
#  '型': ['丿', '土', '廾', '刂'],
#  '垓': ['亠', '人', '土'],
#  '垠': ['土', '艮'],
#  '垢': ['丿', '亅', '厂', '口', '土', '斤'],
#  '垣': ['土', '日'],
#  '垤': ['厶', '土', '至'],
#  '垪': ['｜', '丿', '二', '土', '廾', '丷'],
#  '垰': ['卜', '土'],
#  '垳': ['土', '彳', '行'],
#  '埀': ['丿', '匕', '土', '爿'],
#  '埃': ['厶', '土', '矢'],
#  '埆': ['土', '角'],
#  '埋': ['土', '里'],
#  '城': ['丿', '土', '戈'],
#  '埒': ['土', '寸', '爪'],
#  '埓': ['丿', '土', '寸'],
#  '埔': ['丶', '十', '土', '用'],
#  '埖': ['匕', '土', '亻', '艹'],
#  '埜': ['土', '木'],
#  '域': ['口', '土', '戈'],
#  '埠': ['｜', '十', '口', '土', '阝.'],
#  '埣': ['亠', '人', '十', '土'],
#  '埴': ['十', '土', '目'],
#  '執': ['丶', '丿', '亠', '十', '土', '立', '辛', '九'],
#  '培': ['口', '土', '立'],
#  '基': ['八', '土', '甘'],
#  '埼': ['｜', '口', '土', '大'],
#  '堀': ['｜', '土', '尸', '山'],
#  '堂': ['冖', '口', '土', '尚'],
#  '堅': ['又', '土', '臣'],
#  '堆': ['土', '隹'],
#  '堊': ['二', '土'],
#  '堋': ['土', '月'],
#  '堕': ['丿', '土', '月', '阝.'],
#  '堙': ['｜', '土', '襾'],
#  '堝': ['冂', '口', '土'],
#  '堡': ['口', '土', '木', '亻'],
#  '堤': ['土', '日', '疋'],
#  '堪': ['儿', '匚', '土', '甘'],
#  '堯': ['儿', '土'],
#  '堰': ['匚', '土', '女', '日'],
#  '報': ['亠', '十', '卩', '又', '土', '立', '辛'],
#  '場': ['土', '日', '勿'],
#  '堵': ['土', '日', '老'],
#  '堺': ['儿', '八', '土', '田'],
#  '堽': ['土', '止', '网'],
#  '塀': ['｜', '丿', '二', '八', '土', '尸', '廾'],
#  '塁': ['冫', '土', '田'],
#  '塊': ['儿', '匕', '厶', '土', '田', '鬼'],
#  '塋': ['冖', '土', '火'],
#  '塑': ['土', '屮', '月', '丷'],
#  '塒': ['土', '寸', '日'],
#  '塔': ['口', '土', '个', '艹'],
#  '塗': ['亅', '八', '土', '木', '个', '氵'],
#  '塘': ['｜', '口', '土', '广', '彐'],
#  '塙': ['亠', '冂', '口', '土', '高'],
#  '塚': ['冖', '土', '豕'],
#  '塞': ['八', '土', '宀'],
#  '塢': ['土', '鳥', '灬'],
#  '塩': ['口', '土', '皿'],
#  '填': ['八', '十', '土', '目'],
#  '塰': ['土', '毋', '氵'],
#  '塲': ['土', '日', '勿'],
#  '塵': ['土', '广', '比', '鹿'],
#  '塹': ['土', '斤', '車'],
#  '塾': ['丶', '亠', '口', '土', '子', '九'],
#  '境': ['儿', '土', '日', '立', '音'],
#  '墅': ['土', '里', 'マ'],
#  '墓': ['土', '大', '日', '艹'],
#  '増': ['土', '日', '田', '丷'],
#  '墜': ['土', '豕', '丷', '阝.'],
#  '墟': ['｜', '匕', '卜', '厂', '土', '虍', '丷'],
#  '墨': ['土', '里', '黒', '灬'],
#  '墫': ['土', '寸', '酉', '丷'],
#  '墮': ['土', '工', '月', '阝.'],
#  '墳': ['十', '土', '貝', '艹'],
#  '墸': ['土', '日', '老', '艹'],
#  '墹': ['土', '日', '門'],
#  '墺': ['冂', '土', '大', '米'],
#  '墻': ['人', '口', '囗', '土'],
#  '墾': ['土', '爪', '艮', '豸', '犭'],
#  '壁': ['十', '口', '土', '尸', '立', '辛'],
#  '壅': ['亠', '土', '隹'],
#  '壇': ['亠', '口', '囗', '土', '日'],
#  '壊': ['十', '土', '网', '衣'],
#  '壌': ['亠', '八', '土', '衣'],
#  '壑': ['八', '冖', '卜', '又', '口', '土', '个'],
#  '壓': ['厂', '土', '日', '月', '犬'],
#  '壕': ['亠', '冖', '口', '土', '豕'],
#  '壗': ['土', '彐', '皿', '聿', '灬'],
#  '壘': ['土', '田'],
#  '壙': ['｜', '二', '八', '土', '广', '田', '黄'],
#  '壜': ['二', '厶', '土', '日', '雨'],
#  '壞': ['亠', '土', '网', '衣'],
#  '壟': ['土', '月', '立'],
#  '壤': ['｜', '亠', '口', '土', '衣'],
#  '壥': ['厂', '土', '里', '黒', '灬'],
#  '壬': ['丿', '士'],
#  '壮': ['士', '爿'],
#  '壯': ['士', '爿'],
#  '声': ['士', '尸'],
#  '壱': ['冖', '匕', '士'],
#  '売': ['儿', '冖', '士'],
#  '壷': ['｜', '冖', '口', '士'],
#  '壹': ['冖', '口', '士', '豆', '丷'],
#  '壺': ['冖', '士'],
#  '壻': ['土', '月', '疋'],
#  '壼': ['二', '冖', '士'],
#  '壽': ['口', '士', '寸', '工'],
#  '夂': ['攴'],
#  '変': ['亠', '夂'],
#  '夊': ['夂'],
#  '夏': ['夂', '自'],
#  '夐': ['人', '冂', '勹', '夂', '目'],
#  '外': ['卜', '夕'],
#  '夘': ['卩', '夕'],
#  '夙': ['几', '歹'],
#  '多': ['夕'],
#  '夛': ['夕', '彐'],
#  '夜': ['亠', '夕', '亻'],
#  '夢': ['冖', '夕', '网', '艹'],
#  '夥': ['夕', '木', '田'],
#  '天': ['大'],
#  '太': ['丶', '大'],
#  '夫': ['二', '人', '大'],
#  '夬': ['二', '人', '大', 'ユ'],
#  '夭': ['丿', '大'],
#  '央': ['丿', '冖', '大'],
#  '失': ['丿', '二', '人', '大'],
#  '夲': ['十', '大'],
#  '夷': ['丿', '大', '弓'],
#  '夸': ['二', '勹', '大'],
#  '夾': ['人', '大'],
#  '奄': ['乙', '大', '日'],
#  '奇': ['亅', '口', '大'],
#  '奈': ['大', '示'],
#  '奉': ['｜', '丿', '二', '人', '大'],
#  '奎': ['土', '大'],
#  '奏': ['｜', '丿', '二', '大', '禾'],
#  '奐': ['儿', '冂', '勹', '大'],
#  '契': ['亠', '刀', '土', '大'],
#  '奔': ['丿', '十', '大', '廾'],
#  '奕': ['亠', '八', '大', '赤'],
#  '套': ['厶', '大', '長'],
#  '奘': ['士', '大', '爿'],
#  '奚': ['大', '幺', '爪'],
#  '奠': ['大', '酉', '丷'],
#  '奢': ['大', '日', '老'],
#  '奥': ['冂', '大', '米'],
#  '奧': ['丿', '冂', '大', '米'],
#  '奨': ['大', '寸', '爪', '爿'],
#  '奩': ['匚', '口', '大', '品'],
#  '奪': ['大', '寸', '隹'],
#  '奬': ['夕', '大', '寸', '爿'],
#  '奮': ['大', '田', '隹'],
#  '奴': ['又', '女'],
#  '奸': ['女', '干'],
#  '好': ['女', '子'],
#  '妁': ['丶', '勹', '女'],
#  '如': ['口', '女'],
#  '妃': ['女', '己'],
#  '妄': ['亠', '女', '亡'],
#  '妊': ['丿', '士', '女', '玉'],
#  '妍': ['｜', '丿', '二', '女', '廾'],
#  '妓': ['十', '又', '女', '支'],
#  '妖': ['丿', '大', '女'],
#  '妙': ['丿', '女', '小'],
#  '妛': ['女', '山'],
#  '妝': ['女', '爿'],
#  '妣': ['女', '比'],
#  '妥': ['女', '爪'],
#  '妨': ['女', '方'],
#  '妬': ['口', '女', '石'],
#  '妲': ['女', '日'],
#  '妹': ['｜', '二', '亠', '八', '女', '木'],
#  '妻': ['｜', '女', '彐'],
#  '妾': ['女', '立'],
#  '姆': ['女', '毋'],
#  '姉': ['亠', '女', '巾'],
#  '始': ['厶', '口', '女'],
#  '姐': ['女', '目'],
#  '姑': ['十', '口', '女'],
#  '姓': ['女', '生'],
#  '委': ['女', '禾'],
#  '姙': ['丿', '士', '女', '亻'],
#  '姚': ['儿', '冫', '女'],
#  '姜': ['女', '玉', '羊', '丷'],
#  '姥': ['匕', '女', '老'],
#  '姦': ['女'],
#  '姨': ['人', '大', '女', '弓'],
#  '姪': ['厶', '土', '女', '至'],
#  '姫': ['女', '臣'],
#  '姶': ['口', '女', '个'],
#  '姻': ['囗', '大', '女'],
#  '姿': ['冫', '女', '欠'],
#  '威': ['丿', '厂', '女', '戈'],
#  '娃': ['土', '女'],
#  '娉': ['｜', '勹', '女', '田'],
#  '娑': ['丿', '女', '小', '氵'],
#  '娘': ['女', '艮'],
#  '娚': ['力', '女', '田'],
#  '娜': ['二', '刀', '女', '.阝'],
#  '娟': ['口', '女', '月'],
#  '娠': ['厂', '女', '衣', '辰'],
#  '娥': ['亅', '女', '戈'],
#  '娩': ['儿', '女', '免'],
#  '娯': ['八', '口', '女'],
#  '娵': ['又', '女', '耳'],
#  '娶': ['又', '女', '耳'],
#  '娼': ['女', '日'],
#  '婀': ['亅', '口', '女', '阝.'],
#  '婁': ['｜', '口', '女'],
#  '婆': ['又', '女', '皮', '氵'],
#  '婉': ['卩', '夕', '女', '宀'],
#  '婚': ['女', '日', '氏'],
#  '婢': ['十', '女', '田'],
#  '婦': ['冖', '女', '巾', '彐'],
#  '婪': ['女', '木'],
#  '婬': ['丿', '士', '女', '爪'],
#  '婿': ['女', '月', '疋'],
#  '媒': ['女', '木', '甘'],
#  '媚': ['｜', '女', '尸', '目'],
#  '媛': ['丿', '又', '女', '爪'],
#  '媼': ['女', '日', '皿'],
#  '媽': ['女', '馬'],
#  '媾': ['｜', '二', '冂', '女'],
#  '嫁': ['女', '宀', '豕'],
#  '嫂': ['｜', '又', '女', '田'],
#  '嫉': ['女', '疒', '矢'],
#  '嫋': ['冫', '女', '弓'],
#  '嫌': ['｜', '八', '女', '彐', '丷'],
#  '嫐': ['力', '女', '田'],
#  '嫖': ['女', '示', '襾'],
#  '嫗': ['匚', '口', '女', '品'],
#  '嫡': ['亠', '冂', '十', '口', '女', '立', '丷', '啇'],
#  '嫣': ['女', '止', '鳥', '灬'],
#  '嫦': ['口', '女', '巾', '尚'],
#  '嫩': ['｜', '八', '口', '女', '攴', '木'],
#  '嫺': ['女', '日', '門'],
#  '嫻': ['女', '木', '門'],
#  '嬉': ['口', '士', '女', '豆', '丷'],
#  '嬋': ['｜', '十', '口', '女', '田'],
#  '嬌': ['丿', '冂', '口', '大', '女'],
#  '嬖': ['十', '口', '女', '尸', '立', '辛'],
#  '嬢': ['亠', '八', '女', '衣'],
#  '嬪': ['丿', '女', '宀', '小', '貝'],
#  '嬬': ['女', '而', '雨'],
#  '嬰': ['女', '貝'],
#  '嬲': ['力', '女', '田'],
#  '嬶': ['女', '廾', '田', '目', '自', '鼻'],
#  '嬾': ['｜', '八', '口', '女', '木', '貝', '頁'],
#  '孀': ['女', '木', '目', '雨'],
#  '孃': ['｜', '亠', '口', '女', '衣'],
#  '孅': ['人', '女', '戈', '韭'],
#  '孔': ['乙', '子'],
#  '孕': ['子', '乃'],
#  '字': ['子', '宀'],
#  '存': ['｜', '丿', '子'],
#  '孚': ['子', '爪'],
#  '孛': ['冖', '十', '士', '子'],
#  '孜': ['子', '攴'],
#  '孝': ['子', '老'],
#  '孟': ['子', '皿'],
#  '季': ['子', '禾'],
#  '孤': ['子', '瓜'],
#  '孥': ['又', '女', '子'],
#  '学': ['冖', '子', '尚'],
#  '孩': ['亠', '子'],
#  '孫': ['丿', '子', '糸'],
#  '孰': ['丶', '亠', '口', '子', '九'],
#  '孱': ['子', '尸'],
#  '孳': ['子', '幺', '丷'],
#  '孵': ['丶', '卩', '子', '爪'],
#  '學': ['冖', '子', '臼'],
#  '孺': ['｜', '冂', '子', '而', '雨'],
#  '它': ['匕', '宀'],
#  '宅': ['丿', '乙', '宀'],
#  '宇': ['亅', '宀', '干'],
#  '守': ['宀', '寸'],
#  '安': ['女', '宀'],
#  '宋': ['宀', '木'],
#  '完': ['二', '儿', '宀', '元'],
#  '宍': ['亠', '八', '宀'],
#  '宏': ['丿', '厶', '宀'],
#  '宕': ['口', '宀', '石'],
#  '宗': ['宀', '示'],
#  '官': ['口', '宀'],
#  '宙': ['｜', '宀', '日', '田'],
#  '定': ['宀', '疋'],
#  '宛': ['卩', '夕', '宀'],
#  '宜': ['宀', '目'],
#  '宝': ['丶', '宀', '玉'],
#  '実': ['士', '大', '宀'],
#  '客': ['口', '夂', '宀'],
#  '宣': ['宀', '日'],
#  '室': ['厶', '土', '宀', '至'],
#  '宥': ['丿', '宀', '月'],
#  '宦': ['宀', '臣'],
#  '宮': ['口', '宀'],
#  '宰': ['十', '宀', '立', '辛'],
#  '害': ['亠', '口', '土', '宀'],
#  '宴': ['女', '宀', '日'],
#  '宵': ['宀', '月', '尚'],
#  '家': ['宀', '豕'],
#  '宸': ['厂', '宀', '衣', '辰'],
#  '容': ['八', '口', '宀', '穴', '谷', '个'],
#  '宿': ['宀', '白', '亻'],
#  '寂': ['卜', '又', '宀', '小'],
#  '寃': ['丶', '儿', '宀', '免'],
#  '寄': ['亅', '口', '大', '宀'],
#  '寅': ['八', '宀', '田'],
#  '密': ['丶', '丿', '宀', '山', '心'],
#  '寇': ['二', '儿', '卜', '又', '宀', '元'],
#  '寉': ['宀', '隹'],
#  '富': ['口', '宀', '田'],
#  '寐': ['亅', '二', '八', '宀', '爿'],
#  '寒': ['丶', '八', '宀', '井'],
#  '寓': ['冂', '厶', '宀', '田', '禸'],
#  '寔': ['宀', '日', '疋'],
#  '寛': ['宀', '見', '艹'],
#  '寝': ['冖', '又', '宀', '彐', '爿'],
#  '寞': ['大', '宀', '日', '艹'],
#  '察': ['丿', '宀', '癶', '示'],
#  '寡': ['八', '刀', '宀', '自'],
#  '寢': ['冖', '又', '宀', '彐', '爿'],
#  '寤': ['口', '宀', '爿', '五'],
#  '寥': ['冫', '宀', '彡', '羽', '个'],
#  '實': ['宀', '田', '貝'],
#  '寧': ['亅', '宀', '心', '网'],
#  '寨': ['｜', '八', '宀', '木'],
#  '審': ['宀', '田', '米', '釆'],
#  '寫': ['勹', '宀', '臼', '灬'],
#  '寮': ['宀', '小', '日', '个', '丷'],
#  '寰': ['口', '宀', '网', '衣'],
#  '寳': ['宀', '小', '玉', '貝'],
#  '寵': ['宀', '月', '立'],
#  '寶': ['凵', '宀', '玉', '缶', '貝'],
#  '寺': ['土', '寸'],
#  '対': ['寸', '文'],
#  '寿': ['丿', '二', '寸'],
#  '封': ['土', '寸'],
#  '専': ['十', '寸', '田'],
#  '射': ['寸', '身'],
#  '尅': ['儿', '十', '口', '寸'],
#  '将': ['寸', '爪', '爿'],
#  '將': ['夕', '寸', '爿'],
#  '專': ['十', '厶', '寸', '田', '虫'],
#  '尉': ['寸', '尸', '示'],
#  '尊': ['寸', '酉', '丷'],
#  '尋': ['口', '寸', '工', '彐'],
#  '對': ['寸', '玉', '羊', '丷'],
#  '導': ['寸', '自', '丷', '辶'],
#  '少': ['丿', '小'],
#  '尓': ['丿', '小'],
#  '尖': ['大', '小'],
#  '尚': ['冂', '口'],
#  '尠': ['丿', '儿', '匚', '小', '甘'],
#  '尤': ['丶', '尢'],
#  '尨': ['丶', '尢', '彡', '尤'],
#  '尭': ['儿', '十', '廾'],
#  '就': ['丶', '亠', '口', '小', '尢', '尤'],
#  '尹': ['丿', '彐'],
#  '尺': ['丶', '尸'],
#  '尻': ['尸', '九'],
#  '尼': ['匕', '尸'],
#  '尽': ['丶', '尸'],
#  '尾': ['尸', '毛'],
#  '尿': ['尸', '水'],
#  '局': ['口', '尸'],
#  '屁': ['尸', '比'],
#  '居': ['十', '口', '尸'],
#  '屆': ['凵', '土', '士', '尸'],
#  '屈': ['｜', '尸', '山'],
#  '届': ['｜', '尸', '日', '田'],
#  '屋': ['厶', '土', '尸', '至'],
#  '屍': ['匕', '夕', '尸', '歹'],
#  '屎': ['尸', '米'],
#  '屏': ['｜', '丿', '二', '尸', '廾', '丷'],
#  '屐': ['十', '又', '尸', '彳', '支'],
#  '屑': ['尸', '月', '尚'],
#  '屓': ['尸', '貝'],
#  '展': ['｜', '二', '尸', '衣'],
#  '属': ['丿', '尸', '禸'],
#  '屠': ['尸', '日', '老'],
#  '屡': ['女', '尸', '米'],
#  '層': ['尸', '日', '田', '丷'],
#  '履': ['夂', '尸', '彳', '日'],
#  '屬': ['勹', '尸', '网', '虫'],
#  '屯': ['丿', '乙', '凵'],
#  '屶': ['刀', '山'],
#  '屹': ['丿', '乙', '山'],
#  '岌': ['山', '及'],
#  '岐': ['十', '又', '山', '支'],
#  '岑': ['山', '个'],
#  '岔': ['八', '刀', '山'],
#  '岡': ['冂', '山', '丷'],
#  '岨': ['｜', '山', '目'],
#  '岩': ['口', '山', '石'],
#  '岫': ['｜', '山', '田'],
#  '岬': ['｜', '山', '日', '田'],
#  '岱': ['山', '弋', '亻'],
#  '岳': ['山', '斤'],
#  '岶': ['山', '白'],
#  '岷': ['口', '山', '氏'],
#  '岸': ['厂', '山', '干'],
#  '岻': ['山', '氏'],
#  '岼': ['｜', '二', '山', '干', '丷'],
#  '岾': ['卜', '口', '山'],
#  '峅': ['厶', '山', '廾'],
#  '峇': ['口', '山', '个'],
#  '峙': ['土', '寸', '山'],
#  '峠': ['｜', '卜', '山'],
#  '峡': ['二', '亠', '人', '大', '山', '丷'],
#  '峨': ['亅', '山', '戈', '手'],
#  '峩': ['亅', '山', '戈'],
#  '峪': ['八', '口', '山', '谷', '个'],
#  '峭': ['山', '月', '尚'],
#  '峯': ['｜', '夂', '山'],
#  '峰': ['｜', '夂', '山'],
#  '島': ['山', '白', '鳥'],
#  '峺': ['丿', '山', '田'],
#  '峻': ['儿', '厶', '夂', '山'],
#  '峽': ['人', '大', '山'],
#  '崇': ['宀', '山', '示'],
#  '崋': ['｜', '山'],
#  '崎': ['｜', '口', '大', '山'],
#  '崑': ['山', '日', '比'],
#  '崔': ['山', '隹'],
#  '崕': ['厂', '土', '山'],
#  '崖': ['厂', '土', '山'],
#  '崗': ['冂', '凵', '山', '丷', '岡'],
#  '崘': ['｜', '山', '个', '冊'],
#  '崙': ['｜', '山', '个', '冊'],
#  '崚': ['儿', '土', '夂', '山'],
#  '崛': ['｜', '尸', '山'],
#  '崟': ['山', '金'],
#  '崢': ['亅', '尸', '山', '彐', '爪'],
#  '崩': ['山', '月'],
#  '嵋': ['｜', '尸', '山', '目'],
#  '嵌': ['山', '欠', '甘'],
#  '嵎': ['山', '田', '禸'],
#  '嵐': ['山', '風'],
#  '嵒': ['口', '山', '品'],
#  '嵜': ['亅', '亠', '口', '大', '山', '立', '丷'],
#  '嵩': ['亠', '冂', '口', '山', '高'],
#  '嵬': ['儿', '匕', '山', '田', '鬼'],
#  '嵯': ['丿', '山', '工', '玉', '羊', '丷'],
#  '嵳': ['山', '工', '玉', '羊', '丷'],
#  '嵶': ['冫', '山', '弓'],
#  '嶂': ['十', '山', '日', '曰', '立', '音'],
#  '嶄': ['山', '斤', '車'],
#  '嶇': ['匚', '口', '山', '品'],
#  '嶋': ['山', '鳥', '灬'],
#  '嶌': ['山', '鳥', '灬'],
#  '嶐': ['夂', '山', '生', '阝.'],
#  '嶝': ['口', '山', '癶', '豆', '丷'],
#  '嶢': ['儿', '土', '山'],
#  '嶬': ['亅', '山', '戈', '玉', '羊', '丷'],
#  '嶮': ['人', '口', '山', '个'],
#  '嶷': ['匕', '山', '疋', '矢'],
#  '嶺': ['卩', '山', '貝', '頁', '个'],
#  '嶼': ['八', '山', '臼'],
#  '嶽': ['山', '犬', '言'],
#  '巉': ['丶', '儿', '勹', '口', '山', '比'],
#  '巌': ['厂', '山', '攴', '耳', '尚'],
#  '巍': ['儿', '匕', '女', '山', '田', '禾', '鬼'],
#  '巒': ['山', '糸', '言'],
#  '巓': ['八', '十', '山', '目', '貝', '頁'],
#  '巖': ['厂', '口', '山', '攴', '耳'],
#  '州': ['｜', '丶', '巛'],
#  '巡': ['巛', '辶'],
#  '巣': ['木', '田', '尚'],
#  '左': ['丿', '工'],
#  '巧': ['勹', '工'],
#  '巨': ['匚'],
#  '巫': ['人', '工'],
#  '差': ['丿', '工', '玉', '羊', '丷'],
#  '巴': ['乙', '己'],
#  '巵': ['厂', '巴'],
#  '巷': ['八', '己', '井'],
#  '巻': ['二', '大', '己', '丷'],
#  '巽': ['｜', '二', '八', '己'],
#  '巾': ['｜', '冂'],
#  '市': ['亠', '巾'],
#  '布': ['丿', '巾'],
#  '帆': ['丶', '几', '巾'],
#  '帋': ['巾', '氏'],
#  '希': ['丿', '巾'],
#  '帑': ['又', '女', '巾'],
#  '帖': ['卜', '口', '巾'],
#  '帙': ['丿', '二', '人', '大', '巾'],
#  '帚': ['冖', '巾', '彐'],
#  '帛': ['巾', '白'],
#  '帝': ['亠', '冖', '巾', '立', '丷'],
#  '帥': ['｜', '口', '巾'],
#  '師': ['｜', '口', '巾'],
#  '席': ['巾', '广'],
#  '帯': ['｜', '冖', '巾'],
#  '帰': ['冖', '巾', '彐', '刂'],
#  '帳': ['巾', '長'],
#  '帶': ['儿', '冖', '凵', '巾'],
#  '帷': ['巾', '隹'],
#  '常': ['冖', '口', '巾', '尚'],
#  '帽': ['巾', '日', '目'],
#  '幀': ['卜', '巾', '貝'],
#  '幃': ['口', '巾', '韋'],
#  '幄': ['厶', '土', '尸', '巾', '至'],
#  '幅': ['口', '巾', '田'],
#  '幇': ['土', '寸', '巾'],
#  '幌': ['儿', '巾', '日', '尚'],
#  '幎': ['亠', '八', '冖', '巾', '日'],
#  '幔': ['又', '巾', '日', '网'],
#  '幕': ['大', '巾', '日', '艹'],
#  '幗': ['口', '囗', '巾', '戈'],
#  '幟': ['巾', '戈', '日', '立', '音'],
#  '幡': ['巾', '田', '米', '釆'],
#  '幢': ['巾', '立', '里'],
#  '幣': ['冂', '巾', '攴', '丷'],
#  '幤': ['冂', '口', '巾', '攴', '尚'],
#  '干': ['十'],
#  '平': ['干', '丷'],
#  '年': ['丿', '干'],
#  '幵': ['干'],
#  '并': ['丿', '二', '干', '丷'],
#  '幸': ['亠', '十', '立', '辛'],
#  '幹': ['十', '干', '日', '个'],
#  '幻': ['幺'],
#  '幼': ['力', '幺'],
#  '幽': ['｜', '凵', '幺'],
#  '幾': ['丿', '幺', '戈'],
#  '庁': ['亅', '广'],
#  '広': ['厶', '广'],
#  '庄': ['土', '广'],
#  '庇': ['广', '比'],
#  '床': ['广', '木'],
#  '序': ['亅', '子', '广'],
#  '底': ['广', '氏'],
#  '庖': ['勹', '己', '广'],
#  '店': ['卜', '口', '广'],
#  '庚': ['人', '广', '彐'],
#  '府': ['寸', '广', '亻'],
#  '庠': ['广', '玉', '羊', '丷'],
#  '度': ['又', '广'],
#  '座': ['｜', '入', '土', '广'],
#  '庫': ['广', '車'],
#  '庭': ['广', '廴', '玉'],
#  '庵': ['大', '广', '田'],
#  '庶': ['广', '灬'],
#  '康': ['广', '彐', '水', '隶'],
#  '庸': ['广', '彐', '用', '聿'],
#  '廁': ['广', '貝', '刂'],
#  '廂': ['广', '木', '目'],
#  '廃': ['儿', '广', '癶'],
#  '廈': ['夂', '广', '自'],
#  '廉': ['｜', '八', '广', '彐', '丷'],
#  '廊': ['广', '艮', '.阝'],
#  '廏': ['广', '殳', '艮'],
#  '廐': ['广', '无', '艮'],
#  '廓': ['亅', '亠', '口', '子', '广', '.阝'],
#  '廖': ['冫', '广', '彡', '羽', '个'],
#  '廚': ['口', '士', '寸', '广', '豆', '丷'],
#  '廛': ['儿', '土', '广', '里'],
#  '廝': ['八', '广', '斤', '甘'],
#  '廟': ['十', '广', '日', '月'],
#  '廠': ['冂', '口', '广', '攴', '尚'],
#  '廡': ['｜', '广', '灬', '無'],
#  '廢': ['广', '弓', '殳', '癶'],
#  '廣': ['八', '广', '田', '黄'],
#  '廨': ['刀', '广', '牛', '角'],
#  '廩': ['亠', '口', '囗', '广', '禾'],
#  '廬': ['匕', '卜', '厂', '广', '田', '皿', '虍'],
#  '廰': ['十', '广', '心', '网', '耳'],
#  '廱': ['口', '巛', '广', '隹', '巴'],
#  '廳': ['十', '广', '心', '玉', '网', '耳'],
#  '延': ['廴', '止'],
#  '廷': ['士', '廴', '玉'],
#  '廸': ['｜', '廴', '日'],
#  '建': ['廴', '聿'],
#  '廻': ['口', '囗', '廴'],
#  '廼': ['廴', '襾'],
#  '廿': ['｜', '凵'],
#  '弁': ['厶', '廾'],
#  '弃': ['亠', '厶', '廾'],
#  '弄': ['廾', '玉'],
#  '弉': ['士', '廾', '爿'],
#  '弊': ['｜', '冂', '巾', '廾', '攴', '丷', '尚'],
#  '弌': ['弋'],
#  '弍': ['二', '弋'],
#  '式': ['工', '弋'],
#  '弐': ['二', '弋'],
#  '弑': ['工', '弋', '木'],
#  '弔': ['｜', '弓'],
#  '引': ['｜', '弓'],
#  '弖': ['弓'],
#  '弗': ['｜', '丿', '弓'],
#  '弘': ['厶', '弓'],
#  '弛': ['弓', '也'],
#  '弟': ['｜', '丿', '弓', '丷'],
#  '弥': ['丿', '亅', '小', '弓'],
#  '弦': ['亠', '幺', '弓', '玄'],
#  '弧': ['弓', '瓜'],
#  '弩': ['又', '女', '弓'],
#  '弭': ['弓', '耳'],
#  '弯': ['亠', '八', '弓', '赤'],
#  '弱': ['冫', '弓'],
#  '張': ['弓', '長'],
#  '強': ['厶', '弓', '虫'],
#  '弸': ['弓', '月'],
#  '弼': ['丿', '弓', '白'],
#  '弾': ['十', '弓', '田', '尚'],
#  '彁': ['亅', '口', '弓'],
#  '彈': ['｜', '十', '口', '弓', '田'],
#  '彊': ['弓', '田'],
#  '彌': ['｜', '八', '冂', '弓', '爻'],
#  '彎': ['弓', '糸', '言'],
#  '彑': ['彐'],
#  '当': ['彐', '尚'],
#  '彖': ['豕', '彑'],
#  '彗': ['二', '亠', '土', '彐'],
#  '彙': ['冖', '彐', '木', '田', '彑'],
#  '彜': ['刀', '廾', '彐', '米', '丷', '彑'],
#  '彝': ['廾', '彐', '米', '糸', '彑'],
#  '形': ['丿', '廾', '彡'],
#  '彦': ['亠', '厂', '彡', '立', '丷'],
#  '彩': ['彡', '木', '爪'],
#  '彪': ['儿', '匕', '卜', '厂', '彡', '虍'],
#  '彫': ['冂', '口', '土', '彡'],
#  '彬': ['彡', '木'],
#  '彭': ['口', '土', '彡', '豆', '丷'],
#  '彰': ['十', '彡', '日', '立', '音'],
#  '影': ['亠', '口', '小', '彡', '日'],
#  '彷': ['彳', '方'],
#  '役': ['彳', '殳'],
#  '彼': ['又', '彳', '皮'],
#  '彿': ['｜', '丿', '弓', '彳'],
#  '往': ['丶', '彳', '玉'],
#  '征': ['彳', '止'],
#  '徂': ['彳', '目'],
#  '徃': ['彳', '生'],
#  '径': ['又', '土', '彳'],
#  '待': ['土', '寸', '彳'],
#  '徇': ['勹', '彳', '日'],
#  '很': ['彳', '艮'],
#  '徊': ['口', '囗', '彳'],
#  '律': ['彳', '聿'],
#  '後': ['夂', '幺', '彳'],
#  '徐': ['彳', '禾', '个'],
#  '徑': ['巛', '工', '彳'],
#  '徒': ['土', '彳', '走'],
#  '従': ['彳', '疋', '丷'],
#  '得': ['寸', '彳', '日'],
#  '徘': ['彳', '非'],
#  '徙': ['彳', '止', '疋'],
#  '從': ['人', '彳', '疋'],
#  '徠': ['｜', '人', '八', '彳', '木'],
#  '御': ['丿', '卩', '彳', '止'],
#  '徨': ['彳', '玉', '白'],
#  '復': ['夂', '彳', '日'],
#  '循': ['十', '厂', '彳', '斤', '目'],
#  '徭': ['凵', '夕', '彳', '缶'],
#  '微': ['山', '彳', '攴'],
#  '徳': ['十', '彳', '心', '网'],
#  '徴': ['山', '彳', '攴', '玉'],
#  '徹': ['亠', '厶', '彳', '攴', '月'],
#  '徼': ['夂', '彳', '方', '白'],
#  '徽': ['夂', '山', '彳', '糸'],
#  '必': ['丿', '心'],
#  '忌': ['己', '心'],
#  '忍': ['丶', '刀', '心'],
#  '忖': ['寸', '忄'],
#  '志': ['士', '心'],
#  '忘': ['亠', '心', '亡'],
#  '忙': ['亠', '忄', '亡'],
#  '応': ['广', '心'],
#  '忝': ['丿', '大', '心'],
#  '忠': ['｜', '口', '心'],
#  '忤': ['丿', '十', '干', '忄'],
#  '快': ['二', '人', '大', '忄'],
#  '忰': ['十', '九', '忄'],
#  '忱': ['儿', '冖', '尢', '忄'],
#  '念': ['｜', '心', '个'],
#  '忸': ['｜', '忄'],
#  '忻': ['斤', '忄'],
#  '忽': ['勹', '心', '勿'],
#  '忿': ['八', '刀', '心'],
#  '怎': ['｜', '丿', '心'],
#  '怏': ['人', '冂', '大', '忄'],
#  '怐': ['勹', '口', '忄'],
#  '怒': ['又', '女', '心'],
#  '怕': ['白', '忄'],
#  '怖': ['丿', '巾', '忄'],
#  '怙': ['十', '口', '忄'],
#  '怛': ['日', '忄'],
#  '怜': ['卩', '个', '忄'],
#  '思': ['心', '田'],
#  '怠': ['厶', '口', '心'],
#  '怡': ['厶', '口', '忄'],
#  '急': ['勹', '彐', '心'],
#  '怦': ['干', '丷', '忄'],
#  '性': ['生', '忄'],
#  '怨': ['卩', '夕', '心'],
#  '怩': ['匕', '尸', '忄'],
#  '怪': ['又', '土', '忄'],
#  '怫': ['｜', '丿', '弓', '忄'],
#  '怯': ['厶', '土', '忄'],
#  '怱': ['丶', '丿', '勹', '心', '勿'],
#  '怺': ['丶', '水', '忄'],
#  '恁': ['丿', '士', '心', '亻'],
#  '恂': ['勹', '日', '忄'],
#  '恃': ['土', '寸', '忄'],
#  '恆': ['｜', '彑', '忄'],
#  '恊': ['力', '忄'],
#  '恋': ['亠', '八', '心'],
#  '恍': ['儿', '尚', '忄'],
#  '恐': ['丶', '几', '工', '心'],
#  '恒': ['日', '忄'],
#  '恕': ['口', '女', '心'],
#  '恙': ['心', '玉', '羊', '丷'],
#  '恚': ['土', '心'],
#  '恟': ['凵', '勹', '忄'],
#  '恠': ['丿', '土', '忄'],
#  '恢': ['厂', '火', '忄'],
#  '恣': ['冫', '心', '欠'],
#  '恤': ['皿', '血', '忄'],
#  '恥': ['心', '耳'],
#  '恨': ['艮', '忄'],
#  '恩': ['囗', '大', '心'],
#  '恪': ['口', '夂', '忄'],
#  '恫': ['冂', '口', '忄'],
#  '恬': ['口', '舌', '忄'],
#  '恭': ['八', '心', '井'],
#  '息': ['心', '自'],
#  '恰': ['口', '个', '忄'],
#  '恵': ['心', '田'],
#  '恷': ['心', '木', '亻'],
#  '悁': ['口', '月', '忄'],
#  '悃': ['囗', '木', '忄'],
#  '悄': ['月', '尚', '忄'],
#  '悉': ['丿', '心', '米', '釆'],
#  '悋': ['口', '文', '忄'],
#  '悌': ['｜', '丿', '弓', '丷', '忄'],
#  '悍': ['干', '日', '忄'],
#  '悒': ['口', '忄', '巴'],
#  '悔': ['毋', '忄'],
#  '悖': ['冖', '十', '子', '忄'],
#  '悗': ['儿', '忄', '免'],
#  '悚': ['｜', '八', '口', '木', '忄'],
#  '悛': ['儿', '厶', '夂', '忄'],
#  '悟': ['口', '忄'],
#  '悠': ['｜', '夂', '心', '攴', '亻'],
#  '患': ['｜', '口', '心'],
#  '悦': ['儿', '口', '丷', '忄'],
#  '悧': ['禾', '刂', '忄'],
#  '悩': ['凵', '尚', '忄'],
#  '悪': ['｜', '口', '心'],
#  '悲': ['心', '非'],
#  '悳': ['十', '心', '目'],
#  '悴': ['亠', '人', '十', '忄'],
#  '悵': ['長', '忄'],
#  '悶': ['心', '門'],
#  '悸': ['子', '禾', '忄'],
#  '悼': ['十', '卜', '日', '忄'],
#  '悽': ['女', '彐', '忄'],
#  '情': ['二', '亠', '土', '月', '青', '忄'],
#  '惆': ['冂', '口', '土', '忄'],
#  '惇': ['亠', '口', '子', '忄'],
#  '惑': ['口', '心', '戈'],
#  '惓': ['二', '大', '己', '丷', '忄'],
#  '惘': ['冂', '工', '丷', '忄'],
#  '惚': ['心', '忄', '勿'],
#  '惜': ['｜', '二', '日', '忄'],
#  '惟': ['隹', '忄'],
#  '惠': ['｜', '厶', '心', '日', '虫'],
#  '惡': ['二', '心'],
#  '惣': ['心', '牛', '勿'],
#  '惧': ['八', '目', '忄'],
#  '惨': ['厶', '彡', '忄'],
#  '惰': ['丿', '工', '月', '忄'],
#  '惱': ['囗', '巛', '忄'],
#  '想': ['心', '木', '目'],
#  '惴': ['山', '而', '忄'],
#  '惶': ['玉', '白', '忄'],
#  '惷': ['二', '大', '心', '日'],
#  '惹': ['丿', '口', '心', '艹'],
#  '惺': ['日', '生', '忄'],
#  '惻': ['貝', '刂', '忄'],
#  '愀': ['火', '禾', '忄'],
#  '愁': ['心', '火', '禾'],
#  '愃': ['二', '宀', '日', '忄'],
#  '愆': ['彳', '心', '行', '氵'],
#  '愈': ['心', '月', '个', '刂'],
#  '愉': ['月', '个', '刂', '忄'],
#  '愍': ['口', '心', '攴', '氏'],
#  '愎': ['夂', '日', '忄'],
#  '意': ['心', '日', '立', '音'],
#  '愕': ['二', '勹', '口', '忄'],
#  '愚': ['冂', '厶', '心', '田', '禸'],
#  '愛': ['冖', '夂', '心', '爪'],
#  '感': ['丿', '口', '心', '戈'],
#  '愡': ['丶', '丿', '心', '忄', '勿'],
#  '愧': ['儿', '匕', '田', '鬼', '忄'],
#  '愨': ['冖', '士', '心', '殳'],
#  '愬': ['屮', '心', '月', '丷'],
#  '愴': ['人', '口', '戸', '忄'],
#  '愼': ['八', '匕', '目', '忄'],
#  '愽': ['丶', '十', '寸', '田', '忄'],
#  '愾': ['气', '米', '忄'],
#  '愿': ['厂', '小', '心', '白'],
#  '慂': ['心', '用', 'マ', '氵'],
#  '慄': ['木', '襾', '忄'],
#  '慇': ['心', '日', '殳'],
#  '慈': ['幺', '心', '丷'],
#  '慊': ['｜', '彐', '丷', '忄'],
#  '態': ['匕', '厶', '心', '月'],
#  '慌': ['亠', '巛', '忄', '艹'],
#  '慍': ['日', '皿', '忄'],
#  '慎': ['八', '十', '目', '忄'],
#  '慓': ['示', '襾', '忄'],
#  '慕': ['大', '心', '日', '艹'],
#  '慘': ['厶', '彡', '个', '忄'],
#  '慙': ['心', '斤', '車'],
#  '慚': ['斤', '車', '忄'],
#  '慝': ['丿', '匚', '厂', '口', '心', '艹'],
#  '慟': ['｜', '丿', '力', '日', '忄'],
#  '慢': ['又', '日', '网', '忄'],
#  '慣': ['毋', '貝', '忄'],
#  '慥': ['口', '土', '忄', '辶'],
#  '慧': ['｜', '彐', '心'],
#  '慨': ['牙', '艮', '忄'],
#  '慫': ['彳', '心', '疋', '丷'],
#  '慮': ['匕', '卜', '厂', '心', '田', '虍'],
#  '慯': ['丿', '勹', '日', '忄'],
#  '慰': ['寸', '尸', '心', '示'],
#  '慱': ['亠', '十', '厶', '寸', '日', '虫', '忄'],
#  '慳': ['又', '土', '臣', '忄'],
#  '慴': ['冫', '白', '羽', '忄'],
#  '慵': ['冂', '广', '彐', '用', '聿', '忄'],
#  '慶': ['冖', '夂', '广', '心'],
#  '慷': ['广', '彐', '水', '隶', '忄'],
#  '慾': ['八', '口', '心', '欠', '谷', '个'],
#  '憂': ['冖', '夂', '心', '自'],
#  '憇': ['口', '心', '甘', '舌'],
#  '憊': ['厂', '心', '用', '亻', '艹'],
#  '憎': ['日', '田', '丷', '忄'],
#  '憐': ['夕', '米', '舛', '忄'],
#  '憑': ['冫', '心', '馬'],
#  '憔': ['隹', '忄', '灬'],
#  '憖': ['｜', '人', '八', '心', '木', '犬'],
#  '憙': ['八', '口', '士', '心', '豆'],
#  '憚': ['｜', '十', '口', '田', '忄'],
#  '憤': ['十', '貝', '忄', '艹'],
#  '憧': ['立', '里', '忄'],
#  '憩': ['口', '心', '自', '舌'],
#  '憫': ['文', '門', '忄'],
#  '憬': ['亠', '口', '小', '日', '忄'],
#  '憮': ['忄', '灬', '無'],
#  '憲': ['亠', '土', '宀', '心', '网'],
#  '憶': ['心', '日', '立', '音', '忄'],
#  '憺': ['儿', '勹', '厂', '言', '忄'],
#  '憾': ['丿', '口', '心', '戈', '忄'],
#  '懃': ['力', '心', '艹'],
#  '懆': ['口', '木', '忄', '品'],
#  '懇': ['心', '爪', '艮', '豸', '犭'],
#  '懈': ['刀', '牛', '角', '忄'],
#  '應': ['广', '心', '隹', '亻'],
#  '懊': ['冂', '大', '米', '忄'],
#  '懋': ['心', '木', '矛', 'マ'],
#  '懌': ['亠', '十', '土', '立', '网', '辛', '忄'],
#  '懍': ['亠', '口', '囗', '禾', '忄'],
#  '懐': ['十', '网', '衣', '忄'],
#  '懣': ['｜', '入', '冂', '凵', '心', '氵'],
#  '懦': ['而', '雨', '忄'],
#  '懲': ['山', '彳', '心', '攴', '玉'],
#  '懴': ['土', '戈', '韭', '忄'],
#  '懶': ['｜', '八', '口', '木', '貝', '頁', '忄'],
#  '懷': ['亠', '网', '衣', '忄'],
#  '懸': ['丿', '小', '心', '目', '糸'],
#  '懺': ['人', '戈', '韭', '忄'],
#  '懼': ['目', '隹', '忄'],
#  '懽': ['十', '口', '隹', '忄', '艹'],
#  '懾': ['耳', '忄'],
#  '懿': ['冖', '冫', '口', '士', '心', '欠', '豆', '丷'],
#  '戀': ['心', '糸', '言'],
#  '戉': ['戈'],
#  '戊': ['丿', '戈'],
#  '戌': ['丿', '戈'],
#  '戍': ['丶', '丿', '戈'],
#  '戎': ['戈'],
#  '成': ['丿', '戈'],
#  '我': ['亅', '戈', '手'],
#  '戒': ['廾', '戈'],
#  '戔': ['戈'],
#  '或': ['口', '戈'],
#  '戚': ['丿', '卜', '小', '戈'],
#  '戛': ['戈', '白', '自'],
#  '戝': ['戈', '貝'],
#  '戞': ['冖', '戈', '自'],
#  '戟': ['十', '戈', '日'],
#  '戡': ['儿', '匚', '戈', '甘'],
#  '戦': ['十', '戈', '田', '尚'],
#  '截': ['土', '戈', '隹'],
#  '戮': ['冫', '彡', '戈', '羽', '个'],
#  '戯': ['匕', '卜', '厂', '戈', '虍'],
#  '戰': ['｜', '十', '口', '戈', '田'],
#  '戲': ['匕', '卜', '厂', '口', '戈', '虍', '豆', '丷'],
#  '戳': ['彐', '戈', '隹'],
#  '戴': ['｜', '二', '八', '土', '戈', '田'],
#  '戻': ['大', '戸'],
#  '房': ['戸', '方'],
#  '所': ['戸', '斤'],
#  '扁': ['｜', '冂', '戸', '冊'],
#  '扇': ['冫', '戸', '羽'],
#  '扈': ['口', '戸', '.阝', '巴'],
#  '扉': ['戸', '非'],
#  '才': ['丿', '亅'],
#  '扎': ['乙', '扌'],
#  '打': ['亅', '扌'],
#  '払': ['厶', '扌'],
#  '托': ['丿', '乙', '扌'],
#  '扛': ['工', '扌'],
#  '扞': ['干', '扌'],
#  '扠': ['丶', '又', '扌'],
#  '扣': ['口', '扌'],
#  '扨': ['丶', '刀', '扌'],
#  '扮': ['八', '刀', '扌'],
#  '扱': ['扌', '及'],
#  '扶': ['二', '人', '大', '扌'],
#  '批': ['比', '扌'],
#  '扼': ['卩', '厂', '扌'],
#  '找': ['戈', '扌'],
#  '承': ['丿', '亅', '二', '手', 'マ'],
#  '技': ['十', '又', '支', '扌'],
#  '抂': ['玉', '扌'],
#  '抃': ['亠', '卜', '扌'],
#  '抄': ['丿', '小', '扌'],
#  '抉': ['二', '人', '大', 'ユ', '扌'],
#  '把': ['扌', '巴'],
#  '抑': ['卩', '扌'],
#  '抒': ['亅', '矛', 'マ', '扌'],
#  '抓': ['爪', '扌'],
#  '抔': ['｜', '丶', '丿', '扌'],
#  '投': ['殳', '扌'],
#  '抖': ['斗', '扌'],
#  '抗': ['亠', '几', '扌'],
#  '折': ['斤', '扌'],
#  '抛': ['丿', '力', '九', '扌'],
#  '抜': ['亠', '又', '夂', '扌'],
#  '択': ['尸', '扌'],
#  '披': ['又', '皮', '扌'],
#  '抬': ['厶', '口', '扌'],
#  '抱': ['勹', '己', '扌'],
#  '抵': ['氏', '扌'],
#  '抹': ['｜', '亠', '八', '木', '扌'],
#  '抻': ['｜', '日', '田', '扌'],
#  '押': ['｜', '日', '田', '扌'],
#  '抽': ['｜', '日', '田', '扌'],
#  '拂': ['｜', '丿', '弓', '扌'],
#  '担': ['日', '扌'],
#  '拆': ['丶', '斤', '扌'],
#  '拇': ['毋', '扌'],
#  '拈': ['卜', '口', '扌'],
#  '拉': ['立', '扌'],
#  '拊': ['寸', '亻', '扌'],
#  '拌': ['｜', '二', '十', '干', '丷', '尚', '扌'],
#  '拍': ['白', '扌'],
#  '拏': ['又', '女', '手'],
#  '拐': ['刀', '口', '扌'],
#  '拑': ['甘', '扌'],
#  '拒': ['匚', '扌', '巨'],
#  '拓': ['口', '石', '扌'],
#  '拔': ['丶', '丿', '扌'],
#  '拗': ['力', '幺', '扌'],
#  '拘': ['勹', '口', '扌'],
#  '拙': ['｜', '山', '扌'],
#  '招': ['刀', '口', '扌'],
#  '拜': ['丿', '干', '扌'],
#  '拝': ['｜', '干', '扌'],
#  '拠': ['几', '夂', '扌'],
#  '拡': ['厶', '广', '扌'],
#  '括': ['丿', '十', '口', '舌', '扌'],
#  '拭': ['工', '弋', '扌'],
#  '拮': ['口', '士', '扌'],
#  '拯': ['水', '扌'],
#  '拱': ['｜', '二', '八', '扌'],
#  '拳': ['大', '手', '丷'],
#  '拵': ['丿', '子', '扌'],
#  '拶': ['夕', '巛', '扌'],
#  '拷': ['老', '扌'],
#  '拾': ['口', '个', '扌'],
#  '拿': ['口', '手', '个'],
#  '持': ['土', '寸', '扌'],
#  '挂': ['土', '扌'],
#  '指': ['匕', '日', '扌'],
#  '挈': ['刀', '土', '手'],
#  '按': ['女', '宀', '扌'],
#  '挌': ['口', '夂', '扌'],
#  '挑': ['儿', '冫', '扌'],
#  '挙': ['八', '手', '尚'],
#  '挟': ['丶', '二', '亠', '人', '大', '丷', '扌'],
#  '挧': ['冫', '羽', '扌'],
#  '挨': ['厶', '矢', '扌'],
#  '挫': ['｜', '入', '土', '扌'],
#  '振': ['厂', '衣', '辰', '扌'],
#  '挺': ['廴', '玉', '扌'],
#  '挽': ['｜', '儿', '扌', '免'],
#  '挾': ['人', '大', '扌'],
#  '挿': ['｜', '丿', '十', '日', '田', '扌'],
#  '捉': ['口', '足', '扌'],
#  '捌': ['力', '口', '刂', '扌'],
#  '捍': ['干', '日', '扌'],
#  '捏': ['土', '日', '扌'],
#  '捐': ['口', '月', '扌'],
#  '捕': ['丶', '十', '用', '扌'],
#  '捗': ['丿', '小', '止', '扌'],
#  '捜': ['｜', '又', '日', '田', '扌'],
#  '捧': ['｜', '丿', '二', '人', '大', '扌'],
#  '捨': ['口', '土', '个', '扌'],
#  '捩': ['大', '戸', '扌'],
#  '捫': ['門', '扌'],
#  '据': ['十', '口', '尸', '扌'],
#  '捲': ['大', '己', '丷', '扌'],
#  '捶': ['｜', '丿', '二', '扌'],
#  '捷': ['彐', '疋', '扌'],
#  '捺': ['大', '示', '扌'],
#  '捻': ['｜', '心', '个', '扌'],
#  '掀': ['斤', '欠', '扌'],
#  '掃': ['冖', '巾', '彐', '扌'],
#  '授': ['冖', '又', '爪', '扌'],
#  '掉': ['十', '卜', '日', '曰', '扌'],
#  '掌': ['冖', '口', '手', '尚'],
#  '掎': ['亅', '口', '大', '扌'],
#  '掏': ['凵', '勹', '缶', '扌'],
#  '排': ['非', '扌'],
#  '掖': ['丶', '亠', '夂', '夕', '亻', '扌'],
#  '掘': ['｜', '尸', '山', '扌'],
#  '掛': ['卜', '土', '扌'],
#  '掟': ['宀', '疋', '扌'],
#  '掠': ['亠', '口', '小', '扌'],
#  '採': ['木', '爪', '扌'],
#  '探': ['儿', '冖', '木', '扌'],
#  '掣': ['凵', '巾', '手', '牛', '缶', '刂'],
#  '接': ['女', '立', '扌'],
#  '控': ['儿', '宀', '工', '穴', '扌'],
#  '推': ['隹', '扌'],
#  '掩': ['乙', '大', '日', '扌', '奄'],
#  '措': ['｜', '二', '日', '扌'],
#  '掫': ['又', '耳', '扌'],
#  '掬': ['勹', '米', '扌'],
#  '掲': ['勹', '匕', '日', '扌'],
#  '掴': ['丶', '囗', '玉', '扌'],
#  '掵': ['卩', '口', '个', '扌'],
#  '掻': ['又', '虫', '扌'],
#  '掾': ['彐', '豕', '扌'],
#  '揀': ['｜', '八', '日', '木', '扌'],
#  '揃': ['月', '丷', '刂', '扌'],
#  '揄': ['月', '个', '刂', '扌'],
#  '揆': ['二', '人', '大', '癶', '扌'],
#  '揉': ['木', '矛', 'マ', '扌'],
#  '描': ['田', '扌', '艹'],
#  '提': ['日', '疋', '扌'],
#  '插': ['丿', '十', '臼', '扌'],
#  '揖': ['口', '耳', '扌'],
#  '揚': ['日', '扌', '勿'],
#  '換': ['儿', '冂', '勹', '大', '扌'],
#  '握': ['厶', '土', '尸', '至', '扌'],
#  '揣': ['山', '而', '扌'],
#  '揩': ['比', '白', '扌'],
#  '揮': ['冖', '車', '扌'],
#  '援': ['丿', '又', '爪', '扌'],
#  '揶': ['耳', '扌', '.阝'],
#  '揺': ['凵', '干', '爪', '缶', '扌'],
#  '搆': ['｜', '八', '冂', '黄', '扌'],
#  '損': ['口', '貝', '扌'],
#  '搏': ['丶', '十', '寸', '田', '扌'],
#  '搓': ['工', '玉', '羊', '丷', '扌'],
#  '搖': ['凵', '夕', '缶', '扌'],
#  '搗': ['山', '鳥', '扌'],
#  '搜': ['｜', '十', '又', '支', '臼', '扌'],
#  '搦': ['冫', '弓', '扌'],
#  '搨': ['冫', '日', '羽', '扌'],
#  '搬': ['殳', '舟', '扌'],
#  '搭': ['口', '个', '扌', '艹'],
#  '搴': ['｜', '二', '八', '宀', '手'],
#  '搶': ['口', '戸', '个', '扌'],
#  '携': ['丿', '隹', '乃', '扌'],
#  '搾': ['｜', '丿', '儿', '宀', '穴', '扌'],
#  '摂': ['冫', '耳', '扌'],
#  '摎': ['冫', '彡', '羽', '个', '扌'],
#  '摘': ['亠', '冂', '十', '口', '立', '丷', '扌', '啇'],
#  '摧': ['山', '隹', '扌'],
#  '摩': ['广', '手', '木', '麻'],
#  '摯': ['丶', '丿', '十', '手', '立', '辛', '九'],
#  '摶': ['十', '厶', '寸', '日', '虫', '扌'],
#  '摸': ['大', '日', '扌', '艹'],
#  '摺': ['冫', '白', '羽', '扌'],
#  '撃': ['手', '殳', '車'],
#  '撈': ['冖', '力', '火', '扌'],
#  '撒': ['｜', '夂', '攴', '月', '扌'],
#  '撓': ['儿', '土', '扌'],
#  '撕': ['八', '斤', '甘', '扌'],
#  '撚': ['夕', '犬', '扌', '灬'],
#  '撞': ['立', '里', '扌'],
#  '撤': ['亠', '厶', '攴', '月', '扌'],
#  '撥': ['二', '儿', '癶', '扌'],
#  '撩': ['亠', '人', '大', '小', '日', '丷', '扌'],
#  '撫': ['｜', '丿', '扌', '灬', '無'],
#  '播': ['田', '米', '釆', '扌'],
#  '撮': ['又', '日', '耳', '扌'],
#  '撰': ['｜', '二', '八', '己', '扌'],
# ...
#  '雉': ['矢', '隹'],
#  '雋': ['亅', '冂', '凵', '隹'],
#  '雌': ['匕', '止', '隹'],
#  '雍': ['亠', '幺', '隹'],
#  '雎': ['目', '隹'],
#  '雑': ['木', '隹', '九'],
#  '雕': ['冂', '口', '士', '隹'],
#  '雖': ['口', '虫', '隹'],
#  '雙': ['又', '隹'],
#  '雛': ['勹', '屮', '隹'],
#  '雜': ['亠', '人', '木', '隹'],
#  '離': ['亠', '凵', '禸', '隹'],
#  '難': ['亠', '口', '大', '隹', '艹'],
#  '雪': ['彐', '雨'],
#  '雫': ['｜', '丶', '雨'],
#  '雰': ['八', '刀', '雨'],
#  '雲': ['二', '厶', '雨'],
#  '零': ['卩', '雨', '个'],
#  '雷': ['田', '雨'],
#  '雹': ['勹', '己', '雨'],
#  '電': ['乙', '田', '雨'],
#  '需': ['而', '雨'],
#  '霄': ['月', '雨', '尚'],
#  '霆': ['廴', '玉', '雨'],
#  '震': ['厂', '衣', '辰', '雨'],
#  '霈': ['亠', '巾', '雨', '氵'],
#  '霊': ['｜', '二', '雨'],
#  '霍': ['隹', '雨'],
#  '霎': ['女', '立', '雨'],
#  '霏': ['雨', '非'],
#  '霑': ['卜', '口', '雨', '氵'],
#  '霓': ['儿', '臼', '雨'],
#  '霖': ['木', '雨'],
#  '霙': ['冂', '大', '雨', '艹'],
#  '霜': ['木', '目', '雨'],
#  '霞': ['又', '雨'],
#  '霤': ['刀', '厶', '田', '雨'],
#  '霧': ['力', '夂', '矛', '雨'],
#  '霪': ['爪', '玉', '雨', '氵'],
#  '霰': ['｜', '二', '攴', '月', '雨'],
#  '露': ['口', '夂', '足', '雨'],
#  '霸': ['月', '雨', '革'],
#  '霹': ['十', '口', '尸', '立', '辛', '雨'],
#  '霽': ['亠', '雨', '齊'],
#  '霾': ['豸', '里', '雨'],
#  '靂': ['厂', '木', '止', '雨'],
#  '靄': ['勹', '匕', '日', '言', '雨'],
#  '靆': ['二', '厶', '彐', '水', '隶', '雨', '辶'],
#  '靈': ['人', '口', '工', '雨'],
#  '靉': ['二', '冖', '厶', '夂', '心', '爪', '雨'],
#  '青': ['二', '亠', '土', '月'],
#  '靖': ['二', '亠', '土', '月', '立', '青'],
#  '静': ['亅', '亠', '勹', '土', '彐', '月', '青'],
#  '靜': ['丿', '亅', '二', '亠', '土', '彐', '月', '爪', '青', '尚'],
#  '靠': ['丿', '口', '土', '非'],
#  '靡': ['广', '木', '非', '麻'],
#  '靤': ['勹', '己', '面'],
#  '靦': ['見', '面'],
#  '靨': ['厂', '日', '犬', '目', '面'],
#  '革': ['十', '口', '廾'],
#  '靫': ['丶', '又', '革'],
#  '靭': ['丶', '刀', '革'],
#  '靱': ['刀', '革'],
#  '靴': ['匕', '革', '亻'],
#  '靹': ['人', '冂', '革'],
#  '靺': ['｜', '亠', '八', '凵', '口', '木', '革'],
#  '靼': ['日', '革'],
#  '鞁': ['又', '皮', '革'],
#  '鞄': ['勹', '己', '革'],
#  '鞅': ['人', '冂', '凵', '口', '大', '革'],
#  '鞆': ['人', '冂', '革'],
#  '鞋': ['土', '革'],
#  '鞍': ['女', '宀', '革'],
#  '鞏': ['丶', '几', '工', '革'],
#  '鞐': ['卜', '革'],
#  '鞘': ['月', '革', '尚'],
#  '鞜': ['日', '水', '革'],
#  '鞠': ['勹', '米', '革'],
#  '鞣': ['｜', '凵', '口', '木', '矛', '革', 'マ'],
#  '鞦': ['火', '禾', '革'],
#  '鞨': ['勹', '匕', '日', '革'],
#  '鞫': ['勹', '言', '革'],
#  '鞭': ['丿', '日', '田', '革', '亻'],
#  '鞳': ['口', '革', '个', '艹'],
#  '鞴': ['厂', '用', '革', '艹'],
#  '韃': ['土', '玉', '羊', '革', '丷', '辶'],
#  '韆': ['八', '己', '襾', '革', '辶'],
#  '韈': ['丿', '戈', '网', '革', '艹'],
#  '韋': ['口'],
#  '韓': ['十', '口', '日', '韋'],
#  '韜': ['口', '爪', '臼', '韋'],
#  '韮': ['韭', '艹'],
#  '韲': ['亠', '韭', '齊'],
#  '音': ['日', '立'],
#  '韵': ['冫', '勹', '日', '立', '音'],
#  '韶': ['刀', '口', '日', '立', '音'],
#  '韻': ['口', '日', '立', '貝', '音'],
#  '響': ['幺', '日', '立', '艮', '音', '.阝'],
#  '頁': ['貝'],
#  '頂': ['亅', '貝', '頁'],
#  '頃': ['匕', '貝', '頁'],
#  '項': ['工', '貝', '頁'],
#  '順': ['巛', '貝', '頁'],
#  '須': ['彡', '貝', '頁'],
#  '頌': ['八', '厶', '貝', '頁'],
#  '頏': ['亠', '儿', '貝', '頁'],
#  '預': ['亅', '欠', '貝', '頁', 'マ'],
#  '頑': ['二', '儿', '貝', '頁', '元'],
#  '頒': ['八', '刀', '貝', '頁'],
#  '頓': ['貝', '頁', '屯'],
#  '頗': ['又', '皮', '貝', '頁'],
#  '領': ['卩', '貝', '頁', '个'],
#  '頚': ['又', '土', '貝', '頁'],
#  '頡': ['口', '士', '貝', '頁'],
#  '頤': ['匚', '臣', '貝', '頁'],
#  '頬': ['二', '人', '貝', '頁', '丷'],
#  '頭': ['口', '豆', '貝', '頁', '丷'],
#  '頴': ['匕', '示', '貝', '頁'],
#  '頷': ['口', '貝', '頁', '个'],
#  '頸': ['巛', '工', '貝', '頁'],
#  '頻': ['丿', '小', '止', '貝', '頁'],
#  '頼': ['｜', '八', '口', '木', '貝', '頁'],
#  '頽': ['几', '禾', '貝', '頁'],
#  '顆': ['｜', '日', '木', '田', '貝', '頁'],
#  '顋': ['心', '田', '貝', '頁'],
#  '題': ['日', '疋', '貝', '頁'],
#  '額': ['口', '夂', '宀', '貝', '頁'],
#  '顎': ['二', '勹', '口', '貝', '頁'],
#  '顏': ['厂', '彡', '文', '貝', '頁'],
#  '顔': ['亠', '八', '厂', '彡', '立', '貝', '頁'],
#  '顕': ['日', '貝', '頁'],
#  '願': ['厂', '小', '白', '貝', '頁'],
#  '顛': ['八', '十', '目', '貝', '頁'],
#  '類': ['大', '米', '貝', '頁'],
#  '顧': ['戸', '貝', '隹', '頁'],
#  '顫': ['亠', '口', '囗', '日', '貝', '頁'],
#  '顯': ['幺', '日', '貝', '頁', '灬'],
#  '顰': ['丿', '十', '小', '止', '田', '貝', '頁'],
#  '顱': ['匕', '卜', '厂', '田', '皿', '虍', '貝', '頁'],
#  '顳': ['耳', '貝', '頁'],
#  '顴': ['十', '口', '貝', '隹', '頁', '艹'],
#  '風': ['丿', '冂', '虫'],
#  '颪': ['卜', '風'],
#  '颯': ['立', '風'],
#  '颱': ['厶', '口', '風'],
#  '颶': ['八', '目', '風'],
#  '飃': ['示', '襾', '風'],
#  '飄': ['示', '襾', '風'],
#  '飆': ['犬', '風'],
#  '飜': ['田', '米', '釆', '飛'],
#  '飢': ['几', '食'],
#  '飩': ['食', '屯'],
#  '飫': ['丿', '大', '食'],
#  '飭': ['力', '食'],
#  '飮': ['｜', '欠', '食', '个'],
#  '飯': ['厂', '又', '食'],
#  '飲': ['欠', '食'],
#  '飴': ['厶', '口', '食'],
#  '飼': ['亅', '口', '艮', '食', '个'],
#  '飽': ['勹', '己', '食'],
#  '飾': ['丿', '巾', '食'],
#  '餃': ['亠', '父', '食'],
#  '餅': ['｜', '丿', '二', '廾', '食', '丷'],
#  '餉': ['冂', '口', '食'],
#  '養': ['玉', '羊', '食', '丷'],
#  '餌': ['耳', '艮', '食'],
#  '餐': ['又', '夕', '食'],
#  '餒': ['女', '爪', '食'],
#  '餓': ['亅', '戈', '手', '食'],
#  '餔': ['丶', '十', '用', '食'],
#  '餘': ['亅', '二', '八', '干', '食', '个'],
#  '餝': ['方', '食', '艹'],
#  '餞': ['戈', '食'],
#  '餠': ['｜', '干', '食'],
#  '餡': ['臼', '食'],
#  '餤': ['火', '食'],
#  '館': ['口', '宀', '食'],
#  '餬': ['十', '口', '月', '食'],
#  '餮': ['彡', '歹', '食', '个'],
#  '餽': ['儿', '匕', '田', '食', '鬼'],
#  '餾': ['卩', '厶', '田', '食'],
#  '饂': ['日', '皿', '食'],
#  '饅': ['又', '日', '网', '食'],
#  '饉': ['｜', '二', '食', '艹'],
#  '饋': ['｜', '口', '貝', '食'],
#  '饌': ['｜', '二', '八', '己', '食'],
#  '饐': ['冖', '口', '士', '豆', '食', '丷'],
#  '饑': ['丶', '幺', '戈', '食'],
#  '饒': ['儿', '土', '食'],
#  '饕': ['儿', '匕', '卜', '厂', '口', '虍', '食'],
#  '饗': ['幺', '艮', '食', '.阝'],
#  '首': ['目', '自', '丷'],
#  '馗': ['目', '自', '首', '丷', '九'],
#  '馘': ['口', '戈', '目', '自', '首', '丷'],
#  '香': ['日', '禾'],
#  '馥': ['夂', '日', '禾', '香'],
#  '馨': ['几', '又', '士', '日', '禾', '香'],
#  '馭': ['又', '馬'],
#  '馮': ['冫', '馬'],
#  '馳': ['馬', '也'],
#  '馴': ['巛', '馬', '鳥', '灬'],
#  '馼': ['文', '馬'],
#  '駁': ['爻', '馬'],
#  '駄': ['丶', '大', '馬'],
#  '駅': ['尸', '馬'],
#  '駆': ['丶', '丿', '匚', '馬'],
#  '駈': ['斤', '馬'],
#  '駐': ['丶', '玉', '馬'],
#  '駑': ['又', '女', '馬'],
#  '駒': ['勹', '口', '馬'],
#  '駕': ['力', '口', '馬'],
#  '駘': ['厶', '口', '馬'],
#  '駛': ['丿', '口', '馬'],
#  '駝': ['匕', '宀', '馬'],
#  '駟': ['儿', '囗', '馬'],
#  '駢': ['｜', '丿', '二', '廾', '馬', '丷'],
#  '駭': ['亠', '人', '馬'],
#  '駮': ['亠', '父', '馬'],
#  '駱': ['口', '夂', '馬'],
#  '駲': ['｜', '丶', '丿', '巛', '馬'],
#  '駸': ['冖', '又', '彐', '馬'],
#  '駻': ['干', '日', '馬'],
#  '駿': ['儿', '厶', '夂', '馬'],
#  '騁': ['｜', '勹', '日', '田', '馬'],
#  '騅': ['隹', '馬'],
#  '騎': ['亅', '口', '大', '馬'],
#  '騏': ['八', '甘', '馬'],
#  '騒': ['又', '虫', '馬'],
#  '験': ['人', '口', '馬', '个'],
#  '騙': ['｜', '冂', '戸', '馬', '冊'],
#  '騨': ['十', '田', '馬', '尚'],
#  '騫': ['｜', '八', '宀', '馬'],
#  '騰': ['月', '馬', '丷'],
#  '騷': ['丶', '又', '虫', '馬'],
#  '騾': ['田', '糸', '馬'],
#  '驀': ['大', '日', '馬', '艹'],
#  '驂': ['厶', '大', '彡', '馬'],
#  '驃': ['示', '襾', '馬'],
#  '驅': ['匚', '口', '馬', '品'],
#  '驍': ['儿', '土', '馬'],
#  '驕': ['丿', '冂', '口', '大', '馬'],
#  '驗': ['人', '口', '馬', '个'],
#  '驚': ['勹', '口', '夂', '攴', '馬', '艹'],
#  '驛': ['亠', '十', '立', '网', '辛', '馬'],
#  '驟': ['又', '耳', '衣', '馬'],
#  '驢': ['匕', '卜', '厂', '田', '皿', '虍', '馬'],
#  '驤': ['｜', '二', '亠', '八', '衣', '馬'],
#  '驥': ['｜', '二', '八', '匕', '爿', '田', '馬'],
#  '驩': ['十', '口', '隹', '馬', '艹'],
#  '驪': ['亠', '冂', '广', '比', '馬', '鹿'],
#  '驫': ['馬'],
#  '骨': ['冂', '冖', '月'],
#  '骭': ['冂', '冖', '干', '月', '骨'],
#  '骰': ['冂', '冖', '月', '殳', '骨'],
#  '骸': ['亠', '人', '冂', '冖', '月', '骨'],
#  '骼': ['冂', '冖', '口', '夂', '月', '骨'],
#  '髀': ['冂', '冖', '十', '月', '田', '骨'],
#  '髄': ['丿', '冖', '月', '骨', '辶'],
#  '髏': ['｜', '冂', '冖', '口', '女', '月', '骨'],
#  '髑': ['冂', '冖', '勹', '月', '网', '虫', '骨'],
#  '髓': ['丿', '冂', '冖', '工', '月', '骨', '辶'],
#  '體': ['｜', '冂', '冖', '口', '日', '月', '豆', '骨', '丷'],
#  '高': ['亠', '冂', '口'],
#  '髞': ['亠', '冂', '口', '木', '高', '品'],
#  '髟': ['彡', '長'],
#  '髢': ['匕', '彡', '長', '髟', '也'],
#  '髣': ['彡', '方', '長', '髟'],
#  '髦': ['彡', '毛', '長', '髟'],
#  '髪': ['夂', '彡', '長', '髟'],
#  '髫': ['刀', '口', '彡', '長', '髟'],
#  '髭': ['匕', '彡', '止', '長', '髟'],
#  '髮': ['又', '彡', '攴', '長', '髟'],
#  '髯': ['｜', '冂', '厶', '彡', '長', '髟'],
#  '髱': ['勹', '己', '彡', '長', '髟'],
#  '髴': ['｜', '丿', '弓', '彡', '長', '髟'],
#  '髷': ['｜', '厶', '彡', '日', '長', '髟'],
#  '髻': ['口', '士', '彡', '長', '髟'],
#  '鬆': ['八', '厶', '彡', '木', '長', '髟'],
#  '鬘': ['又', '彡', '日', '网', '長', '髟'],
#  '鬚': ['彡', '貝', '長', '頁', '髟'],
#  '鬟': ['口', '彡', '网', '衣', '長', '髟'],
#  '鬢': ['丿', '宀', '小', '彡', '貝', '長', '髟'],
#  '鬣': ['囗', '彡', '臼', '長', '髟', '鼠'],
#  '鬧': ['亠', '巾', '鬥'],
#  '鬨': ['｜', '亅', '二', '八', '鬥'],
#  '鬩': ['儿', '臼', '鬥'],
#  '鬪': ['口', '寸', '豆', '鬥', '丷'],
#  '鬮': ['鬥', '龜'],
#  '鬯': ['凵', '匕'],
#  '鬱': ['冖', '凵', '匕', '彡', '木', '缶'],
#  '鬲': ['儿', '冂', '口'],
#  '鬻': ['儿', '冂', '口', '弓', '米', '鬲'],
#  '鬼': ['儿', '匕', '厶', '田'],
#  '魁': ['儿', '厶', '斗', '田', '鬼'],
#  '魂': ['二', '儿', '匕', '厶', '田', '鬼'],
#  '魃': ['丶', '儿', '匕', '攴', '田', '鬼'],
#  '魄': ['儿', '匕', '田', '白', '鬼'],
#  '魅': ['｜', '二', '亠', '儿', '八', '匕', '木', '田', '鬼'],
#  '魍': ['儿', '冂', '匕', '田', '鬼', '丷', '亡'],
#  '魎': ['｜', '儿', '入', '冂', '厶', '田', '鬼'],
#  '魏': ['儿', '匕', '女', '田', '禾', '鬼'],
#  '魑': ['亠', '儿', '凵', '匕', '田', '禸', '鬼'],
#  '魔': ['儿', '匕', '广', '木', '田', '鬼', '麻'],
#  '魘': ['儿', '匕', '厂', '日', '月', '犬', '田', '鬼'],
#  '魚': ['田', '灬'],
#  '魯': ['日', '田', '魚', '灬'],
#  '魴': ['方', '田', '魚', '灬'],
#  '鮃': ['干', '田', '魚', '丷', '灬'],
#  '鮎': ['卜', '口', '田', '魚'],
#  '鮑': ['勹', '己', '田', '魚', '灬'],
#  '鮒': ['寸', '田', '魚', '亻', '灬'],
#  '鮓': ['｜', '丿', '田', '魚', '灬'],
#  '鮖': ['口', '田', '石', '魚', '灬'],
#  '鮗': ['冫', '夂', '田', '魚', '灬'],
#  '鮟': ['女', '宀', '田', '魚', '灬'],
#  '鮠': ['卩', '厂', '田', '隹', '魚', '灬'],
#  '鮨': ['匕', '日', '田', '魚', '灬'],
#  '鮪': ['丿', '月', '田', '魚', '灬'],
#  '鮫': ['亠', '父', '田', '魚', '灬'],
#  '鮭': ['土', '田', '魚', '灬'],
#  '鮮': ['玉', '田', '羊', '魚', '丷', '灬'],
#  '鮴': ['木', '田', '魚', '亻', '灬'],
#  '鮹': ['月', '田', '魚', '尚', '灬'],
#  '鯀': ['丿', '田', '糸', '魚', '灬'],
#  '鯆': ['丶', '十', '用', '田', '魚', '灬'],
#  '鯉': ['田', '里', '魚', '灬'],
#  '鯊': ['丿', '小', '田', '魚', '氵', '灬'],
#  '鯏': ['田', '禾', '魚', '刂', '灬'],
#  '鯑': ['丿', '巾', '田', '魚', '灬'],
#  '鯒': ['用', '田', '魚', '灬'],
#  '鯔': ['巛', '田', '魚', '灬'],
#  '鯖': ['二', '亠', '土', '月', '田', '青', '魚', '灬'],
#  '鯛': ['冂', '口', '土', '田', '魚', '灬'],
#  '鯡': ['田', '非', '魚', '灬'],
#  '鯢': ['儿', '田', '臼', '魚', '灬'],
#  '鯣': ['丿', '勹', '日', '田', '魚', '灬'],
#  '鯤': ['日', '比', '田', '魚', '灬'],
#  '鯨': ['亠', '口', '小', '田', '魚', '灬'],
#  '鯰': ['心', '田', '魚', '个', '灬'],
#  '鯱': ['儿', '匕', '卜', '厂', '田', '虍', '魚', '灬'],
#  '鯲': ['冫', '方', '田', '魚', '个', '灬'],
#  '鯵': ['厶', '大', '彡', '田', '魚', '灬'],
#  '鰄': ['丿', '女', '戈', '田', '魚', '灬'],
#  '鰆': ['二', '人', '大', '日', '田', '魚', '灬'],
#  '鰈': ['木', '田', '魚', '灬', '世'],
#  '鰉': ['玉', '田', '白', '魚', '灬'],
#  '鰊': ['｜', '口', '木', '田', '网', '魚', '丷', '灬'],
#  '鰌': ['八', '田', '酉', '魚', '灬'],
#  '鰍': ['火', '田', '禾', '魚', '灬'],
#  '鰐': ['二', '勹', '口', '田', '魚', '灬'],
#  '鰒': ['夂', '日', '田', '魚', '灬'],
#  '鰓': ['心', '田', '魚', '灬'],
#  '鰔': ['丿', '口', '戈', '田', '魚', '灬'],
#  '鰕': ['｜', '又', '口', '田', '魚', '灬'],
#  '鰛': ['日', '田', '皿', '魚', '灬'],
#  '鰡': ['刀', '厶', '田', '魚', '灬'],
#  '鰤': ['｜', '冂', '口', '巾', '田', '魚', '灬'],
#  '鰥': ['｜', '冫', '田', '网', '魚', '灬'],
#  '鰭': ['日', '田', '老', '魚', '灬'],
#  '鰮': ['人', '囗', '田', '皿', '魚', '灬'],
#  '鰯': ['冫', '弓', '田', '魚', '灬'],
#  '鰰': ['｜', '田', '魚', '灬', '礻'],
#  '鰲': ['土', '攴', '方', '田', '魚', '灬'],
#  '鰹': ['又', '土', '田', '臣', '魚', '灬'],
#  '鰺': ['厶', '彡', '田', '魚', '个', '灬'],
#  '鰻': ['又', '日', '田', '网', '魚', '灬'],
#  '鰾': ['田', '示', '襾', '魚', '灬'],
#  '鱆': ['十', '日', '田', '立', '音', '魚', '灬'],
#  '鱇': ['广', '彐', '水', '田', '隶', '魚', '灬'],
#  '鱈': ['彐', '田', '雨', '魚', '灬'],
#  '鱒': ['寸', '田', '酉', '魚', '丷', '灬'],
#  '鱗': ['夕', '田', '米', '舛', '魚', '灬'],
#  '鱚': ['十', '口', '士', '田', '豆', '魚', '丷', '灬'],
#  '鱠': ['日', '田', '网', '魚', '个', '灬'],
#  '鱧': ['｜', '日', '田', '豆', '魚', '灬'],
#  '鱶': ['玉', '田', '羊', '艮', '食', '魚', '丷', '灬'],
#  '鱸': ['匕', '卜', '厂', '田', '皿', '虍', '魚', '灬'],
#  '鳥': ['灬'],
#  '鳧': ['几', '鳥', '灬'],
#  '鳩': ['鳥', '九', '灬'],
#  '鳫': ['厂', '鳥', '灬'],
#  '鳬': ['几', '鳥'],
#  '鳰': ['入', '鳥', '灬'],
#  '鳳': ['几', '鳥', '灬'],
#  '鳴': ['口', '鳥', '灬'],
#  '鳶': ['弋', '鳥', '灬'],
#  '鴃': ['二', '人', '大', '鳥', '灬'],
#  '鴆': ['尢', '鳥', '灬'],
#  '鴇': ['匕', '十', '鳥', '灬'],
#  '鴈': ['厂', '鳥', '亻', '灬'],
#  '鴉': ['牙', '鳥', '灬'],
#  '鴎': ['丶', '丿', '匚', '鳥', '灬'],
#  '鴒': ['卩', '鳥', '个', '灬'],
#  '鴕': ['匕', '宀', '鳥', '灬'],
#  '鴛': ['卩', '夕', '鳥', '灬'],
#  '鴟': ['氏', '鳥', '灬'],
#  '鴣': ['十', '口', '鳥', '灬'],
#  '鴦': ['大', '鳥', '灬'],
#  '鴨': ['｜', '日', '田', '鳥', '灬'],
#  '鴪': ['八', '宀', '穴', '鳥', '灬'],
#  '鴫': ['田', '鳥', '灬'],
#  '鴬': ['冖', '鳥', '尚', '灬'],
#  '鴻': ['工', '鳥', '氵', '灬'],
#  '鴾': ['厶', '牛', '鳥', 'マ', '灬'],
#  '鴿': ['口', '鳥', '个', '灬'],
#  '鵁': ['亠', '父', '鳥', '灬'],
#  '鵄': ['厶', '土', '至', '鳥', '灬'],
#  '鵆': ['彳', '行', '鳥', '灬'],
#  '鵈': ['耳', '鳥', '灬'],
#  '鵐': ['人', '工', '鳥', '灬'],
#  '鵑': ['口', '月', '鳥', '灬'],
#  '鵙': ['貝', '鳥', '灬'],
#  '鵜': ['｜', '丿', '弓', '鳥', '丷', '灬'],
#  '鵝': ['亅', '戈', '鳥', '灬'],
#  '鵞': ['亅', '戈', '鳥', '灬'],
#  '鵠': ['丿', '口', '土', '鳥', '灬'],
#  '鵡': ['弋', '戈', '止', '鳥', '灬'],
#  '鵤': ['角', '鳥', '灬'],
#  '鵬': ['月', '鳥', '灬'],
#  '鵯': ['十', '田', '鳥', '灬'],
#  '鵲': ['｜', '日', '鳥'],
#  '鵺': ['亠', '夕', '衣', '鳥', '灬'],
#  '鶇': ['｜', '八', '日', '木', '田', '鳥', '灬'],
#  '鶉': ['亠', '口', '子', '鳥', '灬'],
#  '鶏': ['人', '土', '大', '爪', '鳥'],
#  '鶚': ['二', '勹', '口', '鳥', '灬'],
#  '鶤': ['冖', '車', '鳥', '灬'],
#  '鶩': ['攴', '矛', '鳥', '灬'],
#  '鶫': ['｜', '口', '木', '网', '鳥', '丷', '灬'],
#  '鶯': ['冖', '火', '鳥', '灬'],
#  '鶲': ['八', '冫', '厶', '羽', '鳥', '灬'],
#  '鶴': ['宀', '隹', '鳥', '灬'],
#  '鶸': ['冫', '弓', '鳥', '灬'],
#  '鶺': ['人', '冫', '月', '鳥', '灬'],
#  '鶻': ['冂', '冖', '月', '骨', '鳥', '灬'],
#  '鷁': ['皿', '鳥', '丷', '灬'],
#  '鷂': ['凵', '夕', '缶', '鳥', '灬'],
#  '鷄': ['大', '幺', '爪', '鳥', '灬'],
#  '鷆': ['八', '匕', '目', '鳥', '灬'],
#  '鷏': ['八', '十', '目', '鳥', '灬'],
#  '鷓': ['凵', '广', '鳥', '灬'],
#  '鷙': ['丶', '亠', '十', '立', '辛', '鳥', '九', '灬'],
#  '鷦': ['隹', '鳥', '灬'],
#  '鷭': ['田', '米', '釆', '鳥', '灬'],
#  '鷯': ['亠', '小', '日', '鳥', '个', '丷', '灬'],
#  '鷲': ['丶', '亠', '口', '小', '尢', '鳥', '灬', '尤'],
#  '鷸': ['儿', '冂', '口', '矛', '鳥', '灬'],
#  '鷹': ['广', '隹', '鳥', '亻', '灬'],
#  '鷺': ['口', '夂', '足', '鳥', '灬'],
#  '鷽': ['冖', '爻', '臼', '鳥', '灬'],
#  '鸚': ['女', '貝', '鳥', '灬'],
#  '鸛': ['十', '口', '隹', '鳥', '艹', '灬'],
#  '鸞': ['糸', '言', '鳥', '灬'],
#  '鹵': ['十', '囗'],
#  '鹸': ['人', '十', '口', '囗', '鹵', '个'],
#  '鹹': ['丿', '卜', '口', '囗', '戈', '鹵'],
#  '鹽': ['十', '囗', '皿', '臣', '鹵'],
#  '鹿': ['广', '比'],
#  '麁': ['勹', '广', '比', '鹿'],
#  '麈': ['丶', '广', '比', '玉', '鹿'],
#  '麋': ['广', '比', '米', '鹿'],
#  '麌': ['八', '口', '广', '比', '鹿'],
#  '麑': ['儿', '广', '比', '臼', '鹿'],
#  '麒': ['八', '广', '比', '甘', '鹿'],
#  '麓': ['广', '木', '比', '鹿'],
#  '麕': ['囗', '广', '比', '禾', '鹿'],
#  '麗': ['冂', '广', '比', '鹿'],
#  '麝': ['寸', '广', '比', '身', '鹿'],
#  '麟': ['夕', '广', '比', '米', '舛', '鹿'],
#  '麥': ['夂'],
#  '麦': ['夂'],
#  '麩': ['二', '人', '夂', '麥'],
#  '麪': ['夂', '止', '疋', '麥'],
#  '麭': ['勹', '夂', '己', '麥'],
#  '麸': ['二', '亠', '人', '土', '夂', '大', '麥'],
#  '麹': ['亠', '勹', '土', '夂', '米', '麥'],
#  '麺': ['夂', '面', '麥'],
#  '麻': ['广', '木'],
#  '麼': ['幺', '广', '木', '麻'],
#  '麾': ['广', '木', '毛', '麻'],
#  '麿': ['口', '广', '木', '麻'],
#  '黄': ['八', '田'],
#  '黌': ['八', '冖', '爻', '田', '臼', '黄'],
#  '黍': ['水', '禾'],
#  '黎': ['黍', '勿'],
#  '黏': ['卜', '口', '黍'],
#  '黐': ['亠', '凵', '禸', '黍'],
#  '黒': ['里', '灬'],
#  '黔': ['里', '黒', '个', '灬'],
#  '默': ['犬', '里', '黒', '灬'],
#  '黙': ['犬', '里', '黒', '灬'],
#  '黛': ['弋', '里', '黒', '亻', '灬'],
#  '黜': ['｜', '山', '里', '黒', '灬'],
#  '黝': ['力', '幺', '里', '黒', '灬'],
#  '點': ['卜', '口', '里', '黒', '灬'],
#  '黠': ['口', '士', '里', '黒', '灬'],
#  '黥': ['亠', '口', '小', '里', '黒', '灬'],
#  '黨': ['冖', '口', '里', '黒', '尚', '灬'],
#  '黯': ['日', '立', '里', '音', '黒', '灬'],
#  '黴': ['山', '彳', '攴', '里', '黒', '灬'],
#  '黶': ['厂', '日', '犬', '里', '黒', '灬'],
#  '黷': ['儿', '囗', '士', '貝', '里', '黒', '灬'],
#  '黹': ['八', '冂', '丷'],
#  '黻': ['丶', '八', '冂', '攴', '黹', '丷'],
#  '黼': ['丶', '八', '冂', '十', '用', '黹', '丷'],
#  '鼇': ['土', '攴', '方', '黽'],
#  '鼈': ['冂', '小', '攴', '黽', '尚'],
#  '鼎': ['｜', '爿', '片', '目'],
#  '鼓': ['十', '又', '口', '士', '支', '豆', '丷'],
#  '鼕': ['八', '冫', '十', '又', '口', '士', '夂', '支', '鼓'],
#  '鼠': ['臼'],
#  '鼡': ['臼'],
#  '鼬': ['｜', '日', '田', '臼', '鼠'],
#  '鼻': ['廾', '田', '自'],
#  '鼾': ['干', '廾', '田', '目', '自', '鼻'],
#  '齋': ['小', '齊', '元'],
#  '齎': ['亠', '貝', '齊'],
#  '齏': ['亠', '韭', '齊'],
#  '齒': ['人', '凵', '止'],
#  '齔': ['凵', '匕', '止', '米', '齒'],
#  '齟': ['凵', '止', '目', '米', '齒'],
#  '齠': ['凵', '刀', '口', '止', '米', '齒'],
#  '齡': ['人', '凵', '卩', '止', '齒', '个'],
#  '齢': ['凵', '卩', '止', '米', '齒', '个'],
#  '齣': ['凵', '勹', '口', '止', '米', '齒'],
#  '齦': ['凵', '止', '米', '艮', '齒'],
#  '齧': ['亠', '凵', '刀', '土', '止', '米', '齒'],
#  '齪': ['凵', '口', '止', '米', '足', '齒'],
#  '齬': ['凵', '口', '止', '米', '齒', '五'],
#  '齲': ['丿', '冂', '凵', '止', '禸', '米', '虫', '齒'],
#  '齶': ['二', '凵', '勹', '口', '止', '米', '齒'],
#  '齷': ['凵', '厶', '土', '尸', '止', '米', '至', '齒'],
#  '龍': ['月', '立'],
#  '龕': ['口', '月', '立', '个'],
#  '龝': ['禾', '龜'],
#  '龠': ['口', '个', '冊']}

# %% [markdown]
# ## Data Structure

# %%
class KanjiNode:
    def __init__(self, symbol: str, dtype: str, meaning: str):
        self.symbol  = symbol
        self.dtype   = dtype
        self.meaning = meaning        
        self.color = 'red' if dtype == 'kanji' else 'orange'
        
    def __repr__(self):
        return self.symbol + '*' + self.dtype + '*' + self.meaning
    
    def __str__(self):
        return self.symbol + '\n' + self.meaning

# %%
class KanjiGraph:
    
    def __init__(self, data_kanji, data_radical, data_edges):
        self.nodes_kanji   = { s: KanjiNode(s, 'kanji', m)   for s, m in data_kanji.items()}
        self.nodes_radical = { s: KanjiNode(s, 'radical', m) for s, m in data_radical.items()}
        
        self.nodes = list(self.nodes_kanji.values()) + list(self.nodes_radical.values())
        
        self.edges = self.convert_into_data_edges(data_edges)
    
    def get_node(self, symbol, dtype):
        if dtype == 'kanji':
            mp = self.nodes_kanji
        elif dtype == 'radical':
            mp = self.nodes_radical
        else:
            raise ValueError(f"{dtype} is not valid")
        if symbol not in mp:
#             raise ValueError(f"{symbol} is not 1 of {len(mp)} nodes_{dtype}")
            return None
        return mp[symbol]
    
    def convert_into_data_edges(self, data_edges):
        kanjigen_edges = []
        
        for kanji, radical_list in data_edges.items():
            kanji_node = self.get_node(kanji, 'kanji')
            if kanji_node != None:
                for r in radical_list:
                    radical_node = self.get_node(r, 'radical')
                    kanjigen_edges.append( (kanji_node, radical_node) )
        return list(set(kanjigen_edges))

# %%
kjg = KanjiGraph(data_kanji, data_radical, data_edges)

# %%
print(kjg.get_node('人', 'radical'))
# Out:
# 人
# person

# %%
kjg.nodes[:3]
# Out:
# [亜*kanji*Asia, 唖*kanji*mute, 逢*kanji*meeting]

# %%
kjg.nodes_kanji
# Out:
# {'亜': 亜*kanji*Asia,
#  '唖': 唖*kanji*mute,
#  '逢': 逢*kanji*meeting,
#  '悪': 悪*kanji*bad,
#  '以': 以*kanji*by means of,
#  '伊': 伊*kanji*Italy,
#  '井': 井*kanji*well,
#  '稲': 稲*kanji*rice plant,
#  '印': 印*kanji*stamp,
#  '引': 引*kanji*pull,
#  '鵜': 鵜*kanji*cormorant,
#  '丑': 丑*kanji*sign of the ox or cow,
#  '渦': 渦*kanji*whirlpool,
#  '焔': 焔*kanji*flame,
#  '艶': 艶*kanji*glossy,
#  '押': 押*kanji*push,
#  '横': 横*kanji*sideways,
#  '沖': 沖*kanji*open sea,
#  '下': 下*kanji*below,
#  '果': 果*kanji*fruit,
#  '華': 華*kanji*splendor,
#  '嘩': 嘩*kanji*noisy,
#  '柿': 柿*kanji*persimmon,
#  '角': 角*kanji*angle,
#  '樺': 樺*kanji*birch,
#  '鴨': 鴨*kanji*wild duck,
#  '患': 患*kanji*afflicted,
#  '諌': 諌*kanji*admonish,
#  '陥': 陥*kanji*collapse,
#  '貴': 貴*kanji*precious,
#  '糾': 糾*kanji*twist,
#  '旧': 旧*kanji*old times,
#  '供': 供*kanji*submit,
#  '叫': 叫*kanji*shout,
#  '業': 業*kanji*business,
#  '曲': 曲*kanji*bend,
#  '巾': 巾*kanji*towel,
#  '串': 串*kanji*spit,
#  '屈': 屈*kanji*yield,
#  '掘': 掘*kanji*dig,
#  '窟': 窟*kanji*cavern,
#  '勲': 勲*kanji*meritorious deed,
#  '薫': 薫*kanji*send forth fragrance,
#  '慧': 慧*kanji*wise,
#  '継': 継*kanji*inherit,
#  '兼': 兼*kanji*concurrently,
#  '嫌': 嫌*kanji*dislike,
#  '研': 研*kanji*polish,
#  '謙': 謙*kanji*self-effacing,
#  '遣': 遣*kanji*dispatch,
#  '碁': 碁*kanji*Go,
#  '候': 候*kanji*climate,
#  '洪': 洪*kanji*deluge,
#  '甲': 甲*kanji*armor,
#  '耕': 耕*kanji*till,
#  '購': 購*kanji*subscription,
#  '坤': 坤*kanji*divination sign,
#  '詐': 詐*kanji*lie,
#  '坐': 坐*kanji*sit,
#  '座': 座*kanji*squat,
#  '挫': 挫*kanji*crush,
#  '再': 再*kanji*again,
#  '妻': 妻*kanji*wife,
#  '済': 済*kanji*settle (debt, etc.),
#  '犀': 犀*kanji*rhinocerous,
#  '斎': 斎*kanji*purification,
#  '剤': 剤*kanji*dose,
#  '在': 在*kanji*exist,
#  '榊': 榊*kanji*sacred Shinto tree,
#  '崎': 崎*kanji*promontory,
#  '埼': 埼*kanji*cape,
#  '碕': 碕*kanji*cape,
#  '作': 作*kanji*make,
#  '咋': 咋*kanji*shout,
#  '搾': 搾*kanji*squeeze,
#  '昨': 昨*kanji*yesterday,
#  '柵': 柵*kanji*stockade,
#  '窄': 窄*kanji*narrow,
#  '策': 策*kanji*scheme,
#  '錯': 錯*kanji*confused,
#  '冊': 冊*kanji*tome,
#  '撒': 撒*kanji*scatter,
#  '散': 散*kanji*scatter,
#  '珊': 珊*kanji*coral,
#  '刺': 刺*kanji*thorn,
#  '嗣': 嗣*kanji*heir,
#  '師': 師*kanji*expert,
#  '獅': 獅*kanji*lion,
#  '児': 児*kanji*newborn babe,
#  '爾': 爾*kanji*you,
#  '璽': 璽*kanji*emperor's seal,
#  '軸': 軸*kanji*axis,
#  '雫': 雫*kanji*drop,
#  '湿': 湿*kanji*damp,
#  '篠': 篠*kanji*bamboo grass,
#  '朱': 朱*kanji*vermilion,
#  '殊': 殊*kanji*particularly,
#  '珠': 珠*kanji*pearl,
#  '種': 種*kanji*species,
#  '腫': 腫*kanji*tumor,
#  '収': 収*kanji*income,
#  '州': 州*kanji*state,
#  '修': 修*kanji*discipline,
#  '洲': 洲*kanji*continent,
#  '繍': 繍*kanji*sew,
#  '酬': 酬*kanji*repay,
#  '重': 重*kanji*heavy,
#  '粛': 粛*kanji*solemn,
#  '出': 出*kanji*exit,
#  '衝': 衝*kanji*collide,
#  '鍾': 鍾*kanji*spindle,
#  '乗': 乗*kanji*ride,
#  '剰': 剰*kanji*surplus,
#  '伸': 伸*kanji*expand,
#  '申': 申*kanji*have the honor to,
#  '神': 神*kanji*gods,
#  '紳': 紳*kanji*sire,
#  '酢': 酢*kanji*vinegar,
#  '垂': 垂*kanji*droop,
#  '帥': 帥*kanji*commander,
#  '睡': 睡*kanji*drowsy,
#  '錘': 錘*kanji*weight,
#  '菅': 菅*kanji*sedge,
#  '世': 世*kanji*generation,
#  '瀬': 瀬*kanji*rapids,
#  '整': 整*kanji*organize,
#  '斉': 斉*kanji*adjusted,
#  '惜': 惜*kanji*pity,
#  '昔': 昔*kanji*once upon a time,
#  '籍': 籍*kanji*enroll,
#  '拙': 拙*kanji*bungling,
#  '撰': 撰*kanji*composing,
#  '選': 選*kanji*elect,
#  '岨': 岨*kanji*a rocky mountain,
#  '措': 措*kanji*set aside,
#  '狙': 狙*kanji*aim at,
#  '疎': 疎*kanji*alienate,
#  '祖': 祖*kanji*ancestor,
#  '租': 租*kanji*tariff,
#  '粗': 粗*kanji*coarse,
#  '組': 組*kanji*association,
#  '阻': 阻*kanji*thwart,
#  '喪': 喪*kanji*miss,
#  '奏': 奏*kanji*play music,
#  '捜': 捜*kanji*search,
#  '挿': 挿*kanji*insert,
#  '曹': 曹*kanji*office,
#  '槽': 槽*kanji*vat,
#  '漕': 漕*kanji*rowing,
#  '糟': 糟*kanji*dregs,
#  '遭': 遭*kanji*encounter,
#  '束': 束*kanji*bundle,
#  '速': 速*kanji*quick,
#  '袖': 袖*kanji*sleeve,
#  '存': 存*kanji*exist,
#  '唾': 唾*kanji*saliva,
#  '帯': 帯*kanji*sash,
#  '戴': 戴*kanji*be crowned with,
#  '泰': 泰*kanji*peaceful,
#  '凧': 凧*kanji*kite,
#  '巽': 巽*kanji*southeast,
#  '湛': 湛*kanji*fill,
#  '断': 断*kanji*severance,
#  '段': 段*kanji*grade,
#  '値': 値*kanji*price,
#  '中': 中*kanji*in,
#  '仲': 仲*kanji*go-between,
#  '宙': 宙*kanji*mid-air,
#  '忠': 忠*kanji*loyalty,
#  '抽': 抽*kanji*pluck,
#  '弔': 弔*kanji*condolences,
#  '暢': 暢*kanji*stretch,
#  '勅': 勅*kanji*imperial order,
#  '直': 直*kanji*straightaway,
#  '陳': 陳*kanji*exhibit,
#  '槌': 槌*kanji*hammer,
#  '追': 追*kanji*chase,
#  '鎚': 鎚*kanji*hammer,
#  '壷': 壷*kanji*jar,
#  '紬': 紬*kanji*pongee (a knotted silk cloth),
#  '剃': 剃*kanji*shave,
#  '弟': 弟*kanji*younger brother,
#  '悌': 悌*kanji*serving our elders,
#  '梯': 梯*kanji*ladder,
#  '逓': 逓*kanji*relay,
#  '鼎': 鼎*kanji*three legged kettle,
#  '笛': 笛*kanji*flute,
#  '迭': 迭*kanji*transfer,
#  '典': 典*kanji*code,
#  '展': 展*kanji*unfold,
#  '殿': 殿*kanji*Mr.,
#  '澱': 澱*kanji*sediment,
#  '兎': 兎*kanji*rabbit,
#  '菟': 菟*kanji*dodder (plant),
#  '凍': 凍*kanji*frozen,
#  '唐': 唐*kanji*T'ang,
#  '塘': 塘*kanji*dike,
#  '東': 東*kanji*east,
#  '棟': 棟*kanji*ridgepole,
#  '湯': 湯*kanji*hot water,
#  '董': 董*kanji*correct,
#  '蕩': 蕩*kanji*melt,
#  '藤': 藤*kanji*wisteria,
#  '謄': 謄*kanji*mimeograph,
#  '働': 働*kanji*work,
#  '動': 動*kanji*move,
#  '峠': 峠*kanji*mountain peak,
#  '橡': 橡*kanji*horse chestnut,
#  '凸': 凸*kanji*convex,
#  '届': 届*kanji*deliver,
#  '乍': 乍*kanji*though,
#  '廿': 廿*kanji*twenty,
#  '禰': 禰*kanji*ancestral shrine,
#  '念': 念*kanji*wish,
#  '捻': 捻*kanji*twirl,
#  '乃': 乃*kanji*from,
#  '嚢': 嚢*kanji*pouch,
#  '濃': 濃*kanji*concentrated,
#  '膿': 膿*kanji*pus,
#  '農': 農*kanji*agriculture,
#  '拝': 拝*kanji*worship,
#  '杯': 杯*kanji*counter for cupfuls,
#  '矧': 矧*kanji*feather (arrow),
#  '曝': 曝*kanji*bleach,
#  '爆': 爆*kanji*bomb,
#  '伴': 伴*kanji*consort,
#  '判': 判*kanji*judgement,
#  '半': 半*kanji*half,
#  '畔': 畔*kanji*paddy ridge,
#  '挽': 挽*kanji*saw,
#  '費': 費*kanji*expense,
#  '眉': 眉*kanji*eyebrow,
#  '畢': 畢*kanji*the end,
#  '紐': 紐*kanji*string,
#  '評': 評*kanji*evaluate,
#  '不': 不*kanji*negative,
#  '埠': 埠*kanji*wharf,
#  '普': 普*kanji*universal,
#  '譜': 譜*kanji*musical score,
#  '撫': 撫*kanji*stroke,
#  '舞': 舞*kanji*dance,
#  '蕪': 蕪*kanji*turnip,
#  '淵': 淵*kanji*abyss,
#  '弗': 弗*kanji*dollar,
#  '沸': 沸*kanji*seethe,
#  '糞': 糞*kanji*shit,
#  '併': 併*kanji*join,
#  '塀': 塀*kanji*fence,
#  '弊': 弊*kanji*abuse,
#  '並': 並*kanji*row,
#  '蔽': 蔽*kanji*cover,
#  '瞥': 瞥*kanji*glance at,
#  '偏': 偏*kanji*partial,
#  '篇': 篇*kanji*volume,
#  '編': 編*kanji*compilation,
#  '遍': 遍*kanji*everywhere,
#  '便': 便*kanji*convenience,
#  '俸': 俸*kanji*stipend,
#  '奉': 奉*kanji*observance,
#  '峰': 峰*kanji*summit,
#  '峯': 峯*kanji*peak,
#  '捧': 捧*kanji*lift up,
#  '縫': 縫*kanji*sew,
#  '蓬': 蓬*kanji*sagebrush,
#  '蜂': 蜂*kanji*bee,
#  '豊': 豊*kanji*bountiful,
#  '鋒': 鋒*kanji*dagger,
#  '暴': 暴*kanji*outburst,
#  '棒': 棒*kanji*rod,
#  '堀': 堀*kanji*ditch,
#  '妹': 妹*kanji*younger sister,
#  '昧': 昧*kanji*dark,
#  '抹': 抹*kanji*rub,
#  '末': 末*kanji*end,
#  '沫': 沫*kanji*splash,
#  '万': 万*kanji*ten thousand,
#  '満': 満*kanji*full,
#  '味': 味*kanji*flavor,
#  '未': 未*kanji*un-,
#  '魅': 魅*kanji*fascination,
#  '岬': 岬*kanji*headland,
#  '無': 無*kanji*nothingness,
#  '免': 免*kanji*excuse,
#  '耗': 耗*kanji*decrease,
#  '餅': 餅*kanji*mochi rice cake,
#  '也': 也*kanji*to be (classical),
#  '鑓': 鑓*kanji*spear,
#  '油': 油*kanji*oil,
#  '幽': 幽*kanji*seclude,
#  '悠': 悠*kanji*permanence,
#  '柚': 柚*kanji*citron,
#  '由': 由*kanji*wherefore,
#  '郵': 郵*kanji*mail,
#  '翼': 翼*kanji*wing,
#  '来': 来*kanji*come,
#  '莱': 莱*kanji*goosefoot,
#  '頼': 頼*kanji*trust,
#  '欄': 欄*kanji*column,
#  '蘭': 蘭*kanji*orchid,
#  '侶': 侶*kanji*companion,
#  '両': 両*kanji*both,
#  '倫': 倫*kanji*ethics,
#  '輪': 輪*kanji*wheel,
#  '霊': 霊*kanji*spirits,
#  '廉': 廉*kanji*bargain,
#  '煉': 煉*kanji*refine metals,
#  '簾': 簾*kanji*bamboo screen,
#  '練': 練*kanji*practice,
#  '錬': 錬*kanji*tempering,
#  '婁': 婁*kanji*frequently,
#  '蝋': 蝋*kanji*wax,
#  '論': 論*kanji*argument,
#  '歪': 歪*kanji*warp,
#  '丕': 丕*kanji*large,
#  '个': 个*kanji*counter for articles,
#  '丱': 丱*kanji*saguaro-like kanji,
#  '丼': 丼*kanji*bowl,
#  '豫': 豫*kanji*relaxed,
#  '佛': 佛*kanji*France,
#  '來': 來*kanji*come,
#  '俤': 俤*kanji*(kokuji),
#  '倔': 倔*kanji*stubborn,
#  '倆': 倆*kanji*skill,
#  '假': 假*kanji*temporary,
#  '儂': 儂*kanji*I,
#  '兩': 兩*kanji*old Japanese coin,
#  '冉': 冉*kanji*red,
#  '冓': 冓*kanji*put together,
#  '冲': 冲*kanji*offing,
#  '剏': 剏*kanji*begin,
#  '剌': 剌*kanji*opposed,
#  '剩': 剩*kanji*leftovers,
#  '勳': 勳*kanji*meritorious deed,
#  '匣': 匣*kanji*box,
#  '卅': 卅*kanji*thirty,
#  '丗': 丗*kanji*thirty,
#  '卍': 卍*kanji*swastika,
#  '吽': 吽*kanji*bark,
#  '呷': 呷*kanji*sip,
#  '呻': 呻*kanji*moan,
#  '咄': 咄*kanji*exclamation of surprise,
#  '哄': 哄*kanji*resound,
#  '喘': 喘*kanji*pant,
#  '喇': 喇*kanji*chatter,
#  '嗽': 嗽*kanji*rinse,
#  '嘸': 嘸*kanji*how,
#  '嘯': 嘯*kanji*roar,
#  '坏': 坏*kanji*bowl,
#  '垪': 垪*kanji*used in proper names,
#  '堙': 堙*kanji*close up,
#  '墟': 墟*kanji*ruins,
#  '壙': 壙*kanji*hole,
#  '壤': 壤*kanji*soil,
#  '妍': 妍*kanji*beauty,
#  '娉': 娉*kanji*ask after a woman's name,
#  '媚': 媚*kanji*flatter,
#  '媾': 媾*kanji*association,
#  '嫂': 嫂*kanji*elder brother's wife,
#  '嫩': 嫩*kanji*young,
#  '嬋': 嬋*kanji*beautiful,
#  '嬾': 嬾*kanji*lazy,
#  '孃': 孃*kanji*girl,
#  '孺': 孺*kanji*child,
#  '屏': 屏*kanji*wall,
#  '岫': 岫*kanji*gorge,
#  '岼': 岼*kanji*level spot part-way up a mountain,
#  '崋': 崋*kanji*name of mountain,
#  '崛': 崛*kanji*high & lofty (mountains),
#  '崙': 崙*kanji*place name,
#  '崘': 崘*kanji*Kunlun mountains in Jiangsu,
#  '嵋': 嵋*kanji*place name,
#  '廡': 廡*kanji*walking under the eaves,
#  '廸': 廸*kanji*path,
#  '彈': 彈*kanji*bullet,
#  '彌': 彌*kanji*extensive,
#  '彿': 彿*kanji*dimly,
#  '徠': 徠*kanji*induce,
#  '忸': 忸*kanji*shame,
#  '怎': 怎*kanji*why,
#  '怫': 怫*kanji*anger,
#  '恆': 恆*kanji*constant,
#  '悚': 悚*kanji*fear,
#  '惠': 惠*kanji*blessing,
#  '慊': 慊*kanji*satisfaction,
#  '慟': 慟*kanji*be sad,
#  '憖': 憖*kanji*thoughtlessly,
#  '憚': 憚*kanji*hesitate,
#  '懣': 懣*kanji*worry,
#  '懶': 懶*kanji*languid,
#  '戰': 戰*kanji*war,
#  '扁': 扁*kanji*level,
#  '抔': 抔*kanji*and so forth,
#  '抻': 抻*kanji*stretch,
#  '拌': 拌*kanji*stir and mix,
#  '拂': 拂*kanji*clear out,
#  '拱': 拱*kanji*arch,
#  '搜': 搜*kanji*search,
#  '捶': 捶*kanji*strike,
#  '揀': 揀*kanji*select,
#  '搴': 搴*kanji*take,
#  '搆': 搆*kanji*pull,
#  '舉': 舉*kanji*raise,
#  '收': 收*kanji*income,
#  '攸': 攸*kanji*relaxed,
#  '敕': 敕*kanji*an imperial order or decree,
#  '敝': 敝*kanji*be worn-out,
#  '數': 數*kanji*number,
#  '斷': 斷*kanji*sever,
#  '曄': 曄*kanji*shine,
#  '曩': 曩*kanji*before,
#  '朏': 朏*kanji*new moon,
#  '朮': 朮*kanji*a type of millet,
#  '朿': 朿*kanji*thorn,
#  '柞': 柞*kanji*type of oak,
#  '柮': 柮*kanji*to cut,
#  '棘': 棘*kanji*thorn,
#  '棗': 棗*kanji*jujube,
#  '椪': 椪*kanji*name of a place in India,
#  '椣': 椣*kanji*type of deciduous birch tree,
#  '棆': 棆*kanji*camphor tree,
#  '寨': 寨*kanji*fort,
#  '樓': 樓*kanji*tower,
#  '飮': 飮*kanji*drink,
#  '歉': 歉*kanji*insufficiency,
#  '洙': 洙*kanji*name of a Chinese river,
#  '涕': 涕*kanji*tears,
#  '渊': 渊*kanji*edge,
#  '淒': 淒*kanji*bitter cold,
#  '淪': 淪*kanji*sink,
#  '溂': 溂*kanji*opposed,
#  '溏': 溏*kanji*mud,
#  '澑': 澑*kanji*slide,
#  '濂': 濂*kanji*name of Chinese river,
#  '濔': 濔*kanji*much,
#  '瀑': 瀑*kanji*waterfall,
#  '瀟': 瀟*kanji*pure,
#  '瀰': 瀰*kanji*copious flow,
#  '瀾': 瀾*kanji*large waves,
#  '炸': 炸*kanji*frying,
#  '烽': 烽*kanji*signal fire,
#  '熏': 熏*kanji*smoke,
#  '燻': 燻*kanji*smoulder,
#  '燼': 燼*kanji*embers,
#  '爛': 爛*kanji*be sore,
#  '狃': 狃*kanji*get used to,
#  '狆': 狆*kanji*Pekinese dog,
#  '狎': 狎*kanji*get used to,
#  '狒': 狒*kanji*baboon,
#  '璢': 璢*kanji*precious stone,
#  '瑕': 瑕*kanji*flaw,
#  '瑾': 瑾*kanji*jewel,
#  '畍': 畍*kanji*circle,
#  '畊': 畊*kanji*plow,
#  '疥': 疥*kanji*scabby eruption,
#  '痞': 痞*kanji*constipation,
#  '瘻': 瘻*kanji*fistula,
#  '眛': 眛*kanji*dark,
#  '睇': 睇*kanji*looking askance at,
#  '睫': 睫*kanji*eyelashes,
#  '瞞': 瞞*kanji*deception,
#  '瞶': 瞶*kanji*see everything,
#  '矗': 矗*kanji*luxuriance,
#  '祟': 祟*kanji*curse,
#  '祚': 祚*kanji*imperial throne,
#  '禪': 禪*kanji*Zen Buddhism,
#  '禮': 禮*kanji*social custom,
#  '禳': 禳*kanji*exorcise,
#  '秉': 秉*kanji*take,
#  '秣': 秣*kanji*fodder,
#  '稱': 稱*kanji*call,
#  '穰': 穰*kanji*abundance,
#  '穽': 穽*kanji*sunken trap,
#  '窶': 窶*kanji*emaciated,
#  '竦': 竦*kanji*crouch,
#  '笨': 笨*kanji*coarse,
#  '笄': 笄*kanji*hairpin,
#  '筰': 筰*kanji*bamboo rope,
#  '筱': 筱*kanji*dwarf bamboo,
#  '篝': 篝*kanji*campfire,
#  '篳': 篳*kanji*fence,
#  '簍': 簍*kanji*bamboo basket,
#  '簣': 簣*kanji*earth-carrying basket,
#  '簫': 簫*kanji*pan pipes,
#  '籟': 籟*kanji*rattling of the wind,
#  '籥': 籥*kanji*three-holed flute,
#  '糶': 糶*kanji*auction,
#  '絆': 絆*kanji*bonds,
#  '絣': 絣*kanji*splashed pattern (on cloth),
#  '綸': 綸*kanji*thread,
#  '綰': 綰*kanji*bend around,
#  '緞': 緞*kanji*damask,
#  '縣': 縣*kanji*county,
#  '縋': 縋*kanji*cling,
#  '縷': 縷*kanji*thread,
#  '繖': 繖*kanji*parasol,
#  '繼': 繼*kanji*succeed,
#  '罘': 罘*kanji*rabbit catching net,
#  '翩': 翩*kanji*fluttering of flag,
#  '耘': 耘*kanji*weed,
#  '耙': 耙*kanji*forked hoe,
#  '耜': 耜*kanji*plough,
#  '耡': 耡*kanji*plough,
#  '耨': 耨*kanji*hoe,
#  '聘': 聘*kanji*invite,
#  '胛': 胛*kanji*shoulder blade,
#  '胙': 胙*kanji*offerings to gods,
#  '胄': 胄*kanji*lineage,
#  '胚': 胚*kanji*embryo,
#  '胖': 胖*kanji*half a sacrifice,
#  '脯': 脯*kanji*dried meat,
#  '腆': 腆*kanji*much,
#  '胼': 胼*kanji*callus,
#  '舳': 舳*kanji*bow,
#  '艚': 艚*kanji*boat,
#  '苡': 苡*kanji*adlay,
#  '苒': 苒*kanji*flourishing,
#  '茉': 茉*kanji*jasmine,
#  '茱': 茱*kanji*river ginger tree,
#  '菫': 菫*kanji*the violet,
#  '萋': 萋*kanji*luxuriant growth,
#  '葭': 葭*kanji*reed,
#  '葮': 葮*kanji*rose of Sharon,
#  '蒹': 蒹*kanji*type of reed,
#  '蕀': 蕀*kanji*milwort,
#  '蕭': 蕭*kanji*a weed,
#  '薛': 薛*kanji*type of mugwort,
#  '藪': 藪*kanji*thicket,
#  '藉': 藉*kanji*carpet,
#  '藕': 藕*kanji*lotus,
#  '藾': 藾*kanji*type of mugwort,
#  '乕': 乕*kanji*tiger,
#  '蚓': 蚓*kanji*earthworm,
#  '蚌': 蚌*kanji*clam,
#  '蚰': 蚰*kanji*millipede,
#  '蛬': 蛬*kanji*cricket,
#  '蛛': 蛛*kanji*spider,
#  '蝙': 蝙*kanji*bat,
#  '螻': 螻*kanji*mole cricket,
#  '蠹': 蠹*kanji*moth,
#  '衄': 衄*kanji*nosebleed,
#  '袢': 袢*kanji*summer kimono,
#  '裲': 裲*kanji*ancient robe,
#  '褄': 褄*kanji*skirt,
#  '褊': 褊*kanji*narrow,
#  '襄': 襄*kanji*rise,
#  '褸': 褸*kanji*rags,
#  '覯': 覯*kanji*happening to meet,
#  '誅': 誅*kanji*death penalty,
#  '誄': 誄*kanji*condolence message,
#  '諫': 諫*kanji*admonish,
#  '諞': 諞*kanji*flattering,
#  '謇': 謇*kanji*stutter,
#  '譁': 譁*kanji*noisy,
#  '譴': 譴*kanji*reproach,
#  '讓': 讓*kanji*allow,
#  '賽': 賽*kanji*dice,
#  '賺': 賺*kanji*coax,
#  '贐': 贐*kanji*going away present,
#  '赧': 赧*kanji*get red,
#  '赳': 赳*kanji*strong and brave,
#  '跚': 跚*kanji*stagger,
#  '踈': 踈*kanji*neglect,
#  '踵': 踵*kanji*heel,
#  '蹇': 蹇*kanji*cripple,
#  '蹕': 蹕*kanji*one who preceeds king in procession,
#  '躰': 躰*kanji*the body,
#  '軆': 軆*kanji*body,
#  '輛': 輛*kanji*counter for large vehicles,
#  '輌': 輌*kanji*numerary adjunct for vehicles,
#  '輾': 輾*kanji*squeak,
#  '辣': 辣*kanji*pungent,
#  '迚': 迚*kanji*some way or other,
#  '迪': 迪*kanji*edify,
#  '邇': 邇*kanji*approach,
#  '迸': 迸*kanji*gush out,
#  '遐': 遐*kanji*distant,
#  '遘': 遘*kanji*meet,
#  '鄲': 鄲*kanji*place name,
#  '醋': 醋*kanji*vinegar,
#  '醴': 醴*kanji*sweet sake,
#  '醺': 醺*kanji*hunger,
#  '釀': 釀*kanji*brew,
#  '釉': 釉*kanji*glaze,
#  '釐': 釐*kanji*few,
#  '鈕': 鈕*kanji*button,
#  '鉞': 鉞*kanji*battleaxe,
#  '銖': 銖*kanji*measuring unit, 1/16 of a ryou,
#  '錏': 錏*kanji*armour havelock,
#  '鍜': 鍜*kanji*armour neck plates,
#  '鎭': 鎭*kanji*ancient peace-preservation centers,
#  '鏤': 鏤*kanji*inlay,
#  '鑰': 鑰*kanji*lock,
#  '閘': 閘*kanji*water gate,
#  '閧': 閧*kanji*war cry,
#  '闌': 闌*kanji*rise high,
#  '陲': 陲*kanji*boundary,
#  '霰': 霰*kanji*hail,
#  '靺': 靺*kanji*leather tabi,
#  '鞣': 鞣*kanji*tanned leather,
#  '顆': 顆*kanji*grain (e.g. rice),
#  '餠': 餠*kanji*rice cake,
#  '饉': 饉*kanji*hunger,
#  '饋': 饋*kanji*give,
#  '饌': 饌*kanji*food,
#  '駲': 駲*kanji*horse's buttocks,
#  '騁': 騁*kanji*run fast,
#  '駢': 駢*kanji*two-horse carriage,
#  '騙': 騙*kanji*deceive,
#  '騫': 騫*kanji*lift up,
#  '驥': 驥*kanji*fast horse,
#  '驤': 驤*kanji*lift one's head,
#  '髏': 髏*kanji*skull,
#  '體': 體*kanji*the body,
#  '髯': 髯*kanji*beard,
#  '髴': 髴*kanji*dimly,
#  '髷': 髷*kanji*topknot,
#  '鬨': 鬨*kanji*fight,
#  '魎': 魎*kanji*spirits of trees and rocks,
#  '鮓': 鮓*kanji*sushi,
#  '鰕': 鰕*kanji*shrimp,
#  '鰊': 鰊*kanji*herring,
#  '鰥': 鰥*kanji*widower,
#  '鰤': 鰤*kanji*yellowtail,
#  '鰰': 鰰*kanji*sandfish,
#  '鱧': 鱧*kanji*conger,
#  '鵲': 鵲*kanji*magpie,
#  '鶇': 鶇*kanji*thrush,
#  '鶫': 鶫*kanji*thrush,
#  '黜': 黜*kanji*draw back,
#  '鼬': 鼬*kanji*weasel,
#  '槇': 槇*kanji*twig,
#  '浦': 浦*kanji*bay,
#  '永': 永*kanji*eternity,
#  '泳': 泳*kanji*swim,
#  '詠': 詠*kanji*recitation,
#  '往': 往*kanji*journey,
#  '欧': 欧*kanji*Europe,
#  '殴': 殴*kanji*assault,
#  '鴎': 鴎*kanji*seagull,
#  '蒲': 蒲*kanji*bullrush,
#  '釜': 釜*kanji*kettle,
#  '鎌': 鎌*kanji*sickle,
#  '寒': 寒*kanji*cold,
#  '丸': 丸*kanji*round,
#  '機': 機*kanji*loom,
#  '気': 気*kanji*spirit,
#  '稀': 稀*kanji*rare,
#  '偽': 偽*kanji*falsehood,
#  '及': 及*kanji*reach out,
#  '救': 救*kanji*salvation,
#  '求': 求*kanji*request,
#  '球': 球*kanji*ball,
#  '兇': 兇*kanji*wickedness,
#  '凶': 凶*kanji*villain,
#  '恐': 恐*kanji*fear,
#  '挟': 挟*kanji*pinch,
#  '狭': 狭*kanji*cramped,
#  '胸': 胸*kanji*bosom,
#  '玉': 玉*kanji*jewel,
#  '禽': 禽*kanji*bird,
#  '区': 区*kanji*ward,
#  '躯': 躯*kanji*body,
#  '駆': 駆*kanji*drive,
#  '犬': 犬*kanji*dog,
#  '国': 国*kanji*country,
#  '叉': 叉*kanji*fork in road,
#  '肴': 肴*kanji*accompaniment for drinks,
#  '殺': 殺*kanji*kill,
#  '桟': 桟*kanji*scaffold,
#  '残': 残*kanji*remainder,
#  '似': 似*kanji*becoming,
#  '執': 執*kanji*tenacious,
#  '勺': 勺*kanji*ladle,
#  '尺': 尺*kanji*shaku,
#  '杓': 杓*kanji*ladle,
#  '灼': 灼*kanji*miraculous,
#  '酌': 酌*kanji*bar-tending,
#  '釈': 釈*kanji*explanation,
#  '主': 主*kanji*lord,
#  '就': 就*kanji*concerning,
#  '蹴': 蹴*kanji*kick,
#  '住': 住*kanji*dwell,
#  '塾': 塾*kanji*cram school,
#  '熟': 熟*kanji*mellow,
#  '術': 術*kanji*art,
#  '述': 述*kanji*mention,
#  '丈': 丈*kanji*length,
#  '刃': 刃*kanji*blade,
#  '尽': 尽*kanji*exhaust,
#  '靭': 靭*kanji*soft,
#  '勢': 勢*kanji*forces,
#  '斥': 斥*kanji*reject,
#  '浅': 浅*kanji*shallow,
#  '賎': 賎*kanji*despise,
#  '践': 践*kanji*tread,
#  '銭': 銭*kanji*coin,
#  '訴': 訴*kanji*accusation,
#  '双': 双*kanji*pair,
#  '太': 太*kanji*plump,
#  '汰': 汰*kanji*washing,
#  '駄': 駄*kanji*burdensome,
#  '丹': 丹*kanji*rust-colored,
#  '築': 築*kanji*fabricate,
#  '筑': 筑*kanji*an ancient musical instrument,
#  '昼': 昼*kanji*daytime,
#  '柱': 柱*kanji*pillar,
#  '注': 注*kanji*pour,
#  '註': 註*kanji*notes,
#  '駐': 駐*kanji*stop-over,
#  '掴': 掴*kanji*catch,
#  '釣': 釣*kanji*angling,
#  '的': 的*kanji*bull's eye,
#  '冬': 冬*kanji*winter,
#  '忍': 忍*kanji*endure,
#  '認': 認*kanji*acknowledge,
#  '葱': 葱*kanji*stone leek,
#  '熱': 熱*kanji*heat,
#  '之': 之*kanji*of,
#  '博': 博*kanji*Dr.,
#  '薄': 薄*kanji*dilute,
#  '縛': 縛*kanji*truss,
#  '帆': 帆*kanji*sail,
#  '汎': 汎*kanji*pan-,
#  '泌': 泌*kanji*ooze,
#  '秘': 秘*kanji*secret,
#  '柊': 柊*kanji*holly,
#  '氷': 氷*kanji*icicle,
#  '豹': 豹*kanji*leopard,
#  '敷': 敷*kanji*spread,
#  '舗': 舗*kanji*shop,
#  '鋪': 鋪*kanji*shop,
#  '圃': 圃*kanji*garden,
#  '捕': 捕*kanji*catch,
#  '甫': 甫*kanji*for the first time,
#  '補': 補*kanji*supplement,
#  '輔': 輔*kanji*help,
#  '簿': 簿*kanji*register,
#  '宝': 宝*kanji*treasure,
#  '乏': 乏*kanji*destitution,
#  '凡': 凡*kanji*commonplace,
#  '密': 密*kanji*secrecy,
#  '蜜': 蜜*kanji*honey,
#  '尤': 尤*kanji*reasonable,
#  '籾': 籾*kanji*unhulled rice,
#  '匁': 匁*kanji*monme,
#  '約': 約*kanji*promise,
#  '訳': 訳*kanji*translate,
#  '猷': 猷*kanji*plan,
#  '卵': 卵*kanji*egg,
#  '吏': 吏*kanji*officer,
#  '梁': 梁*kanji*weir,
#  '鷲': 鷲*kanji*eagle,
#  '亙': 亙*kanji*range,
#  '仞': 仞*kanji*fathom,
#  '仭': 仭*kanji*fathom,
#  '偬': 偬*kanji*feel pain,
#  '傅': 傅*kanji*tutor,
#  '兔': 兔*kanji*rabbit,
#  '冤': 冤*kanji*false charge,
#  '劔': 劔*kanji*sword,
#  '劒': 劒*kanji*sword,
#  '剱': 剱*kanji*sword,
#  '匆': 匆*kanji*rush,
#  '匍': 匍*kanji*crawl,
#  '厖': 厖*kanji*large,
#  '咏': 咏*kanji*recitation,
#  '哺': 哺*kanji*nurse,
#  '囈': 囈*kanji*foolish talk,
#  '埔': 埔*kanji*used in Chinese place names,
#  '妁': 妁*kanji*go-between,
#  '孰': 孰*kanji*which,
#  '孵': 孵*kanji*hatch,
#  '寃': 寃*kanji*grievance,
#  '尨': 尨*kanji*shaggy hair or dog,
#  '巉': 巉*kanji*rising precipitously,
#  '怱': 怱*kanji*rush,
#  '怺': 怺*kanji*endure,
#  '愡': 愡*kanji*meaningless,
#  '愽': 愽*kanji*grieving,
#  '戍': 戍*kanji*protection,
#  '扠': 扠*kanji*well,
#  '扨': 扨*kanji*well,
#  '拔': 拔*kanji*extract,
#  '拆': 拆*kanji*to split apart,
#  '掖': 掖*kanji*side (of body),
#  '搏': 搏*kanji*seize,
#  '摯': 摯*kanji*gift,
#  '昶': 昶*kanji*long day,
#  '柝': 柝*kanji*sounding sticks,
#  '梵': 梵*kanji*Sanskrit,
#  '榑': 榑*kanji*unbarked lumber,
#  '樒': 樒*kanji*tree whose branches are placed on Buddhist graves,
#  '櫁': 櫁*kanji*Japanese star anise,
#  '樣': 樣*kanji*Esq.,
#  '毬': 毬*kanji*burr,
#  '泝': 泝*kanji*go upstream,
#  '溥': 溥*kanji*far and wide,
#  '漾': 漾*kanji*drift,
#  '澀': 澀*kanji*astringent,
#  '瀛': 瀛*kanji*ocean,
#  '炙': 炙*kanji*roast,
#  '犹': 犹*kanji*condition,
#  '瑟': 瑟*kanji*large koto,
#  '疣': 疣*kanji*wart,
#  '疼': 疼*kanji*ache,
#  '祕': 祕*kanji*mysterious,
#  '祓': 祓*kanji*exorcise,
#  '秡': 秡*kanji*damaged grain,
#  '笂': 笂*kanji*quiver,
#  '筺': 筺*kanji*bamboo basket,
#  '簗': 簗*kanji*weir,
#  '綛': 綛*kanji*splashed dye pattern,
#  '网': 网*kanji*net,
#  '羸': 羸*kanji*thin,
#  '肬': 肬*kanji*wart,
#  '脉': 脉*kanji*vein (blood, ore),
#  '膊': 膊*kanji*arm,
#  '舖': 舖*kanji*shop,
#  '芍': 芍*kanji*peony,
#  '苳': 苳*kanji*butterbur,
#  '荵': 荵*kanji*hare's foot fern,
#  '葯': 葯*kanji*pollen pod at tip of stamen,
#  '葢': 葢*kanji*cover,
#  '藝': 藝*kanji*art,
#  '蛩': 蛩*kanji*cricket,
#  '螽': 螽*kanji*grasshopper,
#  '蟄': 蟄*kanji*hibernation of insects,
#  '衂': 衂*kanji*nosebleed,
#  '裘': 裘*kanji*leather clothing,
#  '褻': 褻*kanji*filthy,
#  '謐': 謐*kanji*quiet,
#  '譏': 譏*kanji*slander,
#  '賻': 賻*kanji*condolence gift,
#  '贄': 贄*kanji*offering,
#  '跋': 跋*kanji*epilogue,
#  '跫': 跫*kanji*sound of footsteps,
#  '逑': 逑*kanji*pair,
#  '逋': 逋*kanji*flee,
#  '釼': 釼*kanji*sword,
#  '釵': 釵*kanji*ornamental hairpin,
#  '靫': 靫*kanji*quiver,
#  '鞏': 鞏*kanji*hard,
#  '餔': 餔*kanji*eat,
#  '饑': 饑*kanji*hunger,
#  '騷': 騷*kanji*harass,
#  '魃': 魃*kanji*(god of) drought,
#  '鯆': 鯆*kanji*type of herring,
#  '鷙': 鷙*kanji*bird of prey,
#  '麈': 麈*kanji*moose,
#  '黻': 黻*kanji*lap robe,
#  '黼': 黼*kanji*embroidery,
#  '遙': 遙*kanji*far off,
#  '瑤': 瑤*kanji*beautiful (as a jewel),
#  '葵': 葵*kanji*hollyhock,
#  '夷': 夷*kanji*barbarian,
#  '威': 威*kanji*intimidate,
#  '為': 為*kanji*do,
#  '郁': 郁*kanji*cultural progress,
#  '磯': 磯*kanji*seashore,
#  '逸': 逸*kanji*deviate,
#  '淫': 淫*kanji*lewdness,
#  '隠': 隠*kanji*conceal,
#  '右': 右*kanji*right,
#  '映': 映*kanji*reflect,
#  '洩': 洩*kanji*leak,
#  '瑛': 瑛*kanji*sparkle of jewelry,
#  '盈': 盈*kanji*fullness,
#  '英': 英*kanji*England,
#  '援': 援*kanji*abet,
#  '央': 央*kanji*center,
#  '卸': 卸*kanji*wholesale,
#  '禾': 禾*kanji*two-branch tree radical (no. 115),
#  '括': 括*kanji*fasten,
#  '活': 活*kanji*lively,
#  '勧': 勧*kanji*persuade,
#  '感': 感*kanji*emotion,
#  '憾': 憾*kanji*remorse,
#  '看': 看*kanji*watch over,
#  '希': 希*kanji*hope,
#  '幾': 幾*kanji*how many,
#  '杵': 杵*kanji*wooden pestle,
#  '久': 久*kanji*long time,
#  '吸': 吸*kanji*suck,
#  '汲': 汲*kanji*draw (water),
#  '笈': 笈*kanji*backpack bookcase,
#  '級': 級*kanji*class,
#  '許': 許*kanji*permit,
#  '僑': 僑*kanji*temporary home,
#  '喬': 喬*kanji*high,
#  '橋': 橋*kanji*bridge,
#  '矯': 矯*kanji*rectify,
#  '蕎': 蕎*kanji*buckwheat,
#  '君': 君*kanji*mister,
#  '係': 係*kanji*person in charge,
#  '刑': 刑*kanji*punish,
#  '型': 型*kanji*mould,
#  '形': 形*kanji*shape,
#  '携': 携*kanji*portable,
#  '系': 系*kanji*lineage,
#  '荊': 荊*kanji*thorn,
#  '懸': 懸*kanji*state of suspension,
#  '乎': 乎*kanji*question mark,
#  '呼': 呼*kanji*call,
#  '午': 午*kanji*noon,
#  '御': 御*kanji*honorable,
#  '乞': 乞*kanji*beg,
#  '后': 后*kanji*empress,
#  '垢': 垢*kanji*dirt,
#  '宏': 宏*kanji*wide,
#  '更': 更*kanji*grow late,
#  '梗': 梗*kanji*for the most part,
#  '浩': 浩*kanji*wide expanse,
#  '硬': 硬*kanji*stiff,
#  '紘': 紘*kanji*large,
#  '肱': 肱*kanji*ability,
#  '告': 告*kanji*revelation,
#  '酷': 酷*kanji*cruel,
#  '鵠': 鵠*kanji*swan,
#  '佐': 佐*kanji*assistant,
#  '嵯': 嵯*kanji*steep,
#  '左': 左*kanji*left,
#  '差': 差*kanji*distinction,
#  '沙': 沙*kanji*sand,
#  '瑳': 瑳*kanji*polish,
#  '砂': 砂*kanji*sand,
#  '裟': 裟*kanji*Buddhist surplice,
#  '才': 才*kanji*genius,
#  '歳': 歳*kanji*year-end,
#  '砕': 砕*kanji*smash,
#  '際': 際*kanji*occasion,
#  '材': 材*kanji*lumber,
#  '財': 財*kanji*property,
#  '察': 察*kanji*guess,
#  '擦': 擦*kanji*grate,
#  '薩': 薩*kanji*salvation,
#  '産': 産*kanji*products,
#  '使': 使*kanji*use,
#  '史': 史*kanji*history,
#  '施': 施*kanji*give,
#  '七': 七*kanji*seven,
#  '失': 失*kanji*lose,
#  '悉': 悉*kanji*all,
#  '紗': 紗*kanji*gauze,
#  '若': 若*kanji*young,
#  '惹': 惹*kanji*attract,
#  '寿': 寿*kanji*longevity,
#  '春': 春*kanji*springtime,
#  '傷': 傷*kanji*wound,
#  '升': 升*kanji*measuring box,
#  '少': 少*kanji*few,
#  '承': 承*kanji*acquiesce,
#  '抄': 抄*kanji*extract,
#  '昇': 昇*kanji*rise up,
#  '渉': 渉*kanji*ford,
#  '省': 省*kanji*focus,
#  '称': 称*kanji*appellation,
#  '丞': 丞*kanji*help,
#  '城': 城*kanji*castle,
#  '杖': 杖*kanji*staff,
#  '蒸': 蒸*kanji*steam,
#  '飾': 飾*kanji*decorate,
#  '榛': 榛*kanji*hazelnut,
#  '秦': 秦*kanji*Manchu dynasty,
#  '壬': 壬*kanji*9th calendar sign,
#  '訊': 訊*kanji*request,
#  '随': 随*kanji*follow,
#  '髄': 髄*kanji*marrow,
#  '雀': 雀*kanji*sparrow,
#  '制': 制*kanji*system,
#  '成': 成*kanji*turn into,
#  '盛': 盛*kanji*boom,
#  '誠': 誠*kanji*sincerity,
#  '戚': 戚*kanji*grieve,
#  '先': 先*kanji*before,
#  '千': 千*kanji*thousand,
#  '栴': 栴*kanji*maple tree,
#  '洗': 洗*kanji*wash,
#  '銑': 銑*kanji*pig iron,
#  '倉': 倉*kanji*godown,
#  '蒼': 蒼*kanji*blue,
#  '鎗': 鎗*kanji*spear,
#  '臓': 臓*kanji*entrails,
#  '蔵': 蔵*kanji*storehouse,
#  '造': 造*kanji*create,
#  '属': 属*kanji*belong,
#  '孫': 孫*kanji*grandchild,
#  '遜': 遜*kanji*humble,
#  '堕': 堕*kanji*degenerate,
#  '惰': 惰*kanji*lazy,
#  '楕': 楕*kanji*ellipse,
#  '宅': 宅*kanji*home,
#  '托': 托*kanji*requesting,
#  '託': 託*kanji*consign,
#  '諾': 諾*kanji*consent,
#  '嘆': 嘆*kanji*sigh,
#  '誕': 誕*kanji*nativity,
#  '暖': 暖*kanji*warmth,
#  '秩': 秩*kanji*regularity,
#  '着': 着*kanji*don,
#  '鋳': 鋳*kanji*casting,
#  ...}

# %%
kjg.edges[:3]
# Out:
# [(艀*kanji*sampan, 舟*radical*ship),
#  (髭*kanji*beard, 髟*radical*long hair),
#  (賻*kanji*condolence gift, 丶*radical*dot)]

# %% [markdown]
# ## Graph

# %%
import networkx as nx

# %%
G = nx.Graph()

G.add_nodes_from(kjg.nodes)
G.add_edges_from(kjg.edges)

print("nodes:", list(G.nodes())[:5])
print("edges:", list(G.edges())[:2])
# Out:
# nodes: [亜*kanji*Asia, 唖*kanji*mute, 逢*kanji*meeting, 悪*kanji*bad, 以*kanji*by means of]
# edges: [(亜*kanji*Asia, 口*radical*mouth), (亜*kanji*Asia, ｜*radical*stick)]

# %% [markdown]
# ## Visualization

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Install Font

# %%
import matplotlib.font_manager as fm

# Reference: https://albertauyeung.github.io/2020/03/15/matplotlib-cjk-fonts.html
[f for f in fm.fontManager.ttflist if 'CJK JP' in f.name]
# Out:
# [<Font 'Noto Serif CJK JP' (NotoSerifCJK-Regular.ttc) normal normal 400 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Serif CJK JP' (NotoSerifCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Regular.ttc) normal normal 400 normal>]

# %%
def visualize_graph(Graph: nx.Graph, figsize: tuple=(15,15), color_map: List[str]=None, node_size: int=3000, with_labels: bool=True) -> None:
    if color_map == None:
        color_map = [n.color for n in Graph]  
    else:
        color_map = color_map
    
    plt.figure(1,figsize=figsize) 
    nx.draw_kamada_kawai(Graph, node_color=color_map, with_labels=with_labels, node_size=node_size, font_size=20,font_family="Noto Serif CJK JP")
    plt.show()

# %% [markdown]
# ### Sample Visualization

# %%
def get_sg_kanji_with() -> nx.Graph:
    sg = nx.Graph()
    p = kjg.get_node('痘', 'kanji')
    radical_p = [n for n in G.neighbors(p)]
    sg.add_nodes_from(radical_p + [p])
    sg.add_edges_from([(p, rp) for rp in radical_p])
    return sg

# %%
sg = dict() # sample_graph
sg['full_graph'] = G
sg['sample_nodes'] = lambda size: G.subgraph(random.sample(G.nodes, size))
sg['kanji_plus_radical_neighbor'] = get_sg_kanji_with()

# %%
visualize_graph(Graph=sg['kanji_plus_radical_neighbor'], figsize=(10,10))

# %%
visualize_graph(Graph=sg['sample_nodes'](400), figsize=(15,15))

# %%
# visualize_graph(Graph=sg['full_graph'], node_size=1000, with_labels=False)

# %% [markdown]
# # Querying Knowledge Graph

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 6470
# Number of edges: 22273
# Average degree:   6.8850

# %%
# https://networkx.org/documentation/stable/reference/algorithms/component.html

print('number of connected components: ', nx.number_connected_components(G))
# Out:
# number of connected components:  10

# %%
# https://networkx.org/documentation/stable/reference/algorithms/isolates.html
# EDA + Preprocessing: Removing Isolated Nodes

print('number of isolated: ', nx.number_of_isolates(G))
isolated_nodes = [k for k in kjg.nodes if k in nx.isolates(G)]
pp(isolated_nodes)

# trim kjg node
# for k in isolated_nodes:
#     if k.dtype == 'kanji':
#         kjg.nodes_kanji.pop(k, None)
#     elif k.dtype =='radical':
#         kjg.nodes_radical.pop(k, None)
# kjg.nodes = list(kjg.nodes_kanji.values()) + list(kjg.nodes_radical.values())

# G.remove_nodes_from(list(nx.isolates(G)))
# Out:
# number of isolated:  9
# [匸*radical*hiding,
#  夊*radical*go slowly,
#  艸*radical*grass,
#  辵*radical*road,
#  邑*radical*right village,
#  阜*radical*left village,
#  鬯*radical*fragrant herbs,
#  鼎*radical*three legged kettle,
#  龍*radical*dragon]

# %%
assert 1 == 0

# %%
print(nx.info(G))

# %%
node = kjg.get_node('怨', 'kanji')

print(node in G)

# %% [markdown]
# ## User Input

# %%
kin = kjg.get_node('怨', 'kanji')
kout = kjg.get_node('浦', 'kanji')

result_shortest_path = nx.shortest_path(G, source=kin, target=kout)
print(result_shortest_path)
# Out:
# [怨*kanji*grudge, 心*radical*heart, 蜜*kanji*honey, 丶*radical*dot, 浦*kanji*bay]

# %%
def generate_graph(nodes: List[KanjiNode]) -> nx.Graph:
    R = nx.Graph()
    R.add_nodes_from(nodes)
    R.add_edges_from(nx.utils.pairwise(nodes))
    return R

# %%
def get_node_color_result(kinputs, koutputs, union_result):
    color_map = []
    for n in union_result:
        if n in kinputs:
            color_map.append("green")
        elif n in koutputs:
            color_map.append("blue")
        else:
            color_map.append(n.color)
    return color_map

# %% [markdown]
# ### Test Case

# %%
def get_tc(filepath: str):
    fullpath = f"testcase/{filepath}"
    with open(fullpath) as file:
        return [row.strip() for row in file.readlines()]
    return None

# %%
tc_kanji_raw = [(get_tc(f"{i}.in"),get_tc(f"{i}.out")) for i in range(1,11)]

# %%
tc_kanji_clean = [{
        'MOrig': [kjg.get_node(o, 'kanji') for o in tc[0] if kjg.get_node(o, 'kanji')],
        'MDest': [kjg.get_node(o, 'kanji') for o in tc[1] if kjg.get_node(o, 'kanji')]
    } for tc in tc_kanji_raw]

# %%
pp(tc_kanji_clean[1])
# Out:
# {'MDest': [丁*kanji*street,
#            行*kanji*going,
#            寺*kanji*Buddhist temple,
#            時*kanji*time,
#            上*kanji*above,
#            分*kanji*part,
#            禾*kanji*two-branch tree radical (no. 115),
#            私*kanji*private,
#            中*kanji*in,
#            尹*kanji*an official rank,
#            事*kanji*matter,
#            可*kanji*can,
#            何*kanji*what,
#            乂*kanji*mow,
#            皮*kanji*pelt,
#            彼*kanji*he,
#            間*kanji*interval,
#            本*kanji*book],
#  'MOrig': [口*kanji*mouth,
#            見*kanji*see,
#            出*kanji*exit,
#            未*kanji*un-,
#            来*kanji*come,
#            了*kanji*complete,
#            思*kanji*think]}

# %% [markdown]
# ## Brute Force Algorithm

# %%
def find_path_bf(MOrig: List[KanjiNode], MDest: List[KanjiNode]) -> nx.Graph:
    
    result = []
    
    for kin in MOrig:
        for kout in MDest:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
MOrig = tc_kanji_clean[1]['MOrig']
MDest = tc_kanji_clean[1]['MDest']

# %%
result = find_path_bf(MOrig, MDest)
result.nodes()
# Out:
# NodeView((口*kanji*mouth, 囗*radical*box, 鹸*kanji*saltiness, 个*radical*human roof (top), 飼*kanji*domesticate, 亅*radical*feathered stick, 丁*kanji*street, 徊*kanji*wandering, 彳*radical*going man, 行*kanji*going, 園*kanji*park, 土*radical*earth, 寺*kanji*Buddhist temple, 團*kanji*association, 寸*radical*inch, 時*kanji*time, 滷*kanji*brine, 卜*radical*divining rod, 上*kanji*above, 囹*kanji*prison, 刀*radical*sword, 分*kanji*part, 囿*kanji*game preserve, 丿*radical*kana no, 禾*kanji*two-branch tree radical (no. 115), 厶*radical*myself, 私*kanji*private, 艢*kanji*bow, 口*radical*mouth, 中*kanji*in, 尹*kanji*an official rank, 事*kanji*matter, 可*kanji*can, 囮*kanji*decoy, 亻*radical*person, 何*kanji*what, 乂*kanji*mow, 壑*kanji*valley, 又*radical*again, 皮*kanji*pelt, 彼*kanji*he, 擅*kanji*self-indulgent, 日*radical*sun, 間*kanji*interval, 悃*kanji*sincerity, 木*radical*tree, 本*kanji*book, 見*kanji*see, 目*radical*eye, 眄*kanji*looking askance, 循*kanji*sequential, 儿*radical*human legs, 崚*kanji*mountains towering in a row, 尅*kanji*subdue, 冦*kanji*foe, 耡*kanji*plough, 八*radical*eight, 銑*kanji*pig iron, 俊*kanji*sagacious, 橘*kanji*mandarin orange, 睫*kanji*eyelashes, 彐*radical*pig head, 値*kanji*price, 讚*kanji*praise, 皴*kanji*wrinkles, 皮*radical*skin, 閲*kanji*review, 門*radical*gate, 橈*kanji*oar, 出*kanji*exit, 山*radical*mountain, 嶬*kanji*high, 徴*kanji*indications, 峙*kanji*tower, 峠*kanji*mountain peak, ｜*radical*stick, 曩*kanji*before, 熏*kanji*smoke, 耘*kanji*weed, 鬨*kanji*fight, 密*kanji*secrecy, 岐*kanji*branch off, 爛*kanji*be sore, 棡*kanji*mast crossbeam, 未*kanji*un-, 刺*kanji*thorn, 衝*kanji*collide, 堀*kanji*ditch, 重*kanji*heavy, 種*kanji*species, 禾*radical*two branch tree, 簍*kanji*bamboo basket, 偏*kanji*partial, 捜*kanji*search, 来*kanji*come, 二*radical*two, 迂*kanji*roundabout way, 樅*kanji*fir, 瞎*kanji*blind eye, 罎*kanji*bottle, 罅*kanji*fissure, 碁*kanji*Go, 捧*kanji*lift up, 湲*kanji*flowing water, 了*kanji*complete, 崢*kanji*high, 尸*radical*flag, 屐*kanji*clog, 瀞*kanji*pure water, 策*kanji*scheme, 呼*kanji*call, 預*kanji*deposit, 貝*radical*shellfish, 癪*kanji*spasms, 司*kanji*director, 頗*kanji*prejudiced, 閉*kanji*closed, 材*kanji*lumber, 思*kanji*think, 田*radical*rice field, 町*kanji*town, 衡*kanji*equilibrium, 鰹*kanji*bonito, 溥*kanji*far and wide, 櫨*kanji*wax tree, 鰌*kanji*loach (fish), 遇*kanji*meet, 心*radical*heart, 忠*kanji*loyalty, 穩*kanji*calm, 聹*kanji*noisy, 伸*kanji*expand, 怒*kanji*angry, 闡*kanji*clarify))

# %%
visualize_graph(Graph=result, color_map=get_node_color_result(MOrig, MDest, result))

# %% [markdown]
# ## All-at-Once

# %%
def find_path_bf(MO: List[KanjigenNode], MD: List[KanjigenNode]) -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %% [markdown]
# ## Heuristic Algorithm

# %%
def find_path_heuristic(MO: List[KanjigenNode], MD: List[KanjigenNode], dist_func: 'function(o,d)') -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.astar_path(G, source=kin, target=kout, heuristic=dist_func)
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
centrality_degree = nx.degree_centrality(G)

# %%
def dist_func(orig: KanjigenNode, dest: KanjigenNode) -> float:
    a = centrality_degree[orig]
    b = centrality_degree[dest]
    return (abs(a-b)) ** 0.5

# %%
result = find_path_heuristic(MO, MD, dist_func)
result.nodes()

# %% [markdown]
# ## Evaluation

# %%
# https://networkx.org/documentation/stable/reference/algorithms/similarity.html

# %%
# https://networkx.org/documentation/stable/reference/algorithms/centrality.html
