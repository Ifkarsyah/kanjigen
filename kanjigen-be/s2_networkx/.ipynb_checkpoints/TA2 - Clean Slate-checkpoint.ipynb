# %%
from pprint import pprint as pp
from typing import Dict, List, Tuple

import random
import csv

# %% [markdown]
# # Building Knowledge Graph

# %% [markdown]
# ## Extract Data from CSV

# %%
def get_csv_data(filepath, handle_row_func):
    data = dict()
    with open(filepath) as file:
        next(file)
        rows = csv.reader(file, delimiter=",")
        for row in rows:
            handle_row_func(data, row)
    return data

# %%
def handle_csv_kanji_func(data, row):
    _,kanji,meaning = row
    data[kanji] = meaning

# %%
data_kanji = get_csv_data("dataset/s7_nodes_kanji_meaning.csv", handle_csv_kanji_func)
print("len(data_kanji) = ", len(data_kanji))
# pp(data_kanji)
# Out:
# len(data_kanji) =  2136

# %%
def handle_csv_radical_func(data, row):
    radical,meaning,_ = row
    data[radical] = meaning

# %%
data_radical = get_csv_data("dataset/s7_nodes_radical_meaning.csv", handle_csv_radical_func)
print("len(data_radical) = ", len(data_radical))
# pp(data_radical)
# Out:
# len(data_radical) =  255

# %%
def handle_csv_edges_func(data, row):
    kanji,radical_list = row
    data[kanji] = radical_list.split(':')

# %%
data_edges = get_csv_data("dataset/s7_edges_kanji_radical.csv", handle_csv_edges_func)
print("len(data_edges) = ", len(data_edges))
# pp(data_edges)
# Out:
# len(data_edges) =  6215

# %% [markdown]
# ## Data Structure

# %%
class KanjiNode:
    def __init__(self, symbol: str, dtype: str, meaning: str):
        self.symbol  = symbol
        self.dtype   = dtype
        self.meaning = meaning        
        self.color = 'red' if dtype == 'kanji' else 'orange'
        
    def __repr__(self):
        return self.symbol + '*' + self.dtype + '*' + self.meaning
    
    def __str__(self):
        return self.symbol + '\n' + self.meaning

# %%
class KanjiGraph:
    
    def __init__(self, data_kanji, data_radical, data_edges):
        self.nodes_kanji   = { s: KanjiNode(s, 'kanji', m)   for s, m in data_kanji.items()}
        self.nodes_radical = { s: KanjiNode(s, 'radical', m) for s, m in data_radical.items()}
        
        self.nodes = list(self.nodes_kanji.values()) + list(self.nodes_radical.values())
        
        self.edges = self.convert_into_data_edges(data_edges)
    
    def get_node(self, symbol, dtype):
        if dtype == 'kanji':
            mp = self.nodes_kanji
        elif dtype == 'radical':
            mp = self.nodes_radical
        else:
            raise ValueError(f"{dtype} is not valid")
        if symbol not in mp:
#             raise ValueError(f"{symbol} is not 1 of {len(mp)} nodes_{dtype}")
            return None
        return mp[symbol]
    
    def convert_into_data_edges(self, data_edges):
        kanjigen_edges = []
        
        for kanji, radical_list in data_edges.items():
            kanji_node = self.get_node(kanji, 'kanji')
            if kanji_node != None:
                for r in radical_list:
                    radical_node = self.get_node(r, 'radical')
                    kanjigen_edges.append( (kanji_node, radical_node) )
        return list(set(kanjigen_edges))

# %%
kjg = KanjiGraph(data_kanji, data_radical, data_edges)

# %%
print(kjg.get_node('人', 'kanji'))
# Out:
# 人
# person

# %%
kjg.nodes[:3]
# Out:
# [亜*kanji*sub-, 哀*kanji*pathetic, 挨*kanji*push open]

# %%
kjg.nodes_kanji
# Out:
# {'亜': 亜*kanji*sub-,
#  '哀': 哀*kanji*pathetic,
#  '挨': 挨*kanji*push open,
#  '愛': 愛*kanji*love,
#  '曖': 曖*kanji*not clear,
#  '悪': 悪*kanji*bad,
#  '握': 握*kanji*grip,
#  '圧': 圧*kanji*pressure,
#  '扱': 扱*kanji*handle,
#  '宛': 宛*kanji*allocate,
#  '嵐': 嵐*kanji*storm,
#  '安': 安*kanji*cheap,
#  '案': 案*kanji*plan,
#  '暗': 暗*kanji*dark,
#  '以': 以*kanji*by means of,
#  '衣': 衣*kanji*clothes,
#  '位': 位*kanji*rank,
#  '囲': 囲*kanji*surround,
#  '医': 医*kanji*medicine,
#  '依': 依*kanji*reliant,
#  '委': 委*kanji*committee,
#  '威': 威*kanji*intimidate,
#  '為': 為*kanji*do,
#  '畏': 畏*kanji*fear,
#  '胃': 胃*kanji*stomach,
#  '尉': 尉*kanji*military officer,
#  '異': 異*kanji*uncommon,
#  '移': 移*kanji*shift,
#  '萎': 萎*kanji*wither,
#  '偉': 偉*kanji*admirable,
#  '椅': 椅*kanji*chair,
#  '彙': 彙*kanji*same kind,
#  '意': 意*kanji*idea,
#  '違': 違*kanji*differ,
#  '維': 維*kanji*fiber,
#  '慰': 慰*kanji*consolation,
#  '遺': 遺*kanji*bequeath,
#  '緯': 緯*kanji*horizontal,
#  '域': 域*kanji*range,
#  '育': 育*kanji*nurture,
#  '一': 一*kanji*one,
#  '壱': 壱*kanji*one (falsification prevention),
#  '逸': 逸*kanji*deviate,
#  '茨': 茨*kanji*thorn,
#  '芋': 芋*kanji*potato,
#  '引': 引*kanji*pull,
#  '印': 印*kanji*mark,
#  '因': 因*kanji*cause,
#  '咽': 咽*kanji*throat,
#  '姻': 姻*kanji*matrimony,
#  '員': 員*kanji*member,
#  '院': 院*kanji*institution,
#  '淫': 淫*kanji*lewdness,
#  '陰': 陰*kanji*shade,
#  '飲': 飲*kanji*drink,
#  '隠': 隠*kanji*conceal,
#  '韻': 韻*kanji*rhyme,
#  '右': 右*kanji*right (direction),
#  '宇': 宇*kanji*eaves,
#  '羽': 羽*kanji*feather,
#  '雨': 雨*kanji*rain,
#  '唄': 唄*kanji*song,
#  '鬱': 鬱*kanji*gloom,
#  '畝': 畝*kanji*furrow,
#  '浦': 浦*kanji*bay,
#  '運': 運*kanji*carry,
#  '雲': 雲*kanji*cloud,
#  '永': 永*kanji*eternity,
#  '泳': 泳*kanji*swim,
#  '英': 英*kanji*England,
#  '映': 映*kanji*reflect,
#  '栄': 栄*kanji*prosperity,
#  '営': 営*kanji*manage,
#  '詠': 詠*kanji*recitation,
#  '影': 影*kanji*shadow,
#  '鋭': 鋭*kanji*pointed,
#  '衛': 衛*kanji*defense,
#  '易': 易*kanji*easy,
#  '疫': 疫*kanji*epidemic,
#  '益': 益*kanji*benefit,
#  '液': 液*kanji*fluid,
#  '駅': 駅*kanji*station,
#  '悦': 悦*kanji*ecstasy,
#  '越': 越*kanji*cross over,
#  '謁': 謁*kanji*audience,
#  '閲': 閲*kanji*review,
#  '円': 円*kanji*round, yen,
#  '延': 延*kanji*prolong,
#  '沿': 沿*kanji*run alongside,
#  '炎': 炎*kanji*inflammation,
#  '怨': 怨*kanji*grudge,
#  '宴': 宴*kanji*banquet,
#  '媛': 媛*kanji*princess,
#  '援': 援*kanji*aid,
#  '園': 園*kanji*garden,
#  '煙': 煙*kanji*smoke,
#  '猿': 猿*kanji*monkey,
#  '遠': 遠*kanji*far,
#  '鉛': 鉛*kanji*lead,
#  '塩': 塩*kanji*salt,
#  '演': 演*kanji*perform,
#  '縁': 縁*kanji*affinity,
#  '艶': 艶*kanji*glossy,
#  '汚': 汚*kanji*dirty,
#  '王': 王*kanji*king,
#  '凹': 凹*kanji*concave,
#  '央': 央*kanji*center,
#  '応': 応*kanji*respond,
#  '往': 往*kanji*outward journey,
#  '押': 押*kanji*push,
#  '旺': 旺*kanji*flourishing,
#  '欧': 欧*kanji*Europe,
#  '殴': 殴*kanji*assault,
#  '桜': 桜*kanji*cherry tree,
#  '翁': 翁*kanji*venerable old man,
#  '奥': 奥*kanji*heart,
#  '横': 横*kanji*side,
#  '岡': 岡*kanji*hill,
#  '屋': 屋*kanji*roof,
#  '億': 億*kanji*hundred million,
#  '憶': 憶*kanji*recollection,
#  '臆': 臆*kanji*timidity,
#  '虞': 虞*kanji*uneasiness,
#  '乙': 乙*kanji*the latter,
#  '俺': 俺*kanji*I, we,
#  '卸': 卸*kanji*wholesale,
#  '音': 音*kanji*sound,
#  '恩': 恩*kanji*grace,
#  '温': 温*kanji*warm,
#  '穏': 穏*kanji*calm,
#  '下': 下*kanji*below,
#  '化': 化*kanji*change,
#  '火': 火*kanji*fire,
#  '加': 加*kanji*add,
#  '可': 可*kanji*possible,
#  '仮': 仮*kanji*temporary,
#  '何': 何*kanji*what,
#  '花': 花*kanji*flower,
#  '佳': 佳*kanji*excellent,
#  '価': 価*kanji*value,
#  '果': 果*kanji*fruit,
#  '河': 河*kanji*river,
#  '苛': 苛*kanji*torment,
#  '科': 科*kanji*section,
#  '架': 架*kanji*rack,
#  '夏': 夏*kanji*summer,
#  '家': 家*kanji*house,
#  '荷': 荷*kanji*luggage,
#  '華': 華*kanji*splendor,
#  '菓': 菓*kanji*confectionery,
#  '貨': 貨*kanji*freight,
#  '渦': 渦*kanji*whirlpool,
#  '過': 過*kanji*go beyond,
#  '嫁': 嫁*kanji*marry into,
#  '暇': 暇*kanji*spare time,
#  '禍': 禍*kanji*calamity,
#  '靴': 靴*kanji*shoes,
#  '寡': 寡*kanji*widow,
#  '歌': 歌*kanji*song,
#  '箇': 箇*kanji*counters for things,
#  '稼': 稼*kanji*earnings,
#  '課': 課*kanji*section,
#  '蚊': 蚊*kanji*mosquito,
#  '牙': 牙*kanji*tusk,
#  '瓦': 瓦*kanji*tile,
#  '我': 我*kanji*ego,
#  '画': 画*kanji*tableau,
#  '芽': 芽*kanji*bud,
#  '賀': 賀*kanji*congratulations,
#  '雅': 雅*kanji*gracious,
#  '餓': 餓*kanji*starve,
#  '介': 介*kanji*jammed in,
#  '回': 回*kanji*times,
#  '灰': 灰*kanji*ashes,
#  '会': 会*kanji*association,
#  '快': 快*kanji*cheerful,
#  '戒': 戒*kanji*commandment,
#  '改': 改*kanji*reformation,
#  '怪': 怪*kanji*suspicious,
#  '拐': 拐*kanji*kidnap,
#  '悔': 悔*kanji*repent,
#  '海': 海*kanji*sea,
#  '界': 界*kanji*world,
#  '皆': 皆*kanji*all,
#  '械': 械*kanji*contraption,
#  '絵': 絵*kanji*picture,
#  '開': 開*kanji*open,
#  '階': 階*kanji*floor of a building,
#  '塊': 塊*kanji*clod,
#  '楷': 楷*kanji*square character style,
#  '解': 解*kanji*untie,
#  '潰': 潰*kanji*crush,
#  '壊': 壊*kanji*demolition,
#  '懐': 懐*kanji*pocket,
#  '諧': 諧*kanji*harmony,
#  '貝': 貝*kanji*shellfish,
#  '外': 外*kanji*outside,
#  '劾': 劾*kanji*censure,
#  '害': 害*kanji*harm,
#  '崖': 崖*kanji*cliff,
#  '涯': 涯*kanji*horizon,
#  '街': 街*kanji*street,
#  '慨': 慨*kanji*rue,
#  '蓋': 蓋*kanji*cover,
#  '該': 該*kanji*above-stated,
#  '概': 概*kanji*outline,
#  '骸': 骸*kanji*dead remains,
#  '垣': 垣*kanji*hedge,
#  '柿': 柿*kanji*persimmon,
#  '各': 各*kanji*each,
#  '角': 角*kanji*angle,
#  '拡': 拡*kanji*broaden,
#  '革': 革*kanji*leather,
#  '格': 格*kanji*status,
#  '核': 核*kanji*nucleus,
#  '殻': 殻*kanji*husk,
#  '郭': 郭*kanji*enclosure,
#  '覚': 覚*kanji*memorize,
#  '較': 較*kanji*contrast,
#  '隔': 隔*kanji*isolate,
#  '閣': 閣*kanji*tall,
#  '確': 確*kanji*certain,
#  '獲': 獲*kanji*seize,
#  '嚇': 嚇*kanji*menacing,
#  '穫': 穫*kanji*harvest,
#  '学': 学*kanji*study,
#  '岳': 岳*kanji*point,
#  '楽': 楽*kanji*pleasure,
#  '額': 額*kanji*amount,
#  '顎': 顎*kanji*jaw,
#  '掛': 掛*kanji*hang,
#  '潟': 潟*kanji*lagoon,
#  '括': 括*kanji*fasten,
#  '活': 活*kanji*active,
#  '喝': 喝*kanji*hoarse,
#  '渇': 渇*kanji*thirst,
#  '割': 割*kanji*divide,
#  '葛': 葛*kanji*arrowroot,
#  '滑': 滑*kanji*slippery,
#  '褐': 褐*kanji*brown,
#  '轄': 轄*kanji*control,
#  '且': 且*kanji*moreover,
#  '株': 株*kanji*stocks,
#  '釜': 釜*kanji*kettle,
#  '鎌': 鎌*kanji*sickle,
#  '刈': 刈*kanji*reap,
#  '干': 干*kanji*dry,
#  '刊': 刊*kanji*publish,
#  '甘': 甘*kanji*sweet,
#  '汗': 汗*kanji*sweat,
#  '缶': 缶*kanji*tin can,
#  '完': 完*kanji*perfect,
#  '肝': 肝*kanji*liver,
#  '官': 官*kanji*government official,
#  '冠': 冠*kanji*crown,
#  '巻': 巻*kanji*scroll,
#  '看': 看*kanji*watch over,
#  '陥': 陥*kanji*collapse,
#  '乾': 乾*kanji*dry,
#  '勘': 勘*kanji*intuition,
#  '患': 患*kanji*afflicted,
#  '貫': 貫*kanji*pierce,
#  '寒': 寒*kanji*cold,
#  '喚': 喚*kanji*yell,
#  '堪': 堪*kanji*withstand,
#  '換': 換*kanji*interchange,
#  '敢': 敢*kanji*daring,
#  '棺': 棺*kanji*coffin,
#  '款': 款*kanji*goodwill,
#  '間': 間*kanji*interval,
#  '閑': 閑*kanji*leisure,
#  '勧': 勧*kanji*persuade,
#  '寛': 寛*kanji*tolerant,
#  '幹': 幹*kanji*tree-trunk,
#  '感': 感*kanji*feeling,
#  '漢': 漢*kanji*China,
#  '慣': 慣*kanji*accustomed,
#  '管': 管*kanji*pipe,
#  '関': 関*kanji*related,
#  '歓': 歓*kanji*delight,
#  '監': 監*kanji*oversee,
#  '緩': 緩*kanji*slacken,
#  '憾': 憾*kanji*remorse,
#  '還': 還*kanji*send back,
#  '館': 館*kanji*public building,
#  '環': 環*kanji*ring,
#  '簡': 簡*kanji*simplicity,
#  '観': 観*kanji*observe,
#  '韓': 韓*kanji*Korea,
#  '艦': 艦*kanji*warship,
#  '鑑': 鑑*kanji*specimen,
#  '丸': 丸*kanji*circle,
#  '含': 含*kanji*include,
#  '岸': 岸*kanji*beach,
#  '岩': 岩*kanji*boulder,
#  '玩': 玩*kanji*trifle with,
#  '眼': 眼*kanji*eyeball,
#  '頑': 頑*kanji*stubborn,
#  '顔': 顔*kanji*face,
#  '願': 願*kanji*request,
#  '企': 企*kanji*plan,
#  '伎': 伎*kanji*deed,
#  '危': 危*kanji*dangerous,
#  '机': 机*kanji*desk,
#  '気': 気*kanji*feeling,
#  '岐': 岐*kanji*branch off,
#  '希': 希*kanji*hope,
#  '忌': 忌*kanji*mourning,
#  '汽': 汽*kanji*steam,
#  '奇': 奇*kanji*strange,
#  '祈': 祈*kanji*pray,
#  '季': 季*kanji*seasons,
#  '紀': 紀*kanji*chronicle,
#  '軌': 軌*kanji*rut,
#  '既': 既*kanji*previously,
#  '記': 記*kanji*write down,
#  '起': 起*kanji*wake up,
#  '飢': 飢*kanji*hungry,
#  '鬼': 鬼*kanji*ghost,
#  '帰': 帰*kanji*return,
#  '基': 基*kanji*foundation,
#  '寄': 寄*kanji*approach,
#  '規': 規*kanji*rule,
#  '亀': 亀*kanji*turtle,
#  '喜': 喜*kanji*rejoice,
#  '幾': 幾*kanji*how many,
#  '揮': 揮*kanji*brandish,
#  '期': 期*kanji*period of time,
#  '棋': 棋*kanji*chess piece,
#  '貴': 貴*kanji*precious,
#  '棄': 棄*kanji*abandon,
#  '毀': 毀*kanji*destroy,
#  '旗': 旗*kanji*national flag,
#  '器': 器*kanji*container,
#  '畿': 畿*kanji*capital,
#  '輝': 輝*kanji*radiance,
#  '機': 機*kanji*machine,
#  '騎': 騎*kanji*equestrian,
#  '技': 技*kanji*skill,
#  '宜': 宜*kanji*best regards,
#  '偽': 偽*kanji*falsehood,
#  '欺': 欺*kanji*deceit,
#  '義': 義*kanji*righteousness,
#  '疑': 疑*kanji*doubt,
#  '儀': 儀*kanji*ceremony,
#  '戯': 戯*kanji*frolic,
#  '擬': 擬*kanji*mimic,
#  '犠': 犠*kanji*sacrifice,
#  '議': 議*kanji*deliberation,
#  '菊': 菊*kanji*chrysanthemum,
#  '吉': 吉*kanji*good luck,
#  '喫': 喫*kanji*consume,
#  '詰': 詰*kanji*packed,
#  '却': 却*kanji*instead,
#  '客': 客*kanji*guest,
#  '脚': 脚*kanji*leg,
#  '逆': 逆*kanji*inverted,
#  '虐': 虐*kanji*tyrannize,
#  '九': 九*kanji*nine,
#  '久': 久*kanji*long time,
#  '及': 及*kanji*reach out,
#  '弓': 弓*kanji*bow (archery, violin),
#  '丘': 丘*kanji*hill,
#  '旧': 旧*kanji*old times,
#  '休': 休*kanji*rest,
#  '吸': 吸*kanji*suck,
#  '朽': 朽*kanji*decay,
#  '臼': 臼*kanji*mortar,
#  '求': 求*kanji*request,
#  '究': 究*kanji*research,
#  '泣': 泣*kanji*cry,
#  '急': 急*kanji*hurry,
#  '級': 級*kanji*rank,
#  '糾': 糾*kanji*twist,
#  '宮': 宮*kanji*Shinto shrine,
#  '救': 救*kanji*salvation,
#  '球': 球*kanji*sphere,
#  '給': 給*kanji*salary,
#  '嗅': 嗅*kanji*smell,
#  '窮': 窮*kanji*hard up,
#  '牛': 牛*kanji*cow,
#  '去': 去*kanji*leave,
#  '巨': 巨*kanji*gigantic,
#  '居': 居*kanji*reside,
#  '拒': 拒*kanji*repel,
#  '拠': 拠*kanji*foothold,
#  '挙': 挙*kanji*raise,
#  '虚': 虚*kanji*void,
#  '許': 許*kanji*permit,
#  '距': 距*kanji*long-distance,
#  '魚': 魚*kanji*fish,
#  '御': 御*kanji*honorable,
#  '漁': 漁*kanji*fishing,
#  '凶': 凶*kanji*villain,
#  '共': 共*kanji*together,
#  '叫': 叫*kanji*shout,
#  '狂': 狂*kanji*lunatic,
#  '京': 京*kanji*capital,
#  '享': 享*kanji*receive,
#  '供': 供*kanji*offer,
#  '協': 協*kanji*cooperation,
#  '況': 況*kanji*condition,
#  '峡': 峡*kanji*gorge,
#  '挟': 挟*kanji*pinch,
#  '狭': 狭*kanji*cramped,
#  '恐': 恐*kanji*fear,
#  '恭': 恭*kanji*respect,
#  '胸': 胸*kanji*bosom,
#  '脅': 脅*kanji*threaten,
#  '強': 強*kanji*strong,
#  '教': 教*kanji*teach,
#  '郷': 郷*kanji*home town,
#  '境': 境*kanji*boundary,
#  '橋': 橋*kanji*bridge,
#  '矯': 矯*kanji*rectify,
#  '鏡': 鏡*kanji*mirror,
#  '競': 競*kanji*compete,
#  '響': 響*kanji*echo,
#  '驚': 驚*kanji*wonder,
#  '仰': 仰*kanji*face-up,
#  '暁': 暁*kanji*daybreak,
#  '業': 業*kanji*business,
#  '凝': 凝*kanji*congeal,
#  '曲': 曲*kanji*musical composition,
#  '局': 局*kanji*office,
#  '極': 極*kanji*poles,
#  '玉': 玉*kanji*ball,
#  '巾': 巾*kanji*towel,
#  '斤': 斤*kanji*axe,
#  '均': 均*kanji*level,
#  '近': 近*kanji*near,
#  '金': 金*kanji*gold,
#  '菌': 菌*kanji*germ,
#  '勤': 勤*kanji*diligence,
#  '琴': 琴*kanji*harp,
#  '筋': 筋*kanji*muscle,
#  '僅': 僅*kanji*a wee bit,
#  '禁': 禁*kanji*prohibition,
#  '緊': 緊*kanji*tense,
#  '錦': 錦*kanji*brocade,
#  '謹': 謹*kanji*discreet,
#  '襟': 襟*kanji*collar,
#  '吟': 吟*kanji*versify,
#  '銀': 銀*kanji*silver,
#  '区': 区*kanji*ward,
#  '句': 句*kanji*phrase,
#  '苦': 苦*kanji*suffer,
#  '駆': 駆*kanji*drive,
#  '具': 具*kanji*tool,
#  '惧': 惧*kanji*dread,
#  '愚': 愚*kanji*foolish,
#  '空': 空*kanji*sky,
#  '偶': 偶*kanji*accidentally,
#  '遇': 遇*kanji*interview,
#  '隅': 隅*kanji*corner,
#  '串': 串*kanji*skewer,
#  '屈': 屈*kanji*yield,
#  '掘': 掘*kanji*dig,
#  '窟': 窟*kanji*cavern,
#  '熊': 熊*kanji*bear,
#  '繰': 繰*kanji*winding,
#  '君': 君*kanji*you,
#  '訓': 訓*kanji*instruction,
#  '勲': 勲*kanji*meritorious deed,
#  '薫': 薫*kanji*fragrant,
#  '軍': 軍*kanji*army,
#  '郡': 郡*kanji*county,
#  '群': 群*kanji*flock,
#  '兄': 兄*kanji*older brother,
#  '刑': 刑*kanji*punish,
#  '形': 形*kanji*shape,
#  '系': 系*kanji*lineage,
#  '径': 径*kanji*diameter,
#  '茎': 茎*kanji*stalk,
#  '係': 係*kanji*person in charge,
#  '型': 型*kanji*model,
#  '契': 契*kanji*pledge,
#  '計': 計*kanji*measure,
#  '恵': 恵*kanji*favor,
#  '啓': 啓*kanji*disclose,
#  '掲': 掲*kanji*put up (a notice),
#  '渓': 渓*kanji*mountain stream,
#  '経': 経*kanji*manage,
#  '蛍': 蛍*kanji*lightning-bug,
#  '敬': 敬*kanji*respect,
#  '景': 景*kanji*scenery,
#  '軽': 軽*kanji*light,
#  '傾': 傾*kanji*lean,
#  '携': 携*kanji*portable,
#  '継': 継*kanji*inherit,
#  '詣': 詣*kanji*visit a temple,
#  '慶': 慶*kanji*jubilation,
#  '憬': 憬*kanji*long for,
#  '稽': 稽*kanji*consider,
#  '憩': 憩*kanji*recess,
#  '警': 警*kanji*guard against,
#  '鶏': 鶏*kanji*chicken,
#  '芸': 芸*kanji*art,
#  '迎': 迎*kanji*welcome,
#  '鯨': 鯨*kanji*whale,
#  '隙': 隙*kanji*fissure,
#  '劇': 劇*kanji*drama,
#  '撃': 撃*kanji*beat,
#  '激': 激*kanji*violent,
#  '桁': 桁*kanji*beam,
#  '欠': 欠*kanji*lack,
#  '穴': 穴*kanji*hole,
#  '血': 血*kanji*blood,
#  '決': 決*kanji*decide,
#  '結': 結*kanji*tie,
#  '傑': 傑*kanji*greatness,
#  '潔': 潔*kanji*undefiled,
#  '月': 月*kanji*month, moon,
#  '犬': 犬*kanji*dog,
#  '件': 件*kanji*affair,
#  '見': 見*kanji*see,
#  '券': 券*kanji*ticket,
#  '肩': 肩*kanji*shoulder,
#  '建': 建*kanji*build,
#  '研': 研*kanji*sharpen,
#  '県': 県*kanji*prefecture,
#  '倹': 倹*kanji*frugal,
#  '兼': 兼*kanji*concurrently,
#  '剣': 剣*kanji*sabre,
#  '拳': 拳*kanji*fist,
#  '軒': 軒*kanji*flats,
#  '健': 健*kanji*healthy,
#  '険': 険*kanji*precipitous,
#  '圏': 圏*kanji*sphere,
#  '堅': 堅*kanji*strict,
#  '検': 検*kanji*examine,
#  '嫌': 嫌*kanji*dislike,
#  '献': 献*kanji*offering,
#  '絹': 絹*kanji*silk,
#  '遣': 遣*kanji*dispatch,
#  '権': 権*kanji*rights,
#  '憲': 憲*kanji*constitution,
#  '賢': 賢*kanji*intelligent,
#  '謙': 謙*kanji*self-effacing,
#  '鍵': 鍵*kanji*key,
#  '繭': 繭*kanji*cocoon,
#  '顕': 顕*kanji*appear,
#  '験': 験*kanji*test,
#  '懸': 懸*kanji*suspend,
#  '元': 元*kanji*origin,
#  '幻': 幻*kanji*phantasm,
#  '玄': 玄*kanji*mysterious,
#  '言': 言*kanji*say,
#  '弦': 弦*kanji*bowstring,
#  '限': 限*kanji*limit,
#  '原': 原*kanji*field,
#  '現': 現*kanji*appear,
#  '舷': 舷*kanji*gunwale,
#  '減': 減*kanji*decrease,
#  '源': 源*kanji*origin,
#  '厳': 厳*kanji*strict,
#  '己': 己*kanji*self,
#  '戸': 戸*kanji*door,
#  '古': 古*kanji*old,
#  '呼': 呼*kanji*call,
#  '固': 固*kanji*hard,
#  '股': 股*kanji*crotch,
#  '虎': 虎*kanji*tiger,
#  '孤': 孤*kanji*orphan,
#  '弧': 弧*kanji*arc,
#  '故': 故*kanji*circumstances,
#  '枯': 枯*kanji*wither,
#  '個': 個*kanji*individual,
#  '庫': 庫*kanji*warehouse,
#  '湖': 湖*kanji*lake,
#  '雇': 雇*kanji*employ,
#  '誇': 誇*kanji*boast,
#  '鼓': 鼓*kanji*drum,
#  '錮': 錮*kanji*tie up,
#  '顧': 顧*kanji*look back,
#  '五': 五*kanji*five,
#  '互': 互*kanji*mutually,
#  '午': 午*kanji*noon,
#  '呉': 呉*kanji*give,
#  '後': 後*kanji*behind,
#  '娯': 娯*kanji*recreation,
#  '悟': 悟*kanji*enlightenment,
#  '碁': 碁*kanji*Go,
#  '語': 語*kanji*language,
#  '誤': 誤*kanji*mistake,
#  '護': 護*kanji*safeguard,
#  '口': 口*kanji*mouth,
#  '工': 工*kanji*craft,
#  '公': 公*kanji*public,
#  '勾': 勾*kanji*capture,
#  '孔': 孔*kanji*cavity,
#  '功': 功*kanji*achievement,
#  '巧': 巧*kanji*adroit,
#  '広': 広*kanji*wide,
#  '甲': 甲*kanji*armor,
#  '交': 交*kanji*mix,
#  '光': 光*kanji*ray,
#  '向': 向*kanji*over there,
#  '后': 后*kanji*empress,
#  '好': 好*kanji*like,
#  '江': 江*kanji*inlet,
#  '考': 考*kanji*think,
#  '行': 行*kanji*go,
#  '坑': 坑*kanji*pit,
#  '孝': 孝*kanji*filial piety,
#  '抗': 抗*kanji*confront,
#  '攻': 攻*kanji*aggression,
#  '更': 更*kanji*grow late,
#  '効': 効*kanji*effect,
#  '幸': 幸*kanji*happiness,
#  '拘': 拘*kanji*arrest,
#  '肯': 肯*kanji*agreement,
#  '侯': 侯*kanji*marquis,
#  '厚': 厚*kanji*thick,
#  '恒': 恒*kanji*constancy,
#  '洪': 洪*kanji*deluge,
#  '皇': 皇*kanji*emperor,
#  '紅': 紅*kanji*deep red,
#  '荒': 荒*kanji*laid waste,
#  '郊': 郊*kanji*outskirts,
#  '香': 香*kanji*incense,
#  '候': 候*kanji*climate,
#  '校': 校*kanji*school,
#  '耕': 耕*kanji*till,
#  '航': 航*kanji*cruise,
#  '貢': 貢*kanji*tribute,
#  '降': 降*kanji*descend,
#  '高': 高*kanji*tall, expensive,
#  '康': 康*kanji*health,
#  '控': 控*kanji*withdraw,
#  '梗': 梗*kanji*close up,
#  '黄': 黄*kanji*yellow,
#  '喉': 喉*kanji*throat,
#  '慌': 慌*kanji*disconcerted,
#  '港': 港*kanji*harbor,
#  '硬': 硬*kanji*stiff,
#  '絞': 絞*kanji*strangle,
#  '項': 項*kanji*paragraph,
#  '溝': 溝*kanji*gutter,
#  '鉱': 鉱*kanji*mineral,
#  '構': 構*kanji*construct,
#  '綱': 綱*kanji*hawser,
#  '酵': 酵*kanji*fermentation,
#  '稿': 稿*kanji*draft,
#  '興': 興*kanji*entertain,
#  '衡': 衡*kanji*equilibrium,
#  '鋼': 鋼*kanji*steel,
#  '講': 講*kanji*lecture,
#  '購': 購*kanji*subscription,
#  '乞': 乞*kanji*beg,
#  '号': 号*kanji*number,
#  '合': 合*kanji*fit,
#  '拷': 拷*kanji*torture,
#  '剛': 剛*kanji*sturdy,
#  '傲': 傲*kanji*be proud,
#  '豪': 豪*kanji*overpowering,
#  '克': 克*kanji*overcome,
#  '告': 告*kanji*tell,
#  '谷': 谷*kanji*valley,
#  '刻': 刻*kanji*engrave,
#  '国': 国*kanji*country,
#  '黒': 黒*kanji*black,
#  '穀': 穀*kanji*cereals,
#  '酷': 酷*kanji*cruel,
#  '獄': 獄*kanji*prison,
#  '骨': 骨*kanji*bone,
#  '駒': 駒*kanji*horse,
#  '込': 込*kanji*crowded,
#  '頃': 頃*kanji*times,
#  '今': 今*kanji*now,
#  '困': 困*kanji*become distressed,
#  '昆': 昆*kanji*descendants,
#  '恨': 恨*kanji*rancor,
#  '根': 根*kanji*root,
#  '婚': 婚*kanji*marriage,
#  '混': 混*kanji*mix,
#  '痕': 痕*kanji*mark,
#  '紺': 紺*kanji*dark blue,
#  '魂': 魂*kanji*soul,
#  '墾': 墾*kanji*ground-breaking,
#  '懇': 懇*kanji*sociable,
#  '左': 左*kanji*left (direction),
#  '佐': 佐*kanji*help,
#  '沙': 沙*kanji*sand,
#  '査': 査*kanji*investigate,
#  '砂': 砂*kanji*sand,
#  '唆': 唆*kanji*tempt,
#  '差': 差*kanji*distinction,
#  '詐': 詐*kanji*lie,
#  '鎖': 鎖*kanji*chain,
#  '座': 座*kanji*sit,
#  '挫': 挫*kanji*sprain,
#  '才': 才*kanji*genius,
#  '再': 再*kanji*again,
#  '災': 災*kanji*disaster,
#  '妻': 妻*kanji*wife,
#  '采': 采*kanji*form,
#  '砕': 砕*kanji*smash,
#  '宰': 宰*kanji*superintend,
#  '栽': 栽*kanji*plantation,
#  '彩': 彩*kanji*coloring,
#  '採': 採*kanji*pick,
#  '済': 済*kanji*settle,
#  '祭': 祭*kanji*festival,
#  '斎': 斎*kanji*purification,
#  '細': 細*kanji*thin,
#  '菜': 菜*kanji*vegetable,
#  '最': 最*kanji*most,
#  '裁': 裁*kanji*judge,
#  '債': 債*kanji*bond,
#  '催': 催*kanji*sponsor,
#  '塞': 塞*kanji*obstruct,
#  '歳': 歳*kanji*year-end,
#  '載': 載*kanji*ride,
#  '際': 際*kanji*occasion,
#  '埼': 埼*kanji*cape (geography),
#  '在': 在*kanji*exist,
#  '材': 材*kanji*lumber,
#  '剤': 剤*kanji*dose,
#  '財': 財*kanji*wealth,
#  '罪': 罪*kanji*guilt,
#  '崎': 崎*kanji*promontory,
#  '作': 作*kanji*make,
#  '削': 削*kanji*plane,
#  '昨': 昨*kanji*previous,
#  '柵': 柵*kanji*fence,
#  '索': 索*kanji*cord,
#  '策': 策*kanji*scheme,
#  '酢': 酢*kanji*vinegar,
#  '搾': 搾*kanji*squeeze,
#  '錯': 錯*kanji*confused,
#  '咲': 咲*kanji*blossom,
#  '冊': 冊*kanji*counter for books,
#  '札': 札*kanji*tag,
#  '刷': 刷*kanji*printing,
#  '刹': 刹*kanji*temple,
#  '拶': 拶*kanji*be imminent,
#  '殺': 殺*kanji*kill,
#  '察': 察*kanji*guess,
#  '撮': 撮*kanji*snapshot,
#  '擦': 擦*kanji*grate,
#  '雑': 雑*kanji*miscellaneous,
#  '皿': 皿*kanji*dish,
#  '三': 三*kanji*three,
#  '山': 山*kanji*mountain,
#  '参': 参*kanji*participate,
#  '桟': 桟*kanji*scaffold,
#  '蚕': 蚕*kanji*silkworm,
#  '惨': 惨*kanji*wretched,
#  '産': 産*kanji*give birth,
#  '傘': 傘*kanji*umbrella,
#  '散': 散*kanji*scatter,
#  '算': 算*kanji*calculate,
#  '酸': 酸*kanji*acid,
#  '賛': 賛*kanji*approve,
#  '残': 残*kanji*remainder,
#  '斬': 斬*kanji*kill by slicing,
#  '暫': 暫*kanji*temporarily,
#  '士': 士*kanji*gentleman,
#  '子': 子*kanji*child,
#  '支': 支*kanji*branch,
#  '止': 止*kanji*stop,
#  '氏': 氏*kanji*family name,
#  '仕': 仕*kanji*do,
#  '史': 史*kanji*history,
#  '司': 司*kanji*director,
#  '四': 四*kanji*four,
#  '市': 市*kanji*market,
#  '矢': 矢*kanji*arrow,
#  '旨': 旨*kanji*delicious,
#  '死': 死*kanji*death,
#  '糸': 糸*kanji*thread,
#  '至': 至*kanji*climax,
#  '伺': 伺*kanji*pay respects,
#  '志': 志*kanji*intention,
#  '私': 私*kanji*me,
#  '使': 使*kanji*use,
#  '刺': 刺*kanji*thorn,
#  '始': 始*kanji*begin,
#  '姉': 姉*kanji*older sister,
#  '枝': 枝*kanji*branch,
#  '祉': 祉*kanji*welfare,
#  '肢': 肢*kanji*limb,
#  '姿': 姿*kanji*figure,
#  '思': 思*kanji*think,
#  '指': 指*kanji*finger,
#  '施': 施*kanji*carry out,
#  '師': 師*kanji*expert,
#  '恣': 恣*kanji*selfish,
#  '紙': 紙*kanji*paper,
#  '脂': 脂*kanji*fat,
#  '視': 視*kanji*look at,
#  '紫': 紫*kanji*purple,
#  '詞': 詞*kanji*poetry,
#  '歯': 歯*kanji*tooth,
#  '嗣': 嗣*kanji*heir,
#  '試': 試*kanji*test,
#  '詩': 詩*kanji*poem,
#  '資': 資*kanji*resources,
#  '飼': 飼*kanji*domesticate,
#  '誌': 誌*kanji*document,
#  '雌': 雌*kanji*feminine,
#  '摯': 摯*kanji*seriousness,
#  '賜': 賜*kanji*grant,
#  '諮': 諮*kanji*consult with,
#  '示': 示*kanji*indicate,
#  '字': 字*kanji*letter,
#  '寺': 寺*kanji*Buddhist temple,
#  '次': 次*kanji*next,
#  '耳': 耳*kanji*ear,
#  '自': 自*kanji*oneself,
#  '似': 似*kanji*becoming,
#  '児': 児*kanji*child,
#  '事': 事*kanji*abstract thing,
#  '侍': 侍*kanji*waiter,
#  '治': 治*kanji*govern,
#  '持': 持*kanji*hold,
#  '時': 時*kanji*time,
#  '滋': 滋*kanji*nourishing,
#  '慈': 慈*kanji*mercy,
#  '辞': 辞*kanji*resign,
#  '磁': 磁*kanji*magnet,
#  '餌': 餌*kanji*bait,
#  '璽': 璽*kanji*emperor's seal,
#  '鹿': 鹿*kanji*deer,
#  '式': 式*kanji*style,
#  '識': 識*kanji*discriminating,
#  '軸': 軸*kanji*axis,
#  '七': 七*kanji*seven,
#  '𠮟': 𠮟*kanji*scold,
#  '失': 失*kanji*lose,
#  '室': 室*kanji*room,
#  '疾': 疾*kanji*rapidly,
#  '執': 執*kanji*tenacious,
#  '湿': 湿*kanji*damp,
#  '嫉': 嫉*kanji*envy,
#  '漆': 漆*kanji*lacquer,
#  '質': 質*kanji*quality,
#  '実': 実*kanji*truth,
#  '芝': 芝*kanji*turf,
#  '写': 写*kanji*copy,
#  '社': 社*kanji*company,
#  '車': 車*kanji*car,
#  '舎': 舎*kanji*cottage,
#  '者': 者*kanji*someone,
#  '射': 射*kanji*shoot,
#  '捨': 捨*kanji*throw away,
#  '赦': 赦*kanji*pardon,
#  '斜': 斜*kanji*diagonal,
#  '煮': 煮*kanji*boil,
#  '遮': 遮*kanji*intercept,
#  '謝': 謝*kanji*apologize,
#  '邪': 邪*kanji*wicked,
#  '蛇': 蛇*kanji*snake,
#  '尺': 尺*kanji*shaku,
#  '借': 借*kanji*borrow,
#  '酌': 酌*kanji*bartending,
#  '釈': 釈*kanji*explanation,
#  '爵': 爵*kanji*baron,
#  '若': 若*kanji*young,
#  '弱': 弱*kanji*weak,
#  '寂': 寂*kanji*loneliness,
#  '手': 手*kanji*hand,
#  '主': 主*kanji*master,
#  '守': 守*kanji*protect,
#  '朱': 朱*kanji*vermilion,
#  '取': 取*kanji*take,
#  '狩': 狩*kanji*hunt,
#  '首': 首*kanji*neck,
#  '殊': 殊*kanji*particularly,
#  '珠': 珠*kanji*pearl,
#  '酒': 酒*kanji*alcoholic drink,
#  '腫': 腫*kanji*tumor,
#  '種': 種*kanji*kind,
#  '趣': 趣*kanji*gist,
#  '寿': 寿*kanji*longevity,
#  '受': 受*kanji*accept,
#  '呪': 呪*kanji*curse,
#  '授': 授*kanji*instruct,
#  '需': 需*kanji*demand,
#  '儒': 儒*kanji*Confucian,
#  '樹': 樹*kanji*trees,
#  '収': 収*kanji*take in,
#  '囚': 囚*kanji*captured,
#  '州': 州*kanji*state,
#  '舟': 舟*kanji*boat,
#  '秀': 秀*kanji*excel,
#  '周': 周*kanji*circumference,
#  '宗': 宗*kanji*religion,
#  '拾': 拾*kanji*pick up,
#  '秋': 秋*kanji*autumn,
#  '臭': 臭*kanji*stinking,
#  '修': 修*kanji*discipline,
#  '袖': 袖*kanji*sleeve,
#  '終': 終*kanji*end,
#  '羞': 羞*kanji*feel ashamed,
#  '習': 習*kanji*learn,
#  '週': 週*kanji*week,
#  '就': 就*kanji*concerning,
#  '衆': 衆*kanji*masses,
#  '集': 集*kanji*collect,
#  '愁': 愁*kanji*distress,
#  '酬': 酬*kanji*repay,
#  '醜': 醜*kanji*ugly,
#  '蹴': 蹴*kanji*kick,
#  '襲': 襲*kanji*attack,
#  '十': 十*kanji*ten,
#  '汁': 汁*kanji*soup,
#  '充': 充*kanji*allot,
#  '住': 住*kanji*dwelling,
#  '柔': 柔*kanji*tender,
#  '重': 重*kanji*heavy,
#  '従': 従*kanji*obey,
#  '渋': 渋*kanji*astringent,
#  '銃': 銃*kanji*gun,
#  '獣': 獣*kanji*animal,
#  '縦': 縦*kanji*vertical,
#  '叔': 叔*kanji*uncle,
#  '祝': 祝*kanji*celebrate,
#  '宿': 宿*kanji*inn,
#  '淑': 淑*kanji*graceful,
#  '粛': 粛*kanji*solemn,
#  '縮': 縮*kanji*shrink,
#  '塾': 塾*kanji*cram school,
#  '熟': 熟*kanji*ripen,
#  '出': 出*kanji*exit,
#  '述': 述*kanji*mention,
#  '術': 術*kanji*art,
#  '俊': 俊*kanji*genius,
#  '春': 春*kanji*springtime,
#  '瞬': 瞬*kanji*wink,
#  '旬': 旬*kanji*10-day period (of the month),
#  '巡': 巡*kanji*patrol,
#  '盾': 盾*kanji*shield,
#  '准': 准*kanji*quasi-,
#  '殉': 殉*kanji*martyrdom,
#  '純': 純*kanji*genuine,
#  '循': 循*kanji*sequential,
#  '順': 順*kanji*obey,
#  '準': 準*kanji*standard,
#  '潤': 潤*kanji*wet,
#  '遵': 遵*kanji*abide by,
#  '処': 処*kanji*dispose,
#  '初': 初*kanji*first,
#  '所': 所*kanji*place,
#  '書': 書*kanji*write,
#  '庶': 庶*kanji*commoner,
#  '暑': 暑*kanji*hot,
#  '署': 署*kanji*government office,
#  '緒': 緒*kanji*thong,
#  '諸': 諸*kanji*various,
#  '女': 女*kanji*woman,
#  '如': 如*kanji*likeness,
#  '助': 助*kanji*help,
#  '序': 序*kanji*preface,
#  '叙': 叙*kanji*confer,
#  '徐': 徐*kanji*gradually,
#  '除': 除*kanji*exclude,
#  '小': 小*kanji*small,
#  '升': 升*kanji*measuring box,
#  '少': 少*kanji*few,
#  '召': 召*kanji*summon,
#  '匠': 匠*kanji*artisan,
#  '床': 床*kanji*bed,
#  '抄': 抄*kanji*extract,
#  '肖': 肖*kanji*resemblance,
#  '尚': 尚*kanji*esteem,
#  '招': 招*kanji*beckon,
#  '承': 承*kanji*acquiesce,
#  '昇': 昇*kanji*rise up,
#  '松': 松*kanji*pine,
#  '沼': 沼*kanji*marsh,
#  '昭': 昭*kanji*shining,
#  '宵': 宵*kanji*wee hours,
#  '将': 将*kanji*leader,
#  '消': 消*kanji*extinguish,
#  '症': 症*kanji*symptoms,
#  '祥': 祥*kanji*auspicious,
#  '称': 称*kanji*appellation,
#  '笑': 笑*kanji*laugh,
#  '唱': 唱*kanji*chant,
#  '商': 商*kanji*sell,
#  '渉': 渉*kanji*ford,
#  '章': 章*kanji*chapter,
#  '紹': 紹*kanji*introduce,
#  '訟': 訟*kanji*sue,
#  '勝': 勝*kanji*win,
#  '掌': 掌*kanji*manipulate,
#  '晶': 晶*kanji*sparkle,
#  '焼': 焼*kanji*bake,
#  '焦': 焦*kanji*char,
#  '硝': 硝*kanji*nitrate,
#  '粧': 粧*kanji*cosmetics,
#  '詔': 詔*kanji*imperial edict,
#  '証': 証*kanji*evidence,
#  '象': 象*kanji*elephant,
#  '傷': 傷*kanji*wound,
#  '奨': 奨*kanji*exhort,
#  '照': 照*kanji*illuminate,
#  '詳': 詳*kanji*detailed,
#  ...}

# %%
kjg.edges[:3]
# Out:
# [(斬*kanji*kill by slicing, 車*radical*car),
#  (騎*kanji*equestrian, 亅*radical*feathered stick),
#  (亡*kanji*deceased, 亠*radical*lid)]

# %% [markdown]
# ## Graph

# %%
import networkx as nx

# %%
G = nx.Graph()

G.add_nodes_from(kjg.nodes)
G.add_edges_from(kjg.edges)

print("nodes:", list(G.nodes())[:5])
print("edges:", list(G.edges())[:2])
# Out:
# nodes: [亜*kanji*sub-, 哀*kanji*pathetic, 挨*kanji*push open, 愛*kanji*love, 曖*kanji*not clear]
# edges: [(亜*kanji*sub-, ｜*radical*stick), (亜*kanji*sub-, 口*radical*mouth)]

# %% [markdown]
# ## Visualization

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Install Font

# %%
import matplotlib.font_manager as fm

# Reference: https://albertauyeung.github.io/2020/03/15/matplotlib-cjk-fonts.html
[f for f in fm.fontManager.ttflist if 'CJK JP' in f.name]
# Out:
# [<Font 'Noto Serif CJK JP' (NotoSerifCJK-Regular.ttc) normal normal 400 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Serif CJK JP' (NotoSerifCJK-Bold.ttc) normal normal 700 normal>,
#  <Font 'Noto Sans CJK JP' (NotoSansCJK-Regular.ttc) normal normal 400 normal>]

# %%
def visualize_graph(Graph: nx.Graph, figsize: tuple=(15,15), color_map: List[str]=None, node_size: int=3000, with_labels: bool=True) -> None:
    if color_map == None:
        color_map = [n.color for n in Graph]  
    else:
        color_map = color_map
    
    plt.figure(1,figsize=figsize) 
    nx.draw_kamada_kawai(Graph, node_color=color_map, with_labels=with_labels, node_size=node_size, font_size=20,font_family="Noto Serif CJK JP")
    plt.show()

# %% [markdown]
# ### Sample Visualization

# %%
def get_sg_kanji_with() -> nx.Graph:
    sg = nx.Graph()
    p = kjg.get_node('痘', 'kanji')
    radical_p = [n for n in G.neighbors(p)]
    sg.add_nodes_from(radical_p + [p])
    sg.add_edges_from([(p, rp) for rp in radical_p])
    return sg

# %%
sg = dict() # sample_graph
sg['full_graph'] = G
sg['sample_nodes'] = lambda size: G.subgraph(random.sample(G.nodes, size))
sg['kanji_plus_radical_neighbor'] = get_sg_kanji_with()

# %%
visualize_graph(Graph=sg['kanji_plus_radical_neighbor'], figsize=(10,10))

# %%
visualize_graph(Graph=sg['sample_nodes'](280), figsize=(15,15))

# %%
# visualize_graph(Graph=sg['full_graph'], node_size=1000, with_labels=False)

# %% [markdown]
# # Querying Knowledge Graph

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 2391
# Number of edges: 6753
# Average degree:   5.6487

# %%
# https://networkx.org/documentation/stable/reference/algorithms/component.html

print('number of connected components: ', nx.number_connected_components(G))
# Out:
# number of connected components:  109

# %%
# https://networkx.org/documentation/stable/reference/algorithms/isolates.html
# EDA + Preprocessing: Removing Isolated Nodes

print('number of isolated: ', nx.number_of_isolates(G))
isolated_nodes = [k for k in kjg.nodes if k not in nx.isolates(G)]
print(type(isolated_nodes))


kjg.nodes = list(set(kjg.nodes) - set(isolated_nodes))
kjg.nodes_kanji = list(set(kjg.nodes_kanji) - set(isolated_nodes))
kjg.nodes_radical = list(set(kjg.nodes_radical) - set(isolated_nodes))
G.remove_nodes_from(list(nx.isolates(G)))
# Out:
# number of isolated:  108
# <class 'list'>

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 2283
# Number of edges: 6753
# Average degree:   5.9159

# %% [markdown]
# ## User Input

# %%
kin = kjg.get_node('怨', 'kanji')
kout = kjg.get_node('浦', 'kanji')

result_shortest_path = nx.shortest_path(G, source=kin, target=kout)
print(result_shortest_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11056/880477274.py in <module>
# ----> 1 kin = kjg.get_node('怨', 'kanji')
#       2 kout = kjg.get_node('浦', 'kanji')
#       3
#       4 result_shortest_path = nx.shortest_path(G, source=kin, target=kout)
#       5 print(result_shortest_path)
#
# /tmp/ipykernel_11056/3480005655.py in get_node(self, symbol, dtype)
#      19 #             raise ValueError(f"{symbol} is not 1 of {len(mp)} nodes_{dtype}")
#      20             return None
# ---> 21         return mp[symbol]
#      22
#      23     def convert_into_data_edges(self, data_edges):
#
# TypeError: list indices must be integers or slices, not str

# %%
def generate_graph(nodes: List[KanjigenNode]) -> nx.Graph:
    R = nx.Graph()
    R.add_nodes_from(nodes)
    R.add_edges_from(nx.utils.pairwise(nodes))
    return R

# %%
def get_node_color_result(kinputs, koutputs, union_result):
    color_map = []
    for n in union_result:
        if n.symbol in kinputs:
            color_map.append("green")
        elif n.symbol in koutputs:
            color_map.append("blue")
        else:
            color_map.append(n.color)
    return color_map

# %% [markdown]
# ### Test Case

# %%
def get_tc(filepath: str):
    fullpath = f"testcase/{filepath}"
    with open(fullpath) as file:
        return [row.strip() for row in file.readlines()]
    return None

# %%
tc_kanji_raw = [(get_tc(f"{i}.in"),get_tc(f"{i}.out")) for i in range(1,11)]

# %%
tc_kanji_clean = [{
        'MOrig': [kjg.get_node(o, 'kanji') for o in tc[0] if kjg.get_node(o, 'kanji')],
        'MDest': [kjg.get_node(o, 'kanji') for o in tc[1] if kjg.get_node(o, 'kanji')]
    } for tc in tc_kanji_raw]

# %%
pp(tc_kanji_clean[1])
# Out:
# {'MDest': [二*kanji*two,
#            丁*kanji*ward,
#            行*kanji*go,
#            寸*kanji*measurement,
#            寺*kanji*Buddhist temple,
#            時*kanji*time,
#            上*kanji*up,
#            刀*kanji*sword,
#            分*kanji*part, minute of time,
#            私*kanji*me,
#            中*kanji*middle,
#            事*kanji*abstract thing,
#            可*kanji*possible,
#            何*kanji*what,
#            自*kanji*oneself,
#            又*kanji*or again,
#            皮*kanji*skin,
#            彼*kanji*he,
#            方*kanji*direction,
#            生*kanji*life,
#            月*kanji*month, moon,
#            門*kanji*gates,
#            間*kanji*interval,
#            手*kanji*hand,
#            言*kanji*say,
#            女*kanji*woman,
#            本*kanji*book],
#  'MOrig': [人*kanji*person,
#            一*kanji*one,
#            口*kanji*mouth,
#            日*kanji*day,
#            目*kanji*eye,
#            見*kanji*see,
#            山*kanji*mountain,
#            出*kanji*exit,
#            十*kanji*ten,
#            八*kanji*eight,
#            木*kanji*tree,
#            未*kanji*not yet,
#            来*kanji*come,
#            大*kanji*large,
#            了*kanji*finish,
#            子*kanji*child,
#            心*kanji*heart,
#            土*kanji*soil,
#            田*kanji*rice paddy,
#            思*kanji*think]}

# %% [markdown]
# ## Brute Force Algorithm

# %%
def find_path_bf(MOrig: List[KanjigenNode], MDest: List[KanjigenNode]) -> nx.Graph:
    
    result = []
    
    for kin in MOrig:
        for kout in MDest:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
MOrig = tc_kanji_clean[1]['MOrig']
MDest = tc_kanji_clean[1]['MDest']

# %%
node = kjg.get_node('人', 'kanji')
G.degree(node)
# Out:
# 0

# %%
result = find_path_bf(MOrig, MDest)
result.nodes()
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# /tmp/ipykernel_11056/3607564407.py in <module>
# ----> 1 result = find_path_bf(MOrig, MDest)
#       2 result.nodes()
#
# /tmp/ipykernel_11056/65353644.py in find_path_bf(MOrig, MDest)
#       5     for kin in MOrig:
#       6         for kout in MDest:
# ----> 7             sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
#       8             sp_graph = generate_graph(sp_raw)
#       9
#
# ~/Documents/ITB/kanjigen/kanjigen-be/venv/lib/python3.8/site-packages/networkx/algorithms/shortest_paths/generic.py in shortest_path(G, source, target, weight, method)
#     158             # Find shortest source-target path.
#     159             if method == "unweighted":
# --> 160                 paths = nx.bidirectional_shortest_path(G, source, target)
#     161             elif method == "dijkstra":
#     162                 paths = nx.dijkstra_path(G, source, target, weight)
#
# ~/Documents/ITB/kanjigen/kanjigen-be/venv/lib/python3.8/site-packages/networkx/algorithms/shortest_paths/unweighted.py in bidirectional_shortest_path(G, source, target)
#     222
#     223     # call helper to do the real work
# --> 224     results = _bidirectional_pred_succ(G, source, target)
#     225     pred, succ, w = results
#     226
#
# ~/Documents/ITB/kanjigen/kanjigen-be/venv/lib/python3.8/site-packages/networkx/algorithms/shortest_paths/unweighted.py in _bidirectional_pred_succ(G, source, target)
#     290                         return pred, succ, w
#     291
# --> 292     raise nx.NetworkXNoPath(f"No path between {source} and {target}.")
#     293
#     294
#
# NetworkXNoPath: No path between 人
# person and 二
# two.

# %%
visualize_graph(Graph=result, color_map=get_node_color_result(MO_raw, MD_raw, result))

# %% [markdown]
# ## All-at-Once

# %%
def find_path_bf(MO: List[KanjigenNode], MD: List[KanjigenNode]) -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.shortest_path(G, source=kin, target=kout, method='dijkstra')
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %% [markdown]
# ## Heuristic Algorithm

# %%
def find_path_heuristic(MO: List[KanjigenNode], MD: List[KanjigenNode], dist_func: 'function(o,d)') -> nx.Graph:
    
    result = []
    
    for kin in MO:
        for kout in MD:
            sp_raw = nx.astar_path(G, source=kin, target=kout, heuristic=dist_func)
            sp_graph = generate_graph(sp_raw)
            
            result.append(sp_graph)
    
    
    return nx.compose_all(result)

# %%
centrality_degree = nx.degree_centrality(G)

# %%
def dist_func(orig: KanjigenNode, dest: KanjigenNode) -> float:
    a = centrality_degree[orig]
    b = centrality_degree[dest]
    return (abs(a-b)) ** 0.5

# %%
result = find_path_heuristic(MO, MD, dist_func)
result.nodes()

# %% [markdown]
# ## Evaluation

# %%
# https://networkx.org/documentation/stable/reference/algorithms/similarity.html

# %%
# https://networkx.org/documentation/stable/reference/algorithms/centrality.html
